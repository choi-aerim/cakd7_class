# %% [markdown]
# # 원천정산경락가격원시데이터

# %%
#쉼표구분이 어딘가 잘못되어있음을 의미

import pandas as pd

price_wholesale= pd.read_csv('원천정산경락가격원시데이터_202206.csv', encoding='utf-16')
price_wholesale
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Input In [1], in <cell line: 5>()
#       1 #쉼표구분이 어딘가 잘못되어있음을 의미
#       3 import pandas as pd
# ----> 5 price_wholesale= pd.read_csv('원천정산경락가격원시데이터_202206.csv', encoding='utf-16')
#       6 price_wholesale
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\pandas\io\parsers\readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\pandas\io\parsers\readers.py:581, in _read(filepath_or_buffer, kwds)
#     578     return parser
#     580 with parser:
# --> 581     return parser.read(nrows)
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\pandas\io\parsers\readers.py:1254, in TextFileReader.read(self, nrows)
#    1252 nrows = validate_integer("nrows", nrows)
#    1253 try:
# -> 1254     index, columns, col_dict = self._engine.read(nrows)
#    1255 except Exception:
#    1256     self.close()
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:225, in CParserWrapper.read(self, nrows)
#     223 try:
#     224     if self.low_memory:
# --> 225         chunks = self._reader.read_low_memory(nrows)
#     226         # destructive to chunks
#     227         data = _concatenate_chunks(chunks)
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\pandas\_libs\parsers.pyx:805, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\pandas\_libs\parsers.pyx:861, in pandas._libs.parsers.TextReader._read_rows()
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\pandas\_libs\parsers.pyx:847, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\pandas\_libs\parsers.pyx:1960, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 45 fields in line 46297, saw 47

# %%
#쉼표가 아닌 탭으로 분류해서 일단 뽑아봄 

price_wholesale= pd.read_csv('원천정산경락가격원시데이터_202206.csv', encoding='utf-16',sep='\t,', )
price_wholesale
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_3476\3486333133.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   price_wholesale= pd.read_csv('원천정산경락가격원시데이터_202206.csv', encoding='utf-16',sep='\t,', )
#         경락일자,경매시간,경매구분코드,경매구분코드명,시장코드,시장명,구시장코드,구시장명,법인코드,법인명,구법인코드,구법인명,경매원표번호,일련번호,부류코드,부류명,구부류코드,구부류명,품목코드,품목명,구품목코드,구품목명,품종코드,품종명,구품종코드,구품종명,거래단량,단위코드,단위명,포장상태코드,포장상태명,크기코드,크기명,등급코드,등급명,법인사용품목코드,법인사용품목명,거래가격,출하구분코드,출하구분명,산지코드,산지명,구산지코드,구산지명,거래량
# 0        2022-06-01,2022-06-01,7,기타,1005601,가락동농수산물시장,1...
# 1        2022-06-01,2022-06-01,2,정가수의,1005601,가락동농수산물시장...
# 2        2022-06-01,2022-06-01,2,정가수의,1005601,가락동농수산물시장...
# 3        2022-06-01,2022-06-01,1,경매,1005601,가락동농수산물시장,1...
# 4        2022-06-01,2022-06-01,1,경매,1005601,가락동농수산물시장,1...
# ...                                                    ...
# 3422647  2022-06-30,2022-06-30,1,경매,1052601,진주농산물도매시장,3...
# 3422648  2022-06-30,2022-06-30,1,경매,1052601,진주농산물도매시장,3...
# 3422649  2022-06-30,2022-06-30,1,경매,1052601,진주농산물도매시장,3...
# 3422650  2022-06-30,2022-06-30,1,경매,1052601,진주농산물도매시장,3...
# 3422651  2022-06-30,2022-06-30,1,경매,1052601,진주농산물도매시장,3...
#
# [3422652 rows x 1 columns]

# %%
price_wholesale.columns
# Out:
# Index(['경락일자,경매시간,경매구분코드,경매구분코드명,시장코드,시장명,구시장코드,구시장명,법인코드,법인명,구법인코드,구법인명,경매원표번호,일련번호,부류코드,부류명,구부류코드,구부류명,품목코드,품목명,구품목코드,구품목명,품종코드,품종명,구품종코드,구품종명,거래단량,단위코드,단위명,포장상태코드,포장상태명,크기코드,크기명,등급코드,등급명,법인사용품목코드,법인사용품목명,거래가격,출하구분코드,출하구분명,산지코드,산지명,구산지코드,구산지명,거래량'], dtype='object')

# %%
#컬럼 개수는 45개

len(str(list(price_wholesale.columns)).split(','))
# Out:
# 45

# %%
#컬럼 개수가 45개 이상이고 서울을 포함한 행  내용  뽑아내기 (나중에 직접 추가하게,,)

import re

with open('원천정산경락가격원시데이터_202206.csv', encoding='utf-16' ) as f:
    lines = f.readlines()
    i = 0
    j = 0
    for line in lines:
        i += 1
        if len(line.split(','))>45 and len(re.findall( '서울',line))>0:
            length=len(line.split(','))
            print(f'{i}번째 행: {length}', line)
            j+=1
print(j)
# Out:
# 214672번째 행: 47 2022-06-02,경매안함,2,정가수의,1026301,원주농산물도매시장,320201,원주도매시장,6026302,원주원협(공),32020102,원주원협(공),500,170,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),15,12,kg,101,상자,125,50내,11,특,9805,그레이프푸룻(자몽),50000,5,수입,05600,서울특별시 송파구,138050,서울 송파구 방이동,2
#
# 215017번째 행: 47 2022-06-02,경매안함,2,정가수의,1026301,원주농산물도매시장,320201,원주도매시장,6026302,원주원협(공),32020102,원주원협(공),702,160,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),15,12,kg,101,상자,125,50내,11,특,9805,그레이프푸룻(자몽),57200,3,개별,05600,서울특별시 송파구,138701,서울 송파구 가락1동,2
#
# 215046번째 행: 47 2022-06-02,경매안함,2,정가수의,1026301,원주농산물도매시장,320201,원주도매시장,6026302,원주원협(공),32020102,원주원협(공),702,420,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),15,12,kg,101,상자,125,50내,11,특,9805,그레이프푸룻(자몽),57200,3,개별,05600,서울특별시 송파구,138701,서울 송파구 가락1동,5
#
# 215052번째 행: 47 2022-06-02,경매안함,2,정가수의,1026301,원주농산물도매시장,320201,원주도매시장,6026302,원주원협(공),32020102,원주원협(공),702,70,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),15,12,kg,101,상자,125,50내,11,특,9805,그레이프푸룻(자몽),57200,3,개별,05600,서울특별시 송파구,138701,서울 송파구 가락1동,5
#
# 707071번째 행: 47 2022-06-07,경매안함,2,정가수의,1016301,수원농수산물도매시장,310101,수원도매시장,6016302,경기청과,31010101,경기청과,190100601,00450,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),15,12,kg,101,상자,1ZZ,기타,11,특,06-19-00,자몽,45000,5,수입,05600,서울특별시 송파구,138200,서울 송파구 문정동,4
#
# 707072번째 행: 47 2022-06-07,경매안함,2,정가수의,1016301,수원농수산물도매시장,310101,수원도매시장,6016302,경기청과,31010101,경기청과,190100601,00451,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),15,12,kg,101,상자,1ZZ,기타,12,상,06-19-00,자몽,10000,5,수입,05600,서울특별시 송파구,138200,서울 송파구 문정동,1
#
# 707073번째 행: 47 2022-06-07,경매안함,2,정가수의,1016301,수원농수산물도매시장,310101,수원도매시장,6016302,경기청과,31010101,경기청과,190100601,00452,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),15,12,kg,101,상자,1ZZ,기타,11,특,06-19-00,자몽,45000,5,수입,05600,서울특별시 송파구,138200,서울 송파구 문정동,10
#
# 707074번째 행: 47 2022-06-07,경매안함,2,정가수의,1016301,수원농수산물도매시장,310101,수원도매시장,6016302,경기청과,31010101,경기청과,190100601,00453,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),15,12,kg,101,상자,1ZZ,기타,11,특,06-19-00,자몽,45000,5,수입,05600,서울특별시 송파구,138200,서울 송파구 문정동,10
#
# 707075번째 행: 47 2022-06-07,경매안함,2,정가수의,1016301,수원농수산물도매시장,310101,수원도매시장,6016302,경기청과,31010101,경기청과,190100601,00454,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),15,12,kg,101,상자,1ZZ,기타,11,특,06-19-00,자몽,45000,5,수입,05600,서울특별시 송파구,138200,서울 송파구 문정동,10
#
# 707076번째 행: 47 2022-06-07,경매안함,2,정가수의,1016301,수원농수산물도매시장,310101,수원도매시장,6016302,경기청과,31010101,경기청과,190100601,00455,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),15,12,kg,101,상자,1ZZ,기타,11,특,06-19-00,자몽,35000,5,수입,05600,서울특별시 송파구,138200,서울 송파구 문정동,30
#
# 720108번째 행: 47 2022-06-07,경매안함,2,정가수의,1026301,원주농산물도매시장,320201,원주도매시장,6026302,원주원협(공),32020102,원주원협(공),700,220,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),15,12,kg,101,상자,125,50내,11,특,9805,그레이프푸룻(자몽),54000,5,수입,05600,서울특별시 송파구,138050,서울 송파구 방이동,2
#
# 720336번째 행: 47 2022-06-07,경매안함,2,정가수의,1026301,원주농산물도매시장,320201,원주도매시장,6026302,원주원협(공),32020102,원주원협(공),800,210,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),15,12,kg,101,상자,125,50내,11,특,9805,그레이프푸룻(자몽),50960,3,개별,05600,서울특별시 송파구,138701,서울 송파구 가락1동,3
#
# 950980번째 행: 47 2022-06-09,경매안함,2,정가수의,1026301,원주농산물도매시장,320201,원주도매시장,6026302,원주원협(공),32020102,원주원협(공),502,20,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),15,12,kg,101,상자,125,50내,11,특,9805,그레이프푸룻(자몽),56160,3,개별,05600,서울특별시 송파구,138701,서울 송파구 가락1동,1
#
# 950982번째 행: 47 2022-06-09,경매안함,2,정가수의,1026301,원주농산물도매시장,320201,원주도매시장,6026302,원주원협(공),32020102,원주원협(공),502,210,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),15,12,kg,101,상자,125,50내,11,특,9805,그레이프푸룻(자몽),52000,3,개별,05600,서울특별시 송파구,138701,서울 송파구 가락1동,9
#
# 1110320번째 행: 47 2022-06-10,경매안함,2,정가수의,1026301,원주농산물도매시장,320201,원주도매시장,6026302,원주원협(공),32020102,원주원협(공),500,140,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),15,12,kg,101,상자,125,50내,11,특,9805,그레이프푸룻(자몽),54000,5,수입,05600,서울특별시 송파구,138050,서울 송파구 방이동,2
#
# 1298436번째 행: 47 2022-06-13,2022-06-13,1,경매,1007701,강서농수산물도매시장,110008,서울강서도매시장,6007706,농협강서(공),11000801,농협강서(공),220614004645346,1,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),16,12,kg,107,파렛트,125,50내,11,특,,,48000,,기타,00000,,800000,수입산  ,11
#
# 1298437번째 행: 47 2022-06-13,2022-06-13,1,경매,1007701,강서농수산물도매시장,110008,서울강서도매시장,6007706,농협강서(공),11000801,농협강서(공),220614004645347,1,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),16,12,kg,107,파렛트,125,50내,11,특,,,49000,,기타,00000,,800000,수입산  ,11
#
# 1298438번째 행: 47 2022-06-13,2022-06-13,1,경매,1007701,강서농수산물도매시장,110008,서울강서도매시장,6007706,농협강서(공),11000801,농협강서(공),220614004645348,1,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),16,12,kg,107,파렛트,125,50내,11,특,,,49000,,기타,00000,,800000,수입산  ,11
#
# 1298439번째 행: 47 2022-06-13,2022-06-13,1,경매,1007701,강서농수산물도매시장,110008,서울강서도매시장,6007706,농협강서(공),11000801,농협강서(공),220614004645349,1,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),16,12,kg,107,파렛트,125,50내,11,특,,,49000,,기타,00000,,800000,수입산  ,11
#
# 1298440번째 행: 47 2022-06-13,2022-06-13,1,경매,1007701,강서농수산물도매시장,110008,서울강서도매시장,6007706,농협강서(공),11000801,농협강서(공),220614004645350,1,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),16,12,kg,107,파렛트,125,50내,11,특,,,49000,,기타,00000,,800000,수입산  ,9
#
# 1298441번째 행: 47 2022-06-13,2022-06-13,1,경매,1007701,강서농수산물도매시장,110008,서울강서도매시장,6007706,농협강서(공),11000801,농협강서(공),220614004645351,1,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),16,12,kg,107,파렛트,125,50내,11,특,,,50000,,기타,00000,,800000,수입산  ,10
#
# 1298442번째 행: 47 2022-06-13,2022-06-13,1,경매,1007701,강서농수산물도매시장,110008,서울강서도매시장,6007706,농협강서(공),11000801,농협강서(공),220614004645352,1,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),16,12,kg,107,파렛트,125,50내,11,특,,,25000,,기타,00000,,800000,수입산  ,2
#
# 1388730번째 행: 47 2022-06-13,경매안함,2,정가수의,1026301,원주농산물도매시장,320201,원주도매시장,6026302,원주원협(공),32020102,원주원협(공),502,400,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),15,12,kg,101,상자,125,50내,11,특,9805,그레이프푸룻(자몽),52000,3,개별,05600,서울특별시 송파구,138701,서울 송파구 가락1동,5
#
# 1529915번째 행: 47 2022-06-14,경매안함,2,정가수의,1026301,원주농산물도매시장,320201,원주도매시장,6026302,원주원협(공),32020102,원주원협(공),500,90,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),15,12,kg,101,상자,125,50내,11,특,9805,그레이프푸룻(자몽),57200,3,개별,05600,서울특별시 송파구,138701,서울 송파구 가락1동,2
#
# 1530009번째 행: 47 2022-06-14,경매안함,2,정가수의,1026301,원주농산물도매시장,320201,원주도매시장,6026302,원주원협(공),32020102,원주원협(공),506,170,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),15,12,kg,101,상자,125,50내,11,특,9805,그레이프푸룻(자몽),67000,5,수입,05600,서울특별시 송파구,138050,서울 송파구 방이동,4
#
# 1652473번째 행: 47 2022-06-15,경매안함,2,정가수의,1026301,원주농산물도매시장,320201,원주도매시장,6026302,원주원협(공),32020102,원주원협(공),500,240,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),15,12,kg,101,상자,125,50내,11,특,9805,그레이프푸룻(자몽),67000,5,수입,05600,서울특별시 송파구,138050,서울 송파구 방이동,3
#
# 1766838번째 행: 47 2022-06-16,경매안함,2,정가수의,1026301,원주농산물도매시장,320201,원주도매시장,6026302,원주원협(공),32020102,원주원협(공),502,20,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),15,12,kg,101,상자,125,50내,11,특,9805,그레이프푸룻(자몽),57200,3,개별,05600,서울특별시 송파구,138701,서울 송파구 가락1동,2
#
# 1766857번째 행: 47 2022-06-16,경매안함,2,정가수의,1026301,원주농산물도매시장,320201,원주도매시장,6026302,원주원협(공),32020102,원주원협(공),502,380,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),15,12,kg,101,상자,125,50내,11,특,9805,그레이프푸룻(자몽),44720,3,개별,05600,서울특별시 송파구,138701,서울 송파구 가락1동,5
#
# 1766868번째 행: 47 2022-06-16,경매안함,2,정가수의,1026301,원주농산물도매시장,320201,원주도매시장,6026302,원주원협(공),32020102,원주원협(공),502,70,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),15,12,kg,101,상자,125,50내,11,특,9805,그레이프푸룻(자몽),56160,3,개별,05600,서울특별시 송파구,138701,서울 송파구 가락1동,2
#
# 1766879번째 행: 47 2022-06-16,경매안함,2,정가수의,1026301,원주농산물도매시장,320201,원주도매시장,6026302,원주원협(공),32020102,원주원협(공),506,120,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),15,12,kg,101,상자,125,50내,11,특,9805,그레이프푸룻(자몽),67000,5,수입,05600,서울특별시 송파구,138050,서울 송파구 방이동,1
#
# 1766880번째 행: 47 2022-06-16,경매안함,2,정가수의,1026301,원주농산물도매시장,320201,원주도매시장,6026302,원주원협(공),32020102,원주원협(공),506,130,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),15,12,kg,101,상자,125,50내,11,특,9805,그레이프푸룻(자몽),67000,5,수입,05600,서울특별시 송파구,138050,서울 송파구 방이동,1
#
# 1801748번째 행: 47 2022-06-17,2022-06-17,8,기타,1005601,가락동농수산물시장,110001,서울가락도매시장,6005607,농협가락(공),11000102,농협가락(공),220618000713007,1,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),14,12,kg,101,상자,124,40내,11,특,,,42000,,기타,00000,,800000,수입산  ,8
#
# 1807362번째 행: 47 2022-06-17,2022-06-17,8,기타,1005601,가락동농수산물시장,110001,서울가락도매시장,6005607,농협가락(공),11000102,농협가락(공),220620015613160,1,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),14,12,kg,101,상자,124,40내,11,특,,,42000,,기타,00000,,800000,수입산  ,8
# 2223270번째 행: 47 2022-06-20,경매안함,2,정가수의,1011901,구리농수산물도매시장,311201,구리도매시장,6011904,구리청과,31120103,구리청과,853,853,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),16,12,kg,101,상자,1ZZ,기타,19,등외,061901,,33000,2,계통,02500,서울특별시 동대문구,130010,서울 동대문구 청량리동,63
#
# 2223271번째 행: 47 2022-06-20,경매안함,2,정가수의,1011901,구리농수산물도매시장,311201,구리도매시장,6011904,구리청과,31120103,구리청과,854,854,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),16,12,kg,101,상자,1ZZ,기타,19,등외,061901,,60000,2,계통,02500,서울특별시 동대문구,130010,서울 동대문구 청량리동,65
#
# 2223272번째 행: 47 2022-06-20,경매안함,2,정가수의,1011901,구리농수산물도매시장,311201,구리도매시장,6011904,구리청과,31120103,구리청과,855,855,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),16,12,kg,101,상자,1ZZ,기타,19,등외,061901,,65000,2,계통,02500,서울특별시 동대문구,130010,서울 동대문구 청량리동,65
#
# 2236748번째 행: 47 2022-06-20,경매안함,2,정가수의,1031201,천안농산물도매시장,340101,천안도매시장,6031201,천안농협(공),34010102,천안농협(공),504,10,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),15,12,kg,101,상자,103,3,11,특,9805,그레이프푸룻(자몽),49000,5,수입,05600,서울특별시 송파구,138807,서울 송파구 가락2동,10
#
# 2626030번째 행: 47 2022-06-23,경매안함,2,정가수의,1026301,원주농산물도매시장,320201,원주도매시장,6026302,원주원협(공),32020102,원주원협(공),502,100,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),15,12,kg,101,상자,125,50내,11,특,9805,그레이프푸룻(자몽),55120,3,개별,05600,서울특별시 송파구,138701,서울 송파구 가락1동,2
#
# 2626084번째 행: 47 2022-06-23,경매안함,2,정가수의,1026301,원주농산물도매시장,320201,원주도매시장,6026302,원주원협(공),32020102,원주원협(공),505,140,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),15,12,kg,101,상자,125,50내,11,특,9805,그레이프푸룻(자몽),67000,5,수입,05600,서울특별시 송파구,138050,서울 송파구 방이동,2
#
# 3045952번째 행: 47 2022-06-27,경매안함,2,정가수의,1026301,원주농산물도매시장,320201,원주도매시장,6026302,원주원협(공),32020102,원주원협(공),502,210,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),15,12,kg,101,상자,125,50내,11,특,9805,그레이프푸룻(자몽),43680,3,개별,05600,서울특별시 송파구,138701,서울 송파구 가락1동,5
#
# 3045953번째 행: 47 2022-06-27,경매안함,2,정가수의,1026301,원주농산물도매시장,320201,원주도매시장,6026302,원주원협(공),32020102,원주원협(공),502,30,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),15,12,kg,101,상자,125,50내,11,특,9805,그레이프푸룻(자몽),60320,3,개별,05600,서울특별시 송파구,138701,서울 송파구 가락1동,2
#
# 3178552번째 행: 47 2022-06-28,경매안함,2,정가수의,1026301,원주농산물도매시장,320201,원주도매시장,6026302,원주원협(공),32020102,원주원협(공),501,60,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),15,12,kg,101,상자,125,50내,11,특,9805,그레이프푸룻(자몽),60320,3,개별,05600,서울특별시 송파구,138701,서울 송파구 가락1동,2
#
# 3178553번째 행: 47 2022-06-28,경매안함,2,정가수의,1026301,원주농산물도매시장,320201,원주도매시장,6026302,원주원협(공),32020102,원주원협(공),501,70,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),15,12,kg,101,상자,125,50내,11,특,9805,그레이프푸룻(자몽),60320,3,개별,05600,서울특별시 송파구,138701,서울 송파구 가락1동,2
#
# 3206956번째 행: 47 2022-06-29,2022-06-29,8,기타,1005601,가락동농수산물시장,110001,서울가락도매시장,6005607,농협가락(공),11000102,농협가락(공),220630000612259,1,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),17,12,kg,101,상자,1ZZ,기타,11,특,,,78440,,기타,00000,,800000,수입산  ,63
#
# 3210428번째 행: 47 2022-06-29,2022-06-29,8,기타,1005601,가락동농수산물시장,110001,서울가락도매시장,6005607,농협가락(공),11000102,농협가락(공),220702015637663,1,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),17,12,kg,101,상자,1ZZ,기타,11,특,,,78440,,기타,00000,,800000,수입산  ,63
#
# 3302046번째 행: 47 2022-06-29,경매안함,2,정가수의,1026301,원주농산물도매시장,320201,원주도매시장,6026302,원주원협(공),32020102,원주원협(공),501,150,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),15,12,kg,101,상자,125,50내,11,특,9805,그레이프푸룻(자몽),65000,5,수입,05600,서울특별시 송파구,138050,서울 송파구 방이동,2
#
# 3302049번째 행: 47 2022-06-29,경매안함,2,정가수의,1026301,원주농산물도매시장,320201,원주도매시장,6026302,원주원협(공),32020102,원주원협(공),501,180,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),15,12,kg,101,상자,125,50내,11,특,9805,그레이프푸룻(자몽),65000,5,수입,05600,서울특별시 송파구,138050,서울 송파구 방이동,2
#
# 3407594번째 행: 47 2022-06-30,경매안함,2,정가수의,1026301,원주농산물도매시장,320201,원주도매시장,6026302,원주원협(공),32020102,원주원협(공),501,130,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),15,12,kg,101,상자,125,50내,11,특,9805,그레이프푸룻(자몽),46800,3,개별,05600,서울특별시 송파구,138701,서울 송파구 가락1동,3
#
# 3407612번째 행: 47 2022-06-30,경매안함,2,정가수의,1026301,원주농산물도매시장,320201,원주도매시장,6026302,원주원협(공),32020102,원주원협(공),501,30,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),15,12,kg,101,상자,125,50내,11,특,9805,그레이프푸룻(자몽),60320,3,개별,05600,서울특별시 송파구,138701,서울 송파구 가락1동,2
#
# 3407615번째 행: 47 2022-06-30,경매안함,2,정가수의,1026301,원주농산물도매시장,320201,원주도매시장,6026302,원주원협(공),32020102,원주원협(공),501,320,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),15,12,kg,101,상자,125,50내,11,특,9805,그레이프푸룻(자몽),44720,3,개별,05600,서울특별시 송파구,138701,서울 송파구 가락1동,3
#
# 3412902번째 행: 47 2022-06-30,경매안함,2,정가수의,1031201,천안농산물도매시장,340101,천안도매시장,6031201,천안농협(공),34010102,천안농협(공),503,60,06,과실류,06,과실류,0619,자몽,0619,자몽,061901,그레이프푸룻,자몽(일반),061901,그레이프푸룻,자몽(일반),15,12,kg,101,상자,124,40내,11,특,9805,그레이프푸룻(자몽),49000,5,수입,05600,서울특별시 송파구,138807,서울 송파구 가락2동,10
#
# 51

# %%
3422652-3421692
# Out:
# 960

# %%
#이상한 행은 다 삭제해버린 후 불러오기

price_wholesale2= pd.read_csv('원천정산경락가격원시데이터_202206.csv', encoding='utf-16', on_bad_lines='skip')
price_wholesale2
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_5680\671141865.py:3: DtypeWarning: Columns (12,13,18,20,22,24,29,33,35,36,40,42) have mixed types. Specify dtype option on import or set low_memory=False.
#   price_wholesale2= pd.read_csv('원천정산경락가격원시데이터_202206.csv', encoding='utf-16', on_bad_lines='skip')
#                경락일자        경매시간  경매구분코드 경매구분코드명     시장코드        시장명   구시장코드  \
# 0        2022-06-01  2022-06-01     7.0      기타  1005601  가락동농수산물시장  110001
# 1        2022-06-01  2022-06-01     2.0    정가수의  1005601  가락동농수산물시장  110001
# 2        2022-06-01  2022-06-01     2.0    정가수의  1005601  가락동농수산물시장  110001
# 3        2022-06-01  2022-06-01     1.0      경매  1005601  가락동농수산물시장  110001
# 4        2022-06-01  2022-06-01     1.0      경매  1005601  가락동농수산물시장  110001
# ...             ...         ...     ...     ...      ...        ...     ...
# 3421687  2022-06-30  2022-06-30     1.0      경매  1052601  진주농산물도매시장  380401
# 3421688  2022-06-30  2022-06-30     1.0      경매  1052601  진주농산물도매시장  380401
# 3421689  2022-06-30  2022-06-30     1.0      경매  1052601  진주농산물도매시장  380401
# 3421690  2022-06-30  2022-06-30     1.0      경매  1052601  진주농산물도매시장  380401
# 3421691  2022-06-30  2022-06-30     1.0      경매  1052601  진주농산물도매시장  380401
#
#              구시장명     법인코드     법인명  ...  법인사용품목코드 법인사용품목명   거래가격 출하구분코드  \
# 0        서울가락도매시장  6005601    서울청과  ...       NaN     NaN   8000    NaN
# 1        서울가락도매시장  6005601    서울청과  ...       NaN     NaN  10000    NaN
# 2        서울가락도매시장  6005601    서울청과  ...       NaN     NaN  27000    NaN
# 3        서울가락도매시장  6005601    서울청과  ...       NaN     NaN  13000    NaN
# 4        서울가락도매시장  6005601    서울청과  ...       NaN     NaN   7000    NaN
# ...           ...      ...     ...  ...       ...     ...    ...    ...
# 3421687    진주도매시장  6052601  진주중앙청과  ...     20901      깻잎   3000    2.0
# 3421688    진주도매시장  6052601  진주중앙청과  ...     20900      깻잎  14800    2.0
# 3421689    진주도매시장  6052601  진주중앙청과  ...     20900      깻잎  11000    2.0
# 3421690    진주도매시장  6052601  진주중앙청과  ...     20900      깻잎  14100    2.0
# 3421691    진주도매시장  6052601  진주중앙청과  ...     20900      깻잎  13200    2.0
#
#          출하구분명   산지코드       산지명   구산지코드        구산지명  거래량
# 0           기타  24200   강원도 춘천시  200000     강원 춘천시   840
# 1           기타      0       NaN  800000       수입산      7
# 2           기타      0       NaN  800000       수입산     66
# 3           기타  41000  대구광역시 동구  701000   대구 대구 동구    22
# 4           기타  41000  대구광역시 동구  701000   대구 대구 동구     5
# ...        ...    ...       ...     ...         ...  ...
# 3421687     계통  52200  경상남도 산청군  666810  경남 산청군 차황면    1
# 3421688     계통  52200  경상남도 산청군  666810  경남 산청군 차황면    3
# 3421689     계통  52200  경상남도 산청군  666810  경남 산청군 차황면    2
# 3421690     계통  52200  경상남도 산청군  666810  경남 산청군 차황면    4
# 3421691     계통  52200  경상남도 산청군  666810  경남 산청군 차황면    3
#
# [3421692 rows x 45 columns]

# %%
price_wholesale2['경매구분코드명'].unique()
# Out:
# array(['기타', '정가수의', '경매', '매수도매', '자기계산'], dtype=object)

# %%
import re

for i in set(price_wholesale2['법인사용품목명'].unique()):
    print(i)
# Out:
# nan
# 대파
# 레드쉬(이십일무)
# 고추씨
# 선)조기
# 선인장열매
# 뱅어포
# 그레이프푸룻
# 콩잎
# 활)방어
# 낙지가공
# 아 나 고
# 장뇌
# 홍청양고추
# 참조기
# 로즈마리
# 곤드레
# 칼리플라워(꽃양배추)
# 김가루
# 냉)가리비
# 기타식품
# 키조개
# 가공 홍합
# 바나나
# 바실
# 호키알
# 황기
# 세척당근수입
# 냉)미더덕
# 광어(넙치)
# 팽이
# 바질
# 듀리안
# 개아지살
# 곤드레나물
# 다시마
# 새치
# 선)명태
# 냉)아귀
# 메기
# 냉)게
# 고추(풋고추)
# 자두(표준)
# 수꽃게
# 수입아귀
# 오만등이
# 대추
# 치커리
# 건멸치
# 선)오징어
# 냉)고등어
# 오징어발
# 고구마(기타)
# 생강(국산)
# 활)넙치
# 선)노래미
# 냉)돔
# 냉동고등어
# 문어
# 당근
# 새싹
# 녹광
# 기타엽채
# 무청(무시래기)
# 선)복어
# 활)홍합
# 냉)빙어
# 달래
# 민어
# 고시래기
# 묵
# 뱀장어
# 콩(강낭콩)
# 미꾸라지
# 익모초
# (선)살홍어
# 가지
# 활)게
# 선)낙지
# 주꾸미
# 킹크랩
# 앵두(표준)
# 호박순
# 돌게
# 알로에
# 쭈꾸미
# 활)민어
# 김자반
# 과채류
# 과일기타
# 머위
# 키위(참다래)
# 세러리
# 깨순
# 코 다 리
# 갈근
# 백조기
# 방울토마토
# 활)농어
# 냉오징어
# 야자
# 냉동게
# 기타근채류
# 기타조미류
# 초피
# 홍고추
# 곤달비
# 파
# 기타엽채류
# 고들빼기
# (선)황돔
# 더덕수입
# 버섯(팽이버섯)
# 산채류
# 쌈추
# 파종자
# 크레송(고추무냉이)
# 기타과채류
# 죽순
# 말
# 복숭아
# 챠빌
# 젓)젓갈
# 동부콩
# 버섯(기타)
# 동죽
# 파(대파)
# 삼채
# 새우가공
# 적근대
# 조기
# 냉임연수
# 선)돔
# 방울양배추
# 알배기(일반)
# 천연조미료
# 우렁이
# 선)볼락
# 건)명태
# 도다리
# 포장바지락
# 콩(돈부)
# 복숭아(표준)
# 셀러리(양미나리)
# 깻잎
# 해 삼
# 머위잎
# 유채
# 자두
# 쥐치포수입
# 라임(수입)
# (선)깐바지락
# 신선 해조류
# 냉)개아지살
# 참다래(키위)
# 돗나물
# 묵(기타)
# 가리비
# 냉)새우
# 수입양채
# 감귤류
# 오디(표준)
# 숙주
# 명란
# 식용허브
# 노가리알포수입
# 민들레
# 비듬
# 명태곤니
# 꼬막
# 기타핵과
# 참깨
# 무우
# 적어
# 돈나물
# 두리안
# 감귤
# 파인애플
# 선)갑오징어
# 상어
# 고막
# 활)오징어
# 냉동대구
# 갑오징어
# 곤달비(표준)
# 활)낙지
# 단포수입
# 장대(양태)
# 꼬시래시
# 오징어실채수입
# 상추
# 홍어
# 완두콩(표준)
# 선)고막
# 새송이
# 버섯
# *로메인
# 돔류
# 와송
# 오렌지(수입)
# 가공(기타)
# 칼라후라워
# 해물모듬
# 자몽(수입)
# 라임
# 활)새우
# 가공김
# 기타수입과일
# 할라피뇨
# 칠게
# 활)메기
# 파세리
# 새송이버섯
# 비트(표준)
# 옥수수
# 코라비
# 무청(무시래기표준)
# 컴프리
# 수입우럭
# 건)대구
# 쌈채
# 동초
# 선)넙치
# 기타어류젓
# 춘채
# 동죽살
# 냉가공식품기타
# 배
# 건)한치채
# 눈볼대(적어)
# 청국장
# 봄동배추
# 머위대
# 고등어자반(냉동)
# 민대구
# 피망(청)
# 시레기
# 양채류
# 선)멸치
# 깐바지락
# 도미(돔)
# 미 역
# 냉새우
# 기타
# 포도수입
# 놀래미(노래미)
# 엽경채기타
# 브로코리(녹색꽃양배추)
# 가 리 비
# 목이
# 선)농어
# 우엉대
# 선)고등어
# 아스파리가스
# 활넙치
# 생새우
# 파(쪽파)
# 활)문어
# 메론
# 오만둥이(오만리)
# 농어
# 박
# 갯장어
# 양채류 기타
# 복분자
# 열무(표준)
# 체리
# 알로에(표준)
# 명란젓
# 코다리명태
# 호두
# 냉동꽁치
# 건한치
# 생오징어
# 곤약
# 진미채
# 냉)적어
# 건)노가리
# 냉)복어
# 양송이버섯
# 대게
# 냉)병어
# 애플민트
# 선)가재
# 선)골뱅이
# 괴도라치
# 냉)민어
# 곶감
# 감자(일반
# 활)노래미
# 개불
# 세발나물
# 꼴뚜기
# 활)전갱이
# 가재
# 냉)갈치
# 참죽나무순
# 기타(모듬)
# 수입명태
# 가공 고둥류
# 맛
# 능성어
# 미역
# 도라지
# 붉은대게
# 붉은양배추
# 쑥갓
# 기타양채
# 굴
# 날치
# 고구마순
# 참나물
# 더덕
# 전분 및 사료
# 고구마줄기
# 딜(허브)
# 건어기타
# 기타조미채소류
# 기타과일과채류
# 전복가공
# 참깨(검정깨)수입
# 활)개아지살
# 건)조기
# 기타연체류젓
# 바리
# 기타돔
# 냉)노래미
# 우엉
# 자몽
# 홍탁
# 도미
# 두류기타
# 명엽채수입
# 근대
# 참도미
# 냉)갑오징어
# 북어
# 두릅
# 홍합
# 암꽃게
# 피뿔고동
# 장갱이
# 가죽
# 활)우렁쉥이
# 매실(표준)
# 알타리무(일반)
# 선)다랑어
# 그린빈스(껍질콩)
# 기타수입과일(수)
# 배추
# 탄제린
# 고구마
# 빈스
# 돔
# 머귀
# 삼치
# 브로코리
# 비파
# 양파
# 우엉잎
# 바 지 락
# 기타게
# 꽈리
# 고둥
# 양미리
# 봄무
# 생가자미
# 활)미꾸라지
# 냉)가오리
# 호끼알(민태기타)
# 딱돔
# 부지깽이
# 플럼코트
# 만디(미더덕)
# 냉)우렁이
# 황석어
# 젓갈(일반)
# 쑥갓(표준)
# 볼락
# 앵두(일반)
# 열무
# 향나물
# 약용작물류
# 냉동명태
# 수입동태포
# 토란대
# 유채잎(표준)
# 모자반
# 선)게
# 나문재
# 도 다 리
# 브로코리(녹색꽃양배
# 벗
# 농림가공(땅콩)
# 젓갈
# 실파
# 방풍
# 새우
# 비트
# 다래
# 갈치
# 콩
# 엽경채류 기타
# 오징어(가공)
# 활)성게
# 꼴뚜기젓
# 채소기타
# 만감
# 건취나물
# 냉)낙지
# 고구마(일반)
# 장류
# 비름나물
# 수입냉오징어
# 모시조개
# 굴비
# 오징어채수입
# 흑점줄전갱이
# 홍 합
# 조 개 살
# 부추
# 기타양채류
# 계피
# 건노가리
# 강낭콩(울타리콩)
# 순무
# 고구마순(표준)
# 눈볼대
# 넙치(광어)
# 무청
# 병어
# 연어
# 부추(기타)
# 상치
# 건미역
# 케일
# 꽈리고추
# 마늘
# 활)돔
# 절임류
# 밀감
# 멍게
# 홍진미수입
# 만가닥버섯
# 표고버섯
# 칼리
# 선)준치
# 비타민
# 기타두류
# 활)전복
# 머우대
# 인삼(수삼)
# 브록코리
# 대구
# 건다시마
# 동태(명태)
# 모시잎
# 젓갈(내장)
# 선)연어
# 붉은고추
# 취나물
# 그린빈스
# 망고
# 냉)문어
# 쑥
# 깐마늘(수입)
# 망고스틴
# 가공(고등어)
# 바다장어
# 활)동자개
# 참깨(수입)
# 생삼치
# 깻잎(표준)
# 그레이프루풋(자몽)
# 기타버섯류
# 꼼장어
# 비름
# 당귀
# 기타(채소)
# 칼리후라워
# 날치알
# 선인장
# 냉)새치
# 고추(붉은고추)
# 서대
# 기타채소
# 완두콩
# 브로커리
# 선)굴
# 겨자잎
# 고들배기
# 숙주나물
# 들깨(일반)
# 바다가재
# 방풍나물
# 도라지(표준)
# 양채류(기타)
# 기타나물
# 건)김
# 깐파
# 홍피망
# 개 우 렁
# 활)쥐치
# 청겨자
# 가자미
# 오 만 득 이
# 조미제품
# 왕게(킹크랩)
# 느타리
# 천도복숭아
# 수입갈치
# 간재미
# 장어(바다)
# 노루궁뎅이버섯
# 꼬시래기
# 박(표준)
# 어리굴젓
# 밴댕어
# 돌나물(돗나물)
# 농산
# 메밀잎
# 절임식품
# 빨간양배추(루비볼/적
# 갈치젓
# 애플망고
# 표고
# 수입홍어
# 얼갈이
# 곡물제주
# 민 어 (대)
# 멸치
# 북어포
# 두릅(표준)
# 밤
# 냉동꽃게
# 무화과
# 쥬키니
# 고추잎(표준)
# 춘채(하루나)
# 넙치
# 선)아귀
# 장어
# 시금치
# 배추(일반)
# 선)서대
# 돌나물
# 알타리무
# 레드쉬
# 목이버섯
# 연근
# 용과수입
# 활)배도라치
# 선)방어
# 감
# 냉동삼치
# 활)숭어
# 파인애플(수입)
# 기타갑각류젓
# 원양오징어
# 치콘
# 노루궁뎅이
# 쥐치포
# 선)대구
# 선)장어
# 콩(콩)
# 비름(표준)
# 버섯류
# 냉)오징어
# 팽이버섯
# 미백옥수수
# 꽁치
# 콜라비(순무양배추)
# 양송이
# 동부
# 수입 새치
# 쥐치
# 만가닥
# 생조기
# 숫꽃게
# 선)삼치
# 딸기
# 절단꽃게
# 돌돔
# 가지(표준)
# 참깨(국산)
# 깐홍합
# 선)새치
# 수입꽃게
# 아욱
# 산딸기
# 깐마늘대서(창녕)
# 임연수
# 버섯(표고버섯)
# 문어가공
# 레몬
# 우렁쉥이
# 숭어
# 호박잎
# 식용꽃
# 칼리플라워
# 가죽나물
# 깐마늘한지(의성)
# 쌈샐러리
# 빨간양배추(적채)
# 냉)바지락
# 기타과실
# 건표고버섯
# 망고스턴(일반)
# 노랑가오리
# 알가공류
# 고동
# 놀래미
# 냉)다랑어
# 빨간양배추
# 머위(표준)
# 송이
# 냉)화살오징어
# 비트(붉은사탕무우)
# 고사리
# 수박
# 명태포(북어포)
# 레디쉬
# 냉동조기
# 라디초우
# 파슬리
# 깐마늘남도(남해/제주/전남)
# 쪽파
# 양배추
# 두부류
# 실파(표준)
# 바지락(중)
# 냉)삼치
# 연어훈제
# 참치
# 생표고버섯
# 적치커리
# 은행
# 바나나(수입)
# 봄배추
# 돌가자미
# 수입꽁치
# 개조개
# 우럭
# 수입가자미
# 피마자
# 마늘(피마늘국산)
# 감초
# 고수
# 전갱이
# 생태
# 긴맛
# 수입 임연수
# 잣(일반)
# 두부
# 무순
# 동부묵
# 활)고막
# 수입적어
# 토마토
# 초롱무
# 양태
# 송어
# 아스파라가스
# 겨자채
# 아나고
# 녹두
# 선)조개
# 활)볼락
# 활)바지락
# 선)문어
# 산마늘(일반)
# 홍초
# 와일드루꼴라
# 조미가공
# (선)명태
# 양상추
# 선)쭈꾸미
# 부세
# 오징어젓
# 마
# 살구(표준)
# 양상추(결구상추)
# 느타리버섯
# 오미자(일반)
# 망고스턴
# 선)민어
# 냉)대구
# 영지버섯
# 풋고추
# 알로애
# 청과기타
# 쥐 치
# 살구
# 절임
# 선꽃게
# 꿀
# 보리수(표준)
# 천연꿀
# 들깨(수입)
# 가 재
# 조개젓
# 황기(일반)
# 고추
# 얼갈이배추
# 아보카도
# 선)개아지살
# 나물
# 메밀순
# 신선초(표준)
# 고구마순(줄기)
# 수입포도
# 양파(일반)
# 갓(표준)
# 건고추(수입)
# 레몬(일반)
# 활)가오리
# 피망
# 고추가루
# 냉)쭈꾸미
# 겨자
# 고등어
# 매실
# 청포묵
# 학꽁치
# 선)청어
# 앵두
# 아로니아
# 파세리(향미나리)
# 복어
# 모듬쌈
# 기타부류
# 냉)명태
# 수입가오리
# 얼가리
# 타임(허브)
# 낙지
# 비트(붉은사탕무)
# 오징어(냉)
# 로케트
# 시사모
# 생강
# 콩(기타)
# 선)병어
# 수박(꼭지제거)
# 땅콩
# 냉)고둥
# 멍게(우렁쉥이)
# 완두
# 수삼
# 수입대구
# 아귀
# 애호박
# 뉴그린
# 두류
# 선)홍합
# 선)갈치
# 농 어
# 소라
# 냉동오징어
# 감귤(밀감)
# 인삼
# 골뱅이
# 토당귀
# 버섯(양송이)
# 멸치젓
# 수입청어
# 활새우
# 호박잎(표준)
# 우 럭
# 곡물제조
# 청어
# 포도
# 용과
# 들깨
# 팥
# 삐틀이
# 선)새우
# 유자
# 기타산채류
# 적채
# 활)개불
# 브로커리(녹색꽃양배
# 열무(일반)
# 용가자미
# 병어(덕자)
# 장어(민물)
# 건)다시마
# 파프리카
# 금강초
# 취나물(표준)
# 아보카드
# 멍 게
# 기타과실류
# 선)도루묵
# 고추잎
# 활)가리비
# 콩나물
# 선)꼴뚜기
# 방아
# 북어채
# 비트(붉은사탕수수)
# 골파
# 복분자(일반)
# 연 어
# 신선초
# 곰치
# 타임
# 허브
# 채리
# 우거지
# 고수(일반)
# 한치(화살오징어)
# 참외
# 냉동갈치
# 해삼
# 가오리
# 쪽파(기타)
# 냉동낙지
# 냉)가재
# 토란
# 코라비(순무양배추)
# 마늘(다발)
# 달고기
# 공심채
# 냉삼치
# 건)새우
# 냉)홍합
# 셀러리
# 생멸치
# 건고추(국산)
# 쌈배추(단배추)
# 방아(표준)
# 황태
# 청경채
# 우뭇가사리
# 향신료
# 황강달이
# 건오징어
# 냉동아귀수입
# 수입오징어
# 감자
# 활)조개
# 고비
# 엽경채류기타
# 냉)조기
# 무우순(표준)
# 버섯류 기타
# 미더덕
# 소 라
# 전분및사료제조
# 가죽나무순
# 마늘(쫑/풋/기타)
# 냉)날치
# 선)숭어
# 새꼬막(새고막)
# 선)고둥
# 생고추
# 수조기
# 참다래
# 조개
# 학공치
# 냉)장어
# 참돔
# 조미대구포수입
# 두류(기타)
# 활)고둥
# 로즈
# 버찌
# 가시오이
# 알파파싹
# 가오리포장
# 명태포
# 활)해삼
# 칼리플라워(꽃양배추
# 여주
# 포도(수입)
# (선)은갈치
# 보리수(과일)
# 비타민(표준)
# 강낭콩
# 수입레몬
# 씀바귀
# 활)가무락
# 중하
# 아몬드
# 양배추(일반)
# 샐러리(양미나리)
# 통(망)마늘
# 기타버섯
# 만 듸
# 피망(단고추)
# 맛진미수입
# 선)상어
# 낙 지
# 광어
# 기타어류
# 생고등어
# 숙주나물(녹두나물)
# 수입조기
# 석이
# 피조개
# 빨간양배추(루비볼)
# 건새우
# 선)가오리
# 냉동가자미
# 건태
# 블루베리(일반)
# 깐마늘
# 꼬 막
# 오디
# 무말랭이
# 고사리잎
# 오징어
# 참비름
# 파파야
# 야콘
# 선)화살오징어
# 냉)꽁치
# 기타엽경채류
# 동충하초
# 풋옥수수
# 전분 및 사료제조
# 갓
# 상황버섯
# 산초
# 염옥어
# 밴댕이젓
# 블루베리
# 수입낙지
# 꿀벌
# 미역류
# 선)가자미
# 버섯(느타리)
# 산오징어
# 도토리묵
# 라디치오
# 고추(건고추)
# 어린잎
# 기타과채
# 호박(늙은/단)
# 신선해조류
# 활)가재
# 곤 이
# 샐러리
# 묵류
# 오이
# 알백이
# 파(실파)
# 잉어
# 저장무
# 오렌지
# 참기름
# 선)미더덕
# 생새치
# 은갈치
# 아스파라거스
# 풋콩
# 냉)연어
# 김
# 당귀잎
# 파래
# 청양
# 건)조미가공
# 국화(식용)
# 방어
# 보리수
# 메밀
# 파인애플(일반)
# 농림가공
# 새 우
# 기름가자미
# 수입고등어
# 건)오징어
# 아주까리
# 기타근채
# 전복
# 무
# 가죽나물(표준)
# 개 조 개
# 미숫가루
# 오징어가공
# 사과
# 오크린
# 돗나물(일반)
# 레몬(국산)
# 바지락
# 미나리
# 새우살
# (활)참전복
# 활)바리
# 강남콩
# 사포딜라
# 그레이프푸룻(자몽)
# 피문어
# 참당귀
# 적채(양배추)
# 코코넛
# 콩(완두)
# 코다리
# 톳
# 선)바지락
# 가공바지락
# 베이비순
# 루꼴라
# 쏨뱅이
# 옥수수(과일)
# 부각
# 콜라비(순무양배
# 어채
# 명태
# 건고추(표준)
# 건)멸치
# (선)오징어
# 산채류(기타)
# 적겨자
# 귤(일반)
# 건고추
# 고추(꽈리고추)
# 게
# 로메인
# 백합
# 풋콩류
# 홍해삼
# 단배추
# 양상추(결구상추.레타
# 초당옥수수
# 콜라비
# 도토리
# 브로콜리
# 가공조개살
# 키위
# 곤이
# 모시 조개
# 새조개
# 대구곤이
# 참 치
# 북어머리
# 키위(수입)
# 노래미
# (선)화살오징어
# 냉가오리
# 당귀(참당귀)
# 호박
# 붕장어
# 민어(민태)
# 알타리무우
# 양채류기타
# 산낙지
# 산나물
# 기타과일류
# 활)가자미
# 미역줄기
# 활)장어
# 냉)굴
# (냉)명태
# 수입용과
# 오징어채
# 논우렁이
# 쌈용채소
# 파(일반)
# 냉)가자미
# 재첩
# 한치
# 해파리
# 청초

# %%
len(set(price_wholesale2['법인사용품목명'].unique()))
# Out:
# 1065

# %%
import re

for i in set(price_wholesale2['법인사용품목명'].unique()):
    i = re.sub('\(.*\)','',str(i))
    i = re.sub('\w\)','',i)
    i = re.sub('\s','',i)
    print(i)
# Out:
# nan
# 대파
# 레드쉬
# 고추씨
# 조기
# 선인장열매
# 뱅어포
# 그레이프푸룻
# 콩잎
# 방어
# 낙지가공
# 아나고
# 장뇌
# 홍청양고추
# 참조기
# 로즈마리
# 곤드레
# 칼리플라워
# 김가루
# 가리비
# 기타식품
# 키조개
# 가공홍합
# 바나나
# 바실
# 호키알
# 황기
# 세척당근수입
# 미더덕
# 광어
# 팽이
# 바질
# 듀리안
# 개아지살
# 곤드레나물
# 다시마
# 새치
# 명태
# 아귀
# 메기
# 게
# 고추
# 자두
# 수꽃게
# 수입아귀
# 오만등이
# 대추
# 치커리
# 건멸치
# 오징어
# 고등어
# 오징어발
# 고구마
# 생강
# 넙치
# 노래미
# 돔
# 냉동고등어
# 문어
# 당근
# 새싹
# 녹광
# 기타엽채
# 무청
# 복어
# 홍합
# 빙어
# 달래
# 민어
# 고시래기
# 묵
# 뱀장어
# 콩
# 미꾸라지
# 익모초
# 살홍어
# 가지
# 게
# 낙지
# 주꾸미
# 킹크랩
# 앵두
# 호박순
# 돌게
# 알로에
# 쭈꾸미
# 민어
# 김자반
# 과채류
# 과일기타
# 머위
# 키위
# 세러리
# 깨순
# 코다리
# 갈근
# 백조기
# 방울토마토
# 농어
# 냉오징어
# 야자
# 냉동게
# 기타근채류
# 기타조미류
# 초피
# 홍고추
# 곤달비
# 파
# 기타엽채류
# 고들빼기
# 황돔
# 더덕수입
# 버섯
# 산채류
# 쌈추
# 파종자
# 크레송
# 기타과채류
# 죽순
# 말
# 복숭아
# 챠빌
# 젓갈
# 동부콩
# 버섯
# 동죽
# 파
# 삼채
# 새우가공
# 적근대
# 조기
# 냉임연수
# 돔
# 방울양배추
# 알배기
# 천연조미료
# 우렁이
# 볼락
# 명태
# 도다리
# 포장바지락
# 콩
# 복숭아
# 셀러리
# 깻잎
# 해삼
# 머위잎
# 유채
# 자두
# 쥐치포수입
# 라임
# 깐바지락
# 신선해조류
# 개아지살
# 참다래
# 돗나물
# 묵
# 가리비
# 새우
# 수입양채
# 감귤류
# 오디
# 숙주
# 명란
# 식용허브
# 노가리알포수입
# 민들레
# 비듬
# 명태곤니
# 꼬막
# 기타핵과
# 참깨
# 무우
# 적어
# 돈나물
# 두리안
# 감귤
# 파인애플
# 갑오징어
# 상어
# 고막
# 오징어
# 냉동대구
# 갑오징어
# 곤달비
# 낙지
# 단포수입
# 장대
# 꼬시래시
# 오징어실채수입
# 상추
# 홍어
# 완두콩
# 고막
# 새송이
# 버섯
# *로메인
# 돔류
# 와송
# 오렌지
# 가공
# 칼라후라워
# 해물모듬
# 자몽
# 라임
# 새우
# 가공김
# 기타수입과일
# 할라피뇨
# 칠게
# 메기
# 파세리
# 새송이버섯
# 비트
# 옥수수
# 코라비
# 무청
# 컴프리
# 수입우럭
# 대구
# 쌈채
# 동초
# 넙치
# 기타어류젓
# 춘채
# 동죽살
# 냉가공식품기타
# 배
# 한치채
# 눈볼대
# 청국장
# 봄동배추
# 머위대
# 고등어자반
# 민대구
# 피망
# 시레기
# 양채류
# 멸치
# 깐바지락
# 도미
# 미역
# 냉새우
# 기타
# 포도수입
# 놀래미
# 엽경채기타
# 브로코리
# 가리비
# 목이
# 농어
# 우엉대
# 고등어
# 아스파리가스
# 활넙치
# 생새우
# 파
# 문어
# 메론
# 오만둥이
# 농어
# 박
# 갯장어
# 양채류기타
# 복분자
# 열무
# 체리
# 알로에
# 명란젓
# 코다리명태
# 호두
# 냉동꽁치
# 건한치
# 생오징어
# 곤약
# 진미채
# 적어
# 노가리
# 복어
# 양송이버섯
# 대게
# 병어
# 애플민트
# 가재
# 골뱅이
# 괴도라치
# 민어
# 곶감
# 감자(일반
# 노래미
# 개불
# 세발나물
# 꼴뚜기
# 전갱이
# 가재
# 갈치
# 참죽나무순
# 기타
# 수입명태
# 가공고둥류
# 맛
# 능성어
# 미역
# 도라지
# 붉은대게
# 붉은양배추
# 쑥갓
# 기타양채
# 굴
# 날치
# 고구마순
# 참나물
# 더덕
# 전분및사료
# 고구마줄기
# 딜
# 건어기타
# 기타조미채소류
# 기타과일과채류
# 전복가공
# 참깨수입
# 개아지살
# 조기
# 기타연체류젓
# 바리
# 기타돔
# 노래미
# 우엉
# 자몽
# 홍탁
# 도미
# 두류기타
# 명엽채수입
# 근대
# 참도미
# 갑오징어
# 북어
# 두릅
# 홍합
# 암꽃게
# 피뿔고동
# 장갱이
# 가죽
# 우렁쉥이
# 매실
# 알타리무
# 다랑어
# 그린빈스
# 기타수입과일
# 배추
# 탄제린
# 고구마
# 빈스
# 돔
# 머귀
# 삼치
# 브로코리
# 비파
# 양파
# 우엉잎
# 바지락
# 기타게
# 꽈리
# 고둥
# 양미리
# 봄무
# 생가자미
# 미꾸라지
# 가오리
# 호끼알
# 딱돔
# 부지깽이
# 플럼코트
# 만디
# 우렁이
# 황석어
# 젓갈
# 쑥갓
# 볼락
# 앵두
# 열무
# 향나물
# 약용작물류
# 냉동명태
# 수입동태포
# 토란대
# 유채잎
# 모자반
# 게
# 나문재
# 도다리
# 브로코리(녹색꽃양배
# 벗
# 농림가공
# 젓갈
# 실파
# 방풍
# 새우
# 비트
# 다래
# 갈치
# 콩
# 엽경채류기타
# 오징어
# 성게
# 꼴뚜기젓
# 채소기타
# 만감
# 건취나물
# 낙지
# 고구마
# 장류
# 비름나물
# 수입냉오징어
# 모시조개
# 굴비
# 오징어채수입
# 흑점줄전갱이
# 홍합
# 조개살
# 부추
# 기타양채류
# 계피
# 건노가리
# 강낭콩
# 순무
# 고구마순
# 눈볼대
# 넙치
# 무청
# 병어
# 연어
# 부추
# 상치
# 건미역
# 케일
# 꽈리고추
# 마늘
# 돔
# 절임류
# 밀감
# 멍게
# 홍진미수입
# 만가닥버섯
# 표고버섯
# 칼리
# 준치
# 비타민
# 기타두류
# 전복
# 머우대
# 인삼
# 브록코리
# 대구
# 건다시마
# 동태
# 모시잎
# 젓갈
# 연어
# 붉은고추
# 취나물
# 그린빈스
# 망고
# 문어
# 쑥
# 깐마늘
# 망고스틴
# 가공
# 바다장어
# 동자개
# 참깨
# 생삼치
# 깻잎
# 그레이프루풋
# 기타버섯류
# 꼼장어
# 비름
# 당귀
# 기타
# 칼리후라워
# 날치알
# 선인장
# 새치
# 고추
# 서대
# 기타채소
# 완두콩
# 브로커리
# 굴
# 겨자잎
# 고들배기
# 숙주나물
# 들깨
# 바다가재
# 방풍나물
# 도라지
# 양채류
# 기타나물
# 김
# 깐파
# 홍피망
# 개우렁
# 쥐치
# 청겨자
# 가자미
# 오만득이
# 조미제품
# 왕게
# 느타리
# 천도복숭아
# 수입갈치
# 간재미
# 장어
# 노루궁뎅이버섯
# 꼬시래기
# 박
# 어리굴젓
# 밴댕어
# 돌나물
# 농산
# 메밀잎
# 절임식품
# 빨간양배추(루비볼/적
# 갈치젓
# 애플망고
# 표고
# 수입홍어
# 얼갈이
# 곡물제주
# 민어
# 멸치
# 북어포
# 두릅
# 밤
# 냉동꽃게
# 무화과
# 쥬키니
# 고추잎
# 춘채
# 넙치
# 아귀
# 장어
# 시금치
# 배추
# 서대
# 돌나물
# 알타리무
# 레드쉬
# 목이버섯
# 연근
# 용과수입
# 배도라치
# 방어
# 감
# 냉동삼치
# 숭어
# 파인애플
# 기타갑각류젓
# 원양오징어
# 치콘
# 노루궁뎅이
# 쥐치포
# 대구
# 장어
# 콩
# 비름
# 버섯류
# 오징어
# 팽이버섯
# 미백옥수수
# 꽁치
# 콜라비
# 양송이
# 동부
# 수입새치
# 쥐치
# 만가닥
# 생조기
# 숫꽃게
# 삼치
# 딸기
# 절단꽃게
# 돌돔
# 가지
# 참깨
# 깐홍합
# 새치
# 수입꽃게
# 아욱
# 산딸기
# 깐마늘대서
# 임연수
# 버섯
# 문어가공
# 레몬
# 우렁쉥이
# 숭어
# 호박잎
# 식용꽃
# 칼리플라워
# 가죽나물
# 깐마늘한지
# 쌈샐러리
# 빨간양배추
# 바지락
# 기타과실
# 건표고버섯
# 망고스턴
# 노랑가오리
# 알가공류
# 고동
# 놀래미
# 다랑어
# 빨간양배추
# 머위
# 송이
# 화살오징어
# 비트
# 고사리
# 수박
# 명태포
# 레디쉬
# 냉동조기
# 라디초우
# 파슬리
# 깐마늘남도
# 쪽파
# 양배추
# 두부류
# 실파
# 바지락
# 삼치
# 연어훈제
# 참치
# 생표고버섯
# 적치커리
# 은행
# 바나나
# 봄배추
# 돌가자미
# 수입꽁치
# 개조개
# 우럭
# 수입가자미
# 피마자
# 마늘
# 감초
# 고수
# 전갱이
# 생태
# 긴맛
# 수입임연수
# 잣
# 두부
# 무순
# 동부묵
# 고막
# 수입적어
# 토마토
# 초롱무
# 양태
# 송어
# 아스파라가스
# 겨자채
# 아나고
# 녹두
# 조개
# 볼락
# 바지락
# 문어
# 산마늘
# 홍초
# 와일드루꼴라
# 조미가공
# 명태
# 양상추
# 쭈꾸미
# 부세
# 오징어젓
# 마
# 살구
# 양상추
# 느타리버섯
# 오미자
# 망고스턴
# 민어
# 대구
# 영지버섯
# 풋고추
# 알로애
# 청과기타
# 쥐치
# 살구
# 절임
# 선꽃게
# 꿀
# 보리수
# 천연꿀
# 들깨
# 가재
# 조개젓
# 황기
# 고추
# 얼갈이배추
# 아보카도
# 개아지살
# 나물
# 메밀순
# 신선초
# 고구마순
# 수입포도
# 양파
# 갓
# 건고추
# 레몬
# 가오리
# 피망
# 고추가루
# 쭈꾸미
# 겨자
# 고등어
# 매실
# 청포묵
# 학꽁치
# 청어
# 앵두
# 아로니아
# 파세리
# 복어
# 모듬쌈
# 기타부류
# 명태
# 수입가오리
# 얼가리
# 타임
# 낙지
# 비트
# 오징어
# 로케트
# 시사모
# 생강
# 콩
# 병어
# 수박
# 땅콩
# 고둥
# 멍게
# 완두
# 수삼
# 수입대구
# 아귀
# 애호박
# 뉴그린
# 두류
# 홍합
# 갈치
# 농어
# 소라
# 냉동오징어
# 감귤
# 인삼
# 골뱅이
# 토당귀
# 버섯
# 멸치젓
# 수입청어
# 활새우
# 호박잎
# 우럭
# 곡물제조
# 청어
# 포도
# 용과
# 들깨
# 팥
# 삐틀이
# 새우
# 유자
# 기타산채류
# 적채
# 개불
# 브로커리(녹색꽃양배
# 열무
# 용가자미
# 병어
# 장어
# 다시마
# 파프리카
# 금강초
# 취나물
# 아보카드
# 멍게
# 기타과실류
# 도루묵
# 고추잎
# 가리비
# 콩나물
# 꼴뚜기
# 방아
# 북어채
# 비트
# 골파
# 복분자
# 연어
# 신선초
# 곰치
# 타임
# 허브
# 채리
# 우거지
# 고수
# 한치
# 참외
# 냉동갈치
# 해삼
# 가오리
# 쪽파
# 냉동낙지
# 가재
# 토란
# 코라비
# 마늘
# 달고기
# 공심채
# 냉삼치
# 새우
# 홍합
# 셀러리
# 생멸치
# 건고추
# 쌈배추
# 방아
# 황태
# 청경채
# 우뭇가사리
# 향신료
# 황강달이
# 건오징어
# 냉동아귀수입
# 수입오징어
# 감자
# 조개
# 고비
# 엽경채류기타
# 조기
# 무우순
# 버섯류기타
# 미더덕
# 소라
# 전분및사료제조
# 가죽나무순
# 마늘
# 날치
# 숭어
# 새꼬막
# 고둥
# 생고추
# 수조기
# 참다래
# 조개
# 학공치
# 장어
# 참돔
# 조미대구포수입
# 두류
# 고둥
# 로즈
# 버찌
# 가시오이
# 알파파싹
# 가오리포장
# 명태포
# 해삼
# 칼리플라워(꽃양배추
# 여주
# 포도
# 은갈치
# 보리수
# 비타민
# 강낭콩
# 수입레몬
# 씀바귀
# 가무락
# 중하
# 아몬드
# 양배추
# 샐러리
# 통마늘
# 기타버섯
# 만듸
# 피망
# 맛진미수입
# 상어
# 낙지
# 광어
# 기타어류
# 생고등어
# 숙주나물
# 수입조기
# 석이
# 피조개
# 빨간양배추
# 건새우
# 가오리
# 냉동가자미
# 건태
# 블루베리
# 깐마늘
# 꼬막
# 오디
# 무말랭이
# 고사리잎
# 오징어
# 참비름
# 파파야
# 야콘
# 화살오징어
# 꽁치
# 기타엽경채류
# 동충하초
# 풋옥수수
# 전분및사료제조
# 갓
# 상황버섯
# 산초
# 염옥어
# 밴댕이젓
# 블루베리
# 수입낙지
# 꿀벌
# 미역류
# 가자미
# 버섯
# 산오징어
# 도토리묵
# 라디치오
# 고추
# 어린잎
# 기타과채
# 호박
# 신선해조류
# 가재
# 곤이
# 샐러리
# 묵류
# 오이
# 알백이
# 파
# 잉어
# 저장무
# 오렌지
# 참기름
# 미더덕
# 생새치
# 은갈치
# 아스파라거스
# 풋콩
# 연어
# 김
# 당귀잎
# 파래
# 청양
# 조미가공
# 국화
# 방어
# 보리수
# 메밀
# 파인애플
# 농림가공
# 새우
# 기름가자미
# 수입고등어
# 오징어
# 아주까리
# 기타근채
# 전복
# 무
# 가죽나물
# 개조개
# 미숫가루
# 오징어가공
# 사과
# 오크린
# 돗나물
# 레몬
# 바지락
# 미나리
# 새우살
# 참전복
# 바리
# 강남콩
# 사포딜라
# 그레이프푸룻
# 피문어
# 참당귀
# 적채
# 코코넛
# 콩
# 코다리
# 톳
# 바지락
# 가공바지락
# 베이비순
# 루꼴라
# 쏨뱅이
# 옥수수
# 부각
# 콜라비(순무양배
# 어채
# 명태
# 건고추
# 멸치
# 오징어
# 산채류
# 적겨자
# 귤
# 건고추
# 고추
# 게
# 로메인
# 백합
# 풋콩류
# 홍해삼
# 단배추
# 양상추(결구상추.레타
# 초당옥수수
# 콜라비
# 도토리
# 브로콜리
# 가공조개살
# 키위
# 곤이
# 모시조개
# 새조개
# 대구곤이
# 참치
# 북어머리
# 키위
# 노래미
# 화살오징어
# 냉가오리
# 당귀
# 호박
# 붕장어
# 민어
# 알타리무우
# 양채류기타
# 산낙지
# 산나물
# 기타과일류
# 가자미
# 미역줄기
# 장어
# 굴
# 명태
# 수입용과
# 오징어채
# 논우렁이
# 쌈용채소
# 파
# 가자미
# 재첩
# 한치
# 해파리
# 청초

# %% [markdown]
# # 서울시 생필품 농수축산물 가격 정보

# %%
#서울시 생필품 농수축산물 가격정보: raw 데이터

import pandas as pd
price_retail = pd.read_csv('서울시 생필품 농수축산물 가격.csv',encoding = 'utf-8')
price_retail
# Out:
#           일련번호  시장/마트 번호 시장/마트 이름  품목 번호        품목 이름     실판매규격  가격(원)  \
# 0      1771302       205  둔촌역전통시장    266    고등어(생물국산)       1마리   5000
# 1      1771301       205  둔촌역전통시장    254    오징어(생물국산)       1마리   3333
# 2      1771300       205  둔촌역전통시장    264    명태(냉동수입산)       1마리   3500
# 3      1771299       205  둔촌역전통시장    259     조기(냉동국산)       1마리   1430
# 4      1771298       205  둔촌역전통시장    320      달걀(30개)        특란   8000
# ...        ...       ...      ...    ...          ...       ...    ...
# 47790  1721875        55     광장시장     24           양파  1망 1.5kg   3000
# 47791  1721874        55     광장시장    133       무(세척무)        1개   2000
# 47792  1721873        55     광장시장    307  배추(2.5~3kg)       1포기   6000
# 47793  1721872        55     광장시장    306   배(신고 600g)        1개   5000
# 47794  1721871        55     광장시장    305  사과(부사 300g)        1개   3000
#
#           년도-월            비고        점검일자  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  \
# 0      2022-07           국내산  2022-07-21                  1              전통시장
# 1      2022-07  국내산3마리10000원  2022-07-21                  1              전통시장
# 2      2022-07      수입산(러시아)  2022-07-21                  1              전통시장
# 3      2022-07  국내산7마리10000원  2022-07-21                  1              전통시장
# 4      2022-07           국내산  2022-07-21                  1              전통시장
# ...        ...           ...         ...                ...               ...
# 47790  2022-01         국내산무안  2022-01-27                  1              전통시장
# 47791  2022-01       국내산잎없는것  2022-01-27                  1              전통시장
# 47792  2022-01        국내산통배추  2022-01-27                  1              전통시장
# 47793  2022-01        국내산신고배  2022-01-27                  1              전통시장
# 47794  2022-01       국내산청송사과  2022-01-27                  1              전통시장
#
#        자치구 코드 자치구 이름
# 0      740000    강동구
# 1      740000    강동구
# 2      740000    강동구
# 3      740000    강동구
# 4      740000    강동구
# ...       ...    ...
# 47790  110000    종로구
# 47791  110000    종로구
# 47792  110000    종로구
# 47793  110000    종로구
# 47794  110000    종로구
#
# [47795 rows x 14 columns]

# %%
price_retail['품목 이름'].unique()
# Out:
# array(['고등어(생물국산)', '오징어(생물국산)', '명태(냉동수입산)', '조기(냉동국산)', '달걀(30개)',
#        '달걀(10개)', '닭고기(육계)', '돼지고기(생삼겹살)', '쇠고기(한우불고기)', '애호박', '오이(다다기)',
#        '상추', '양파(1.5kg망)', '무(1kg)', '배추(2.5~3kg)', '배(신고 600g)',
#        '사과(부사 300g)', '명태(러시아냉동)', '조기(국산냉동)', '닭고기(토종닭)', '돼지고기(삼겹살)',
#        '양파', '무', '배추', '배(신고)중급(대)', '사과(부사)중급(대)', '배추(국산)', '상추(100g)',
#        '명태', '조기', '닭고기', '호박(인큐베이터)', '냉동참조기(20cm수입)', '고등어(냉동국산)',
#        '냉동참조기(20cm국산)', '배(신고)', '사과(부사)', '고등어', '오징어(냉동국산)',
#        '조기(냉동수입산)', '조기(국산생물)', '양파(작은망)', '무(세척무)', '오이', '고등어(생물수입산)',
#        '배', '사과', '고등어(냉동수입산)', '동태', '달걀', '쇠고기', '쇠고기(한우2등급)',
#        '명태(45cm수입산)', '조기(생물국산)', '고등어(30cm수입산)', '오징어(냉동수입산)', '호박',
#        '명태(생물국산)', '오징어(생물수입산)', '명태(생물수입산)', '배추(중간)', '쇠고기(육우불고기)',
#        '명태(냉동국산)', '오이(중간)', '쇠고기(한우1등급)', '달걀(15개)', '닭고기(중간)',
#        '무(세척무 중)', '조기(생물수입산)', '호박(인큐베이터)중간', '배(중품)', '오징어',
#        '쇠고기(육우1등급)', '쇠고기(등심)', '오징어(냉동)', '조기(중국산생물)', '고등어(30cm국산)',
#        nan, '달걀(왕란)'], dtype=object)

# %%
#서울시 생필품 농수축산물 가격정보: 판매규격 뽑아내기(냉동, 생물, 국산, 수입, n개)

import re

for i in range(len(price_retail)):
    try:
        price_retail.loc[i,'판매규격'] = re.search('\((.*)\)',str(price_retail.loc[i,'품목 이름'])).group(1)
    except:
        price_retail.loc[i,'판매규격'] = ''
    price_retail.loc[i,'품목 이름'] = re.sub('\(.*\)','',str(price_retail.loc[i,'품목 이름']))

price_retail
# Out:
#           일련번호  시장/마트 번호 시장/마트 이름  품목 번호 품목 이름     실판매규격  가격(원)     년도-월  \
# 0      1771302       205  둔촌역전통시장    266   고등어       1마리   5000  2022-07
# 1      1771301       205  둔촌역전통시장    254   오징어       1마리   3333  2022-07
# 2      1771300       205  둔촌역전통시장    264    명태       1마리   3500  2022-07
# 3      1771299       205  둔촌역전통시장    259    조기       1마리   1430  2022-07
# 4      1771298       205  둔촌역전통시장    320    달걀        특란   8000  2022-07
# ...        ...       ...      ...    ...   ...       ...    ...      ...
# 47790  1721875        55     광장시장     24    양파  1망 1.5kg   3000  2022-01
# 47791  1721874        55     광장시장    133     무        1개   2000  2022-01
# 47792  1721873        55     광장시장    307    배추       1포기   6000  2022-01
# 47793  1721872        55     광장시장    306     배        1개   5000  2022-01
# 47794  1721871        55     광장시장    305    사과        1개   3000  2022-01
#
#                  비고        점검일자  시장유형 구분(시장/마트) 코드 시장유형 구분(시장/마트) 이름  자치구 코드  \
# 0               국내산  2022-07-21                  1              전통시장  740000
# 1      국내산3마리10000원  2022-07-21                  1              전통시장  740000
# 2          수입산(러시아)  2022-07-21                  1              전통시장  740000
# 3      국내산7마리10000원  2022-07-21                  1              전통시장  740000
# 4               국내산  2022-07-21                  1              전통시장  740000
# ...             ...         ...                ...               ...     ...
# 47790         국내산무안  2022-01-27                  1              전통시장  110000
# 47791       국내산잎없는것  2022-01-27                  1              전통시장  110000
# 47792        국내산통배추  2022-01-27                  1              전통시장  110000
# 47793        국내산신고배  2022-01-27                  1              전통시장  110000
# 47794       국내산청송사과  2022-01-27                  1              전통시장  110000
#
#       자치구 이름     판매규격
# 0        강동구     생물국산
# 1        강동구     생물국산
# 2        강동구    냉동수입산
# 3        강동구     냉동국산
# 4        강동구      30개
# ...      ...      ...
# 47790    종로구
# 47791    종로구      세척무
# 47792    종로구  2.5~3kg
# 47793    종로구  신고 600g
# 47794    종로구  부사 300g
#
# [47795 rows x 15 columns]

# %%
set(price_retail['품목 이름'].unique())
