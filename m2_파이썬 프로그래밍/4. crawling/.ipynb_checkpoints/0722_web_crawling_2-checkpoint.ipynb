# %% [markdown]
# ### BeautifulSoup 모듈
# - 홈페이지 내 데이터를 쉽게 추출할 수 있게 해주는 파이썬 외부 라이브러리
# - 웹 문서 내 수많은 HTML 태그들을 parser를 활용해 사용하기 편한 파이썬 객체로 만들어 제공
# - 웹 문서 구조를 알고 있다면 편하게 데이터를 뽑아 활용할 수 있음
#
# #### 기존방식과의 차이점
# - 정규 표현식, 문자열 함수 등을 활용하여 홈페이지 텍스트 내 패턴을 분석하여 하나씩 원하는 데이터를 찾아가는 형식
# - BS는 HTML 문서를 태그를 기반으로 구조화하여 태그로 원하는 데이터를 찾아가는 형식

# %%
#살펴보기

# %%
html_doc = """
<html lang="en">
<head><title>crawl</title></head>
<body>
<p class="a" align="center"> text1</p>
<p class="b" align="center"> text2</p>
<p class="c" align="center"> text3</p>
<div><img src="/source" width="300" height="200"></div>
</body>
</html>
"""

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(html_doc,'html.parser')  # html parser를 사용
print(soup)
# Out:
# <html lang="en">
# <head><title>crawl</title></head>
# <body>
# <p align="center" class="a"> text1</p>
# <p align="center" class="b"> text2</p>
# <p align="center" class="c"> text3</p>
# <div><img height="200" src="/source" width="300"/></div>
# </body>
# </html>

# %%
print(soup.prettify())   #탭도 적용해서 이쁘게 보여줌
# Out:
# <html lang="en">
#  <head>
#   <title>
#    crawl
#   </title>
#  </head>
#  <body>
#   <p align="center" class="a">
#    text1
#   </p>
#   <p align="center" class="b">
#    text2
#   </p>
#   <p align="center" class="c">
#    text3
#   </p>
#   <div>
#    <img height="200" src="/source" width="300"/>
#   </div>
#  </body>
# </html>

# %%
#살펴보기: 태그 안에 텍스트 뽑아내기

# %%
html = """
<html><body>
  <h1>스크레이핑이란?</h1>
  <p>웹 페이지를 분석하는 것</p>
  <p>원하는 부분을 추출하는 것</p>
</body></html>
"""

# %%
soup=BeautifulSoup(html,'html.parser')
print(soup.prettify())
# Out:
# <html>
#  <body>
#   <h1>
#    스크레이핑이란?
#   </h1>
#   <p>
#    웹 페이지를 분석하는 것
#   </p>
#   <p>
#    원하는 부분을 추출하는 것
#   </p>
#  </body>
# </html>

# %%
h1=soup.html.body.h1
h1.string
# Out:
# '스크레이핑이란?'

# %%
p1=soup.html.body.p
p2=p1.next_sibling.next_sibling

print(p1.string, p2.string)
# Out:
# 웹 페이지를 분석하는 것 원하는 부분을 추출하는 것

# %% [markdown]
# ---

# %% [markdown]
# #### find() : HTML의 해당 태그에 대한 첫 번째 정보를 가져옴
# - find(속성='값') : HTML 해당 속성과 일치하는 값에 대한 첫 번째 정보를 가져옴

# %%
html = """
<html><body>
  <h1 id='title'>스크레이핑이란?</h1>
  <p id='body'>웹 페이지를 분석하는 것</p>
  <p>원하는 부분을 추출하는 것</p>
</body></html>
"""

# %%
soup=BeautifulSoup(html,'html.parser')
title=soup.find(id='title')
body=soup.find(id='body')

print(title.string)      
print(title.text)        
print(title.get_text())

print(body.string)
print(body.text)
print(body.get_text())
# Out:
# 스크레이핑이란?
# 스크레이핑이란?
# 스크레이핑이란?
# 웹 페이지를 분석하는 것
# 웹 페이지를 분석하는 것
# 웹 페이지를 분석하는 것

# %% [markdown]
# #### find_all(), findAll() : HTML의 해당 태그에 대한 첫 번째 정보들을 가져옴

# %%
texts=soup.findAll('p')

for t in texts:
    print(t.text)
# Out:
# 웹 페이지를 분석하는 것
# 원하는 부분을 추출하는 것

# %%
#urlopen()과 BeautifulSoup의 조합

from bs4 import BeautifulSoup
import urllib.request as req

url="http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp"   #xlm 데이터
response=req.urlopen(url)

soup=BeautifulSoup(response, 'html.parser')
title=soup.find('title').string
wf=soup.find('wf').string           #weather forecassting의 약자인 wf부르기

print(title, wf)
# Out:
# 기상청 육상 중기예보 ○ (강수) 30일(토)은 전라권에 소나기가 오는 곳이 있겠습니다. <br />○ (기온) 이번 예보기간 아침 기온은 22~26도, 낮 기온은 29~34도로 오늘(24일, 아침최저기온 22~24도, 낮최고기온 25~32도)보다 높겠습니다.<br /><br />* 우리나라 주변 기압계에 따라 소나기가 내리는 구역이 변동될 수 있으며, 돌풍과 함께 천둥.번개를 동반한 강한 소나기가 내리는 곳이 있겠으니 안전에 유의하기 바라며, 앞으로 발표되는 기상정보를 참고하기 바랍니다.
# <?xml version="1.0" encoding="utf-8" ?>
# <rss version="2.0">
# <channel>
# <title>기상청 육상 중기예보</title>
# <link/>http://www.kma.go.kr/weather/forecast/mid-term_01.jsp
# <description>기상청 날씨 웹서비스</description>
# <language>ko</language>
# <generator>기상청</generator>
# <pubdate>2022년 07월 24일 (일)요일 18:00</pubdate>
# <item>
# <author>기상청</author>
# <category>육상중기예보</category>
# <title>전국 육상 중기예보 - 2022년 07월 24일 (일)요일 18:00 발표</title>
# <link/>http://www.kma.go.kr/weather/forecast/mid-term_01.jsp
# <guid>http://www.kma.go.kr/weather/forecast/mid-term_01.jsp</guid>
# <description>
# <header>
# <title>전국 육상중기예보</title>
# <tm>202207241800</tm>
# <wf><![CDATA[○ (강수) 30일(토)은 전라권에 소나기가 오는 곳이 있겠습니다. <br />○ (기온) 이번 예보기간 아침 기온은 22~26도, 낮 기온은 29~34도로 오늘(24일, 아침최저기온 22~24도, 낮최고기온 25~32도)보다 높겠습니다.<br /><br />* 우리나라 주변 기압계에 따라 소나기가 내리는 구역이 변동될 수 있으며, 돌풍과 함께 천둥.번개를 동반한 강한 소나기가 내리는 곳이 있겠으니 안전에 유의하기 바라며, 앞으로 발표되는 기상정보를 참고하기 바랍니다.]]></wf>
# </header>
# <body>
# <location wl_ver="3">
# <province>서울ㆍ인천ㆍ경기도</province>
# <city>서울</city>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>26</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 12:00</tmef>
# <wf>맑음</wf>
# <tmn>26</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 00:00</tmef>
# <wf>맑음</wf>
# <tmn>25</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 12:00</tmef>
# <wf>맑음</wf>
# <tmn>25</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 00:00</tmef>
# <wf>맑음</wf>
# <tmn>25</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>25</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 00:00</tmef>
# <wf>맑음</wf>
# <tmn>25</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>25</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 00:00</tmef>
# <wf>맑음</wf>
# <tmn>25</tmn>
# <tmx>34</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 12:00</tmef>
# <wf>맑음</wf>
# <tmn>25</tmn>
# <tmx>34</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-01 00:00</tmef>
# <wf>흐림</wf>
# <tmn>26</tmn>
# <tmx>34</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-02 00:00</tmef>
# <wf>흐림</wf>
# <tmn>25</tmn>
# <tmx>34</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-03 00:00</tmef>
# <wf>흐림</wf>
# <tmn>25</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>서울ㆍ인천ㆍ경기도</province>
# <city>인천</city>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>25</tmn>
# <tmx>30</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 12:00</tmef>
# <wf>맑음</wf>
# <tmn>25</tmn>
# <tmx>30</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 00:00</tmef>
# <wf>맑음</wf>
# <tmn>25</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 12:00</tmef>
# <wf>맑음</wf>
# <tmn>25</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 00:00</tmef>
# <wf>맑음</wf>
# <tmn>25</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>25</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 00:00</tmef>
# <wf>맑음</wf>
# <tmn>25</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>25</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 00:00</tmef>
# <wf>맑음</wf>
# <tmn>25</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 12:00</tmef>
# <wf>맑음</wf>
# <tmn>25</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-01 00:00</tmef>
# <wf>흐림</wf>
# <tmn>25</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-02 00:00</tmef>
# <wf>흐림</wf>
# <tmn>25</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-03 00:00</tmef>
# <wf>흐림</wf>
# <tmn>25</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>서울ㆍ인천ㆍ경기도</province>
# <city>수원</city>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>25</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 12:00</tmef>
# <wf>맑음</wf>
# <tmn>25</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 00:00</tmef>
# <wf>맑음</wf>
# <tmn>24</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 12:00</tmef>
# <wf>맑음</wf>
# <tmn>24</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 00:00</tmef>
# <wf>맑음</wf>
# <tmn>24</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 00:00</tmef>
# <wf>맑음</wf>
# <tmn>25</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>25</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 00:00</tmef>
# <wf>맑음</wf>
# <tmn>25</tmn>
# <tmx>34</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 12:00</tmef>
# <wf>맑음</wf>
# <tmn>25</tmn>
# <tmx>34</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-01 00:00</tmef>
# <wf>흐림</wf>
# <tmn>25</tmn>
# <tmx>34</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-02 00:00</tmef>
# <wf>흐림</wf>
# <tmn>25</tmn>
# <tmx>34</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-03 00:00</tmef>
# <wf>흐림</wf>
# <tmn>25</tmn>
# <tmx>34</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>서울ㆍ인천ㆍ경기도</province>
# <city>파주</city>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 12:00</tmef>
# <wf>맑음</wf>
# <tmn>23</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 00:00</tmef>
# <wf>맑음</wf>
# <tmn>23</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 12:00</tmef>
# <wf>맑음</wf>
# <tmn>23</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 00:00</tmef>
# <wf>맑음</wf>
# <tmn>23</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 00:00</tmef>
# <wf>맑음</wf>
# <tmn>23</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 00:00</tmef>
# <wf>맑음</wf>
# <tmn>23</tmn>
# <tmx>34</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 12:00</tmef>
# <wf>맑음</wf>
# <tmn>23</tmn>
# <tmx>34</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-01 00:00</tmef>
# <wf>흐림</wf>
# <tmn>24</tmn>
# <tmx>34</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-02 00:00</tmef>
# <wf>흐림</wf>
# <tmn>24</tmn>
# <tmx>34</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-03 00:00</tmef>
# <wf>흐림</wf>
# <tmn>24</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>서울ㆍ인천ㆍ경기도</province>
# <city>이천</city>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 12:00</tmef>
# <wf>맑음</wf>
# <tmn>23</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 00:00</tmef>
# <wf>맑음</wf>
# <tmn>22</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 12:00</tmef>
# <wf>맑음</wf>
# <tmn>22</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 00:00</tmef>
# <wf>맑음</wf>
# <tmn>23</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 00:00</tmef>
# <wf>맑음</wf>
# <tmn>23</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 00:00</tmef>
# <wf>맑음</wf>
# <tmn>23</tmn>
# <tmx>34</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 12:00</tmef>
# <wf>맑음</wf>
# <tmn>23</tmn>
# <tmx>34</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-01 00:00</tmef>
# <wf>흐림</wf>
# <tmn>23</tmn>
# <tmx>34</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-02 00:00</tmef>
# <wf>흐림</wf>
# <tmn>24</tmn>
# <tmx>34</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-03 00:00</tmef>
# <wf>흐림</wf>
# <tmn>24</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>서울ㆍ인천ㆍ경기도</province>
# <city>평택</city>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 12:00</tmef>
# <wf>맑음</wf>
# <tmn>24</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 00:00</tmef>
# <wf>맑음</wf>
# <tmn>23</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 12:00</tmef>
# <wf>맑음</wf>
# <tmn>23</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 00:00</tmef>
# <wf>맑음</wf>
# <tmn>24</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 00:00</tmef>
# <wf>맑음</wf>
# <tmn>24</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 00:00</tmef>
# <wf>맑음</wf>
# <tmn>24</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 12:00</tmef>
# <wf>맑음</wf>
# <tmn>24</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-01 00:00</tmef>
# <wf>흐림</wf>
# <tmn>24</tmn>
# <tmx>34</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-02 00:00</tmef>
# <wf>흐림</wf>
# <tmn>24</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-03 00:00</tmef>
# <wf>흐림</wf>
# <tmn>25</tmn>
# <tmx>34</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>강원도영서</province>
# <city>춘천</city>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 12:00</tmef>
# <wf>맑음</wf>
# <tmn>24</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 00:00</tmef>
# <wf>맑음</wf>
# <tmn>22</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 12:00</tmef>
# <wf>맑음</wf>
# <tmn>22</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 00:00</tmef>
# <wf>맑음</wf>
# <tmn>24</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 12:00</tmef>
# <wf>맑음</wf>
# <tmn>24</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-01 00:00</tmef>
# <wf>흐림</wf>
# <tmn>24</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-02 00:00</tmef>
# <wf>흐림</wf>
# <tmn>24</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-03 00:00</tmef>
# <wf>흐림</wf>
# <tmn>24</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>강원도영서</province>
# <city>원주</city>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 12:00</tmef>
# <wf>맑음</wf>
# <tmn>23</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 00:00</tmef>
# <wf>맑음</wf>
# <tmn>23</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 12:00</tmef>
# <wf>맑음</wf>
# <tmn>23</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 00:00</tmef>
# <wf>맑음</wf>
# <tmn>24</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 12:00</tmef>
# <wf>맑음</wf>
# <tmn>24</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-01 00:00</tmef>
# <wf>흐림</wf>
# <tmn>24</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-02 00:00</tmef>
# <wf>흐림</wf>
# <tmn>24</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-03 00:00</tmef>
# <wf>흐림</wf>
# <tmn>24</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>강원도영동</province>
# <city>강릉</city>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>29</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>29</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 00:00</tmef>
# <wf>흐림</wf>
# <tmn>23</tmn>
# <tmx>29</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 12:00</tmef>
# <wf>흐림</wf>
# <tmn>23</tmn>
# <tmx>29</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 00:00</tmef>
# <wf>흐림</wf>
# <tmn>24</tmn>
# <tmx>30</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>30</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 12:00</tmef>
# <wf>맑음</wf>
# <tmn>24</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 00:00</tmef>
# <wf>맑음</wf>
# <tmn>25</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 12:00</tmef>
# <wf>맑음</wf>
# <tmn>25</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-01 00:00</tmef>
# <wf>흐림</wf>
# <tmn>25</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-02 00:00</tmef>
# <wf>흐림</wf>
# <tmn>25</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-03 00:00</tmef>
# <wf>흐림</wf>
# <tmn>25</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>대전ㆍ세종ㆍ충청남도</province>
# <city>대전</city>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 12:00</tmef>
# <wf>맑음</wf>
# <tmn>24</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 00:00</tmef>
# <wf>맑음</wf>
# <tmn>23</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 00:00</tmef>
# <wf>맑음</wf>
# <tmn>24</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 00:00</tmef>
# <wf>맑음</wf>
# <tmn>24</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 00:00</tmef>
# <wf>맑음</wf>
# <tmn>25</tmn>
# <tmx>34</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>25</tmn>
# <tmx>34</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-01 00:00</tmef>
# <wf>흐림</wf>
# <tmn>25</tmn>
# <tmx>34</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-02 00:00</tmef>
# <wf>흐림</wf>
# <tmn>25</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-03 00:00</tmef>
# <wf>흐림</wf>
# <tmn>25</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>대전ㆍ세종ㆍ충청남도</province>
# <city>세종</city>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 12:00</tmef>
# <wf>맑음</wf>
# <tmn>23</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 00:00</tmef>
# <wf>맑음</wf>
# <tmn>22</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>22</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 00:00</tmef>
# <wf>맑음</wf>
# <tmn>23</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 00:00</tmef>
# <wf>맑음</wf>
# <tmn>23</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 00:00</tmef>
# <wf>맑음</wf>
# <tmn>23</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-01 00:00</tmef>
# <wf>흐림</wf>
# <tmn>24</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-02 00:00</tmef>
# <wf>흐림</wf>
# <tmn>24</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-03 00:00</tmef>
# <wf>흐림</wf>
# <tmn>24</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>대전ㆍ세종ㆍ충청남도</province>
# <city>홍성</city>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 12:00</tmef>
# <wf>맑음</wf>
# <tmn>24</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 00:00</tmef>
# <wf>맑음</wf>
# <tmn>23</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 00:00</tmef>
# <wf>맑음</wf>
# <tmn>24</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 00:00</tmef>
# <wf>맑음</wf>
# <tmn>23</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 00:00</tmef>
# <wf>맑음</wf>
# <tmn>24</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-01 00:00</tmef>
# <wf>흐림</wf>
# <tmn>24</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-02 00:00</tmef>
# <wf>흐림</wf>
# <tmn>24</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-03 00:00</tmef>
# <wf>흐림</wf>
# <tmn>24</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>충청북도</province>
# <city>청주</city>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 12:00</tmef>
# <wf>맑음</wf>
# <tmn>24</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 00:00</tmef>
# <wf>맑음</wf>
# <tmn>24</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 00:00</tmef>
# <wf>맑음</wf>
# <tmn>24</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 00:00</tmef>
# <wf>맑음</wf>
# <tmn>25</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>25</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 00:00</tmef>
# <wf>맑음</wf>
# <tmn>25</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>25</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-01 00:00</tmef>
# <wf>흐림</wf>
# <tmn>25</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-02 00:00</tmef>
# <wf>흐림</wf>
# <tmn>25</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-03 00:00</tmef>
# <wf>흐림</wf>
# <tmn>25</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>충청북도</province>
# <city>충주</city>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 12:00</tmef>
# <wf>맑음</wf>
# <tmn>23</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 00:00</tmef>
# <wf>맑음</wf>
# <tmn>22</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>22</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 00:00</tmef>
# <wf>맑음</wf>
# <tmn>23</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 00:00</tmef>
# <wf>맑음</wf>
# <tmn>23</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 00:00</tmef>
# <wf>맑음</wf>
# <tmn>23</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-01 00:00</tmef>
# <wf>흐림</wf>
# <tmn>24</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-02 00:00</tmef>
# <wf>흐림</wf>
# <tmn>23</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-03 00:00</tmef>
# <wf>흐림</wf>
# <tmn>24</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>충청북도</province>
# <city>영동</city>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>21</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 12:00</tmef>
# <wf>맑음</wf>
# <tmn>21</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 00:00</tmef>
# <wf>맑음</wf>
# <tmn>21</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>10</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>21</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 00:00</tmef>
# <wf>맑음</wf>
# <tmn>22</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>22</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 00:00</tmef>
# <wf>맑음</wf>
# <tmn>22</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>22</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 00:00</tmef>
# <wf>맑음</wf>
# <tmn>22</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>22</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-01 00:00</tmef>
# <wf>흐림</wf>
# <tmn>23</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-02 00:00</tmef>
# <wf>흐림</wf>
# <tmn>23</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-03 00:00</tmef>
# <wf>흐림</wf>
# <tmn>23</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>광주ㆍ전라남도</province>
# <city>광주</city>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 12:00</tmef>
# <wf>구름많고 비</wf>
# <tmn>23</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>60</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 00:00</tmef>
# <wf>맑음</wf>
# <tmn>24</tmn>
# <tmx>34</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 12:00</tmef>
# <wf>구름많고 소나기</wf>
# <tmn>24</tmn>
# <tmx>34</tmx>
# <reliability></reliability>
# <rnst>70</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>25</tmn>
# <tmx>34</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 12:00</tmef>
# <wf>흐림</wf>
# <tmn>25</tmn>
# <tmx>34</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-01 00:00</tmef>
# <wf>흐림</wf>
# <tmn>25</tmn>
# <tmx>34</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-02 00:00</tmef>
# <wf>흐림</wf>
# <tmn>25</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-03 00:00</tmef>
# <wf>흐림</wf>
# <tmn>25</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>광주ㆍ전라남도</province>
# <city>목포</city>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 12:00</tmef>
# <wf>구름많고 비</wf>
# <tmn>23</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>60</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>25</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>25</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 00:00</tmef>
# <wf>맑음</wf>
# <tmn>25</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 12:00</tmef>
# <wf>구름많고 소나기</wf>
# <tmn>25</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>70</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>25</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 12:00</tmef>
# <wf>흐림</wf>
# <tmn>25</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-01 00:00</tmef>
# <wf>흐림</wf>
# <tmn>25</tmn>
# <tmx>30</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-02 00:00</tmef>
# <wf>흐림</wf>
# <tmn>25</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-03 00:00</tmef>
# <wf>흐림</wf>
# <tmn>25</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>광주ㆍ전라남도</province>
# <city>여수</city>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>29</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 12:00</tmef>
# <wf>구름많고 비</wf>
# <tmn>24</tmn>
# <tmx>29</tmx>
# <reliability></reliability>
# <rnst>60</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>30</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>30</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>29</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>29</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 00:00</tmef>
# <wf>맑음</wf>
# <tmn>25</tmn>
# <tmx>30</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 12:00</tmef>
# <wf>구름많고 소나기</wf>
# <tmn>25</tmn>
# <tmx>30</tmx>
# <reliability></reliability>
# <rnst>70</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>26</tmn>
# <tmx>30</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 12:00</tmef>
# <wf>흐림</wf>
# <tmn>26</tmn>
# <tmx>30</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-01 00:00</tmef>
# <wf>흐림</wf>
# <tmn>25</tmn>
# <tmx>30</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-02 00:00</tmef>
# <wf>흐림</wf>
# <tmn>26</tmn>
# <tmx>30</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-03 00:00</tmef>
# <wf>흐림</wf>
# <tmn>25</tmn>
# <tmx>30</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>광주ㆍ전라남도</province>
# <city>순천</city>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 12:00</tmef>
# <wf>구름많고 비</wf>
# <tmn>23</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>60</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 00:00</tmef>
# <wf>맑음</wf>
# <tmn>24</tmn>
# <tmx>34</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 12:00</tmef>
# <wf>구름많고 소나기</wf>
# <tmn>24</tmn>
# <tmx>34</tmx>
# <reliability></reliability>
# <rnst>70</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>25</tmn>
# <tmx>34</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 12:00</tmef>
# <wf>흐림</wf>
# <tmn>25</tmn>
# <tmx>34</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-01 00:00</tmef>
# <wf>흐림</wf>
# <tmn>25</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-02 00:00</tmef>
# <wf>흐림</wf>
# <tmn>26</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-03 00:00</tmef>
# <wf>흐림</wf>
# <tmn>25</tmn>
# <tmx>34</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>광주ㆍ전라남도</province>
# <city>광양</city>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 12:00</tmef>
# <wf>구름많고 비</wf>
# <tmn>23</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>60</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 00:00</tmef>
# <wf>맑음</wf>
# <tmn>24</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 12:00</tmef>
# <wf>구름많고 소나기</wf>
# <tmn>24</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>70</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>25</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 12:00</tmef>
# <wf>흐림</wf>
# <tmn>25</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-01 00:00</tmef>
# <wf>흐림</wf>
# <tmn>25</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-02 00:00</tmef>
# <wf>흐림</wf>
# <tmn>25</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-03 00:00</tmef>
# <wf>흐림</wf>
# <tmn>24</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>광주ㆍ전라남도</province>
# <city>나주</city>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>22</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 12:00</tmef>
# <wf>구름많고 비</wf>
# <tmn>22</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>60</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>22</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>22</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 00:00</tmef>
# <wf>맑음</wf>
# <tmn>23</tmn>
# <tmx>34</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 12:00</tmef>
# <wf>구름많고 소나기</wf>
# <tmn>23</tmn>
# <tmx>34</tmx>
# <reliability></reliability>
# <rnst>70</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>34</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 12:00</tmef>
# <wf>흐림</wf>
# <tmn>24</tmn>
# <tmx>34</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-01 00:00</tmef>
# <wf>흐림</wf>
# <tmn>24</tmn>
# <tmx>34</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-02 00:00</tmef>
# <wf>흐림</wf>
# <tmn>24</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-03 00:00</tmef>
# <wf>흐림</wf>
# <tmn>24</tmn>
# <tmx>34</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>전라북도</province>
# <city>전주</city>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 00:00</tmef>
# <wf>흐리고 비</wf>
# <tmn>24</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>60</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 12:00</tmef>
# <wf>맑음</wf>
# <tmn>24</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 00:00</tmef>
# <wf>맑음</wf>
# <tmn>24</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 00:00</tmef>
# <wf>맑음</wf>
# <tmn>24</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 12:00</tmef>
# <wf>구름많고 소나기</wf>
# <tmn>24</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>60</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>25</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 12:00</tmef>
# <wf>흐림</wf>
# <tmn>25</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-01 00:00</tmef>
# <wf>흐림</wf>
# <tmn>25</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-02 00:00</tmef>
# <wf>흐림</wf>
# <tmn>25</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-03 00:00</tmef>
# <wf>흐림</wf>
# <tmn>25</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>전라북도</province>
# <city>군산</city>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 00:00</tmef>
# <wf>흐리고 비</wf>
# <tmn>24</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>60</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 12:00</tmef>
# <wf>맑음</wf>
# <tmn>24</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 00:00</tmef>
# <wf>맑음</wf>
# <tmn>24</tmn>
# <tmx>30</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>30</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 00:00</tmef>
# <wf>맑음</wf>
# <tmn>24</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 12:00</tmef>
# <wf>구름많고 소나기</wf>
# <tmn>24</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>60</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 12:00</tmef>
# <wf>흐림</wf>
# <tmn>24</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-01 00:00</tmef>
# <wf>흐림</wf>
# <tmn>24</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-02 00:00</tmef>
# <wf>흐림</wf>
# <tmn>24</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-03 00:00</tmef>
# <wf>흐림</wf>
# <tmn>24</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>전라북도</province>
# <city>정읍</city>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 00:00</tmef>
# <wf>흐리고 비</wf>
# <tmn>23</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>60</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 12:00</tmef>
# <wf>맑음</wf>
# <tmn>23</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 00:00</tmef>
# <wf>맑음</wf>
# <tmn>23</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 00:00</tmef>
# <wf>맑음</wf>
# <tmn>24</tmn>
# <tmx>33</tmx>
# ...
# <province>대구ㆍ경상북도</province>
# <city>대구</city>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>34</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>34</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>34</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>34</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-01 00:00</tmef>
# <wf>흐림</wf>
# <tmn>25</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-02 00:00</tmef>
# <wf>흐림</wf>
# <tmn>25</tmn>
# <tmx>34</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-03 00:00</tmef>
# <wf>흐림</wf>
# <tmn>25</tmn>
# <tmx>34</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>대구ㆍ경상북도</province>
# <city>안동</city>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>22</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>22</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>22</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>22</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>22</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>22</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>34</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>34</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-01 00:00</tmef>
# <wf>흐림</wf>
# <tmn>24</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-02 00:00</tmef>
# <wf>흐림</wf>
# <tmn>24</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-03 00:00</tmef>
# <wf>흐림</wf>
# <tmn>24</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>대구ㆍ경상북도</province>
# <city>포항</city>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>28</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>28</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>27</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>27</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>29</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>29</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>30</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>30</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>25</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>25</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-01 00:00</tmef>
# <wf>흐림</wf>
# <tmn>25</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-02 00:00</tmef>
# <wf>흐림</wf>
# <tmn>26</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-03 00:00</tmef>
# <wf>흐림</wf>
# <tmn>25</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>대구ㆍ경상북도</province>
# <city>경주</city>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>22</tmn>
# <tmx>30</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>22</tmn>
# <tmx>30</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>22</tmn>
# <tmx>29</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>22</tmn>
# <tmx>29</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>30</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>30</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>33</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-01 00:00</tmef>
# <wf>흐림</wf>
# <tmn>23</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-02 00:00</tmef>
# <wf>흐림</wf>
# <tmn>24</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-03 00:00</tmef>
# <wf>흐림</wf>
# <tmn>23</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>대구ㆍ경상북도</province>
# <city>울진</city>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>22</tmn>
# <tmx>27</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>22</tmn>
# <tmx>27</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>22</tmn>
# <tmx>28</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>22</tmn>
# <tmx>28</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>22</tmn>
# <tmx>27</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>22</tmn>
# <tmx>27</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>30</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>30</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>30</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>30</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-01 00:00</tmef>
# <wf>흐림</wf>
# <tmn>24</tmn>
# <tmx>29</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-02 00:00</tmef>
# <wf>흐림</wf>
# <tmn>24</tmn>
# <tmx>29</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-03 00:00</tmef>
# <wf>흐림</wf>
# <tmn>24</tmn>
# <tmx>29</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>대구ㆍ경상북도</province>
# <city>울릉도</city>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>22</tmn>
# <tmx>27</tmx>
# <reliability></reliability>
# <rnst>30</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>22</tmn>
# <tmx>27</tmx>
# <reliability></reliability>
# <rnst>20</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>27</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>27</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>27</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>27</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>28</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>23</tmn>
# <tmx>28</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>29</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>29</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-01 00:00</tmef>
# <wf>흐림</wf>
# <tmn>24</tmn>
# <tmx>28</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-02 00:00</tmef>
# <wf>흐림</wf>
# <tmn>24</tmn>
# <tmx>28</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-03 00:00</tmef>
# <wf>흐림</wf>
# <tmn>24</tmn>
# <tmx>28</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>제주도</province>
# <city>제주</city>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 12:00</tmef>
# <wf>구름많고 비</wf>
# <tmn>24</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>60</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>26</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>26</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 00:00</tmef>
# <wf>흐림</wf>
# <tmn>26</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>26</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>26</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>26</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>26</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 12:00</tmef>
# <wf>흐림</wf>
# <tmn>26</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-01 00:00</tmef>
# <wf>흐림</wf>
# <tmn>26</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-02 00:00</tmef>
# <wf>흐림</wf>
# <tmn>26</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-03 00:00</tmef>
# <wf>흐림</wf>
# <tmn>27</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# </location>
# <location wl_ver="3">
# <province>제주도</province>
# <city>서귀포</city>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>24</tmn>
# <tmx>30</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-27 12:00</tmef>
# <wf>구름많고 비</wf>
# <tmn>24</tmn>
# <tmx>30</tmx>
# <reliability></reliability>
# <rnst>60</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>25</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-28 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>25</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 00:00</tmef>
# <wf>흐림</wf>
# <tmn>26</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-29 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>26</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>26</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-30 12:00</tmef>
# <wf>구름많음</wf>
# <tmn>26</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 00:00</tmef>
# <wf>구름많음</wf>
# <tmn>26</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A02</mode>
# <tmef>2022-07-31 12:00</tmef>
# <wf>흐림</wf>
# <tmn>26</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-01 00:00</tmef>
# <wf>흐림</wf>
# <tmn>26</tmn>
# <tmx>31</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-02 00:00</tmef>
# <wf>흐림</wf>
# <tmn>26</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# <data>
# <mode>A01</mode>
# <tmef>2022-08-03 00:00</tmef>
# <wf>흐림</wf>
# <tmn>26</tmn>
# <tmx>32</tmx>
# <reliability></reliability>
# <rnst>40</rnst>
# </data>
# </location>
# </body>
# </description>
# </item>
# </channel>
# </rss>

# %%
import requests
import re

url="http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp" 
data=requests.get(url).text
soup=BeautifulSoup(data,'html.parser')
wf=soup.find('wf').string
wf=re.sub('[^0-9가-힣()]',' ',wf)
wf
# Out:
# '   강수  27일 수 은 수도권과 강원영서에 비가 오겠습니다           기온  이번 예보기간 아침 기온은 22 25도  낮 기온은 29 34도로 어제 21일  아침최저기온 20 24도  낮최고기온 23 32도 보다 높겠습니다               이번 예보기간 북태평양고기압의 발달 여부와 정체전선의 위치에 따라 강수 구역이 변동될 수 있으며  정체전선의 영향권에서 벗어난 지역에도 대기 불안정으로 소나기가 내릴 가능성이 있겠으니  앞으로 발표되는 기상정보를 참고하기 바랍니다 '

# %% [markdown]
# ## 과제 07/22_2

# %% [markdown]
#  #### 다음과 같이 나타나도록 하시오
#  ```
# '(강수) 23일(토) 오후부터 24일(일) 오전 사이 전국에 비가 오겠고, 강원영동은 24일(일) 오후까지 이어지는 곳이 있겠습니다. 27일(수)은 수도권과 강원영서에 비가 오겠습니다.(기온) 이번 예보기간 아침 기온은 22~26도로 어제(19일, 아침최저기온 20~24도)보다 조금 높겠고, 낮 기온은 28~34도로 어제(낮최고기온 27~34도)와 비슷하겠습니다.(주말전망) 23일(토) 오후부터 24일(일) 오전 사이 전국에 비가 오겠고, 강원영동은 24일(일) 오후까지 이어지는 곳이 있겠습니다.
# ```

# %%
import requests
import re
from bs4 import BeautifulSoup

url="http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp" 
data=requests.get(url).text
soup=BeautifulSoup(data,'html.parser')
wf=soup.find('wf').string
wf
# Out:
# '○ (강수) 30일(토)은 전라권에 소나기가 오는 곳이 있겠습니다. <br />○ (기온) 이번 예보기간 아침 기온은 22~26도, 낮 기온은 29~34도로 오늘(24일, 아침최저기온 22~24도, 낮최고기온 25~32도)보다 높겠습니다.<br /><br />* 우리나라 주변 기압계에 따라 소나기가 내리는 구역이 변동될 수 있으며, 돌풍과 함께 천둥.번개를 동반한 강한 소나기가 내리는 곳이 있겠으니 안전에 유의하기 바라며, 앞으로 발표되는 기상정보를 참고하기 바랍니다.'

# %%
#
wf_sub=re.sub('[^가-힣0-9(),~. ]','',wf)
re.sub('  ','',wf_sub)
# Out:
# ' (강수) 30일(토)은 전라권에 소나기가 오는 곳이 있겠습니다. (기온) 이번 예보기간 아침 기온은 22~26도, 낮 기온은 29~34도로 오늘(24일, 아침최저기온 22~24도, 낮최고기온 25~32도)보다 높겠습니다. 우리나라 주변 기압계에 따라 소나기가 내리는 구역이 변동될 수 있으며, 돌풍과 함께 천둥.번개를 동반한 강한 소나기가 내리는 곳이 있겠으니 안전에 유의하기 바라며, 앞으로 발표되는 기상정보를 참고하기 바랍니다.'

# %%
#
wf_sub=re.sub(r'[*<>br○/]','',wf)
re.sub('  ','',wf_sub)
# Out:
# ' (강수) 30일(토)은 전라권에 소나기가 오는 곳이 있겠습니다. (기온) 이번 예보기간 아침 기온은 22~26도, 낮 기온은 29~34도로 오늘(24일, 아침최저기온 22~24도, 낮최고기온 25~32도)보다 높겠습니다. 우리나라 주변 기압계에 따라 소나기가 내리는 구역이 변동될 수 있으며, 돌풍과 함께 천둥.번개를 동반한 강한 소나기가 내리는 곳이 있겠으니 안전에 유의하기 바라며, 앞으로 발표되는 기상정보를 참고하기 바랍니다.'

# %% [markdown]
# ---

# %%
texts=soup.find_all('wf')
for i in texts:
    t=i.text
    t=re.sub('[^0-9가-힣]',' ',t)
    print(t)
# Out:
#    강수  27일 수 은 수도권과 강원영서에 비가 오겠습니다           기온  이번 예보기간 아침 기온은 22 25도  낮 기온은 29 34도로 어제 21일  아침최저기온 20 24도  낮최고기온 23 32도 보다 높겠습니다               이번 예보기간 북태평양고기압의 발달 여부와 정체전선의 위치에 따라 강수 구역이 변동될 수 있으며  정체전선의 영향권에서 벗어난 지역에도 대기 불안정으로 소나기가 내릴 가능성이 있겠으니  앞으로 발표되는 기상정보를 참고하기 바랍니다
# 구름많음
# 맑음
# 구름많음
# 맑음
# 구름많음
# 구름많고 비
# 구름많음
# 구름많음
# 맑음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 맑음
# 구름많음
# 맑음
# 구름많음
# 구름많고 비
# 구름많음
# 구름많음
# 맑음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 맑음
# 구름많음
# 맑음
# 구름많음
# 구름많고 비
# 구름많음
# 구름많음
# 맑음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 맑음
# 구름많음
# 맑음
# 구름많음
# 구름많고 비
# 구름많음
# 구름많음
# 맑음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 맑음
# 구름많음
# 맑음
# 구름많음
# 구름많고 비
# 구름많음
# 구름많음
# 맑음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 맑음
# 구름많음
# 맑음
# 구름많음
# 구름많고 비
# 구름많음
# 구름많음
# 맑음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 맑음
# 구름많음
# 구름많음
# 구름많음
# 구름많고 비
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 흐림
# 흐림
# 구름많음
# 맑음
# 구름많음
# 구름많음
# 구름많음
# 구름많고 비
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 흐림
# 흐림
# 구름많음
# 구름많음
# 흐림
# 흐림
# 구름많음
# 흐림
# 흐림
# 흐림
# 구름많음
# 맑음
# 맑음
# 맑음
# 흐림
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 맑음
# 구름많음
# 구름많음
# 맑음
# 구름많음
# 구름많음
# 맑음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 맑음
# 구름많음
# 구름많음
# 맑음
# 구름많음
# 구름많음
# 맑음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 맑음
# 구름많음
# 구름많음
# 맑음
# 구름많음
# 구름많음
# 맑음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 맑음
# 구름많음
# 맑음
# 맑음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 맑음
# 구름많음
# 맑음
# 맑음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 맑음
# 구름많음
# 맑음
# 맑음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 흐림
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 맑음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 흐림
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 맑음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 흐림
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 맑음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 흐림
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 맑음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 흐림
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 맑음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 흐림
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 맑음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 흐림
# 구름많음
# 흐림
# 흐림
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 흐림
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 흐림
# 구름많음
# 흐림
# 흐림
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 흐림
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 흐림
# 구름많음
# 흐림
# 흐림
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 흐림
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 흐림
# 구름많음
# 흐림
# 흐림
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 흐림
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 흐림
# 구름많음
# 흐림
# 흐림
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 흐림
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 흐림
# 구름많음
# 흐림
# 흐림
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 흐림
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음
# 구름많음

# %%
#네이버 url 및 find_all을 활용해서 정보 추출

req=requests.get('http://naver.com')

html=req.text

soup=BeautifulSoup(html,'html.parser')

result=soup.find_all('span',class_='blind')  
            #span 태그의 class="blind" 일 때, class가 예약어라 '_' 붙여줘야함
result[:5]
# Out:
# [<span class="blind">네이버</span>,
#  <span class="blind">쥬니어네이버</span>,
#  <span class="blind">해피빈</span>,
#  <span class="blind">검색</span>,
#  <span class="blind">한글 입력기</span>]

# %%
result2=soup.find_all('span', class_='fix')
result2
# Out:
# [<span class="fix"><span class="common_ico_kwd"><i class="imsc ico_search"></i></span><span>@txt@</span></span>,
#  <span class="fix"><span class="common_ico_kwd"><i class="imsc ico_search"></i></span>@txt@</span>,
#  <span class="fix"><span class="common_ico_kwd"><i class="imsc ico_search"></i></span>@txt@</span>,
#  <span class="fix"><span class="common_ico_kwd"><i class="imsc ico_search"></i></span>@query@ <span class="context">@intend@</span></span>]

# %%
result3=soup.find_all('span',attrs={'class':'fix'})
result3
# Out:
# [<span class="fix"><span class="common_ico_kwd"><i class="imsc ico_search"></i></span><span>@txt@</span></span>,
#  <span class="fix"><span class="common_ico_kwd"><i class="imsc ico_search"></i></span>@txt@</span>,
#  <span class="fix"><span class="common_ico_kwd"><i class="imsc ico_search"></i></span>@txt@</span>,
#  <span class="fix"><span class="common_ico_kwd"><i class="imsc ico_search"></i></span>@query@ <span class="context">@intend@</span></span>]

# %%
import re

req=requests.get('http://naver.com')
soup=BeautifulSoup(html,'html.parser')

soup.find_all(string='네이버')
# Out:
# ['네이버']

# %%
soup.find_all(string=re.compile('네이버'))
# Out:
# ['네이버',
#  '네이버를 시작페이지로',
#  '쥬니어네이버',
#  '언론사가 직접 편집한 뉴스들을 네이버 홈에서 바로 보실 수 있습니다.',
#  '계절이 바뀔때마다 고민하게 되는 인테리어. 크기가 크고 가격대가 있는 가구보다는 몇 가지 소품으로 여름을 위한 인테리어 해보기. #네이버리빙 #내돈내산 #리빙잇템 여름을 위한 인테리어 소품들 몇 가지. 1 라탄 소품/ 소가구 작은 라탄 바구니와 라탄 스툴이에요. 작지만 인테리어 효과는 크죠. 시원한 느낌도 들구요. 스툴은 협탁처럼 사용할 수 있어서 침대 옆',
#  "( 이 컨텐츠는 꿀하우스 네이버카페, 인스타그램 등 회원분들의 실제 인테리어 공간 제보로 만들어집니다. ) 인스타그램 : 꿀하우스 @ggulhouse따뜻하고 포근하게 따뜻하고 포근하게 제가 좋아하는 노란색으로 가득 채운 공간입니다. 오늘두 smile! 'ᴗ' 무드등 : 젊은이마켓 감성네온 무드등 / 전신거울 : 트리빔하우스 300 확장형 / ",
#  '■ 이벤트 진행 기간 기간 : 2022. 07.01 - 2022.07.31 발표 : 2022. 08.16 ■ 혜택 7월의 공간 100P!CK 우리 집 여러 공간이 선정될 수 있습니다 선정된 공간마다 홈스타일링 지원금 네이버페이 3만 포인트 최우수 공간에는 네이버페이 20만 포인트 - 메인 노출 여부와 관계 없이 공간100P!CK 에 선정될 수 있습니다. -',
#  '네이버 리빙과 함께하는 메인 도전 리빙&레시피와 이웃 추가하고 블로그 혹은 포스팅 url을 비공개 댓글로 남겨주세요. 말머리에 [살림] [취미] 를 붙여 주시고, 포스팅의 간략한 내용 설명도 부탁드릴게요. 살림 추천 키워드 #여름살림 #살림노하우 #살림꿀팁 #창틀청소법 #세탁법 #베이킹소다활용법 #주방정리 #수납노하우 #팬트리정리 #천연세제만들기 #친환경살',
#  '이건 정말 잘 샀는데! 자랑하고 싶은 #내돈내산잇템 을 소개해주세요 잇템은 3개 이상 / 대가성 리뷰 불가 #자랑하고싶은살림아이템5 #내가사고내가쓴후기 #내가산후기 #살림리뷰 #살림잇템 #살림템 #주방잇템 #조리도구 #최애프라이팬 #그릇수집 #그릇장정리 #빈티지수집 #티도구 #커트러리 #키친패브릭 #인테리어소품 #집꾸미기아이템 & more 참여 방법 네이버',
#  '네이버 개발자 센터',
#  '네이버 D2',
#  '네이버 D2SF',
#  '네이버 랩스',
#  '네이버 정책 및 약관',
#  '네이버 정책']

# %% [markdown]
# #### select_one(), select()
# - CSS 선택자를 활용하여 원하는 정보를 가져옴(태그를 검색하는 find, find_all과 비슷함)
# - class는 ".", id는 "#"로 표시

# %%
from bs4 import BeautifulSoup
from urllib import request


url = "https://finance.naver.com/marketindex/"

res=request.urlopen(url)
soup=BeautifulSoup(res,'html.parser')
price=soup.select_one('#exchangeList > li.on > a.head.usd > div > span.value').string
   #copy selector 기능을 사용해서 복붙
print('usd/krw= ',price)
# Out:
# usd/krw=  1,308.80

# %%
html_doc = """<html><head><title>The Dormouse's story</title></head>
<body>
<div></div>
<p class="title"><b>The Dormouse's story</b></p>

<p class="story">Once upon a time there were three little sisters; and their names were
<a href="http://example.com/elsie" class="sister" id="link1">Elsie</a>,
<a href="http://example.com/lacie" class="sister" id="link2">Lacie</a> and
<a href="http://example.com/tillie" class="sister" id="link3">Tillie</a>;
and they lived at the bottom of a well.</p>

<p class="story">...</p>
"""

# %%
# !pip install lxml
# Out:
# Requirement already satisfied: lxml in c:\users\admin\anaconda3\envs\cakd7\lib\site-packages (4.9.1)

# %%
#첫번째 파싱 방법
bs=BeautifulSoup(html_doc, 'html.parser')
print(bs.prettify())
# Out:
# <html>
#  <head>
#   <title>
#    The Dormouse's story
#   </title>
#  </head>
#  <body>
#   <div>
#   </div>
#   <p class="title">
#    <b>
#     The Dormouse's story
#    </b>
#   </p>
#   <p class="story">
#    Once upon a time there were three little sisters; and their names were
#    <a class="sister" href="http://example.com/elsie" id="link1">
#     Elsie
#    </a>
#    ,
#    <a class="sister" href="http://example.com/lacie" id="link2">
#     Lacie
#    </a>
#    and
#    <a class="sister" href="http://example.com/tillie" id="link3">
#     Tillie
#    </a>
#    ;
# and they lived at the bottom of a well.
#   </p>
#   <p class="story">
#    ...
#   </p>
#  </body>
# </html>

# %%
#두번째 파싱 방법
bs2=BeautifulSoup(html_doc, 'lxml')
bs2
# Out:
# <html><head><title>The Dormouse's story</title></head>
# <body>
# <div></div>
# <p class="title"><b>The Dormouse's story</b></p>
# <p class="story">Once upon a time there were three little sisters; and their names were
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
# <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
# and they lived at the bottom of a well.</p>
# <p class="story">...</p>
# </body></html>

# %%
bs.title
# Out:
# <title>The Dormouse's story</title>

# %%
bs.title.name
# Out:
# 'title'

# %%
bs.title.parent
# Out:
# <head><title>The Dormouse's story</title></head>

# %%
bs.title.parent.name
# Out:
# 'head'

# %%
bs.p
# Out:
# <p class="title"><b>The Dormouse's story</b></p>

# %%
bs.a
# Out:
# <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>

# %%
bs.find_all('a')
# Out:
# [<a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>]

# %%
bs.find(id='link3')
# Out:
# <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>

# %%
bs.find('a',calss_='sister')

# %%
bs.a['class']
# Out:
# ['sister']

# %%
#a태그 내에서 href 링크들만 뽑아내기

for link in bs.find_all('a'):
    print(link.get('href'))
# Out:
# http://example.com/elsie
# http://example.com/lacie
# http://example.com/tillie

# %%
bs.find_all()
# Out:
# [<html><head><title>The Dormouse's story</title></head>
#  <body>
#  <div></div>
#  <p class="title"><b>The Dormouse's story</b></p>
#  <p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>
#  <p class="story">...</p>
#  </body></html>,
#  <head><title>The Dormouse's story</title></head>,
#  <title>The Dormouse's story</title>,
#  <body>
#  <div></div>
#  <p class="title"><b>The Dormouse's story</b></p>
#  <p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>
#  <p class="story">...</p>
#  </body>,
#  <div></div>,
#  <p class="title"><b>The Dormouse's story</b></p>,
#  <b>The Dormouse's story</b>,
#  <p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>,
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a>,
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>,
#  <p class="story">...</p>]

# %%
#p태그 내 a태그가 있어서 a태그가 나옴

bs.find_all('p')
# Out:
# [<p class="title"><b>The Dormouse's story</b></p>,
#  <p class="story">Once upon a time there were three little sisters; and their names were
#  <a class="sister" href="http://example.com/elsie" id="link1">Elsie</a>,
#  <a class="sister" href="http://example.com/lacie" id="link2">Lacie</a> and
#  <a class="sister" href="http://example.com/tillie" id="link3">Tillie</a>;
#  and they lived at the bottom of a well.</p>,
#  <p class="story">...</p>]

# %%
len(bs.find_all('p'))  #p태그는 3개인 것을 알 수 있음
# Out:
# 3

# %% [markdown]
# #### string vs. get_text()
# - get_text()를 이용하면 한방에 현재 HTML 문서의 모든 텍스트를 추출할 수 있습니다. 조금 더 정확히 표현하면 get_text() 메서드는 현재 태그를 포함하여 모든 하위 태그를 제거하고 유니코드 텍스트만 들어있는 문자열을 반환
# - string의 경우 문자열이 없으면 None을 출력하지만, get_text()의 경우 유니코드 형식으로 텍스트까지 문자열로 반환하기 때문에  아무 정보도 출력되지 않는다.
# - string 속성은 태그(tag) 내 문자열을 반환. get_text()를 사용하더라도 정확하게 문자열을 추출하기 위해서는 항상 마지막 태그에 메서드를 사용

# %%
print(bs.get_text())    #바디 전체의 텍스트 전체를 뽑아줌
# Out:
# The Dormouse's story
#
#
# The Dormouse's story
# Once upon a time there were three little sisters; and their names were
# Elsie,
# Lacie and
# Tillie;
# and they lived at the bottom of a well.
# ...

# %%
print(bs.body.get_text())
print(bs.find('body').get_text())
# Out:
# The Dormouse's story
# Once upon a time there were three little sisters; and their names were
# Elsie,
# Lacie and
# Tillie;
# and they lived at the bottom of a well.
# ...
#
#
#
# The Dormouse's story
# Once upon a time there were three little sisters; and their names were
# Elsie,
# Lacie and
# Tillie;
# and they lived at the bottom of a well.
# ...

# %%
print(bs.string)      #바디 전체의 텍스트를 뽑아내지 못함
# Out:
# None

# %%
print(bs.body.string)
print(bs.find('body').string)
# Out:
# None
# None

# %%
print(bs.find('div').get_text())   #div안에 아무 내용이 없으면 아무것도 출력이 안됨

# %%
print(bs.find('div').string)     #div 안에 아무 내용이 없으면 None값을 출력함
# Out:
# None

# %%
print(bs.a.string)
# Out:
# Elsie

# %%
li=bs.find_all('p')

for i in li:
    print(i.string)      #a태그 내 text들이 None처리됨
# Out:
# The Dormouse's story
# None
# ...

# %%
for i in li:
    print(i.get_text())    #a태그 내 text들이 출력됨
# Out:
# The Dormouse's story
# Once upon a time there were three little sisters; and their names were
# Elsie,
# Lacie and
# Tillie;
# and they lived at the bottom of a well.
# ...

# %%
#네이버 정치뉴스 크롤링을 lxml 파싱으로 해보기

import urllib.request as rq

url='https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=100'
html=rq.urlopen(url)
bs= BeautifulSoup(html,'lxml')      #
text=bs.p
text=text.get_text()
text
# Out:
# 'AiRS추천으로 구성된 뉴스를 제공합니다.'

# %%
text2=bs.find_all('a')
for t in text2:
    print(t.get_text(),end='')
# Out:
# 메인 메뉴로 바로가기본문으로 바로가기검색NAVER뉴스TV연예스포츠날씨프리미엄언론사별 정치 선택됨경제 사회 생활/문화 IT/과학 세계 랭킹 신문보기 오피니언 TV 팩트체크 전체 언론사뉴스스탠드라이브러리전체 언론사뉴스스탠드라이브러리정치대통령실 국회/정당 북한 행정 국방/외교 정치일반 안내헤드라인 뉴스
#
# 법조계 "민주유공자법, 기준 불분명·과도한 혜택…위헌소송 남발할 것”신문브리핑 3 "與 "野의 민주유공자法, 운동권 신분 세습법"" 외 주요기사우원식 "민주화유공자법, 박종철·이한열를 유공자로 인정해달라는 것"우원식 “모든 유공자법에 교육·취업 혜택...민주유공자법만 뺄 순 없어”19개의 관련뉴스 더보기
#
#  "경찰국 신설 논란, 행안부·경찰청서 필요한 조치할 것"[尹 출근길 한마디]尹대통령, '警亂' 조짐에 "행안부·경찰청이 필요한 조치 잘 할 것"尹, 경찰 반발에 “행안부·경찰청에서 조치 잘 할 것”윤 대통령, 경찰 반발에 "행안부 · 경찰청서 필요 조치"46개의 관련뉴스 더보기
#
# 대통령실, 尹 지지율 하락에 "새 정부, 손발 맞추는 데 시간 필요"대통령실 "경찰국 신설이 치안본부? 프레임 공격"강승규 “경찰국 신설 ‘전두환식’ 비판은 프레임 공격”강승규 “‘치안본부’ 비판은 프레임…경찰국은 권한 견제용”9개의 관련뉴스 더보기
#
# 우상호 "비서실장 첫 등판이 경찰 장악‥대통령 지시로 해석"민주당 "비서실장 첫 등판이 '경찰 장악' 관련…대통령 지시일 것"우상호 "경찰 장악에 비서실장 등판...尹 지시로 해석"여야 전면전 치닫는 경찰국 갈등…정국 최대 쟁점 급부상30개의 관련뉴스 더보기권성동 "대우조선 경영진, 방만 경영 책임지고 물러나야"
#
# 與, `파업·손실` 대우조선 경영진도 책임론…"`文 동생 친구 알박기` 박두선 사장 물러나라"10개의 관련뉴스 더보기
#
# 추미애 "류 총경 대기발령, 속 좁은 인사보복 철회해야"
#
# 추미애, 류삼영 두둔하며 尹정권 저격…“정치경찰화 시도, ‘국민 저항’ 직면할 것”9개의 관련뉴스 더보기
#
# 하태경 “경찰국 신설, 정부가 너무 거칠게 다뤄”
#
# 與 내부서도 경찰국 속도조절론…하태경 "너무 거칠어"8개의 관련뉴스 더보기
#
# "尹 국정지지 하락세 주춤…긍정 33.3% 부정 63.4%"
#
# "尹대통령 지지율 하락세 멈춰…긍정 33.3% 부정 63.4%"39개의 관련뉴스 더보기
#
# 웨버 대령 자택에 ‘한국전 참전용사의 집’ 명패, 보훈처장이 직접 단다
#
# 보훈처장, 美알링턴 참배…웨버 대령 등 참전자 묘역 방문(종합)22개의 관련뉴스 더보기
#
# 軍, '27일 전후 北핵실험' 가능성에 "시기특정 적절치 않아"
#
# 軍, '27일 전후 北핵실험' 가능성에 "시기특정 적절치 않아"7개의 관련뉴스 더보기
#
# 尹 “같은 작가네”…용산 청사에 장애인 미술 작품 15점 걸렸다
#
# 尹 대통령 "그 작가네?" 출근길, 미술계 '우영우' 장애인 작품 걸었다23개의 관련뉴스 더보기
#
# 권성동 "대통령 세종 제2집무실 공약 파기? 가짜뉴스…`임시집무실` 건너뛰자 했더니"
#
# 행정수도완성시민연대 "권성동 세종집무실 공약 이행은 궤변"5개의 관련뉴스 더보기
#
# "낙타 바늘귀 통과할 일이어도"... 이탄희, 이동학 지지선언
#
# 이탄희, 이동학 공개지지 선언…"정치개혁 진정성 믿어"4개의 관련뉴스 더보기
#
# 尹 지지율 보합세로 전환…5주째 '데드크로스'[KSOI]
#
# KSOI "尹대통령 지지율 0.2%p 상승해 32.2%…긍·부정 격차는 더 벌어져"9개의 관련뉴스 더보기김병주 "북송 어민, 南 귀순 아니라 밀항 의도한 듯"
#
# ‘북송 어민 살해’ 오락가락 여당, 우왕좌왕 통일부…정치권 “자료 공개만이 정답”11개의 관련뉴스 더보기
#
# 오늘 윤 정부 첫 대정부질문…정치·외교·통일·안보 분야
#
# '방패' 대신 '칼' 잡은 與, 尹정부 첫 대정부질문서 文정부 공격 나선다54개의 관련뉴스 더보기헤드라인 더보기
# 연재보기
# 군사대로
# [군사대로]'靑습격' 김신조·'KAL폭파' 김현희 북송 안한 이유는?[군사대로] 故 아베의 꿈 '전쟁하는 자위대', 한반도 영향은?[군사대로]나토, 한미일 안보협력 미래로 北 비핵화 모범될까[군사대로]5·24조치로 시작된 독자 대북제재…효과 얼마나 있었나
#
# 이상민 “경찰서장회의, 12·12 쿠데타 준하는 상황”동아일보
#
# 윤 대통령 지지율 20%대로 경고한 20대…9.2%p 급락 …한겨레
#
# [판결남] ‘기말고사 답안지’ 들고 사라진 선생님…중3 학 …KBS
#
# 고우림 측 "김연아와 3년 열애...10월 결혼" (공식입 …YTN
#
# 김연아 10월 결혼한다…신랑은 5살 연하 성악가 고우림중앙일보
#
# ‘피겨 여왕’ 김연아, 10월의 신부 된다…예비신랑은 누구 …조선일보
#
# 동영상기사
# 철장에선 나왔지만‥"8천억 배상하라니‥"MBC
#
# ‘피겨여왕’ 김연아, 5살 연하 고우림과 10월 결혼국민일보
#
# '피겨여왕' 김연아, 5세 연하 고우림과 10월 결혼(종합 …뉴시스
#
# 이상민 장관 "총경 집단행동, 지역 치안 책임자들이 이탈해 …매일신문
#
# "무증상이면 5만원 내세요"…코로나 검사 회피 늘어난다서울경제
#
# ‘피겨여왕’ 김연아, 5세 연하 성악가 고우림과 10월 결 …매일경제
#
# “수지→아기 얼굴” 귀엽다 난리더니, 순식간에 망가진 이곳헤럴드경제
#
# '피겨여왕' 김연아, 포레스텔라 고우림과 10월 결혼JTBC
#
# 피겨여왕 김연아, 성악가 고우림과 ‘10월 결혼’아시아경제
#
# "300만원 넘게 줬는데…" 부모님 집 '2in1 에어컨' …한국경제
#
# [속보]이상민 "무장 가능한 조직이 상부지시 위반 대단히  …이데일리
#
# 민주당 지지율, 한 주 새 9% 상승…국민의힘에 역전[KS …조선비즈
#
# “깨끗하고 안전해”…강물 원샷한 인도 총리, 결국 병원行서울신문
#
# 우영우 실제 모델은 자폐 진단 받은 세계적 동물학자한국일보
#
# 동영상기사
# 피겨퀸 김연아, 10월 결혼…성악가 고우림과 3년 교제 �
#
# 이재용 “목숨 걸고”…삼성전자, 美 ‘260조원 투자계획’ …이코노미스트
#
# 尹대통령 지지율 추락 7주 만에 '멈췄다'…여론조사 모두  …시사저널
#
# "연 8% 적금 나왔다" 카카오뱅크, 출범 5주년 맞이 ' …머니S
#
# 코로나19 인간 활동이 잠시 멈춘 사이 야생동물 세계도 웃 …동아사이언스
#
# [나홀로 세계여행] 몰디브는 비싸다? 선입견을 깬 히마푸시월간 산
#
# 경계에 선 청춘의 험난한 취업 여정주간경향
#
# 박범계 "경찰국 사태, 2만 명이 들고일어나면 징계 못해"조세일보
#
# 일본 여성 자폐인 "'우영우', 살아도 된다는 용기 준 작 …여성신문
#
# 몇 년씩 감금, 아이와 격리…이렇게까지 해야 하나?일다
#
# 또 일가족 극단 선택..'도박빚에 생활고' 유서 발견kbc광주방송
#
# 동영상기사
# 전북도내 코로나19 연일 '2천 명대'.. 확산세 계속전주MBC
#
# WHO, 원숭이두창 '비상사태' 선포..코로나19 이후 2 …JIBS
#
# "이 길로 학교 다니라고?" 대전 도마·변동지구 입주예정민 …대전일보
#
# 밤새 대구 수성구 일대 정전···무더위 속 300여 가구  …대구MBC
#
# 동영상기사
# [영상] 무더위 잊게 해 줄 제천의 2가지 비경CJB청주방송
#
# 끝 모르던 대통령 지지율 하락세 둔화..."사적채용 논란  …국제신문
#
# 동영상기사
# [영상] 무더위 잊게 해 줄 제천의 2가지 비경CJB청주방송
#
# 끝 모르던 대통령 지지율 하락세 둔화..."사적채용 논란  …국제신문
#
# [속보] 이상민 "경찰서장 모임 위법성 엄정조사" 총경회의 …강원도민일보
#
# [양산] 젊은층에게 사랑받고 싶은데…“지드래곤이 써주면 안 …농민신문
#
# 에어컨 없이 여름밤 보내는 몇 가지 방법에 대해레이디경향권성동 "경찰 집단행동, 배부른 밥투정" 맹비난 [경찰국 설치 논란]권성동 “반드시 책임 뒤따를 것” vs 우상호 “경찰장악 맞서 싸우겠다”[뉴스1 PICK]윤 대통령이 가리키는 이 그림…발달장애 예술가 작품[포착] ‘하늘에서 화산재가 비처럼’…日 화산 분화, 최고 경보 발령(영상)머스크, 구글 공동창업자 아내와 ‘잘못된 만남’TSMC 보란듯…삼성 세계 첫 ‘3나노’ 파운드리 출하포스코그룹, 비상경영체제 돌입토지 매매도 얼어붙었다…상반기 거래량 전년대비 27% 감소“IT로 사회 지속가능성 기여”… 카카오, 국내 첫 ‘기술윤리위원회’ 설치LGU+ 5G·LTE 프리미어 레귤러 가입시 `티빙` 무료이상민 "경찰은 무장가능 조직…쿠데타가 이렇게 시작"(종합)이상민?“경찰 집단행동 쿠데타 준해, 대단히 부적절”…권성동 “경찰, 배부른 밥 투정”(종합)윤희근 경찰청장 후보자 “총경회의 참석자, 감찰 후 상응 조치할 것”드라마가 현실로?… 우영우 팽나무 천연기념물 조사나선 문화재청김연아 10월 결혼한다…신랑은 5살 연하 성악가 고우림       서비스 안내  고침 기사 모음  정정·반론·추후 보도 기사 모음  불공정 선거 보도 기사 모음 서비스 안내더보기이젠 페이지맨위로언론사 목록열기로딩 중분야별 목록열기로딩 중이용약관서비스 안내기사배열 원칙 책임자 : 유봉석개인정보처리방침책임의 한계와 법적고지뉴스 고객센터NAVERNAVER Corp.

# %%
item=bs.find('div').find('a').text
item
# Out:
# '메인 메뉴로 바로가기'

# %%
items=bs.find('div').find_all('a')
items
# Out:
# [<a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>,
#  <a href="#main_content" tabindex="2"><span>본문으로 바로가기</span></a>,
#  <a class="tool_button _search_content_toggle_btn nclicks(gnb.sch)" href="javascript:;"><span class="icon_search">검색</span></a>,
#  <a class="h_logo nclicks(gnb.naver)" href="https://www.naver.com/"><span class="blind">NAVER</span></a>,
#  <a class="h_news nclicks(gnb.news)" href="/"><span class="blind">뉴스</span></a>,
#  <a class="entertain nclicks(gnb.enter)" href="https://entertain.naver.com/home">TV연예</a>,
#  <a class="sports nclicks(gnb.sports)" href="https://sports.news.naver.com">스포츠</a>,
#  <a class="weather nclicks(gnb.weather)" href="https://weather.naver.com">날씨</a>,
#  <a class="premium nclicks(gnb.premium)" href="https://contents.premium.naver.com">프리미엄</a>,
#  <a class="nclicks(lnb.pcmedia)" href="/"><span class="tx">언론사별</span> </a>,
#  <a class="nclicks(lnb.pol)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100"><span class="tx">정치</span> <span class="blind">선택됨</span></a>,
#  <a class="nclicks(lnb.eco)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101"><span class="tx">경제</span> </a>,
#  <a class="nclicks(lnb.soc)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102"><span class="tx">사회</span> </a>,
#  <a class="nclicks(lnb.lif)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=103"><span class="tx">생활/문화</span> </a>,
#  <a class="nclicks(lnb.sci)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=105"><span class="tx">IT/과학</span> </a>,
#  <a class="nclicks(lnb.wor)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=104"><span class="tx">세계</span> </a>,
#  <a class="nclicks(lnb.rankin)" href="/main/ranking/popularDay.naver?mid=etc&amp;sid1=111"><span class="tx">랭킹</span> </a>,
#  <a class="nclicks(lnb.paper)" href="/newspaper/home"><span class="tx">신문보기</span> </a>,
#  <a class="nclicks(lnb.opi)" href="/main/opinion/home.naver"><span class="tx">오피니언</span> </a>,
#  <a class="nclicks(lnb.tv)" href="/main/tv/index.naver?mid=tvh"><span class="tx">TV</span> </a>,
#  <a class="nclicks(lnb.fact)" href="/main/factcheck/main.naver"><span class="tx">팩트체크</span> </a>,
#  <a class="lnb_extra_menu_link nclicks(nct.right3)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a>,
#  <a class="lnb_extra_menu_link nclicks(STA.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a>,
#  <a class="lnb_extra_menu_link nclicks(nct.right4)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a>,
#  <a class="nclicks(slb.allmedia)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a>,
#  <a class="nclicks(slb.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a>,
#  <a class="nclicks(slb.library)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a>,
#  <a class="nclicks(lmn_pol.home)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100">정치</a>,
#  <a class="snb_s11 nclicks(lmn_pol.mnl,,1)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=264">대통령실 </a>,
#  <a class="snb_s12 nclicks(lmn_pol.mnl,,2)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=265">국회/정당 </a>,
#  <a class="snb_s13 nclicks(lmn_pol.mnl,,3)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=268">북한 </a>,
#  <a class="snb_s14 nclicks(lmn_pol.mnl,,4)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=266">행정 </a>,
#  <a class="snb_s15 nclicks(lmn_pol.mnl,,5)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=267">국방/외교 </a>,
#  <a class="snb_s16 nclicks(lmn_pol.mnl,,6)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=100&amp;sid2=269">정치일반 </a>,
#  <a class="nclicks(lmn_pol.pmb,,1)" href="https://contents.premium.naver.com/"><img alt="네이버 프리미엄콘텐츠" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/05/28/233112515_DA%2540PC%25B4%25BA%25BD%25BA%25C1%25C2%25C3%25F8.png" width="71"/></a>,
#  <a class="nclicks(lmn_pol.pmb,,1)" href="https://media.naver.com/channel/setting?back=main"><img alt="언론사 구독하기" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/01/14/142956425_144518244_%2525B8%2525F0%2525B9%2525D9%2525C0%2525CF%2525B8%2525DE%2525C0%2525CE.png" width="71"/></a>,
#  <a class="cluster_title_icon_link _news_cluster_layer_btn" href="#biF7L"><i class="cluster_title_icon">안내</i>헤드라인 뉴스</a>,
#  <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/119/0002623717?sid=100">
#  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/119/2022/07/24/2623717.jpg?type=ofullfill132_90" width="132"/>
#  </a>,
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/119/0002623717?sid=100">법조계 "민주유공자법, 기준 불분명·과도한 혜택…위헌소송 남발할 것”</a>,
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/057/0001679080?sid=100">신문브리핑 3 "與 "野의 민주유공자法, 운동권 신분 세습법"" 외 주요기사</a>,
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/277/0005122650?sid=100">우원식 "민주화유공자법, 박종철·이한열를 유공자로 인정해달라는 것"</a>,
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/023/0003705905?sid=100">우원식 “모든 유공자법에 교육·취업 혜택...민주유공자법만 뺄 순 없어”</a>,
#  <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202207220930_00000006&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=119&amp;aid=0002623717"><span class="cluster_foot_more_icon_num">19</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>,
#  <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/119/0002623854?sid=100">
#  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/119/2022/07/25/2623854.jpg?type=ofullfill132_90" width="132"/>
#  </a>,
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/119/0002623854?sid=100"> "경찰국 신설 논란, 행안부·경찰청서 필요한 조치할 것"[尹 출근길 한마디]</a>,
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/448/0000367178?sid=100">尹대통령, '警亂' 조짐에 "행안부·경찰청이 필요한 조치 잘 할 것"</a>,
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/011/0004079759?sid=100">尹, 경찰 반발에 “행안부·경찰청에서 조치 잘 할 것”</a>,
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/055/0000988172?sid=100">윤 대통령, 경찰 반발에 "행안부 · 경찰청서 필요 조치"</a>,
#  <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202207250910_00000027&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=119&amp;aid=0002623854"><span class="cluster_foot_more_icon_num">46</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>,
#  <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/629/0000162777?sid=100">
#  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/629/2022/07/25/162777.jpg?type=ofullfill132_90" width="132"/>
#  </a>,
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/629/0000162777?sid=100">대통령실, 尹 지지율 하락에 "새 정부, 손발 맞추는 데 시간 필요"</a>,
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/018/0005276308?sid=100">대통령실 "경찰국 신설이 치안본부? 프레임 공격"</a>,
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/025/0003211982?sid=100">강승규 “경찰국 신설 ‘전두환식’ 비판은 프레임 공격”</a>,
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/056/0011308113?sid=100">강승규 “‘치안본부’ 비판은 프레임…경찰국은 권한 견제용”</a>,
#  <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202207250920_00000007&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=629&amp;aid=0000162777"><span class="cluster_foot_more_icon_num">9</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>,
#  <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/214/0001211232?sid=100">
#  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/214/2022/07/25/1211232.jpg?type=ofullfill132_90" width="132"/>
#  </a>,
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/214/0001211232?sid=100">우상호 "비서실장 첫 등판이 경찰 장악‥대통령 지시로 해석"</a>,
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/008/0004774779?sid=100">민주당 "비서실장 첫 등판이 '경찰 장악' 관련…대통령 지시일 것"</a>,
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/052/0001768207?sid=100">우상호 "경찰 장악에 비서실장 등판...尹 지시로 해석"</a>,
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/082/0001166459?sid=100">여야 전면전 치닫는 경찰국 갈등…정국 최대 쟁점 급부상</a>,
#  <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202207251010_00000002&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=214&amp;aid=0001211232"><span class="cluster_foot_more_icon_num">30</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>,
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/052/0001768164?sid=100">권성동 "대우조선 경영진, 방만 경영 책임지고 물러나야"</a>,
#  <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/029/0002745589?sid=100">
#  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/029/2022/07/25/2745589.jpg?type=ofullfill132_90" width="132"/>
#  </a>,
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/029/0002745589?sid=100">與, `파업·손실` 대우조선 경영진도 책임론…"`文 동생 친구 알박기` 박두선 사장 물러나라"</a>,
#  <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202207250940_00000061&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=052&amp;aid=0001768164"><span class="cluster_foot_more_icon_num">10</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>,
#  <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/082/0001166462?sid=100">
#  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/082/2022/07/25/1166462.jpg?type=ofullfill132_90" width="132"/>
#  </a>,
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/082/0001166462?sid=100">추미애 "류 총경 대기발령, 속 좁은 인사보복 철회해야"</a>,
#  <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/029/0002745596?sid=100">
#  <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/029/2022/07/25/2745596.jpg?type=ofullfill132_90" width="132"/>
#  </a>,
#  <a class="cluster_text_headline nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/029/0002745596?sid=100">추미애, 류삼영 두둔하며 尹정권 저격…“정치경찰화 시도, ‘국민 저항’ 직면할 것”</a>,
#  <a class="cluster_foot_more nclicks(cls_pol.clstitle)" href="/main/clusterArticles.naver?id=c_202207241830_00000019&amp;mode=LSD&amp;mid=shm&amp;sid1=100&amp;oid=082&amp;aid=0001166462"><span class="cluster_foot_more_icon_num">9</span><span class="cluster_foot_more_text">개의 관련뉴스 더보기</span></a>,
#  <a class="cluster_thumb_link nclicks(cls_pol.clsart)" href="https://n.news.naver.com/mnews/article/020/0
a>,
#  <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/081/0003289754?sid=102" title="이상민?“경찰 집단행동 쿠데타 준해, 대단히 부적절”…권성동 “경찰, 배부른 밥 투정”(종합)">이상민?“경찰 집단행동 쿠데타 준해, 대단히 부적절”…권성동 “경찰, 배부른 밥 투정”(종합)</a>,
#  <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/032/0003162108?sid=102" title="윤희근 경찰청장 후보자 “총경회의 참석자, 감찰 후 상응 조치할 것”">윤희근 경찰청장 후보자 “총경회의 참석자, 감찰 후 상응 조치할 것”</a>,
#  <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/022/0003718561?sid=103" title="드라마가 현실로?… 우영우 팽나무 천연기념물 조사나선 문화재청">드라마가 현실로?… 우영우 팽나무 천연기념물 조사나선 문화재청</a>,
#  <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/025/0003211992?sid=103" title="김연아 10월 결혼한다…신랑은 5살 연하 성악가 고우림">김연아 10월 결혼한다…신랑은 5살 연하 성악가 고우림</a>,
#  <a class="nclicks(rig.banner)" href="https://media.naver.com/channel/settings"> <img alt="네이버 메인에서 바로 보는 언론사 편집뉴스 지금 바로 구독해보세요!" src="https://imgnews.pstatic.net/image/upload/item/2018/11/27/174854048_PC_%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA_%25B1%25B8%25B5%25B6%25C8%25B0%25BC%25BA%25C8%25AD.png" width="300"> </img></a>,
#  <a class="nclicks(rig.banner)" href="https://news.naver.com/main/assembly/index.naver" target="_blank"> <img alt="내일을 여는 국민의 국회" border="0" class="banner" height="60" src="https://imgnews.pstatic.net/image/upload/item/2021/01/08/173235779_%25B1%25B9%25C8%25B8%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA.png" width="300"> </img></a>,
#  <a class="nclicks(rig.banner)" href="https://news.naver.com/main/ombudsman/guidecenter.naver?mid=omb" target="_blank"> <img alt="뉴스 기사와 댓글로 인한 문제 발생 시 24시간 센터로 접수해주세요" src="https://imgnews.pstatic.net/image/upload/item/2018/08/29/183951086_%25BD%25C5%25B0%25ED%25B9%25E8%25B3%25CA.png" width="300"> </img></a>,
#  <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver"> 서비스 안내 </a>,
#  <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb"> 고침 기사 모음 </a>,
#  <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb"> 정정·반론·추후 보도 기사 모음 </a>,
#  <a class="nclicks(rig.text)" href="https://news.naver.com/main/hotissue/sectionList.naver?mid=hot&amp;sid1=100&amp;cid=909906&amp;decorator=ombudsman&amp;confirm=true"> 불공정 선거 보도 기사 모음 </a>,
#  <a class="more_link nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver"><span class="blind">서비스 안내</span>더보기</a>]

# %%
for item in items:
    print(item.get_text())
# Out:
# 메인 메뉴로 바로가기
# 본문으로 바로가기
# 검색
# NAVER
# 뉴스
# TV연예
# 스포츠
# 날씨
# 프리미엄
# 언론사별
# 정치 선택됨
# 경제
# 사회
# 생활/문화
# IT/과학
# 세계
# 랭킹
# 신문보기
# 오피니언
# TV
# 팩트체크
# 전체 언론사
# 뉴스스탠드
# 라이브러리
# 전체 언론사
# 뉴스스탠드
# 라이브러리
# 정치
# 대통령실
# 국회/정당
# 북한
# 행정
# 국방/외교
# 정치일반
#
#
# 안내헤드라인 뉴스
#
#
#
# 법조계 "민주유공자법, 기준 불분명·과도한 혜택…위헌소송 남발할 것”
# 신문브리핑 3 "與 "野의 민주유공자法, 운동권 신분 세습법"" 외 주요기사
# 우원식 "민주화유공자법, 박종철·이한열를 유공자로 인정해달라는 것"
# 우원식 “모든 유공자법에 교육·취업 혜택...민주유공자법만 뺄 순 없어”
# 19개의 관련뉴스 더보기
#
#
#
#  "경찰국 신설 논란, 행안부·경찰청서 필요한 조치할 것"[尹 출근길 한마디]
# 尹대통령, '警亂' 조짐에 "행안부·경찰청이 필요한 조치 잘 할 것"
# 尹, 경찰 반발에 “행안부·경찰청에서 조치 잘 할 것”
# 윤 대통령, 경찰 반발에 "행안부 · 경찰청서 필요 조치"
# 46개의 관련뉴스 더보기
#
#
#
# 대통령실, 尹 지지율 하락에 "새 정부, 손발 맞추는 데 시간 필요"
# 대통령실 "경찰국 신설이 치안본부? 프레임 공격"
# 강승규 “경찰국 신설 ‘전두환식’ 비판은 프레임 공격”
# 강승규 “‘치안본부’ 비판은 프레임…경찰국은 권한 견제용”
# 9개의 관련뉴스 더보기
#
#
#
# 우상호 "비서실장 첫 등판이 경찰 장악‥대통령 지시로 해석"
# 민주당 "비서실장 첫 등판이 '경찰 장악' 관련…대통령 지시일 것"
# 우상호 "경찰 장악에 비서실장 등판...尹 지시로 해석"
# 여야 전면전 치닫는 경찰국 갈등…정국 최대 쟁점 급부상
# 30개의 관련뉴스 더보기
# 권성동 "대우조선 경영진, 방만 경영 책임지고 물러나야"
#
#
#
# 與, `파업·손실` 대우조선 경영진도 책임론…"`文 동생 친구 알박기` 박두선 사장 물러나라"
# 10개의 관련뉴스 더보기
#
#
#
# 추미애 "류 총경 대기발령, 속 좁은 인사보복 철회해야"
#
#
#
# 추미애, 류삼영 두둔하며 尹정권 저격…“정치경찰화 시도, ‘국민 저항’ 직면할 것”
# 9개의 관련뉴스 더보기
#
#
#
# 하태경 “경찰국 신설, 정부가 너무 거칠게 다뤄”
#
#
#
# 與 내부서도 경찰국 속도조절론…하태경 "너무 거칠어"
# 8개의 관련뉴스 더보기
#
#
#
# "尹 국정지지 하락세 주춤…긍정 33.3% 부정 63.4%"
#
#
#
# "尹대통령 지지율 하락세 멈춰…긍정 33.3% 부정 63.4%"
# 39개의 관련뉴스 더보기
#
#
#
# 웨버 대령 자택에 ‘한국전 참전용사의 집’ 명패, 보훈처장이 직접 단다
#
#
#
# 보훈처장, 美알링턴 참배…웨버 대령 등 참전자 묘역 방문(종합)
# 22개의 관련뉴스 더보기
#
#
#
# 軍, '27일 전후 北핵실험' 가능성에 "시기특정 적절치 않아"
#
#
#
# 軍, '27일 전후 北핵실험' 가능성에 "시기특정 적절치 않아"
# 7개의 관련뉴스 더보기
#
#
#
# 尹 “같은 작가네”…용산 청사에 장애인 미술 작품 15점 걸렸다
#
#
#
# 尹 대통령 "그 작가네?" 출근길, 미술계 '우영우' 장애인 작품 걸었다
# 23개의 관련뉴스 더보기
#
#
#
# 권성동 "대통령 세종 제2집무실 공약 파기? 가짜뉴스…`임시집무실` 건너뛰자 했더니"
#
#
#
# 행정수도완성시민연대 "권성동 세종집무실 공약 이행은 궤변"
# 5개의 관련뉴스 더보기
#
#
#
# "낙타 바늘귀 통과할 일이어도"... 이탄희, 이동학 지지선언
#
#
#
# 이탄희, 이동학 공개지지 선언…"정치개혁 진정성 믿어"
# 4개의 관련뉴스 더보기
#
#
#
# 尹 지지율 보합세로 전환…5주째 '데드크로스'[KSOI]
#
#
#
# KSOI "尹대통령 지지율 0.2%p 상승해 32.2%…긍·부정 격차는 더 벌어져"
# 9개의 관련뉴스 더보기
# 김병주 "북송 어민, 南 귀순 아니라 밀항 의도한 듯"
#
#
#
# ‘북송 어민 살해’ 오락가락 여당, 우왕좌왕 통일부…정치권 “자료 공개만이 정답”
# 11개의 관련뉴스 더보기
#
#
#
# 오늘 윤 정부 첫 대정부질문…정치·외교·통일·안보 분야
#
#
#
# '방패' 대신 '칼' 잡은 與, 尹정부 첫 대정부질문서 文정부 공격 나선다
# 54개의 관련뉴스 더보기
# 헤드라인 더보기
#
# 연재보기
# 군사대로
#
# [군사대로]'靑습격' 김신조·'KAL폭파' 김현희 북송 안한 이유는?
# [군사대로] 故 아베의 꿈 '전쟁하는 자위대', 한반도 영향은?
# [군사대로]나토, 한미일 안보협력 미래로 北 비핵화 모범될까
# [군사대로]5·24조치로 시작된 독자 대북제재…효과 얼마나 있었나
#
#
#
#
# 이상민 “경찰서장회의, 12·12 쿠데타 준하는 상황”
# 동아일보
#
#
#
# 윤 대통령 지지율 20%대로 경고한 20대…9.2%p 급락 …
# 한겨레
#
#
#
# [판결남] ‘기말고사 답안지’ 들고 사라진 선생님…중3 학 …
# KBS
#
#
#
# 고우림 측 "김연아와 3년 열애...10월 결혼" (공식입 …
# YTN
#
#
#
# 김연아 10월 결혼한다…신랑은 5살 연하 성악가 고우림
# 중앙일보
#
#
#
# ‘피겨 여왕’ 김연아, 10월의 신부 된다…예비신랑은 누구 …
# 조선일보
#
#
# 동영상기사
#
# 철장에선 나왔지만‥"8천억 배상하라니‥"
# MBC
#
#
#
# ‘피겨여왕’ 김연아, 5살 연하 고우림과 10월 결혼
# 국민일보
#
#
#
# '피겨여왕' 김연아, 5세 연하 고우림과 10월 결혼(종합 …
# 뉴시스
#
#
#
# 이상민 장관 "총경 집단행동, 지역 치안 책임자들이 이탈해 …
# 매일신문
#
#
#
# "무증상이면 5만원 내세요"…코로나 검사 회피 늘어난다
# 서울경제
#
#
#
# ‘피겨여왕’ 김연아, 5세 연하 성악가 고우림과 10월 결 …
# 매일경제
#
#
#
# “수지→아기 얼굴” 귀엽다 난리더니, 순식간에 망가진 이곳
# 헤럴드경제
#
#
#
# '피겨여왕' 김연아, 포레스텔라 고우림과 10월 결혼
# JTBC
#
#
#
# 피겨여왕 김연아, 성악가 고우림과 ‘10월 결혼’
# 아시아경제
#
#
#
# "300만원 넘게 줬는데…" 부모님 집 '2in1 에어컨' …
# 한국경제
#
#
#
# [속보]이상민 "무장 가능한 조직이 상부지시 위반 대단히  …
# 이데일리
#
#
#
# 민주당 지지율, 한 주 새 9% 상승…국민의힘에 역전[KS …
# 조선비즈
#
#
#
# “깨끗하고 안전해”…강물 원샷한 인도 총리, 결국 병원行
# 서울신문
#
#
#
# 우영우 실제 모델은 자폐 진단 받은 세계적 동물학자
# 한국일보
#
#
# 동영상기사
#
# 피겨퀸 김연아, 10월 결혼…성악가 고우림과 3년 교제 끝 …
# SBS
#
#
#
# 4분기 출시 '7세대 그랜저' 대기만 벌써 3만명
# 한국경제TV
#
#
#
# 김연아, 10월 결혼…성악가 고우림과 3년 교제 끝에 웨딩 …
# 연합뉴스
#
#
#
# 김연아, '팬텀싱어' 5세 연하 서울대 출신 고우림과 10 …
# 뉴스1
#
#
#
# 김연아♥고우림, 3년 교제 끝에 10월 결혼
# 노컷뉴스
#
#
#
# 윤 대통령, 또 틀렸다... '반도체 15만 양병설'은 헛 …
# 오마이뉴스
#
#
#
# "밝게 웃는 모습 화나서" 이재명·윤석열 대선 후보 벽보  …
# 부산일보
#
#
# 동영상기사
#
# 공시가 3억 시골집, 양도세·종부세 주택 수서 제외
# 연합뉴스TV
#
#
#
# "머스크, 절친 아내와 불륜…구글 창업자 이혼 사유였다"
# 머니투데이
#
#
#
# "아기 손가락 잘린 유모차, 우리와는 무관"…母 폭로에 업 …
# MBN
#
#
#
# 김연아, 5살 연하 고우림과 결혼...3년 열애
# 파이낸셜뉴스
#
#
#
# 박범계 “한동훈에 ‘법치농단’ 따져 묻겠다”
# 채널A
#
#
#
# ‘피겨퀸’ 김연아, 성악가 고우림과 10월 전격 결혼
# 경향신문
#
#
#
# 피겨퀸 김연아, 10월 결혼…성악가 고우림과 웨딩마치
# TV조선
#
#
#
# '피겨퀸' 김연아, 성악가 고우림과 오는 10월 결혼 …
# SBS Biz
#
#
#
# 전여옥 “‘위험인물’ 류삼영 총경은 ‘정치경찰’…대기발령  …
# 디지털타임스
#
#
#
# 김연아, ‘포레스텔라’ 고우림과 10월 결혼
# 문화일보
#
#
#
# 진도서 막춤 광주서 '치콜', 이준석의 '장외정치' 뒤에는 …
# 주간조선
#
#
#
# 국민의힘 수신료 폐지주장에 "비전문가적 주장" 비판한 KB …
# 미디어오늘
#
#
#
# 드라마가 현실로?… 우영우 팽나무 천연기념물 조사나선 문화 …
# 세계일보
#
#
#
# 일론 머스크, 구글 창업자 세르게이 브린 아내와 불륜
# ZDNet Korea
#
#
#
# [Photo News] Summer holidays at  …
# 코리아헤럴드
#
#
#
# 이상민 장관 격노 "12.12 쿠데타에 준하는 상황…경찰이 …
# 프레시안
#
#
#
# “구글 공동창업자, 머스크 회사 투자 정리 지시…아내와 불 …
# 블로터
#
#
#
# 재테크 빙하기에 최고 6%…예적금 금리 짭짤한 곳은 어디?
# 매경이코노미
#
#
#
# 15세 男학생과 지속적 성관계…28세 공부방 女선생 들통난 …
# 데일리안
#
#
#
# 김의겸 "윤석열 정부를 ‘MB 2기 라고 해...전두환의  …
# 강원일보
#
#
#
# 끝날 것 같았던 코로나 파도 얼마나 거세질까
# 시사IN
#
#
#
# '당뇨병' 예방 팁 10가지
# 코메디닷컴
#
#
#
# [인터뷰] 박지현 "이재명, 팬덤 예쁨 받으려 '애교'…문 …
# 더팩트
#
#
#
# 현대차 '7세대 그랜저', 출시도 안 했는데 3만명 대기
# 전자신문
#
#
#
# ‘우영우’, 제2의 오징어게임 될까…해외도 주목 [IT클로 …
# 디지털데일리
#
#
#
# 김연아·고우림 '10월 결혼'...3년 열애
# 아이뉴스24
#
#
#
# BTS의 버터비치 녹이는 삼척석탄 멈춰라
# 한겨레21
#
#
#
# ‘햇반 천하’에 도전장 낸 오뚜기와 하림, 즉석밥 시장판도 …
# 주간동아
#
#
#
# '연금 환급' 내년엔 최대 연 148만원 받는다고 …
# 비즈니스워치
#
#
#
# Poland to buy jets, tanks, weapo …
# 코리아중앙데일리
#
#
#
# “학생 수 166만 ‘경기도 교육’ 바뀌면 다 바뀐다”
# 신동아
#
#
#
# 자고 싶지만 다리가 불안해서… ‘이 질환’ 의심해야
# 헬스조선
#
#
#
# 이재용 “목숨 걸고”…삼성전자, 美 ‘260조원 투자계획’ …
# 이코노미스트
#
#
#
# 尹대통령 지지율 추락 7주 만에 '멈췄다'…여론조사 모두  …
# 시사저널
#
#
#
# "연 8% 적금 나왔다" 카카오뱅크, 출범 5주년 맞이 ' …
# 머니S
#
#
#
# 코로나19 인간 활동이 잠시 멈춘 사이 야생동물 세계도 웃 …
# 동아사이언스
#
#
#
# [나홀로 세계여행] 몰디브는 비싸다? 선입견을 깬 히마푸시
# 월간 산
#
#
#
# 경계에 선 청춘의 험난한 취업 여정
# 주간경향
#
#
#
# 박범계 "경찰국 사태, 2만 명이 들고일어나면 징계 못해"
# 조세일보
#
#
#
# 일본 여성 자폐인 "'우영우', 살아도 된다는 용기 준 작 …
# 여성신문
#
#
#
# 몇 년씩 감금, 아이와 격리…이렇게까지 해야 하나?
# 일다
#
#
#
# 또 일가족 극단 선택..'도박빚에 생활고' 유서 발견
# kbc광주방송
#
#
# 동영상기사
#
# 전북도내 코로나19 연일 '2천 명대'.. 확산세 계속
# 전주MBC
#
#
#
# WHO, 원숭이두창 '비상사태' 선포..코로나19 이후 2 …
# JIBS
#
#
#
# "이 길로 학교 다니라고?" 대전 도마·변동지구 입주예정민 …
# 대전일보
#
#
#
# 밤새 대구 수성구 일대 정전···무더위 속 300여 가구  …
# 대구MBC
#
#
# 동영상기사
#
# [영상] 무더위 잊게 해 줄 제천의 2가지 비경
# CJB청주방송
#
#
#
# 끝 모르던 대통령 지지율 하락세 둔화..."사적채용 논란  …
# 국제신문
#
#
# 동영상기사
#
# [영상] 무더위 잊게 해 줄 제천의 2가지 비경
# CJB청주방송
#
#
#
# 끝 모르던 대통령 지지율 하락세 둔화..."사적채용 논란  …
# 국제신문
#
#
#
# [속보] 이상민 "경찰서장 모임 위법성 엄정조사" 총경회의 …
# 강원도민일보
#
#
#
# [양산] 젊은층에게 사랑받고 싶은데…“지드래곤이 써주면 안 …
# 농민신문
#
#
#
# 에어컨 없이 여름밤 보내는 몇 가지 방법에 대해
# 레이디경향
# 권성동 "경찰 집단행동, 배부른 밥투정" 맹비난 [경찰국 설치 논란]
# 권성동 “반드시 책임 뒤따를 것” vs 우상호 “경찰장악 맞서 싸우겠다”
# [뉴스1 PICK]윤 대통령이 가리키는 이 그림…발달장애 예술가 작품
# [포착] ‘하늘에서 화산재가 비처럼’…日 화산 분화, 최고 경보 발령(영상)
# 머스크, 구글 공동창업자 아내와 ‘잘못된 만남’
# TSMC 보란듯…삼성 세계 첫 ‘3나노’ 파운드리 출하
# 포스코그룹, 비상경영체제 돌입
# 토지 매매도 얼어붙었다…상반기 거래량 전년대비 27% 감소
# “IT로 사회 지속가능성 기여”… 카카오, 국내 첫 ‘기술윤리위원회’ 설치
# LGU+ 5G·LTE 프리미어 레귤러 가입시 `티빙` 무료
# 이상민 "경찰은 무장가능 조직…쿠데타가 이렇게 시작"(종합)
# 이상민?“경찰 집단행동 쿠데타 준해, 대단히 부적절”…권성동 “경찰, 배부른 밥 투정”(종합)
# 윤희근 경찰청장 후보자 “총경회의 참석자, 감찰 후 상응 조치할 것”
# 드라마가 현실로?… 우영우 팽나무 천연기념물 조사나선 문화재청
# 김연아 10월 결혼한다…신랑은 5살 연하 성악가 고우림
#
#
#
#  서비스 안내
#  고침 기사 모음
#  정정·반론·추후 보도 기사 모음
#  불공정 선거 보도 기사 모음
# 서비스 안내더보기

# %%
items=bs.find('div',id='header').find_all('a')
items
# Out:
# [<a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>,
#  <a href="#main_content" tabindex="2"><span>본문으로 바로가기</span></a>,
#  <a class="tool_button _search_content_toggle_btn nclicks(gnb.sch)" href="javascript:;"><span class="icon_search">검색</span></a>,
#  <a class="h_logo nclicks(gnb.naver)" href="https://www.naver.com/"><span class="blind">NAVER</span></a>,
#  <a class="h_news nclicks(gnb.news)" href="/"><span class="blind">뉴스</span></a>,
#  <a class="entertain nclicks(gnb.enter)" href="https://entertain.naver.com/home">TV연예</a>,
#  <a class="sports nclicks(gnb.sports)" href="https://sports.news.naver.com">스포츠</a>,
#  <a class="weather nclicks(gnb.weather)" href="https://weather.naver.com">날씨</a>,
#  <a class="premium nclicks(gnb.premium)" href="https://contents.premium.naver.com">프리미엄</a>,
#  <a class="nclicks(lnb.pcmedia)" href="/"><span class="tx">언론사별</span> </a>,
#  <a class="nclicks(lnb.pol)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100"><span class="tx">정치</span> <span class="blind">선택됨</span></a>,
#  <a class="nclicks(lnb.eco)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101"><span class="tx">경제</span> </a>,
#  <a class="nclicks(lnb.soc)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102"><span class="tx">사회</span> </a>,
#  <a class="nclicks(lnb.lif)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=103"><span class="tx">생활/문화</span> </a>,
#  <a class="nclicks(lnb.sci)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=105"><span class="tx">IT/과학</span> </a>,
#  <a class="nclicks(lnb.wor)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=104"><span class="tx">세계</span> </a>,
#  <a class="nclicks(lnb.rankin)" href="/main/ranking/popularDay.naver?mid=etc&amp;sid1=111"><span class="tx">랭킹</span> </a>,
#  <a class="nclicks(lnb.paper)" href="/newspaper/home"><span class="tx">신문보기</span> </a>,
#  <a class="nclicks(lnb.opi)" href="/main/opinion/home.naver"><span class="tx">오피니언</span> </a>,
#  <a class="nclicks(lnb.tv)" href="/main/tv/index.naver?mid=tvh"><span class="tx">TV</span> </a>,
#  <a class="nclicks(lnb.fact)" href="/main/factcheck/main.naver"><span class="tx">팩트체크</span> </a>,
#  <a class="lnb_extra_menu_link nclicks(nct.right3)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a>,
#  <a class="lnb_extra_menu_link nclicks(STA.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a>,
#  <a class="lnb_extra_menu_link nclicks(nct.right4)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a>,
#  <a class="nclicks(slb.allmedia)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a>,
#  <a class="nclicks(slb.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a>,
#  <a class="nclicks(slb.library)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a>]

# %%
for item in items:
    print(item.get_text())
# Out:
# 메인 메뉴로 바로가기
# 본문으로 바로가기
# 검색
# NAVER
# 뉴스
# TV연예
# 스포츠
# 날씨
# 프리미엄
# 언론사별
# 정치 선택됨
# 경제
# 사회
# 생활/문화
# IT/과학
# 세계
# 랭킹
# 신문보기
# 오피니언
# TV
# 팩트체크
# 전체 언론사
# 뉴스스탠드
# 라이브러리
# 전체 언론사
# 뉴스스탠드
# 라이브러리

# %% [markdown]
# ---

# %% [markdown]
# ## 과제 07/25_1

# %% [markdown]
# #### Q. 상기 출력물을 불필요한 공백없이 정렬하여 출력하세요.(방법은 마음대로~)

# %% [markdown]
# ---

# %%
texts=bs.find_all('p')
texts
# Out:
# [<p class="airs_info_inner"><i class="airs_info_icon_airs">AiRS</i><span class="airs_info_text"><b>추천</b>으로 구성된 뉴스를 제공합니다.</span></p>,
#  <p class="section_sub_txt">오전 11시~오후 12시까지 집계한 결과입니다.</p>,
#  <p class="copyright">본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.</p>]

# %%
for t in texts:
    print(t.string)
# Out:
# None
# 오전 11시~오후 12시까지 집계한 결과입니다.
# 본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.

# %%
for t in texts:
    print(t.get_text())
# Out:
# AiRS추천으로 구성된 뉴스를 제공합니다.
# 오전 11시~오후 12시까지 집계한 결과입니다.
# 본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.

# %%
import urllib.request as rq
import re

url='http://news.naver.com'
html=rq.urlopen(url)
bs=BeautifulSoup(html)

#한글만 뽑아내기
#방법1
text=bs.get_text()
p=re.findall('[가-힣 ]+',text)

hangeul=''
for i in p:
    hangeul+=i+' '
    hangeul=re.sub('[\s]{2,}','',hangeul)
print(hangeul)
# Out:
# 네이버 뉴스 본문 바로가기 뉴스 연예 스포츠 날씨 프리미엄 검색 언론사별 정치 경제 사회 생활 문화 과학 세계 랭킹 신문보기 오피니언 팩트체크 전체 언론사 뉴스스탠드 라이브러리 콘텐츠 월 전체 언론사 뉴스스탠드 라이브러리 언론사편집 기자연재구독설정시사저널 월일구독 오르는 금리떨어지는 집값영끌족 상환 부담에비상 영끌족대출금리월부터 원리금만원 부담전체 가계대출 중세대 비중대보다 높아대출금리가포인트나 올랐습니다대 남성씨는년 경기 서울경제 월일구독 피겨여왕김연아월 결혼 세 연하 예비신랑 누구 피겨 여왕김연아 가 그룹 포레스텔라 멤버 팝페라 가수 고우림 과 결혼한다일 김연아의 매니지먼트사 올댓스포츠는김연아가 오는월 하순 서울 모처에서 성악가 고우림과 화촉을 밝힌다 고 밝혔다 광주방송 월일구독지지율주째대 긍정부정윤석열 대통령의 국정수행 지지율이 또 소폭 하락했다는 여론조사 결과가 나왔습니다리얼미터가 지난일 닷새 동안 전국세 이상 유권자명을 대상으로 윤 대통령의 국정 수행에 대한 평가를 조사
 노조 집행부는 고소장을 제출하는 등 민형사상 책임을 묻는 작업에 착수했다. 신호 전국언론노조 YTN지부장은 22일 사내 공지를 통해 “
# ■ 월악산 백두대간 소백산과 속리산 중간에 있는 월악산은 기암절벽에 산세가 험해 우리나라 5대 악산 중 하나로 꼽힙니다. 이 때문인지 해발 1,097미터의 주봉은 신령스럽다는 의미의 영봉(靈峯)으로 부릅니다. 한반도
# 포레스텔라 고우림(왼쪽, SNS), 김연아(뉴스1 DB) © 뉴스1(서울=뉴스1) 고승아 기자 = 전 피겨스케이팅 국가대표 선수 김연아(32)와 그룹 포레스텔라 멤버 팝페라 가수 고우림(27)이 깜짝 결혼 소식을 알렸다.고우림 소속사 비트인터렉티브는 25일 공식입장을 내고 "고우림은 오는 10월 김연아와 결혼식을...
# 윤석열 대통령의 국정수행 지지율이 소폭 하락해 33.3%를 기록했다. 여론조사업체 리얼미터가 미디어트리뷴 의뢰로 지난 18~22일 전국 성인 유권자 2527명을 대상으로 조사한 7월 3주차 여론조사에 따르면 윤 대통
#
#
#
#
#                                 방송 모아보기 클릭 시해당 방송사 뉴스를 볼 수 있으며LIVE 표시가 된 경우 생중계로시청 가능합니다.
#
#
#
# [ASMR] 소리로 맛보는 2대를 이어온 올갱이
# 내륙의 바다, 청풍호의 비경
# 충북대병원의 실험 '검사료 후불제' 먹튀는 없었다
# 예민보스 반려견과 여름 휴가 떠날 계획이라면?
# 매출 불씨 꺼지지 않도록… 최대 3억 특례보증·6개월마다 금리 선택
# 소득세 감면 최대 수혜자는 ‘1억 안팎 연봉자’
# 추경호 “안심전환대출로 내년 변동금리 비중 5%P 낮출 것”
# 경찰 갈등은 ‘제2의 윤석열’ 싹 자르는 노림수?
# 현직 경찰이 이상민 장관에게 보내는 편지
# 경찰 시위에 행안부 “투명한 행정 위한 것”? [뉴스큐레이터]
# 시위 막던 경찰 시위
# 초유의 경찰서장 회의에 징계 대응…내부 반발 격화
# 경찰국 신설 공방…"부적절한 집단행동" vs "공안통치"
# 김대기 비서실장 "부적절 행위…경찰도 견제 필요"
# 경찰국 반발 후폭풍…경감·경위도 집단행동 예고
# 대우조선 1독 진수작업 5주 만에 재개, 금속노조 탈퇴 등 勞勞갈등은 불안요소
# 거제 상인들 “큰 걱정 덜어” 타결에 안도
# 대우조선, 8000억 손실 남긴채 파업 ‘매듭’
# ‘불법파업은 책임 문다’는 학습효과 필요 [기자의 눈/이건혁]
# 뉴 앱노멀·초불확실 시대, 금융지식(FQ)부터 쌓아라 [국제경제읽기 한상춘]
# "첫 약세장 만난 美 Z세대 공격적 투자 지속"
# "美증시 약세 국면에 사야할 종목은 운송주와 금융주"
# 골드만삭스 "일부 태양광업체 어닝 서프라이즈 발표 예상"
# 윤희근 경찰청장 후보자 "총경회의는 복무규정 위반…감찰후 상응조치"
# 이상민 "경찰서장회의는 하나회 12·12 구데타에 준하는 부적절한 행위"
# 윤 대통령, 경찰 반발 확산에  "행안부·경찰청서 필요조치 잘 할 것"
# 강원경찰 "정부 밀어붙이기 식 경찰국 설치 반대" 반발 고조
# 美 6월 소비자물가 9.1% 상승,  41년 만에 최고치 찍었다
# ‘1만3000원의 행복’ 돈값 하는 냉면 맛집
# 中 신형 항모 ‘푸젠’, 스펙 뜯어보니 ‘빛 좋은 개살구’
# 리츠도 줄줄이 신저가, 신규 진입자에겐 또 다른 기회
# '슈퍼달러 펀치' 원/달러 환율 1400원 가나
# 환율 역사적 고점 때 '서울 아파트값' 얼마나 하락했나
# "IMF 외환위기 악몽 재현?"… 한·미 통화스와프 부활하나
# [영상] 폭락한 윤석열 지지율 끌어올리는 방법 알려드림 [정치왜그래?]
# [영상] 아베 피격 사망, 평화 헌법 개헌된다고? [정치왜그래?]
# 박지현  “민주당은 고인 물, 계속 돌 던지겠다” [정치왜그래?]
# 하나금융, 상반기 순이익 1.7조원…전년 동기 대비 1.5%↓
# 우리금융, 올 상반기 순익 1조7610억원…반기 최대 실적 냈다
# 신한금융, 올 상반기 순익 2조7208억 '역대 최대'…은행·카드사 선전
# [2022 필즈상] 필즈상은 어떤 상인가
# [2022 필즈상]사상 두 번째 여성 필즈상 수상자 배출…다른 세 명의 수상자들
# [한국계 첫 필즈상 수상] 허준이 교수는 누구인가
# [한국계 첫 필즈상 수상] 허준이 교수 "수학은 '자유로움'을 학습하는 일…얽매이지 않고 생각해야"
# 중첩·얽힘 이용하는 양자컴... 속도가 기하급수로 증가
# "반도체와 양자기술 동시에 잡으려면 재교육 투자해야"
# "한국은 하드웨어 강조하지만... 양자컴 시대에도 소프트웨어가 핵심"
# [신선한 경제] 예적금 '껑충'‥금리상한형 대출 폭증
# [신선한 경제] 가장 큰 수혜는 연봉 1억 안팎 소득층
# [신선한 경제] 스타벅스, 유해물질 검출 의혹 '서머 캐리백' 교환
# [신선한 경제] '서울사랑상품권' 500억 추가 발행‥7% 할인
# “무력수단 가진 집단의 하극상”… 정부, ‘警亂’ 에 초강경 대응
# 이상민 “경찰서장회의, 쿠데타 준하는 상황”
# “경찰, 수사外 치안 기능도 가져…문민통제 필요 행정기관”
# 홍준표 “경찰 독립국 만들겠다는 건가...참 간 큰 조직 돼 간다”
# [단독] 대중교통·학교서 모르는 여성 노려...'정액 테러' 절반은 집행유예
# 마시던 커피·택배에 '정액 테러', 성범죄로 처벌 못한다?
# "한국 성범죄자들, 법 허술해 엄벌 피해" 외신도 '정액 테러' 조명
# 정액테러·메타버스 성추행도 '성범죄'...처벌법 만들어야
# 尹 대통령 지지율 30% 붕괴 '눈앞'.. 긍정 평가 30.4%
# "尹대통령 잘못한다" 64.2%..보수층도 돌아서
# 尹, 사적채용 '부적절 65.5%..40대男·20대女 80%↑'
# 민주당 차기 당 대표 이재명 41.8%..전주대비 3.2%↑
# [아미랑] “여행을 떠나세요, 손을 잡으세요”
# [아미랑] 항암치료로 빠진 눈썹, ‘문신’해도 될까요?
# [아미랑] 폐암과 관련해 알아둘 유전자 상식
# [아미랑] “이별을 준비하는 가장 현명한 방법은…”
# "문 닫아놓으면 손님 줄고 코로나도 걱정"... 종로·홍대 등 가게 80%가 문 열고 냉방중 [현장르포]
# 빚투 탕감… "도덕적 해이 부추겨" vs "회생제도 취지 맞다" [법조 인사이트]
# 재활용되는 캡슐커피, 소비자 41%는 그냥 버려 [지구를 사랑하는 장한 나]
# 우상호, 이상민 '쿠데타' 언급에 "언어도단에 적반하장"(종합)
# [기획] 직장인 소득세 최대 80만원 줄어든다
# [2022 尹정부 세제개편안] 과표 5억 기업 법인세 3000만원 절감효과… 통합고용세액공제 신설
# [2022 尹정부 세제개편안] 연금저축·퇴직연금 세액공제 확대… 납입한도 700만원→900만원
# [2022 尹정부 세제개편안] 종부세 기본공제 9억… 다주택 중과 폐지
# 이상민 "경찰서장회의, 쿠데타 준하는 상황...대단히 부적절"
# [현장영상+] 尹 "경찰 집단 행동, 행안부·경찰청서 필요한 조치할 것"
# 우상호 "경찰 장악에 비서실장 등판...尹 지시로 해석"
# 권성동 "경찰 집단행동, 정치세력화...책임 뒤따를 것"
# [부동산 줍줍]원희룡의 경기도민 (교통지옥) 해방 일지
# [부동산 줍줍]둔촌주공 경매 위기 탈출!?(새 대주단은 비밀)
# [부동산 줍줍]둔촌주공, 합의? 끝날 때까지 끝난 게 아니다
# 22년차 '퀴퍼질'…"이 짓을 왜 하냐고? 외롭지 않으려고"
# '퀴어퍼레이드 고인물' 레즈비언 바 사장이 만드는 '공간'
# 빗속에 핀 무지개…퀴어로 채운 서울광장
# [스쿨존 점검]③ 스쿨존이 님비시설? 어린이 안전과 맞바꾼 주차 편의
# ‘저임금 노동’에 ‘100억 적자’ 따릉이…“나 계속 달릴 수 있죠?”
# “명령 불복종”에 “후보자 사퇴” 맞불…거센 반발 배경은?
# 청소노동자 집회, 대학가의 진짜 생각은?
# [뉴스야?!] 이재명도 기소되면 대표 박탈?
# [포커스] 대법원·헌재, 잇단 '충돌'…최고 사법기관 힘겨루기?
# [따져보니] "젊을수록 재감염 잘된다?"…재감염·첫 감염 비교하니
# [뉴스7 취재후 Talk] '국민간식' 은 옛말…어쩌다 배달 치킨 3만원 시대
# 출근카드가 꼭 직원의 성실성을 보여주는 건 아니다
# 페이스북 광고 위한 개인정보 강제 수집, 법적 문제는?
# 논란의 권성동 '9급 공무원' 발언은 어떻게 언론에 드러났나
# 모든 호수 벨 누르며 "절단된 채 살아남은 김용균들"을 찾다
# [영상] 국비 발목 잡힌 오륙도 트램…4년째 첫 삽 못 떠
# [영상] 한일 갈등에 EEZ 황금어장 잃었다…한숨 쉬는 수산업
# [60초 뉴스]‘반도체 동맹’ 할까 말까? 국내 반도체 업계 고심
# 갑작스러운 심장 두근거림... 부정맥 신호?
# 임차인 세 부담에 임대시장도 세제개편
# 세제개편으로 줄어든 세수 ‘13조원’…기재부, 예산편성 고삐 죈다
# 또 '부자 감세' 프레임…野, 보수 정권 세제개편 발목잡기
# 전경련 “세제개편안, 기업 투자·일자리 창출 도움 기대”
# 與, 경찰 내 '경찰국' 반대에 "조직 이기주의이자 불법"
# 우상호 "장관 수사지휘는 전두환식…이상민 인권의식 이정도?"
# 이상민 장관 "경찰서장 회의는 12·12쿠데타에 해당하는 범죄"
# 尹대통령, 경찰 집단행동 예고에 "행안부·경찰청이 조치 잘할 것"
# ‘우영우’, 제2의 오징어게임 될까…해외도 주목 [IT클로즈업]
# 中 '우영우' 도둑시청하며 호평?…평점 9.3에 팬계정까지 등장
# 中 '우영우' 도둑시청에 분노…"중국 당국이 나서라"
# 두 자릿수 시청률도 돌파한 '이상한 변호사 우영우'... 제작사 주가는?
# 경찰 집단행동 확산…행안부 개입 의혹까지 ‘일파만파’
# ‘경찰국 신설’ 반발 확산에 尹대통령 “지켜보고 있다”
# 경찰청장 후보자 “경찰서장회의 해산명령 불이행…조치할 것”
# [사설] 경찰국 반발 집단행동, 정치권 갈등증폭보다 수습책을
# [사설] 어떤 경우에도 정부·경찰 정면 대결 안 된다
# [박정호의 시시각각] 무지갯빛 ‘우영우’는 있을까
# [김병필의 인공지능 개척시대] 진짜 같은 가짜 데이터로 인공지능 가르치기
# [분수대] 깻잎 논쟁
# [대한민국 대전환 'ON'] 프랑스, 사용후핵연료 '재처리' 세계 최대
# [대한민국 대전환 'ON'] 佛 오라노 수석부사장 "원전 재처리, 자원 아끼는 방안"
# [대한민국 대전환 'ON']우리나라 사용후핵연료 처리 계획은
# “한국, 에너지 전환시 최대 86만개 일자리 창출”
# 尹정부, '120대 국정과제' 확정 "기득권 저항에도 개혁 꼭 필요"
# 문체부 첫 업무보고 실종된 '게임'…"주무부처 바꿔야" 목소리도 [IT돋보기]
# 과기정통부, 위원회 절반 없앤다
# [과기정통부 업무보고] 8월 범정부 '디지털 국가전략' 수립
# [D:리포트] 당신은 볼 수 없었던 그들의 쉴 곳
# [크로스체크] '판스프링' 사람 죽고 다쳐도 '가해자'는 없다
# [D:인사이드] 청년들이 상처를 받았다면 '사과' 드린다
# [밀착카메라] 타결 전까지 팽팽했던 긴장감…거제는 이제 달라질까
# 국회 18개 상임위원장 한 자리도 못 차지한 충청권
# 수년째 셋방살이에 수십억 혈세… 세종시 별관증축은 언제쯤
# '똘똘한 한 채'에 올인… 대전 부동산 매도심리 1년새 9배나
# 원숭이두창 증상도 '변이'… "성병으로 오인 가능성"
# 끝모를 지지율 하락…尹, MB의 길 선택하나
# 尹, 보수층도 등 돌렸다…"국정동력 타격 심각"
# “경제 올인은 기본..尹대통령 언행부터 신중해져야”
# 두 달간 내파된 집권 여당…尹정부에 오히려 악영향
# 다양성 갖춘 새로운 시도들그동안 없었던 클래식 무대
# 이혜연 "농구선수 출신 고졸여성이 은행 지점장까지 된 비결요? ...버텨야 한다는 간절함 때문 ... 나를 믿어야 얻을 수 있더군요"
# [메트로폴리탄 뉴욕]중세풍 유리램프 만들고백악관 인테리어 도맡아명품 주얼리 ‘티파니’ 뜻밖의 도전史
# “우울감·스트레스 심리치료 시스템 우선”
# [뉴스쉽] 코로나에 고환율에…해외여행 갈 수 있는 거야?
# [그사람] 'K-에듀'를 꿈꾸는 사교육 총수, 손주은
# [사실은] 국회의원 토론王은 누구일까요?
# [취재파일] 구의원님, 산하기관 생수 납품이 떳떳한가요?
# [택시의 나라, 모빌리티 잔혹사]④표심에 눈먼 정치권…기사들 삶 나아졌나요?
# [택시의 나라, 모빌리티 잔혹사]③ 해외는 '택시난제' 어떻게 풀고 있나
# [택시의 나라, 모빌리티 잔혹사]②'60세 이상 77%' 노쇠한 택시업…기사가 없다
# [택시의 나라, 모빌리티 잔혹사]①우버부터 타다·카모까지…택시에 막힌 혁신
# [양산] 젊은층에게 사랑받고 싶은데…“지드래곤이 써주면 안되나요?”
# [우산&양산] 단순한 ‘햇빛 가리개’ 아니에요…멋 더해주는 ‘개성만점’ 패션템
# 최상급 한지와 대나무로 만든 ‘왕의 우산’…수려함에 젖어들다
# [우산&양산] 돈 아까워 우산 고치나? 소중한 추억 때문에 그렇지
# 행안부 장관 “경찰 내 특정그룹이 ‘경찰국’ 반발 주도 의심”
# 류삼영 전 울산중부서장 대기발령 후 첫 출근일에 ‘휴가’
# 권성동 “경찰 집단행동은 배부른 밥투정, 정치세력화”
# 윤 대통령, 경찰 집단행동 “행안부·경찰청 필요한 조치할 것”
# 대구농수산물도매시장 '하빈 이전설'…현실화 가능할까?
# 대구농수산물도매시장 '하빈면 이전설' 떠올라
# "건축비 부담 크다" 매천시장 현대화 사업 암초
# ‘모였다고 징계’…검찰정권의 짙어지는 경찰 군기잡기
# 7월 25일 한겨레 그림판
# [사설] ‘경찰 장악’ 예고편 보여준 총경회의 참가자 징계
# 국힘 “엄정 대처”, 민주 “전두환식”…여야 경찰총경 회의 상반 반응
# [원자잿값 추락]슈퍼사이클 꺾였다…"경기둔화 수출기업 직격탄"(종합)
# [원자잿값 추락]철광석 100弗 아래로…철강업계, 위기 경영 돌입
# [원자잿값 추락]역대급 실적 누리던 정유사들…유가 하락에 '악'
# 유가 하락 베팅 한 달 만에 웃었다…"유가 약세장 논하기 일러"
# 물가 78% 뛰고 화폐가치 역대 최저…대통령이 통화정책에 개입한 결과 [조지원의 BOK리포트]
# 골드만삭스 "메타·GE 등에 콜옵션 전략 효과적일 것"[서학개미 리포트]
# "서울경제 유튜브 채널 '어썸머니'서 매주 美 투자전략 알려드려요"
# 금리 인상기, 앱으로 ‘짠테크’ 한다…'손품' 팔아 금리 낮은 곳 찾고, 걸어서 포인트 쌓고
# Will secretaries be replaced to rebound Yoon’s approval rating?
# Yoon calls for end to DSME disruption
# S. Korea targets W340tr investment for chip supremacy
# "쿠데타, 부화뇌동, 처벌"…이상민, 총경회의 '20분 맹폭'
# 尹, 경찰 집단행동에 "행안부·경찰청서 필요한 조치 할 것"(종합)
# 경찰직협, 서울역에서 전단지 돌리며 대국민 홍보전..."12·12 쿠데타 비판, 너무 많이 갔다"
# 우상호 "이상민, 경찰 쿠데타라고? 언어도단 적반하장"(종합)
# 대우조선 적자·파업 수렁…22년 채권단 체제 사실상 실패
# "밑빠진 독…대우조선 원점서 검토를" [뉴스&분석]
# 대한항공·아시아나 '항공 빅딜' 난항…HMM 매각도 불투명
# 대우조선 사태 봉합…정부 "불법 책임묻겠다"
# WHO, 원숭이두창 '비상사태' 선포..코로나19 이후 2년여  만
# 그 시절 소년, 다시 '제주 해녀'와 뭍에 오르다.."몰입 전시로  만나볼까"
# 국내 미기록종 '산다시마이끼' 제주서 첫  발견
# 日 원전 오염수 방류 이르면 내년..어민들 '삼중고' 호소
# 코로나 검사·진료·처방 원스톱 병원 쉽게 찾으려면?
# "코로나19 감염 후 면역 20개월 지속...재감염시 위험 낮아"
# "오미크론 감염됐다면 지금 유행 코로나 덜 걸려"
# [인터뷰] 영화 ‘브로커’ 칸 트로피 뒤에 변호사들 있었다… “韓 영화 국제화로 법률 자문↑”
# [인터뷰] 제임스 콘웨이 하시코프 부사장 “韓 클라우드 급성장하는 시장… 투자·고용 지속 확대”
# [인터뷰] 가상자산 분석업체 쟁글 대표 “주식 수준으로 정보 공개해야”
# [인터뷰] 尹 인수위 출신 주현철 변호사 “가상자산 업계는 방치 수준”
# TSMC 보고 있나…삼성전자, 3나노 파운드리 출하식 개최 [박신영의 일렉트로맨]
# 4000년 전 흙판에 써있다…"아빠 노릇하려면 선물 보내요" [성수영의 그때 그 사람들]
# 위메프 前대표가 만든 스타트업, 130억원 모았다 [김종우의 VC 투자노트]
# '페니(10원) 전쟁' 승부수 던진 美유통업계 [김리안의 글로벌컴퍼니]
# "이기는 민주당 만들겠다"…광주서 의지 다진 이재명 [TF사진관]
# 7개 상임위원장 가져간 국민의힘, 미소짓는 권성동 원내대표 [TF사진관]
# '이렇게 반가울 수가' 권성동·오세훈 악수하며 함박웃음 [TF사진관]
# 우상호, "尹 정부, 과학 방역 큰소리치더니…'각자도생 방역' 됐다" [TF사진관]
# [NOW] TV수신료 폐지안 프랑스 하원 통과
# 英·佛 “수신료 폐지” 日 “10% 인하”… 한국은 인상 추진
# 방만 경영 개선않는 KBS… 수신료 폐지 운동 거세져
# 정권 바뀔 때마다 시끄러운 공영방송
# [주간 뉴스타파] 조작으로 쌓아올린 한동훈 처가의 '아이비 캐슬'
# 한동훈 처조카 논문 데이터 위조... 촛불집회에 다인종 참여?
# 통계 뒤죽박죽 베낀 엉터리 논문 수두룩... 한동훈 처조카 데이터 조작
# 미국 논문 쓰면서 '브라질 주민 데이터' 도용...한동훈 처조카 논문 데이터 위조
# [이슈앤 직설] 尹정부 "종부세 대폭 손질하겠다"…다주택자 "당분간 안 판다"
# [이슈분석] 다주택자 세 부담 '확' 낮춘 정부…시장에 미치는 영향은
# [김대호 박사의 오늘 기업·사람] 스냅·트위터·대우조선해양·삼성전자·스타벅스·이마트
# 석유 한 방울 안 나는데… ‘기름진 사회’ [연중기획 - 지구의 미래]
# 화석연료와의 결별은 가능할까 [연중기획 - 지구의 미래]
# 서민부담 앞세워 ‘유류세 인하’ 땜질만… 탈화석연료 역행 [연중기획-지구의 미래]
# “탄소중립 시계 늦춰라”… 글로벌 석유사들 몸부림 [연중기획-지구의 미래]
# ‘경찰국 반대’ 총경 집단 행동 갈등 격화
# “참석자들 감찰 착수” “총경 응원 모금운동”… 강 대 강 대치
# 우연? …국힘-경찰 갈등 중심에 또 ‘울산’
# 이번엔 ‘공직사회 리더십’ 시험대 윤 정부, 또 ‘압박·설득’ 투트랙 가나
# [WHY] No reservation needed at Korea's hottest dining spot — the convenience store
# [WHY] Jeonse, and the reason behind so many Koreans' choice to forgo monthly rent
# [WHY] Koreans' love-hate relationship with Samsung
# [EDITOR's LETTER] 편견을 걷어내면 보이는 다른 것
# [우영우 읽기] ‘권모술수’ 권민우와 ‘우당탕탕’ 우영우가 회사에서 사는 법
# ‘편견’을 넘어서며 발전하는 인류의 역사
# MY뉴스판 '기자 추천 카드' 오픈 안내
#
# 전체서비스
#
#
#
# 이용약관
# 개인정보처리방침
# 청소년 보호 책임자 : 이희만
# 서비스안내
#
# 각 언론사가 직접 콘텐츠를 편집합니다.

# %%
import requests
from bs4 import BeautifulSoup

url='https://news.naver.com'

response=requests.get(url)
html=response.text
bs=BeautifulSoup(html,'html.parser')


ps=bs.find_all('p')

for p in ps:
    print(p.get_text())
# Out:
# 1000원 미만 초저가 마트 즉석밥도 인기 퇴근하고 집에 와서 배가 고픈데 밥솥에 밥이 똑 떨어졌을 때 부엌 ‘상비군’ 즉석밥을 찾는 사람이 적잖을 것이다. 코로나19에 감염돼 집에서 자가격리를 해야 했을 때도 즉석
# “에너지 문제는 복잡하지만 더 지속 가능한 길이 있을 겁니다. 단기적으론 석탄이 경제적이어도 장기적으로 사회가 감당 가능하고 적절한 에너지 생산 방법이 있습니다. 사회에 더 이익이 가는 방향으로 가야 합니다.” 20
# 전라북도교육청이 지방공무원 필기시험 합격자를 발표했습니다. 전북교육청은 교육행정 직군에서 245명, 전산과 사서, 공업 등 나머지 10개 분야에서 67명 등 총 312명의 필기시험 합격자를 결정했으며, 이들을 대상으
# 일본 출입국관리소에 수용된 외국인 여성들을 만나온 오다 아사히(織田朝日) 씨는 출입국관리 체계와 수용시설의 문제점을 지적하는 활동을 하고 있다. 출입국관리 시스템에 의해 수용된 여성들의 실태를 오다 씨가 직접 전한다
# 2018년 아이스쇼에서 첫 만남…비공개 결혼식 '피겨퀸' 김연아(32)가 오는 10월 결혼한다. 김연아의 매니지먼트사인 올댓스포츠는 25일 "김연아가 10월 하순 서울 모처에서 성악가 고우림(27)과 화촉을 밝힌다"
# #. 지난 4월 철거공사를 끝낸 서울 용산의 한 다세대주택(빌라). 건물 4개를 허문 자리에 각종 폐기물이 방치된 채로 공사장 인부들은 물론 포클레인 등 공사 장비가 3개월째 자취를 감춰버렸다. 건축비 상승으로 공사
# 문화재청은 인기리에 방송 중인 '이상한 변호사 우영우'에 등장한 팽나무의 문화재적 가치를 판단하기 위해 천연기념물 지정 조사를 하기로 했습니다. 이 드라마 8회에 나온 팽나무는 경남 창원시 북부리 마을 산정에 우뚝
# 올 초 전 국민을 충격에 빠뜨렸던 '계곡 살인 사건'이 일어난 경기도 가평 용소계곡에 관광객들의 발길이 북새통을 이루고 있다. 이곳에서는 지난해 7월에도 30대 남성이 숨지는 등 매년 익사 사고가 발생하고 있으나 이
# 정부, 9600여t 공급 발표 농가·중도매인·농협 곤혹 창녕 등 공판장도 대혼란 “자재값·인건비 크게 올라 팔아도 겨우 생산비 건져 대책 없으면 재배농 망해” 정부가 저율관세할당(TRQ) 제도를 통해 외국산 마늘 9
# Under the beaming sunlight, vacationers enjoy beach time at Songjeong Beach in Gangneung, Gangwon Province, one of the c
# '피겨 여왕' 김연아(32)와 팝페라 가수 고우림(27)이 결혼한다. 25일 두 사람의 열애 소식과 함께 고우림 소속사 비트인터렉티브는 이날 공식입장을 내고 "고우림은 오는 10월 '피겨여왕' 김연아와 결혼식을 올린
# 페이스북‧인스타그램을 운영하는 메타가 다음달 9일 개인정보처리방침 및 이용약관을 업데이트한다. 이에 따라 페이스북과 인스타그램 이용자는 개인정보 수
# 대우조선 적자·파업 수렁…22년 채권단 체제 사실상 실패
# "밑빠진 독…대우조선 원점서 검토를" [뉴스&분석]
# 대한항공·아시아나 '항공 빅딜' 난항…HMM 매각도 불투명
# 대우조선 사태 봉합…정부 "불법 책임묻겠다"
# [약손+] 물⑥ 하루에 물 3리터씩 마셔봤더니···
# [뉴스+] "홍준표 시장의 20일, 위험천만하다"
# [달려보니] ⑥대구 하중도(금호꽃섬)-내일을 향해 달려가는 코스
# [뉴스+] 대구시의회 '청부입법' 논란, 왜?
# [WHY] No reservation needed at Korea's hottest dining spot — the convenience store
# [WHY] Jeonse, and the reason behind so many Koreans' choice to forgo monthly rent
# [WHY] Koreans' love-hate relationship with Samsung
# 물가 78% 뛰고 화폐가치 역대 최저…대통령이 통화정책에 개입한 결과 [조지원의 BOK리포트]
# 골드만삭스 "메타·GE 등에 콜옵션 전략 효과적일 것"[서학개미 리포트]
# "서울경제 유튜브 채널 '어썸머니'서 매주 美 투자전략 알려드려요"
# 금리 인상기, 앱으로 ‘짠테크’ 한다…'손품' 팔아 금리 낮은 곳 찾고, 걸어서 포인트 쌓고
# 경찰 집단행동 확산…행안부 개입 의혹까지 ‘일파만파’
# ‘경찰국 신설’ 반발 확산에 尹대통령 “지켜보고 있다”
# 경찰청장 후보자 “경찰서장회의 해산명령 불이행…조치할 것”
# [사설] 경찰국 반발 집단행동, 정치권 갈등증폭보다 수습책을
# 코로나 검사·진료·처방 원스톱 병원 쉽게 찾으려면?
# "코로나19 감염 후 면역 20개월 지속...재감염시 위험 낮아"
# "오미크론 감염됐다면 지금 유행 코로나 덜 걸려"
# [신선한 경제] 예적금 '껑충'‥금리상한형 대출 폭증
# [신선한 경제] 가장 큰 수혜는 연봉 1억 안팎 소득층
# [신선한 경제] 스타벅스, 유해물질 검출 의혹 '서머 캐리백' 교환
# [신선한 경제] '서울사랑상품권' 500억 추가 발행‥7% 할인
# 중첩·얽힘 이용하는 양자컴... 속도가 기하급수로 증가
# "반도체와 양자기술 동시에 잡으려면 재교육 투자해야"
# "한국은 하드웨어 강조하지만... 양자컴 시대에도 소프트웨어가 핵심"
# [세계를 보다]에어컨 없는 런던이 40도…펄펄 끓는 지구
# [현장 카메라]물고기 싹쓸이…골칫덩이 된 가마우지
# [세계를 가다]사룟값 폭등…美서도 “반려동물 포기”
# [사건을 보다]동남아 마약왕 ‘사라 김’…3년 만에 현지 검거
# 이상민 "경찰서장회의, 쿠데타 준하는 상황...대단히 부적절"
# [현장영상+] 尹 "경찰 집단 행동, 행안부·경찰청서 필요한 조치할 것"
# 우상호 "경찰 장악에 비서실장 등판...尹 지시로 해석"
# 권성동 "경찰 집단행동, 정치세력화...책임 뒤따를 것"
# [주간 뉴스타파] 조작으로 쌓아올린 한동훈 처가의 '아이비 캐슬'
# 한동훈 처조카 논문 데이터 위조... 촛불집회에 다인종 참여?
# 통계 뒤죽박죽 베낀 엉터리 논문 수두룩... 한동훈 처조카 데이터 조작
# 미국 논문 쓰면서 '브라질 주민 데이터' 도용...한동훈 처조카 논문 데이터 위조
# 뉴 앱노멀·초불확실 시대, 금융지식(FQ)부터 쌓아라 [국제경제읽기 한상춘]
# "첫 약세장 만난 美 Z세대 공격적 투자 지속"
# "美증시 약세 국면에 사야할 종목은 운송주와 금융주"
# 골드만삭스 "일부 태양광업체 어닝 서프라이즈 발표 예상"
# "이기는 민주당 만들겠다"…광주서 의지 다진 이재명 [TF사진관]
# 7개 상임위원장 가져간 국민의힘, 미소짓는 권성동 원내대표 [TF사진관]
# '이렇게 반가울 수가' 권성동·오세훈 악수하며 함박웃음 [TF사진관]
# 우상호, "尹 정부, 과학 방역 큰소리치더니…'각자도생 방역' 됐다" [TF사진관]
# [D:리포트] 당신은 볼 수 없었던 그들의 쉴 곳
# [크로스체크] '판스프링' 사람 죽고 다쳐도 '가해자'는 없다
# [D:인사이드] 청년들이 상처를 받았다면 '사과' 드린다
# [밀착카메라] 타결 전까지 팽팽했던 긴장감…거제는 이제 달라질까
# 尹 대통령 지지율 30% 붕괴 '눈앞'.. 긍정 평가 30.4%
# "尹대통령 잘못한다" 64.2%..보수층도 돌아서
# 尹, 사적채용 '부적절 65.5%..40대男·20대女 80%↑'
# 민주당 차기 당 대표 이재명 41.8%..전주대비 3.2%↑
# “무력수단 가진 집단의 하극상”… 정부, ‘警亂’ 에 초강경 대응
# 이상민 “경찰서장회의, 쿠데타 준하는 상황”
# “경찰, 수사外 치안 기능도 가져…문민통제 필요 행정기관”
# 홍준표 “경찰 독립국 만들겠다는 건가...참 간 큰 조직 돼 간다”
# 美 6월 소비자물가 9.1% 상승,  41년 만에 최고치 찍었다
# ‘1만3000원의 행복’ 돈값 하는 냉면 맛집
# 中 신형 항모 ‘푸젠’, 스펙 뜯어보니 ‘빛 좋은 개살구’
# 리츠도 줄줄이 신저가, 신규 진입자에겐 또 다른 기회
# 다양성 갖춘 새로운 시도들그동안 없었던 클래식 무대
# 이혜연 "농구선수 출신 고졸여성이 은행 지점장까지 된 비결요? ...버텨야 한다는 간절함 때문 ... 나를 믿어야 얻을 수 있더군요"
# [메트로폴리탄 뉴욕]중세풍 유리램프 만들고백악관 인테리어 도맡아명품 주얼리 ‘티파니’ 뜻밖의 도전史
# “우울감·스트레스 심리치료 시스템 우선”
# [대한민국 대전환 'ON'] 프랑스, 사용후핵연료 '재처리' 세계 최대
# [대한민국 대전환 'ON'] 佛 오라노 수석부사장 "원전 재처리, 자원 아끼는 방안"
# [대한민국 대전환 'ON']우리나라 사용후핵연료 처리 계획은
# “한국, 에너지 전환시 최대 86만개 일자리 창출”
# 경찰 갈등은 ‘제2의 윤석열’ 싹 자르는 노림수?
# 현직 경찰이 이상민 장관에게 보내는 편지
# 경찰 시위에 행안부 “투명한 행정 위한 것”? [뉴스큐레이터]
# 시위 막던 경찰 시위
# 행안부 장관 “경찰 내 특정그룹이 ‘경찰국’ 반발 주도 의심”
# 류삼영 전 울산중부서장 대기발령 후 첫 출근일에 ‘휴가’
# 권성동 “경찰 집단행동은 배부른 밥투정, 정치세력화”
# 윤 대통령, 경찰 집단행동 “행안부·경찰청 필요한 조치할 것”
# 안철수 작심토로 “블랙리스트, 백현동? 정치보복 소리 듣기 싫어 봐주는 게 최악”
# 아베 신조는 정말 ‘극우’였을까
# “아이들이 아빠가 왜 죽었는지는 알아야죠”
# 다시, 김호중의 시간
# Will secretaries be replaced to rebound Yoon’s approval rating?
# Yoon calls for end to DSME disruption
# S. Korea targets W340tr investment for chip supremacy
# [원자잿값 추락]슈퍼사이클 꺾였다…"경기둔화 수출기업 직격탄"(종합)
# [원자잿값 추락]철광석 100弗 아래로…철강업계, 위기 경영 돌입
# [원자잿값 추락]역대급 실적 누리던 정유사들…유가 하락에 '악'
# 유가 하락 베팅 한 달 만에 웃었다…"유가 약세장 논하기 일러"
# [양산] 젊은층에게 사랑받고 싶은데…“지드래곤이 써주면 안되나요?”
# [우산&양산] 단순한 ‘햇빛 가리개’ 아니에요…멋 더해주는 ‘개성만점’ 패션템
# 최상급 한지와 대나무로 만든 ‘왕의 우산’…수려함에 젖어들다
# [우산&양산] 돈 아까워 우산 고치나? 소중한 추억 때문에 그렇지
# [2022 필즈상] 필즈상은 어떤 상인가
# [2022 필즈상]사상 두 번째 여성 필즈상 수상자 배출…다른 세 명의 수상자들
# [한국계 첫 필즈상 수상] 허준이 교수는 누구인가
# [한국계 첫 필즈상 수상] 허준이 교수 "수학은 '자유로움'을 학습하는 일…얽매이지 않고 생각해야"
# [영상] 폭락한 윤석열 지지율 끌어올리는 방법 알려드림 [정치왜그래?]
# [영상] 아베 피격 사망, 평화 헌법 개헌된다고? [정치왜그래?]
# 박지현  “민주당은 고인 물, 계속 돌 던지겠다” [정치왜그래?]
# [인터뷰] 영화 ‘브로커’ 칸 트로피 뒤에 변호사들 있었다… “韓 영화 국제화로 법률 자문↑”
# [인터뷰] 제임스 콘웨이 하시코프 부사장 “韓 클라우드 급성장하는 시장… 투자·고용 지속 확대”
# [인터뷰] 가상자산 분석업체 쟁글 대표 “주식 수준으로 정보 공개해야”
# [인터뷰] 尹 인수위 출신 주현철 변호사 “가상자산 업계는 방치 수준”
# 하나금융, 상반기 순이익 1.7조원…전년 동기 대비 1.5%↓
# 우리금융, 올 상반기 순익 1조7610억원…반기 최대 실적 냈다
# 신한금융, 올 상반기 순익 2조7208억 '역대 최대'…은행·카드사 선전
# [택시의 나라, 모빌리티 잔혹사]④표심에 눈먼 정치권…기사들 삶 나아졌나요?
# [택시의 나라, 모빌리티 잔혹사]③ 해외는 '택시난제' 어떻게 풀고 있나
# [택시의 나라, 모빌리티 잔혹사]②'60세 이상 77%' 노쇠한 택시업…기사가 없다
# [택시의 나라, 모빌리티 잔혹사]①우버부터 타다·카모까지…택시에 막힌 혁신
# [NOW] TV수신료 폐지안 프랑스 하원 통과
# 英·佛 “수신료 폐지” 日 “10% 인하”… 한국은 인상 추진
# 방만 경영 개선않는 KBS… 수신료 폐지 운동 거세져
# 정권 바뀔 때마다 시끄러운 공영방송
# 출근카드가 꼭 직원의 성실성을 보여주는 건 아니다
# 페이스북 광고 위한 개인정보 강제 수집, 법적 문제는?
# 논란의 권성동 '9급 공무원' 발언은 어떻게 언론에 드러났나
# 모든 호수 벨 누르며 "절단된 채 살아남은 김용균들"을 찾다
# TSMC 보고 있나…삼성전자, 3나노 파운드리 출하식 개최 [박신영의 일렉트로맨]
# 테슬라 주가 급반등에…"공매도 한 달새 2조원 날렸다" [테슬람 X랩]
# 위메프 前대표가 만든 스타트업, 130억원 모았다 [김종우의 VC 투자노트]
# '페니(10원) 전쟁' 승부수 던진 美유통업계 [김리안의 글로벌컴퍼니]
# [뉴스돋보기] '경찰국 후폭풍' / 이재명 대항마는? / 윤석열의 그 노래
# [인터넷 와글와글]'킥보드 질주'/쥐가 비둘기 사냥
# [뉴스추적] 원숭이두창 치명률 3~6%? 국내 유행 가능성?
# "분당? 호사가들의 이야기일 뿐 가능성 없어" 윤건영 더불어민주당 의원 직격인터뷰 [시사스페셜]
# 대우조선 1독 진수작업 5주 만에 재개, 금속노조 탈퇴 등 勞勞갈등은 불안요소
# 거제 상인들 “큰 걱정 덜어” 타결에 안도
# 대우조선, 8000억 손실 남긴채 파업 ‘매듭’
# ‘불법파업은 책임 문다’는 학습효과 필요 [기자의 눈/이건혁]
# 22년차 '퀴퍼질'…"이 짓을 왜 하냐고? 외롭지 않으려고"
# '퀴어퍼레이드 고인물' 레즈비언 바 사장이 만드는 '공간'
# 빗속에 핀 무지개…퀴어로 채운 서울광장
# 끝모를 지지율 하락…尹, MB의 길 선택하나
# 尹, 보수층도 등 돌렸다…"국정동력 타격 심각"
# “경제 올인은 기본..尹대통령 언행부터 신중해져야”
# 두 달간 내파된 집권 여당…尹정부에 오히려 악영향
# [EDITOR's LETTER] 편견을 걷어내면 보이는 다른 것
# [우영우 읽기] ‘권모술수’ 권민우와 ‘우당탕탕’ 우영우가 회사에서 사는 법
# ‘편견’을 넘어서며 발전하는 인류의 역사
# [스쿨존 점검]③ 스쿨존이 님비시설? 어린이 안전과 맞바꾼 주차 편의
# ‘저임금 노동’에 ‘100억 적자’ 따릉이…“나 계속 달릴 수 있죠?”
# “명령 불복종”에 “후보자 사퇴” 맞불…거센 반발 배경은?
# 청소노동자 집회, 대학가의 진짜 생각은?
# 與, 경찰 내 '경찰국' 반대에 "조직 이기주의이자 불법"
# 우상호 "장관 수사지휘는 전두환식…이상민 인권의식 이정도?"
# 이상민 장관 "경찰서장 회의는 12·12쿠데타에 해당하는 범죄"
# 尹대통령, 경찰 집단행동 예고에 "행안부·경찰청이 조치 잘할 것"
# [ASMR] 소리로 맛보는 2대를 이어온 올갱이
# 내륙의 바다, 청풍호의 비경
# 충북대병원의 실험 '검사료 후불제' 먹튀는 없었다
# 예민보스 반려견과 여름 휴가 떠날 계획이라면?
# 낸드 가격하락에 ‘칩4’ 압박까지… 하반기 ‘반도체 한파’ 닥치나
# 반도체발 수도권 정원 증가 8000+α… 대입 판도 흔드나
# 경기, 판교밸리·용인플랫폼시티에 ‘반도체 클러스터’ 구축
# '슈퍼달러 펀치' 원/달러 환율 1400원 가나
# 환율 역사적 고점 때 '서울 아파트값' 얼마나 하락했나
# WHO, 원숭이두창 '비상사태' 선포..코로나19 이후 2년여  만
# 그 시절 소년, 다시 '제주 해녀'와 뭍에 오르다.."몰입 전시로  만나볼까"
# 국내 미기록종 '산다시마이끼' 제주서 첫  발견
# 日 원전 오염수 방류 이르면 내년..어민들 '삼중고' 호소
# [사설] 어떤 경우에도 정부·경찰 정면 대결 안 된다
# [박정호의 시시각각] 무지갯빛 ‘우영우’는 있을까
# [김병필의 인공지능 개척시대] 진짜 같은 가짜 데이터로 인공지능 가르치기
# [분수대] 깻잎 논쟁
# [일문일답] 이상민 "경찰국 적법…서장회의 대단히 위험한 행위"
# 윤희근 "총경회의는 복무규정 위반…감찰후 상응조치"
# 권성동 "경찰 집단행동, 배부른 밥투정…반드시 책임 따를 것"
# 우상호, 이상민 '쿠데타' 언급에 "언어도단에 적반하장"(종합)
# 대구농수산물도매시장 '하빈 이전설'…현실화 가능할까?
# 대구농수산물도매시장 '하빈면 이전설' 떠올라
# "건축비 부담 크다" 매천시장 현대화 사업 암초
# 초유의 경찰서장 회의에 징계 대응…내부 반발 격화
# 경찰국 신설 공방…"부적절한 집단행동" vs "공안통치"
# 김대기 비서실장 "부적절 행위…경찰도 견제 필요"
# 경찰국 반발 후폭풍…경감·경위도 집단행동 예고
# 부동산 세금 어떻게 바뀌나…1주택자 재산세 공시가격에 희비 엇갈려
# 국민 숨통 트인다…다주택자 稅 폭탄 시대 끝났다
# 2주택자 기존 주택 팔아 취득세 절약…자녀 ‘부담부 증여’ 양도세 절세 효과
# 빠르면 4년 만에 아파트 단지 뚝딱…모아타운 투자 가치는?
# [단독] 대중교통·학교서 모르는 여성 노려...'정액 테러' 절반은 집행유예
# 마시던 커피·택배에 '정액 테러', 성범죄로 처벌 못한다?
# "한국 성범죄자들, 법 허술해 엄벌 피해" 외신도 '정액 테러' 조명
# 정액테러·메타버스 성추행도 '성범죄'...처벌법 만들어야
# MY뉴스판 '기자 추천 카드' 오픈 안내
#
# 전체서비스
#
#
#
# 이용약관
# 개인정보처리방침
# 청소년 보호 책임자 : 이희만
# 서비스안내
#
# 각 언론사가 직접 콘텐츠를 편집합니다.

# %% [markdown]
# ## 과제 07/25_2

# %% [markdown]
# #### 기상청 육상 정보에서 강원도의 지역번호는 105이다. 강원도의 날씨 예보를 불필요한 공백을 제거한 후 출력하세요.

# %%
url="http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp" 

https://www.weather.go.kr/plus/land/forecast/summary.jsp

# %%
import xmltodict
import urllib
from bs4 import BeautifulSoup
import re

# %%
response=urllib.request.urlopen(url)
xmltodict.parse(response)
# Out:
# {'rss': {'@version': '2.0',
#   'channel': {'title': '기상청 육상 중기예보',
#    'link': 'http://www.kma.go.kr/weather/forecast/mid-term_01.jsp',
#    'description': '기상청 날씨 웹서비스',
#    'language': 'ko',
#    'generator': '기상청',
#    'pubDate': '2022년 07월 25일 (월)요일 06:00',
#    'item': {'author': '기상청',
#     'category': '육상중기예보',
#     'title': '전국 육상 중기예보 - 2022년 07월 25일 (월)요일 06:00 발표',
#     'link': 'http://www.kma.go.kr/weather/forecast/mid-term_01.jsp',
#     'guid': 'http://www.kma.go.kr/weather/forecast/mid-term_01.jsp',
#     'description': {'header': {'title': '전국 육상중기예보',
#       'tm': '202207250600',
#       'wf': '○ (강수) 30일(토)은 전라권에 소나기가 오는 곳이 있겠습니다. <br />○ (기온) 이번 예보기간 아침 기온은 22~26도, 낮 기온은 29~34도로 어제(24일, 아침최저기온 22~24도, 낮최고기온 25~32도)보다 높겠습니다.<br />○ (주말전망) 30일(토)은 전라권에 소나기가 오는 곳이 있겠고, 31일(일)은 중부지방은 대체로 맑겠으며 남부지방과 제주도는 구름많겠습니다. <br />              아침 기온은 23~25도, 낮 기온은 31~34도가 되겠습니다.<br /><br />* 이번 예보기간 동안 우리나라 주변 기압계에 따라 소나기가 내리는 구역이 변동될 수 있으며, 돌풍과 함께 천둥.번개를 동반한 강한 소나기가 내리는 곳이 있겠으니 안전에 유의하기 바라며, 앞으로 발표되는 기상정보를 참고하기 바랍니다.'},
#      'body': {'location': [{'@wl_ver': '3',
#         'province': '서울ㆍ인천ㆍ경기도',
#         'city': '서울',
#         'data': [{'mode': 'A02',
#           'tmEf': '2022-07-28 00:00',
#           'wf': '맑음',
#           'tmn': '25',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '10'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-28 12:00',
#           'wf': '맑음',
#           'tmn': '25',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-29 00:00',
#           'wf': '맑음',
#           'tmn': '25',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-29 12:00',
#           'wf': '구름많음',
#           'tmn': '25',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-30 00:00',
#           'wf': '구름많음',
#           'tmn': '25',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-30 12:00',
#           'wf': '구름많음',
#           'tmn': '25',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-31 00:00',
#           'wf': '맑음',
#           'tmn': '25',
#           'tmx': '34',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-31 12:00',
#           'wf': '맑음',
#           'tmn': '25',
#           'tmx': '34',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-08-01 00:00',
#           'wf': '맑음',
#           'tmn': '26',
#           'tmx': '34',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-08-01 12:00',
#           'wf': '맑음',
#           'tmn': '26',
#           'tmx': '34',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-02 00:00',
#           'wf': '흐림',
#           'tmn': '26',
#           'tmx': '34',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-03 00:00',
#           'wf': '흐림',
#           'tmn': '25',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-04 00:00',
#           'wf': '흐림',
#           'tmn': '25',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'}]},
#        {'@wl_ver': '3',
#         'province': '서울ㆍ인천ㆍ경기도',
#         'city': '인천',
#         'data': [{'mode': 'A02',
#           'tmEf': '2022-07-28 00:00',
#           'wf': '맑음',
#           'tmn': '25',
#           'tmx': '31',
#           'reliability': None,
#           'rnSt': '10'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-28 12:00',
#           'wf': '맑음',
#           'tmn': '25',
#           'tmx': '31',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-29 00:00',
#           'wf': '맑음',
#           'tmn': '25',
#           'tmx': '31',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-29 12:00',
#           'wf': '구름많음',
#           'tmn': '25',
#           'tmx': '31',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-30 00:00',
#           'wf': '구름많음',
#           'tmn': '25',
#           'tmx': '31',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-30 12:00',
#           'wf': '구름많음',
#           'tmn': '25',
#           'tmx': '31',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-31 00:00',
#           'wf': '맑음',
#           'tmn': '25',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-31 12:00',
#           'wf': '맑음',
#           'tmn': '25',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-08-01 00:00',
#           'wf': '맑음',
#           'tmn': '26',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-08-01 12:00',
#           'wf': '맑음',
#           'tmn': '26',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-02 00:00',
#           'wf': '흐림',
#           'tmn': '26',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-03 00:00',
#           'wf': '흐림',
#           'tmn': '25',
#           'tmx': '31',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-04 00:00',
#           'wf': '흐림',
#           'tmn': '25',
#           'tmx': '31',
#           'reliability': None,
#           'rnSt': '40'}]},
#        {'@wl_ver': '3',
#         'province': '서울ㆍ인천ㆍ경기도',
#         'city': '수원',
#         'data': [{'mode': 'A02',
#           'tmEf': '2022-07-28 00:00',
#           'wf': '맑음',
#           'tmn': '24',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '10'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-28 12:00',
#           'wf': '맑음',
#           'tmn': '24',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-29 00:00',
#           'wf': '맑음',
#           'tmn': '24',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-29 12:00',
#           'wf': '구름많음',
#           'tmn': '24',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-30 00:00',
#           'wf': '구름많음',
#           'tmn': '25',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-30 12:00',
#           'wf': '구름많음',
#           'tmn': '25',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-31 00:00',
#           'wf': '맑음',
#           'tmn': '25',
#           'tmx': '34',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-31 12:00',
#           'wf': '맑음',
#           'tmn': '25',
#           'tmx': '34',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-08-01 00:00',
#           'wf': '맑음',
#           'tmn': '25',
#           'tmx': '34',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-08-01 12:00',
#           'wf': '맑음',
#           'tmn': '25',
#           'tmx': '34',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-02 00:00',
#           'wf': '흐림',
#           'tmn': '25',
#           'tmx': '34',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-03 00:00',
#           'wf': '흐림',
#           'tmn': '25',
#           'tmx': '34',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-04 00:00',
#           'wf': '흐림',
#           'tmn': '25',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'}]},
#        {'@wl_ver': '3',
#         'province': '서울ㆍ인천ㆍ경기도',
#         'city': '파주',
#         'data': [{'mode': 'A02',
#           'tmEf': '2022-07-28 00:00',
#           'wf': '맑음',
#           'tmn': '23',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '10'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-28 12:00',
#           'wf': '맑음',
#           'tmn': '23',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-29 00:00',
#           'wf': '맑음',
#           'tmn': '23',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-29 12:00',
#           'wf': '구름많음',
#           'tmn': '23',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-30 00:00',
#           'wf': '구름많음',
#           'tmn': '23',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-30 12:00',
#           'wf': '구름많음',
#           'tmn': '23',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-31 00:00',
#           'wf': '맑음',
#           'tmn': '23',
#           'tmx': '34',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-31 12:00',
#           'wf': '맑음',
#           'tmn': '23',
#           'tmx': '34',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-08-01 00:00',
#           'wf': '맑음',
#           'tmn': '24',
#           'tmx': '34',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-08-01 12:00',
#           'wf': '맑음',
#           'tmn': '24',
#           'tmx': '34',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-02 00:00',
#           'wf': '흐림',
#           'tmn': '25',
#           'tmx': '34',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-03 00:00',
#           'wf': '흐림',
#           'tmn': '24',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-04 00:00',
#           'wf': '흐림',
#           'tmn': '24',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'}]},
#        {'@wl_ver': '3',
#         'province': '서울ㆍ인천ㆍ경기도',
#         'city': '이천',
#         'data': [{'mode': 'A02',
#           'tmEf': '2022-07-28 00:00',
#           'wf': '맑음',
#           'tmn': '22',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '10'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-28 12:00',
#           'wf': '맑음',
#           'tmn': '22',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-29 00:00',
#           'wf': '맑음',
#           'tmn': '23',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-29 12:00',
#           'wf': '구름많음',
#           'tmn': '23',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-30 00:00',
#           'wf': '구름많음',
#           'tmn': '23',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-30 12:00',
#           'wf': '구름많음',
#           'tmn': '23',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-31 00:00',
#           'wf': '맑음',
#           'tmn': '23',
#           'tmx': '34',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-31 12:00',
#           'wf': '맑음',
#           'tmn': '23',
#           'tmx': '34',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-08-01 00:00',
#           'wf': '맑음',
#           'tmn': '24',
#           'tmx': '34',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-08-01 12:00',
#           'wf': '맑음',
#           'tmn': '24',
#           'tmx': '34',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-02 00:00',
#           'wf': '흐림',
#           'tmn': '24',
#           'tmx': '34',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-03 00:00',
#           'wf': '흐림',
#           'tmn': '24',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-04 00:00',
#           'wf': '흐림',
#           'tmn': '24',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'}]},
#        {'@wl_ver': '3',
#         'province': '서울ㆍ인천ㆍ경기도',
#         'city': '평택',
#         'data': [{'mode': 'A02',
#           'tmEf': '2022-07-28 00:00',
#           'wf': '맑음',
#           'tmn': '23',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '10'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-28 12:00',
#           'wf': '맑음',
#           'tmn': '23',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-29 00:00',
#           'wf': '맑음',
#           'tmn': '24',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-29 12:00',
#           'wf': '구름많음',
#           'tmn': '24',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-30 00:00',
#           'wf': '구름많음',
#           'tmn': '24',
#           'tmx': '34',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-30 12:00',
#           'wf': '구름많음',
#           'tmn': '24',
#           'tmx': '34',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-31 00:00',
#           'wf': '맑음',
#           'tmn': '24',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-31 12:00',
#           'wf': '맑음',
#           'tmn': '24',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-08-01 00:00',
#           'wf': '맑음',
#           'tmn': '25',
#           'tmx': '34',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-08-01 12:00',
#           'wf': '맑음',
#           'tmn': '25',
#           'tmx': '34',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-02 00:00',
#           'wf': '흐림',
#           'tmn': '25',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-03 00:00',
#           'wf': '흐림',
#           'tmn': '25',
#           'tmx': '34',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-04 00:00',
#           'wf': '흐림',
#           'tmn': '24',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'}]},
#        {'@wl_ver': '3',
#         'province': '강원도영서',
#         'city': '춘천',
#         'data': [{'mode': 'A02',
#           'tmEf': '2022-07-28 00:00',
#           'wf': '맑음',
#           'tmn': '22',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-28 12:00',
#           'wf': '맑음',
#           'tmn': '22',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-29 00:00',
#           'wf': '구름많음',
#           'tmn': '23',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '30'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-29 12:00',
#           'wf': '구름많음',
#           'tmn': '23',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-30 00:00',
#           'wf': '구름많음',
#           'tmn': '24',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-30 12:00',
#           'wf': '구름많음',
#           'tmn': '24',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-31 00:00',
#           'wf': '맑음',
#           'tmn': '24',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-31 12:00',
#           'wf': '맑음',
#           'tmn': '24',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-08-01 00:00',
#           'wf': '구름많음',
#           'tmn': '25',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '30'},
#          {'mode': 'A02',
#           'tmEf': '2022-08-01 12:00',
#           'wf': '흐림',
#           'tmn': '25',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-02 00:00',
#           'wf': '흐림',
#           'tmn': '25',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-03 00:00',
#           'wf': '흐림',
#           'tmn': '24',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-04 00:00',
#           'wf': '흐림',
#           'tmn': '24',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'}]},
#        {'@wl_ver': '3',
#         'province': '강원도영서',
#         'city': '원주',
#         'data': [{'mode': 'A02',
#           'tmEf': '2022-07-28 00:00',
#           'wf': '맑음',
#           'tmn': '22',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-28 12:00',
#           'wf': '맑음',
#           'tmn': '22',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-29 00:00',
#           'wf': '구름많음',
#           'tmn': '23',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '30'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-29 12:00',
#           'wf': '구름많음',
#           'tmn': '23',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-30 00:00',
#           'wf': '구름많음',
#           'tmn': '24',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-30 12:00',
#           'wf': '구름많음',
#           'tmn': '24',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-31 00:00',
#           'wf': '맑음',
#           'tmn': '24',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-31 12:00',
#           'wf': '맑음',
#           'tmn': '24',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-08-01 00:00',
#           'wf': '구름많음',
#           'tmn': '24',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '30'},
#          {'mode': 'A02',
#           'tmEf': '2022-08-01 12:00',
#           'wf': '흐림',
#           'tmn': '24',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-02 00:00',
#           'wf': '흐림',
#           'tmn': '24',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-03 00:00',
#           'wf': '흐림',
#           'tmn': '24',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-04 00:00',
#           'wf': '흐림',
#           'tmn': '24',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'}]},
#        {'@wl_ver': '3',
#         'province': '강원도영동',
#         'city': '강릉',
#         'data': [{'mode': 'A02',
#           'tmEf': '2022-07-28 00:00',
#           'wf': '구름많음',
#           'tmn': '23',
#           'tmx': '29',
#           'reliability': None,
#           'rnSt': '30'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-28 12:00',
#           'wf': '구름많음',
#           'tmn': '23',
#           'tmx': '29',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-29 00:00',
#           'wf': '구름많음',
#           'tmn': '24',
#           'tmx': '30',
#           'reliability': None,
#           'rnSt': '30'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-29 12:00',
#           'wf': '맑음',
#           'tmn': '24',
#           'tmx': '30',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-30 00:00',
#           'wf': '맑음',
#           'tmn': '24',
#           'tmx': '31',
#           'reliability': None,
#           'rnSt': '10'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-30 12:00',
#           'wf': '구름많음',
#           'tmn': '24',
#           'tmx': '31',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-31 00:00',
#           'wf': '맑음',
#           'tmn': '25',
#           'tmx': '31',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-31 12:00',
#           'wf': '맑음',
#           'tmn': '25',
#           'tmx': '31',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-08-01 00:00',
#           'wf': '흐림',
#           'tmn': '25',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-08-01 12:00',
#           'wf': '흐림',
#           'tmn': '25',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-02 00:00',
#           'wf': '흐림',
#           'tmn': '25',
#           'tmx': '31',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-03 00:00',
#           'wf': '흐림',
#           'tmn': '26',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-04 00:00',
#           'wf': '흐림',
#           'tmn': '26',
#           'tmx': '31',
#           'reliability': None,
#           'rnSt': '40'}]},
#        {'@wl_ver': '3',
#         'province': '대전ㆍ세종ㆍ충청남도',
#         'city': '대전',
#         'data': [{'mode': 'A02',
#           'tmEf': '2022-07-28 00:00',
#           'wf': '맑음',
#           'tmn': '23',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '10'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-28 12:00',
#           'wf': '구름많음',
#           'tmn': '23',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-29 00:00',
#           'wf': '맑음',
#           'tmn': '24',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-29 12:00',
#           'wf': '구름많음',
#           'tmn': '24',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-30 00:00',
#           'wf': '맑음',
#           'tmn': '24',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-30 12:00',
#           'wf': '구름많음',
#           'tmn': '24',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-31 00:00',
#           'wf': '맑음',
#           'tmn': '24',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-31 12:00',
#           'wf': '맑음',
#           'tmn': '24',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-08-01 00:00',
#           'wf': '구름많음',
#           'tmn': '24',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '30'},
#          {'mode': 'A02',
#           'tmEf': '2022-08-01 12:00',
#           'wf': '흐림',
#           'tmn': '24',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-02 00:00',
#           'wf': '흐림',
#           'tmn': '25',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-03 00:00',
#           'wf': '흐림',
#           'tmn': '25',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-04 00:00',
#           'wf': '흐림',
#           'tmn': '25',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'}]},
#        {'@wl_ver': '3',
#         'province': '대전ㆍ세종ㆍ충청남도',
#         'city': '세종',
#         'data': [{'mode': 'A02',
#           'tmEf': '2022-07-28 00:00',
#           'wf': '맑음',
#           'tmn': '22',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '10'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-28 12:00',
#           'wf': '구름많음',
#           'tmn': '22',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-29 00:00',
#           'wf': '맑음',
#           'tmn': '24',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-29 12:00',
#           'wf': '구름많음',
#           'tmn': '24',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-30 00:00',
#           'wf': '맑음',
#           'tmn': '24',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-30 12:00',
#           'wf': '구름많음',
#           'tmn': '24',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-31 00:00',
#           'wf': '맑음',
#           'tmn': '23',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-31 12:00',
#           'wf': '맑음',
#           'tmn': '23',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-08-01 00:00',
#           'wf': '구름많음',
#           'tmn': '24',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '30'},
#          {'mode': 'A02',
#           'tmEf': '2022-08-01 12:00',
#           'wf': '흐림',
#           'tmn': '24',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-02 00:00',
#           'wf': '흐림',
#           'tmn': '24',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-03 00:00',
#           'wf': '흐림',
#           'tmn': '24',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-04 00:00',
#           'wf': '흐림',
#           'tmn': '24',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'}]},
#        {'@wl_ver': '3',
#         'province': '대전ㆍ세종ㆍ충청남도',
#         'city': '홍성',
#         'data': [{'mode': 'A02',
#           'tmEf': '2022-07-28 00:00',
#           'wf': '맑음',
#           'tmn': '23',
#           'tmx': '31',
#           'reliability': None,
#           'rnSt': '10'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-28 12:00',
#           'wf': '구름많음',
#           'tmn': '23',
#           'tmx': '31',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-29 00:00',
#           'wf': '맑음',
#           'tmn': '24',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-29 12:00',
#           'wf': '구름많음',
#           'tmn': '24',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-30 00:00',
#           'wf': '맑음',
#           'tmn': '24',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-30 12:00',
#           'wf': '구름많음',
#           'tmn': '24',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-31 00:00',
#           'wf': '맑음',
#           'tmn': '24',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-31 12:00',
#           'wf': '맑음',
#           'tmn': '24',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-08-01 00:00',
#           'wf': '구름많음',
#           'tmn': '24',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '30'},
#          {'mode': 'A02',
#           'tmEf': '2022-08-01 12:00',
#           'wf': '흐림',
#           'tmn': '24',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-02 00:00',
#           'wf': '흐림',
#           'tmn': '25',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-03 00:00',
#           'wf': '흐림',
#           'tmn': '24',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-04 00:00',
#           'wf': '흐림',
#           'tmn': '24',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'}]},
#        {'@wl_ver': '3',
#         'province': '충청북도',
#         'city': '청주',
#         'data': [{'mode': 'A02',
#           'tmEf': '2022-07-28 00:00',
#           'wf': '맑음',
#           'tmn': '24',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '10'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-28 12:00',
#           'wf': '구름많음',
#           'tmn': '24',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-29 00:00',
#           'wf': '맑음',
#           'tmn': '24',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-29 12:00',
#           'wf': '구름많음',
#           'tmn': '24',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-30 00:00',
#           'wf': '맑음',
#           'tmn': '25',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-30 12:00',
#           'wf': '구름많음',
#           'tmn': '25',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-31 00:00',
#           'wf': '맑음',
#           'tmn': '25',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-31 12:00',
#           'wf': '구름많음',
#           'tmn': '25',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-08-01 00:00',
#           'wf': '흐림',
#           'tmn': '25',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-08-01 12:00',
#           'wf': '흐림',
#           'tmn': '25',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-02 00:00',
#           'wf': '흐림',
#           'tmn': '25',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-03 00:00',
#           'wf': '흐림',
#           'tmn': '25',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-04 00:00',
#           'wf': '흐림',
#           'tmn': '25',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'}]},
#        {'@wl_ver': '3',
#         'province': '충청북도',
#         'city': '충주',
#         'data': [{'mode': 'A02',
#           'tmEf': '2022-07-28 00:00',
#           'wf': '맑음',
#           'tmn': '22',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '10'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-28 12:00',
#           'wf': '구름많음',
#           'tmn': '22',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-29 00:00',
#           'wf': '맑음',
#           'tmn': '23',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-29 12:00',
#           'wf': '구름많음',
#           'tmn': '23',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-30 00:00',
#           'wf': '맑음',
#           'tmn': '23',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-30 12:00',
#           'wf': '구름많음',
#           'tmn': '23',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-31 00:00',
#           'wf': '맑음',
#           'tmn': '23',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-31 12:00',
#           'wf': '구름많음',
#           'tmn': '23',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-08-01 00:00',
#           'wf': '흐림',
#           'tmn': '24',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-08-01 12:00',
#           'wf': '흐림',
#           'tmn': '24',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-02 00:00',
#           'wf': '흐림',
#           'tmn': '24',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-03 00:00',
#           'wf': '흐림',
#           'tmn': '24',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-04 00:00',
#           'wf': '흐림',
#           'tmn': '24',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'}]},
#        {'@wl_ver': '3',
#         'province': '충청북도',
#         'city': '영동',
#         'data': [{'mode': 'A02',
#           'tmEf': '2022-07-28 00:00',
#           'wf': '맑음',
#           'tmn': '22',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '10'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-28 12:00',
#           'wf': '구름많음',
#           'tmn': '22',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-29 00:00',
#           'wf': '맑음',
#           'tmn': '22',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-29 12:00',
#           'wf': '구름많음',
#           'tmn': '22',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-30 00:00',
#           'wf': '맑음',
#           'tmn': '22',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-30 12:00',
#           'wf': '구름많음',
#           'tmn': '22',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-31 00:00',
#           'wf': '맑음',
#           'tmn': '23',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-31 12:00',
#           'wf': '구름많음',
#           'tmn': '23',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-08-01 00:00',
#           'wf': '흐림',
#           'tmn': '23',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-08-01 12:00',
#           'wf': '흐림',
#           'tmn': '23',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-02 00:00',
#           'wf': '흐림',
#           'tmn': '23',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-03 00:00',
#           'wf': '흐림',
#           'tmn': '23',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-04 00:00',
#           'wf': '흐림',
#           'tmn': '24',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'}]},
#        {'@wl_ver': '3',
#         'province': '광주ㆍ전라남도',
#         'city': '광주',
#         'data': [{'mode': 'A02',
#           'tmEf': '2022-07-28 00:00',
#           'wf': '구름많음',
#           'tmn': '24',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-28 12:00',
#           'wf': '구름많음',
#           'tmn': '24',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-29 00:00',
#           'wf': '맑음',
#           'tmn': '24',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-29 12:00',
#           'wf': '구름많음',
#           'tmn': '24',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-30 00:00',
#           'wf': '구름많음',
#           'tmn': '24',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-30 12:00',
#           'wf': '구름많고 소나기',
#           'tmn': '24',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '60'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-31 00:00',
#           'wf': '맑음',
#           'tmn': '25',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-31 12:00',
#           'wf': '흐림',
#           'tmn': '25',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-08-01 00:00',
#           'wf': '흐림',
#           'tmn': '25',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-08-01 12:00',
#           'wf': '흐림',
#           'tmn': '25',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-02 00:00',
#           'wf': '흐림',
#           'tmn': '25',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-03 00:00',
#           'wf': '흐림',
#           'tmn': '25',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-04 00:00',
#           'wf': '흐림',
#           'tmn': '25',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'}]},
#        {'@wl_ver': '3',
#         'province': '광주ㆍ전라남도',
#         'city': '목포',
#         'data': [{'mode': 'A02',
#           'tmEf': '2022-07-28 00:00',
#           'wf': '구름많음',
#           'tmn': '24',
#           'tmx': '31',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-28 12:00',
#           'wf': '구름많음',
#           'tmn': '24',
#           'tmx': '31',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-29 00:00',
#           'wf': '맑음',
#           'tmn': '25',
#           'tmx': '31',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-29 12:00',
#           'wf': '구름많음',
#           'tmn': '25',
#           'tmx': '31',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-30 00:00',
#           'wf': '구름많음',
#           'tmn': '25',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-30 12:00',
#           'wf': '구름많고 소나기',
#           'tmn': '25',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '60'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-31 00:00',
#           'wf': '맑음',
#           'tmn': '25',
#           'tmx': '31',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-31 12:00',
#           'wf': '흐림',
#           'tmn': '25',
#           'tmx': '31',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-08-01 00:00',
#           'wf': '흐림',
#           'tmn': '25',
#           'tmx': '31',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-08-01 12:00',
#           'wf': '흐림',
#           'tmn': '25',
#           'tmx': '31',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-02 00:00',
#           'wf': '흐림',
#           'tmn': '26',
#           'tmx': '31',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-03 00:00',
#           'wf': '흐림',
#           'tmn': '25',
#           'tmx': '31',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-04 00:00',
#           'wf': '흐림',
#           'tmn': '25',
#           'tmx': '31',
#           'reliability': None,
#           'rnSt': '40'}]},
#        {'@wl_ver': '3',
#         'province': '광주ㆍ전라남도',
#         'city': '여수',
#         'data': [{'mode': 'A02',
#           'tmEf': '2022-07-28 00:00',
#           'wf': '구름많음',
#           'tmn': '24',
#           'tmx': '30',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-28 12:00',
#           'wf': '구름많음',
#           'tmn': '24',
#           'tmx': '30',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-29 00:00',
#           'wf': '맑음',
#           'tmn': '25',
#           'tmx': '30',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-29 12:00',
#           'wf': '구름많음',
#           'tmn': '25',
#           'tmx': '30',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-30 00:00',
#           'wf': '구름많음',
#           'tmn': '25',
#           'tmx': '30',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-30 12:00',
#           'wf': '구름많고 소나기',
#           'tmn': '25',
#           'tmx': '30',
#           'reliability': None,
#           'rnSt': '60'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-31 00:00',
#           'wf': '맑음',
#           'tmn': '25',
#           'tmx': '31',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-31 12:00',
#           'wf': '흐림',
#           'tmn': '25',
#           'tmx': '31',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-08-01 00:00',
#           'wf': '흐림',
#           'tmn': '26',
#           'tmx': '30',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-08-01 12:00',
#           'wf': '흐림',
#           'tmn': '26',
#           'tmx': '30',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-02 00:00',
#           'wf': '흐림',
#           'tmn': '26',
#           'tmx': '30',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-03 00:00',
#           'wf': '흐림',
#           'tmn': '25',
#           'tmx': '30',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-04 00:00',
#           'wf': '흐림',
#           'tmn': '26',
#           'tmx': '30',
#           'reliability': None,
#           'rnSt': '40'}]},
#        {'@wl_ver': '3',
#         'province': '광주ㆍ전라남도',
#         'city': '순천',
#         'data': [{'mode': 'A02',
#           'tmEf': '2022-07-28 00:00',
#           'wf': '구름많음',
#           'tmn': '24',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-28 12:00',
#           'wf': '구름많음',
#           'tmn': '24',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-29 00:00',
#           'wf': '맑음',
#           'tmn': '24',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-29 12:00',
#           'wf': '구름많음',
#           'tmn': '24',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-30 00:00',
#           'wf': '구름많음',
#           'tmn': '25',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-30 12:00',
#           'wf': '구름많고 소나기',
#           'tmn': '25',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '60'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-31 00:00',
#           'wf': '맑음',
#           'tmn': '25',
#           'tmx': '34',
#           'reliability': None,
#           'rnSt': '20'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-31 12:00',
# ...
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-08-01 12:00',
#           'wf': '흐림',
#           'tmn': '23',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-02 00:00',
#           'wf': '흐림',
#           'tmn': '24',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-03 00:00',
#           'wf': '흐림',
#           'tmn': '24',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-04 00:00',
#           'wf': '흐림',
#           'tmn': '24',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'}]},
#        {'@wl_ver': '3',
#         'province': '대구ㆍ경상북도',
#         'city': '포항',
#         'data': [{'mode': 'A02',
#           'tmEf': '2022-07-28 00:00',
#           'wf': '구름많음',
#           'tmn': '24',
#           'tmx': '28',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-28 12:00',
#           'wf': '구름많음',
#           'tmn': '24',
#           'tmx': '28',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-29 00:00',
#           'wf': '구름많음',
#           'tmn': '25',
#           'tmx': '30',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-29 12:00',
#           'wf': '구름많음',
#           'tmn': '25',
#           'tmx': '30',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-30 00:00',
#           'wf': '구름많음',
#           'tmn': '25',
#           'tmx': '31',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-30 12:00',
#           'wf': '구름많음',
#           'tmn': '25',
#           'tmx': '31',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-31 00:00',
#           'wf': '구름많음',
#           'tmn': '25',
#           'tmx': '31',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-31 12:00',
#           'wf': '구름많음',
#           'tmn': '25',
#           'tmx': '31',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-08-01 00:00',
#           'wf': '흐림',
#           'tmn': '25',
#           'tmx': '31',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-08-01 12:00',
#           'wf': '흐림',
#           'tmn': '25',
#           'tmx': '31',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-02 00:00',
#           'wf': '흐림',
#           'tmn': '25',
#           'tmx': '31',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-03 00:00',
#           'wf': '흐림',
#           'tmn': '25',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-04 00:00',
#           'wf': '흐림',
#           'tmn': '26',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'}]},
#        {'@wl_ver': '3',
#         'province': '대구ㆍ경상북도',
#         'city': '경주',
#         'data': [{'mode': 'A02',
#           'tmEf': '2022-07-28 00:00',
#           'wf': '구름많음',
#           'tmn': '22',
#           'tmx': '29',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-28 12:00',
#           'wf': '구름많음',
#           'tmn': '22',
#           'tmx': '29',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-29 00:00',
#           'wf': '구름많음',
#           'tmn': '23',
#           'tmx': '31',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-29 12:00',
#           'wf': '구름많음',
#           'tmn': '23',
#           'tmx': '31',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-30 00:00',
#           'wf': '구름많음',
#           'tmn': '23',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-30 12:00',
#           'wf': '구름많음',
#           'tmn': '23',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-31 00:00',
#           'wf': '구름많음',
#           'tmn': '23',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-31 12:00',
#           'wf': '구름많음',
#           'tmn': '23',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-08-01 00:00',
#           'wf': '흐림',
#           'tmn': '23',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-08-01 12:00',
#           'wf': '흐림',
#           'tmn': '23',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-02 00:00',
#           'wf': '흐림',
#           'tmn': '23',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-03 00:00',
#           'wf': '흐림',
#           'tmn': '24',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-04 00:00',
#           'wf': '흐림',
#           'tmn': '24',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'}]},
#        {'@wl_ver': '3',
#         'province': '대구ㆍ경상북도',
#         'city': '울진',
#         'data': [{'mode': 'A02',
#           'tmEf': '2022-07-28 00:00',
#           'wf': '구름많음',
#           'tmn': '21',
#           'tmx': '27',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-28 12:00',
#           'wf': '구름많음',
#           'tmn': '21',
#           'tmx': '27',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-29 00:00',
#           'wf': '구름많음',
#           'tmn': '22',
#           'tmx': '28',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-29 12:00',
#           'wf': '구름많음',
#           'tmn': '22',
#           'tmx': '28',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-30 00:00',
#           'wf': '구름많음',
#           'tmn': '23',
#           'tmx': '29',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-30 12:00',
#           'wf': '구름많음',
#           'tmn': '23',
#           'tmx': '29',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-31 00:00',
#           'wf': '구름많음',
#           'tmn': '23',
#           'tmx': '29',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-31 12:00',
#           'wf': '구름많음',
#           'tmn': '23',
#           'tmx': '29',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-08-01 00:00',
#           'wf': '흐림',
#           'tmn': '24',
#           'tmx': '29',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-08-01 12:00',
#           'wf': '흐림',
#           'tmn': '24',
#           'tmx': '29',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-02 00:00',
#           'wf': '흐림',
#           'tmn': '24',
#           'tmx': '29',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-03 00:00',
#           'wf': '흐림',
#           'tmn': '24',
#           'tmx': '29',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-04 00:00',
#           'wf': '흐림',
#           'tmn': '24',
#           'tmx': '29',
#           'reliability': None,
#           'rnSt': '40'}]},
#        {'@wl_ver': '3',
#         'province': '대구ㆍ경상북도',
#         'city': '울릉도',
#         'data': [{'mode': 'A02',
#           'tmEf': '2022-07-28 00:00',
#           'wf': '구름많음',
#           'tmn': '22',
#           'tmx': '27',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-28 12:00',
#           'wf': '구름많음',
#           'tmn': '22',
#           'tmx': '27',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-29 00:00',
#           'wf': '구름많음',
#           'tmn': '23',
#           'tmx': '28',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-29 12:00',
#           'wf': '구름많음',
#           'tmn': '23',
#           'tmx': '28',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-30 00:00',
#           'wf': '구름많음',
#           'tmn': '24',
#           'tmx': '28',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-30 12:00',
#           'wf': '구름많음',
#           'tmn': '24',
#           'tmx': '28',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-31 00:00',
#           'wf': '구름많음',
#           'tmn': '24',
#           'tmx': '29',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-31 12:00',
#           'wf': '구름많음',
#           'tmn': '24',
#           'tmx': '29',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-08-01 00:00',
#           'wf': '흐림',
#           'tmn': '24',
#           'tmx': '28',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-08-01 12:00',
#           'wf': '흐림',
#           'tmn': '24',
#           'tmx': '28',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-02 00:00',
#           'wf': '흐림',
#           'tmn': '24',
#           'tmx': '28',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-03 00:00',
#           'wf': '흐림',
#           'tmn': '24',
#           'tmx': '29',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-04 00:00',
#           'wf': '흐림',
#           'tmn': '24',
#           'tmx': '29',
#           'reliability': None,
#           'rnSt': '40'}]},
#        {'@wl_ver': '3',
#         'province': '제주도',
#         'city': '제주',
#         'data': [{'mode': 'A02',
#           'tmEf': '2022-07-28 00:00',
#           'wf': '구름많음',
#           'tmn': '26',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-28 12:00',
#           'wf': '구름많음',
#           'tmn': '26',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-29 00:00',
#           'wf': '흐림',
#           'tmn': '26',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-29 12:00',
#           'wf': '구름많음',
#           'tmn': '26',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-30 00:00',
#           'wf': '구름많음',
#           'tmn': '26',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-30 12:00',
#           'wf': '구름많음',
#           'tmn': '26',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-31 00:00',
#           'wf': '구름많음',
#           'tmn': '26',
#           'tmx': '31',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-31 12:00',
#           'wf': '구름많음',
#           'tmn': '26',
#           'tmx': '31',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-08-01 00:00',
#           'wf': '흐림',
#           'tmn': '27',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-08-01 12:00',
#           'wf': '흐림',
#           'tmn': '27',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-02 00:00',
#           'wf': '흐림',
#           'tmn': '26',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-03 00:00',
#           'wf': '흐림',
#           'tmn': '27',
#           'tmx': '33',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-04 00:00',
#           'wf': '흐림',
#           'tmn': '27',
#           'tmx': '34',
#           'reliability': None,
#           'rnSt': '40'}]},
#        {'@wl_ver': '3',
#         'province': '제주도',
#         'city': '서귀포',
#         'data': [{'mode': 'A02',
#           'tmEf': '2022-07-28 00:00',
#           'wf': '구름많음',
#           'tmn': '25',
#           'tmx': '30',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-28 12:00',
#           'wf': '구름많음',
#           'tmn': '25',
#           'tmx': '30',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-29 00:00',
#           'wf': '흐림',
#           'tmn': '26',
#           'tmx': '31',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-29 12:00',
#           'wf': '구름많음',
#           'tmn': '26',
#           'tmx': '31',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-30 00:00',
#           'wf': '구름많음',
#           'tmn': '26',
#           'tmx': '31',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-30 12:00',
#           'wf': '구름많음',
#           'tmn': '26',
#           'tmx': '31',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-31 00:00',
#           'wf': '구름많음',
#           'tmn': '26',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-07-31 12:00',
#           'wf': '구름많음',
#           'tmn': '26',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-08-01 00:00',
#           'wf': '흐림',
#           'tmn': '26',
#           'tmx': '31',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A02',
#           'tmEf': '2022-08-01 12:00',
#           'wf': '흐림',
#           'tmn': '26',
#           'tmx': '31',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-02 00:00',
#           'wf': '흐림',
#           'tmn': '26',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-03 00:00',
#           'wf': '흐림',
#           'tmn': '26',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'},
#          {'mode': 'A01',
#           'tmEf': '2022-08-04 00:00',
#           'wf': '흐림',
#           'tmn': '27',
#           'tmx': '32',
#           'reliability': None,
#           'rnSt': '40'}]}]}}}}}}

# %% [markdown]
# ## 과제 07/25_3

# %% [markdown]
# #### Q. "http://www.naver.com" 사이트에서 span 태그에 연결된 한글만을 불필요한 공백을 제거한 후 출력하세요.

# %%
url="http://www.naver.com"

# %% [markdown]
# ## 과제 07/25_4

# %% [markdown]
# #### Q. "http://www.naver.com" 사이트에서 span 태그에 연결된 문자+숫자를 불필요한 공백을 제거한 후 출력하세요.

# %% [markdown]
# ## 과제 07/25_5

# %% [markdown]
# #### Q. "http://www.naver.com" 사이트에서 a 태그에 id가 있는 경우에 대하여 연결된 문자+숫자를 불필요한 공백을 제거한 후 출력하세요.

# %% [markdown]
# ## 과제 07/25_6

# %% [markdown]
# #### url = 'https://news.naver.com/' 사이트 p태크에서 class가 cjs_ht인 데이터를 한글만을 불필요한 공백을 제거한 후 출력하세요.

# %% [markdown]
# ## find_all( '태그', limit=n)
# - find_all로 찾은 태그의 n개를 뽑아 추출할 수 있음

# %%
from bs4 import BeautifulSoup
import urllib.request as rq

url = "https://naver.com/"

html = rq.urlopen(url)
bs = BeautifulSoup(html,'lxml')

print(bs.find('p'),'\n')
# print(bs.find_all('p'))

print(bs.find_all('p', limit=1),'\n')
print(bs.find_all('p', limit=2),'\n')     
print(bs.find_all('p', limit=3),'\n')
# Out:
# <p class="dsc">
# <i class="imsc ico_election"></i><span class="_alert_passage"></span>
# </p>
#
# [<p class="dsc">
# <i class="imsc ico_election"></i><span class="_alert_passage"></span>
# </p>]
#
# [<p class="dsc">
# <i class="imsc ico_election"></i><span class="_alert_passage"></span>
# </p>, <p class="dsc">ON/OFF 설정은<br/>해당기기(브라우저)에 저장됩니다.</p>]
#
# [<p class="dsc">
# <i class="imsc ico_election"></i><span class="_alert_passage"></span>
# </p>, <p class="dsc">ON/OFF 설정은<br/>해당기기(브라우저)에 저장됩니다.</p>, <p class="dsc"><em class="txt">동일한 시간대/연령/남녀별</em> 사용자 그룹의<br/>관심사에 맞춰 자동완성을 제공합니다.</p>]

# %%
from bs4 import BeautifulSoup
import requests as rq

url='https://news.daum.net/politics#1'

html = requests.get(url)
html = html.text
bs = BeautifulSoup(html, 'lxml')

# %%
#정치 타이틀 추출


#방법1
title = bs.select('#gnbContent > div > ul > li:nth-child(3) > a > span')
print(title)

#방법2
title = bs.find_all('span', class_="txt_gnb")[2]   
print(title)

#방법3
title = bs.find_all('h2', id=True)
title
# Out:
# [<span class="txt_gnb">정치</span>]
# <span class="txt_gnb">정치</span>
# [<h2 class="screen_out" id="mainContent">정치</h2>]

# %%
title = bs.find_all('h2', id=True)
title
# Out:
# [<h2 class="screen_out" id="mainContent">정치</h2>]

# %%
#네이버영화 페이지에서 영화 랭킹을 가져와서 첫번재 영화제목을 출력하기

url = 'https://movie.naver.com/'

html = requests.get(url)
html = html.text

bs = BeautifulSoup(html, 'lxml')

images = bs.find_all('img')
for image in images:
    print(image.attrs['alt'])
# Out:
# 자동완성 펼치기
# NAVER
# 영화
# 미니언즈2
# 외계+인 1부
# 범죄도시2
# 더 킬러: 죽어도 되는 아이
# 내 손 안 영화매거진 무료로 구독하세요
# 스페셜 예고편
# 메인 예고편
# 메인 예고편
# 티저 예고편
# 시선을 빼앗기다
# 신비한 해저세계
# 액션 블록버스터
# 연인의 마지막 장
# 위험에 빠지다
# 신념을 건 작전
# 맨위로
# NAVER

# %%
#두번째 방법
bs = BeautifulSoup(html,'lxml')
title = bs.find_all('div',class_='tit3')

# for t in title:
#     print(t.text)

print(title[0].text)
# Out:
# 외계+인 1부

# %% [markdown]
# ---

# %% [markdown]
# ####  과제 0726_1
# - 네이버 영화 랭킹을 가져와서 조회순 전체 영화제목을 50개 출력하세요( 출력방식: 1위: 외계+인 1부)

# %% [markdown]
# ---

# %%
html = """
<ul>
  <li><a href="hoge.html">hoge</li>
  <li><a href="https://example.com/fuga">fuga*</li>
  <li><a href="https://example.com/foo">foo*</li>
  <li><a href="http://example.com/aaa">aaa</li>
</ul>
"""

# %%
import re

bs = BeautifulSoup(html, 'html.parser')
li = bs.find_all(href = re.compile('https://'))

for e in li:
    print(e.attrs['href'])
# Out:
# https://example.com/fuga
# https://example.com/foo

# %% [markdown]
# ## CSS 선택자
# - 원하는 정보만 선별하여 수집하고 싶을 때 css선택자를 활용할 수 있음
# - (CSS 선택자 설명 추가)
# - F12 >> 수집하고 싶은 부분 클릭 >> 태그 선택 >> copy Selector
# - BeautifulSoup의 select_one, select 활용

# %%
import requests as rq
from bs4 import BeautifulSoup

url = 'http://news.daum.net/politics#1'
r =  rq.get(url)
html = r.text
bs = BeautifulSoup(html)
bs
# Out:
# <!DOCTYPE html>
# <html class="os_unknown none unknown version_0" lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="always" name="referrer"/>
# <meta content="Daum 뉴스" property="og:author"/>
# <meta content="다음뉴스" property="og:site_name"/>
# <meta content="정치" property="og:title"/>
# <meta content="https://t1.daumcdn.net/media/img-media/mobile/meta/news.png" property="og:image"/>
# <meta content="다음뉴스" property="og:description"/>
# <meta content="https://news.daum.net/politics" property="og:url"/>
# <link href="https://m2.daumcdn.net/img-media/2010ci/Daum_favicon.ico" rel="shortcut icon"/>
# <title>정치 | 다음뉴스</title>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="//t1.daumcdn.net/media/kraken/news/ac08ae6/style.css.merged.css" rel="stylesheet" type="text/css"/>
# <link href="//t1.daumcdn.net/media/kraken/news/ac08ae6/calendar.css.merged.css" rel="stylesheet" type="text/css"/>
# <!--[if lte IE 8]>
# <script src="https://m2.daumcdn.net/svc/original/U0301/cssjs/JSON-js/fc535e9cc8/json2.min.js"></script>
# <![endif]-->
# <!--[if lt IE 9]>
# <link rel="stylesheet" type="text/css" href="//t1.daumcdn.net/media/kraken/news/ac08ae6/ie8.css.merged.css" />
# <![endif]-->
# <script src="//t1.daumcdn.net/media/kraken/news/ac08ae6/common.merged.js"></script>
# <script src="https://t1.daumcdn.net/tiara/js/v1/tiara.min.js" type="text/javascript"></script>
# <script>
#   var ENV = {
#     Profile: {
#       isProduction: 'true' || false,
#       isSandbox: '' || false,
#       isCbt: '' || false,
#     }
#   }
# </script>
# <script src="//t1.daumcdn.net/media/kraken/news/ac08ae6/sectionMain.merged.js"></script>
# </head>
# <body>
# <div class="direct-link">
# <!-- 웹접근성용 바로가기 링크 모음 -->
# <a href="#mainContent">본문 바로가기</a>
# <a href="#gnbContent">메뉴 바로가기</a>
# </div>
# <div class="container-doc cont-category">
# <header class="doc-header">
# <!-- head_top -->
# <div class="head_top">
# <h1 class="doc-title">
# <a class="link_daum" data-tiara-layer="gnb default logo" href="https://www.daum.net/">
# <img alt="Daum" class="logo_daum" height="18" src="//t1.daumcdn.net/media/common/newsview_2021/pc/rtn/logo_daum.png" width="44"/>
# </a>
# <a data-tiara-layer="GNB service news" href="https://news.daum.net/" id="kakaoServiceLogo">
# <span class="ir_wa">뉴스</span>
# </a>
# </h1>
# <strong class="screen_out">관련 서비스</strong>
# <ul class="doc-relate" data-tiara-layer="GNB service">
# <li><a class="link_services" data-tiara-layer="enter" href="https://entertain.daum.net">연예</a></li>
# <li><a class="link_services" data-tiara-layer="sports" href="https://sports.daum.net">스포츠</a></li>
# </ul>
# <div id="wrapMinidaum"></div>
# <script type="text/javascript">
# 	var minidaum_options = {
# 		// background 타입 지정 관련 옵션. default: white.
# 		bgType: "white", // white, dark, custom(no background)
#
# 		// logout 시 return url 변경 여부 flag : default: false - 다음탑으로 이동
# 		enableLogoutRetun: false, // false - 다음탑으로 이동, true - 현재페이지 혹은 returnUrl 값으로 이동
# 		returnUrl: '', // default - 현재페이지(window.location.href)
#
# 		// 실시간 이슈 사용 여부, default: false
# 		disableHotissue: true, // false일 경우 사용, true일 경우 미사용
#
# 		// 로고 사용 여부, default: false
# 		disableLogo: true, // false일 경우 사용, true일 경우 미사용
#
# 		// 티아라 사용 여부, default: false
# 		disableTracker: false, // false일 경우 사용, true일 경우 미사용
#
# 		// 플래시에 의한 레이어 가림 현상 방지 사용 여부, default: false
# 		enableShield: false // false일 경우 미사용, true일 경우 사용
# 	}
# </script>
# <script src="https://go.daum.net/minidaum_pc.daum"></script>
# </div> <!-- //head_top -->
# <!-- gnb -->
# <nav class="doc-gnb" id="gnbContent">
# <div class="inner_gnb">
# <h2 class="screen_out">뉴스 메인메뉴</h2>
# <ul class="gnb_comm" data
span>
# <a class="link_txt" href="https://v.daum.net/v/20220726105430765">與 "KBS 신뢰 바닥인데..수신료 강제 징수 안돼"</a>
# </strong>
# </li>
# <li>
# <strong class="tit_g">
# <span class="info_cp">뉴시스</span>
# <a class="link_txt" href="https://v.daum.net/v/20220726105227633">서영교 "김대기·권성동, 尹에 딸랑딸랑만 하냐" 맹폭</a>
# </strong>
# </li>
# </ul>
# </div>
# <div class="box_side" data-tiara-layer="RIGHT today">
# <h3 class="screen_out">코스피/코스닥 지수</h3>
# <div class="stock_wrap">
# <div class="price_stock">
# <a alt="다음금융 코스피" data-tiara-layer="newssection finance kospi" href="https://finance.daum.net/domestic/kospi">
# <div class="item_kospi">
# <strong class="tit_stock">코스피</strong>
# <span class="rate_stock rate_up">
# <!-- 상승 rate_up, 하락 rate_down 클래스 추가 -->
# <span class="num_stock">2,408.45</span>
# <span class="num_change">
# <span class="num_prev">
# <!-- 상승 ico_up, 하락 ico_down, 보합 ico_same 클래스 적용 -->
# <span class="screen_out">전일비</span><span class="ico_up">상승</span>
#                                              4.76
#                                     </span>
# <span class="num_rate">
# <span class="screen_out">등락률</span>(0.20%)
#                                     </span>
# </span>
# </span>
# </div>
# </a>
# <a alt="다음금융 코스닥" data-tiara-layer="newssection finance kosdaq" href="https://finance.daum.net/domestic/kosdaq">
# <div class="item_kosdaq">
# <strong class="tit_stock">코스닥</strong>
# <span class="rate_stock rate_down">
# <span class="num_stock">789.32</span>
# <span class="num_change">
# <span class="num_prev">
# <span class="screen_out">전일비</span><span class="ico_down">하락</span>
#                                              0.37
#                                     </span>
# <span class="num_rate">
# <span class="screen_out">등락률</span>(-0.05%)
#                                     </span>
# </span>
# </span>
# </div>
# </a>
# </div>
# <span class="time_stock">
# <span class="screen_out">기준시간</span>
#                 11:29 장중
#             </span>
# </div>
# </div>
# <div class="box_side box_ad">
# <ins class="kakao_ad_area aside_ad" data-ad-frame-id="AMS_250exp" data-ad-frame-name="AMS_250exp" data-ad-height="250" data-ad-param-channel="media" data-ad-param-cp="pc_media_news" data-ad-type="D" data-ad-unit="05d22" data-ad-width="250" style="display:block">
# </ins>
# </div>
# <div class="box_g box_adbnr">
# <a class="link_adbnr" data-tiara-layer="BANNER wide" href="https://1boon.kakao.com/newsbot/covid">
# <img alt="뉴스봇 '코로나19 현황'" class="thumb_g" src="https://t1.daumcdn.net/section/oc/40e479d697ff47b1bac87e171d6e7e33" style="width:1100px; height:74px;"/>
# </a>
# </div>
# <div class="box_g" data-tiara-layer="SERIES">
# <h3 class="tit_box">오늘의 연재</h3>
# <ul class="list_todayseries">
# <li>
# <div class="item_todayseries">
# <div class="subtxt_thumb">
# <a class="info_cp" data-tiara-id="5335019" data-tiara-layer="series_thumb" data-tiara-ordnum="1" data-tiara-type="series" href="/series/5335019">
# <span class="screen_out">출처</span>한반도N</a>
# </div>
# <a class="wrap_thumb" data-tiara-id="5335019" data-tiara-layer="series_thumb" data-tiara-ordnum="1" data-tiara-type="series" href="https://v.daum.net/v/20220726110304315">
# <img alt="[한반도N] 불황에 대처하는 7가지 방법" class="thumb_g" src="https://img1.daumcdn.net/thumb/S176x136ht.u/?fname=https%3A%2F%2Ft1.daumcdn.net%2Fnews%2F202207%2F26%2Fyonhap%2F20220726110307193oqnp.jpg&amp;scode=media"/>
# </a>
# <div class="cont_thumb">
# <strong class="tit_g">
# <a class="link_txt" data-tiara-id="5335019" data-tiara-layer="article" data-tiara-ordnum="1" data-tiara-type="series" href="https://v.daum.net/v/20220726110304315">불황에 대처하는 7가지 방법</a>
# </strong>
# <span class="info_thumb">
# <span class="txt_info
# <ins class="kakao_ad_area" data-ad-frame-id="AMS_250exp" data-ad-frame-name="AMS_250exp" data-ad-height="250" data-ad-param-channel="media" data-ad-param-cp="pc_media_news" data-ad-type="D" data-ad-unit="DAN-WApyM79GH3N7yEg9" data-ad-width="250" style="display:block"></ins>
# </div>
# <!-- 배너 -->
# </div>
# </div>
# </section>
# </main>
# <footer class="doc-footer" id="kakaoFoot">
# <div class="inner_foot #FOOTER" data-tiara-layer="FOOTER">
# <div class="direct_link #direct" data-tiara-layer="direct">
# <h2 class="tit_direct">바로가기</h2>
# <div class="item_bundle">
# <a class="link_txt #direct_newshome" data-tiara-layer="direct_newshome" href="/">뉴스홈</a>
# <a class="link_txt #direct_society" data-tiara-layer="direct_society" href="/society">사회</a>
# <a class="link_txt #direct_politics" data-tiara-layer="direct_politics" href="/politics">정치</a>
# <a class="link_txt #direct_economic" data-tiara-layer="direct_economic" href="/economic">경제</a>
# <a class="link_txt #direct_foreign" data-tiara-layer="direct_foreign" href="/foreign">국제</a>
# <a class="link_txt #direct_culture" data-tiara-layer="direct_culture" href="/culture">문화</a>
# <a class="link_txt #direct_digital" data-tiara-layer="direct_digital" href="/digital">IT</a>
# <a class="link_txt #direct_photo" data-tiara-layer="direct_photo" href="/photo">포토</a>
# </div>
# <div class="item_bundle">
# <a class="link_txt #direct_media" data-tiara-layer="direct_media" href="/cp">언론사별 뉴스</a>
# </div>
# <div class="item_bundle">
# <a class="link_txt #direct_history" data-tiara-layer="direct_history" href="/newsbox">배열이력</a>
# </div>
# <div class="item_bundle">
# <a class="link_txt #direct_all" data-tiara-layer="direct_all" href="/breakingnews">전체뉴스</a>
# <a class="link_txt #direct_series" data-tiara-layer="direct_series" href="/series">연재</a>
# <a class="link_txt #direct_factcheck" data-tiara-layer="direct_factcheck" href="https://focus.daum.net/ch/news/factcheck">팩트체크</a>
# </div>
# <button class="btn_fold" type="button"><span class="ico_news">바로가기 링크 더보기/접기</span></button>
# </div>
# <h2 class="screen_out">서비스 이용정보</h2>
# <div class="footer_link">
# <a class="link_info #info_daumnews" data-tiara-layer="info_daumnews" href="/info/intro">다음뉴스 소개</a>
# <span class="txt_dot"> ・ </span> <a class="link_info #notice" data-tiara-layer="notice" href="https://magazine.daum.net/daumnews_notice">공지사항</a>
# <span class="txt_dot"> ・ </span> <a class="link_info #bbsrule" data-tiara-layer="bbsrule" href="/info/bbsrule">게시물 운영원칙</a>
# <span class="txt_dot"> ・ </span> <a class="link_info #policy" data-tiara-layer="policy" href="http://policy.daum.net/info/info">서비스 약관/정책</a>
# <span class="txt_dot"> ・ </span> <a class="link_info #harmony" data-tiara-layer="harmony" href="https://with.kakao.com/media">뉴스제휴</a>
# <span class="txt_dot"> ・ </span> <a class="link_info #adinfo" data-tiara-layer="adinfo" href="https://business.kakao.com">비즈니스</a>
# <span class="txt_dot"> ・ </span> <a class="link_info #redbell" data-tiara-layer="redbell" href="https://cs.daum.net/redbell/top.html">권리침해신고</a>
# <span class="txt_dot"> ・ </span> <a class="link_info #consumer" data-tiara-layer="consumer" href="http://cs.daum.net/faq/63.html">다음뉴스 고객센터</a>
# </div>
# <div class="footer_link"> <a class="link_info #newscenter" data-tiara-layer="newscenter" href="/info/newscenter24">24시간 뉴스센터</a>
# <span class="txt_dot"> ・ </span> <a class="link_info #edit" data-tiara-layer="edit" href="/info/edit">서비스원칙</a>
# <span class="txt_dot"> ・ </span> <a class="link_info #correct" data-tiara-layer="correct" href="/info/correct">고침기사, 정정・반론・추후보도 모음</a>
# <span class="txt_dot"> ・ </span> <span class="link_info">기사배열책임자 : 황유지</span> <span class="txt_dot"> ・ </span>
# <span class="link_info">청소년보호책임자 : 정현주</span>
# </div>
# <div class="info_copyright">
# <strong class="info_warn">뉴스 기사에 대한 저작권 및 법적 책임은 자료제공사 또는 <br/>글쓴이에 있으며, Kakao의 입장과 다를 수 있습니다.</strong>
# <small class="txt_copyright">Copyright © <strong class="txt_kakao"><a class="link_kakao" href="http://www.kakaocorp.com/">Kakao Corp.</a></strong> All rights reserved.</small>
# </div>
# </div>
# </footer>
# <script src="//t1.daumcdn.net/media/kraken/news/ac08ae6/footer.merged.js"></script>
# <script async="" src="//t1.daumcdn.net/kas/static/ba.min.js" type="text/javascript"></script>
# </div>
# </body>
# </html>

# %% [markdown]
# ##### body 중간에 기사 헤드 전체 뽑기

# %%
#css 선택자를 이용해서 기사 헤드 전체 추출

line = bs.select('body > div.container-doc.cont-category > main > section > div.main-sub > div.box_g.box_news_major > ul > li:nth-child(1) > strong > a')
lines = bs.select('body > div > main > section > div > div > ul > li > strong > a')

print(line,'\n')
print(lines)
# Out:
# [<a class="link_txt" href="https://v.daum.net/v/20220726111417964">[무등의 아침] 이동학 "이재명 당 대표 되면 적대적 공생..망가진 정치 바꿀 것"</a>]
#
# [<a class="link_txt" href="https://v.daum.net/v/20220726111417964">[무등의 아침] 이동학 "이재명 당 대표 되면 적대적 공생..망가진 정치 바꿀 것"</a>, <a class="link_txt" href="https://v.daum.net/v/20220726111023772">[인터뷰] 與 홍석준 "금산분리 등 금융 규제 들여다볼 것"</a>, <a class="link_txt" href="https://v.daum.net/v/20220726111001736">시간외근로 선원, 수당 대신 휴가 조항 삭제..선원법 개정 추진</a>, <a class="link_txt" href="https://v.daum.net/v/20220726110807623">초유의 경란(警亂).. 尹의 '옐로카드'</a>, <a class="link_txt" href="https://v.daum.net/v/20220726110433391">[뉴스라이브] 민주당 전당대회 컷오프 D-2..'586 당권 주자' 김민석 의원에게 묻는다</a>, <a class="link_txt" href="https://v.daum.net/v/20220726110123240">북한 해역에 나타난 중국 선박.."신분 세탁한 北 선박일 수도"</a>, <a class="link_txt" href="https://v.daum.net/v/20220726105953058">박홍근 "국기문란 자초한건 尹대통령..지지율 폭락원인 몰라?"</a>, <a class="link_txt" href="https://v.daum.net/v/20220726105453780">정점식 "박범계, 한동훈 놓고 재임시절 잘못 합리화..후안무치"</a>, <a class="link_txt" href="https://v.daum.net/v/20220726105430765">與 "KBS 신뢰 바닥인데..수신료 강제 징수 안돼"</a>, <a class="link_txt" href="https://v.daum.net/v/20220726105227633">서영교 "김대기·권성동, 尹에 딸랑딸랑만 하냐" 맹폭</a>]

# %%
#기사 헤드 합치기

body= '\n'.join([line.text for line in lines])
print(body)
# Out:
# [무등의 아침] 이동학 "이재명 당 대표 되면 적대적 공생..망가진 정치 바꿀 것"
# [인터뷰] 與 홍석준 "금산분리 등 금융 규제 들여다볼 것"
# 시간외근로 선원, 수당 대신 휴가 조항 삭제..선원법 개정 추진
# 초유의 경란(警亂).. 尹의 '옐로카드'
# [뉴스라이브] 민주당 전당대회 컷오프 D-2..'586 당권 주자' 김민석 의원에게 묻는다
# 북한 해역에 나타난 중국 선박.."신분 세탁한 北 선박일 수도"
# 박홍근 "국기문란 자초한건 尹대통령..지지율 폭락원인 몰라?"
# 정점식 "박범계, 한동훈 놓고 재임시절 잘못 합리화..후안무치"
# 與 "KBS 신뢰 바닥인데..수신료 강제 징수 안돼"
# 서영교 "김대기·권성동, 尹에 딸랑딸랑만 하냐" 맹폭

# %% [markdown]
# - body 중간에 첫번째 기사 헤드 뽑기

# %%
#select_one 사용

line = bs.select_one('body > div > main > section > div > div > ul > li > strong > a')
print(line)

body = line.text
print(body)
# Out:
# <a class="link_txt" href="https://v.daum.net/v/20220726111417964">[무등의 아침] 이동학 "이재명 당 대표 되면 적대적 공생..망가진 정치 바꿀 것"</a>
# [무등의 아침] 이동학 "이재명 당 대표 되면 적대적 공생..망가진 정치 바꿀 것"

# %% [markdown]
# ##### body 중간에 첫번째 기사 헤드의 내용 뽑아서 불필요한 공백 제거

# %%
url = bs.select_one('body > div > main > section > div > div > ul > li > strong > a').attrs['href']
print(url)

html=rq.get(url)
bs2=BeautifulSoup(html.text, 'html.parser')
bs2
# Out:
# https://v.daum.net/v/20220726111417964
# <!DOCTYPE html>
#
# <html lang="ko">
# <head data-cloud-area="head">
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <style>
#             @import url('//t1.daumcdn.net/harmony_static/cloud/page/07dbf94b96594fe2ea9953108239daca8e501bfc1653982322266.css');
#             @import url('//t1.daumcdn.net/harmony_static/cloud/2022/06/29/common.98cb4e1c81a314168abb.css')
#         </style>
# <style>
#             /* 다음 카페 소셜 쉐어 임시 비활성화 */
#             .list_sns li:nth-child(6) {
#                 display: none;
#             }
#         </style>
# <meta content="Z5yfeJv8jA" property="mccp:docId"/>
# <meta content="다음뉴스" property="og:site_name"/>
# <meta content='[무등의 아침] 이동학 "이재명 당 대표 되면 적대적 공생..망가진 정치 바꿀 것"' property="og:title"/>
# <meta content="20220726111416" property="og:regDate"/>
# <meta content="article" property="og:type"/>
# <meta content="KBS" property="og:article:author"/>
# <meta content="https://news.v.daum.net/v/Z5yfeJv8jA" property="og:url"/>
# <meta content="https://img1.daumcdn.net/thumb/S1200x630/?fname=https://t1.daumcdn.net/news/202207/26/kbs/20220726111418759vxaw.jpg" property="og:image"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="630" property="og:image:height"/>
# <meta content="[KBS 광주] ■ 인터뷰 자료의 저작권은 KBS에 있습니다. 인용보도 시 출처를 밝혀주시기 바랍니다. ■ 프로그램명 : [출발! 무등의 아침] ■ 방송시간 : 08:30∼09:00 KBS광주 1R FM 90.5 MHz ■ 진행 : 정길훈 앵커(전 보도국장) ■ 출연 : 이동학 민주당 당 대표 후보 ■ 구성 : 정유라 작가 ■ 기술 : 임재길" property="og:description"/>
# <meta content="daumapps://web?url=https%3A%2F%2Fnews.v.daum.net/v/Z5yfeJv8jA" property="al:android:url"/>
# <meta content="net.daum.android.daum" property="al:android:package"/>
# <meta content="다음앱" property="al:android:app_name"/>
# <meta content="daumapps://web?url=https%3A%2F%2Fnews.v.daum.net/v/Z5yfeJv8jA" property="al:ios:url"/>
# <meta content="365494029" property="al:ios:app_store_id"/>
# <meta content="다음앱" property="al:ios:app_name"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="daumapps://web?url=https%3A%2F%2Fnews.v.daum.net/v/Z5yfeJv8jA" property="twitter:app:url:googleplay"/>
# <meta content="net.daum.android.daum" property="twitter:app:id:googleplay"/>
# <meta content="다음앱" property="twitter:app:name:googleplay"/>
# <meta content="KR" property="twitter:app:country"/>
# <meta content="daumapps://web?url=https%3A%2F%2Fnews.v.daum.net/v/Z5yfeJv8jA" property="twitter:app:url:iphone"/>
# <meta content="365494029" property="twitter:app:id:iphone"/>
# <meta content="다음앱" property="twitter:app:name:iphone"/>
# <meta content="daumapps://web?url=https%3A%2F%2Fnews.v.daum.net/v/Z5yfeJv8jA" property="twitter:app:url:ipad"/>
# <meta content="365494029" property="twitter:app:id:ipad"/>
# <meta content="다음앱" property="twitter:app:name:ipad"/>
# <meta content="unsafe-url" name="referrer"/>
# <title>[무등의 아침] 이동학 "이재명 당 대표 되면 적대적 공생..망가진 정치 바꿀 것"</title>
# <link href="//t1.daumcdn.net/top/favicon.ico" rel="shortcut icon"/>
# </head>
# <body class="">
# <div id="kakaoIndex"> <a href="#kakaoBody">본문 바로가기</a> <a href="#kakaoGnb">메뉴 바로가기</a>
# </div>
# <div class="newsview_media" id="kakaoWrap">
# <div id="wrapMinidaum"></div>
# <div data-cloud-area="header" id="kakaoHead" role="banner">
# <div class="head_media" data-cloud="pc_header_gnb">
# <h1> <a class="link_daum" href="https://www.daum.net"> <img alt="Daum" class="thumb_g" height="19" src="//t1.daumcdn.net/media/news/news2016/retina/logo_daum.jpg" width="45"/> </a> <a href="//news.daum.net" id="kakaoServiceLogo"><span class="ir_wa">뉴스</span></a> </h1> <strong class="screen_out">관련서비스</strong>
# <ul id="kakaoRelServicesNew">
# <li><a class="link_services" href="https://entertain.daum.net/"><span class="ir_wa">연예</span></a></li>
# <li><a class="link_services" href="https://sports.daum.net/"><span class="ir_wa">스포츠</span></a></li>
# </ul>
# <h2 class="screen_out">검색</h2>
# <div class="search_news" id="search_news">
# <form action="https://search.daum.net/search" id="kakaoSearch" method="get" name="kakaoSearch">
# <fieldset class="fld_inside"> <legend class="screen_out">검색어 입력폼</legend>
# <div class="box_searchbar"> <label class="lab_search" for="qVal">통합검색</label>
# <input name="nil_profile" type="hidden" value="search"/>
# <input name="nil_src" type="hidden" value="media"/>
# <input name="DA" type="hidden" value="23A"/>
# <input name="rtmaxcoll" type="hidden" value="NNS"/>
# <input autocomplete="off" class="tf_keyword" id="qVal" name="q" spellcheck="false" title="검색어 입력" type="text" value=""/> <button class="btn_search" id="kakaoBtnSearch" type="submit"><span class="ir_wa">검색</span></button>
# </div>
# </fieldset>
# <div class="wrap_suggestBox" id="wrap_suggestBox">
# <div class="suggestBox box_sub" id="suggestBox">
# <div class="baseBox bg" style="display: none"></div>
# </div>
# </div>
# </form>
# </div>
# </div>
# <div data-cloud="pc_header_gnb" id="kakaoGnb" role="navigation">
# <div class="inner_gnb">
# <h2 class="screen_out">뉴스 메인메뉴</h2>
# <ul class="gnb_comm" data-category="politics">
# <li class="home"><a class="link_gnb link_gnb1" href="//news.daum.net/"><span class="ir_wa">홈</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li class="society"><a class="link_gnb link_gnb2" href="//news.daum.net/society/"><span class="ir_wa">사회</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li class="politics"><a class="link_gnb link_gnb3" href="//news.daum.net/politics/"><span class="ir_wa">정치</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li class="economic"><a class="link_gnb link_gnb4" href="//news.daum.net/economic/"><span class="ir_wa">경제</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li class="foreign"><a class="link_gnb link_gnb5" href="//news.daum.net/foreign/"><span class="ir_wa">국제</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li class="culture"><a class="link_gnb link_gnb6" href="//news.daum.net/culture/"><span class="ir_wa">문화</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li class="digital"><a class="link_gnb link_gnb7" href="//news.daum.net/digital/"><span class="ir_wa">IT</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li class="series editorial"><a class="link_gnb link_gnb9" href="//news.daum.net/series"><span class="ir_wa">연재</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li class="photo"><a class="link_gnb link_gnb10" href="//news.daum.net/photo"><span class="ir_wa">포토</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li class="factcheck"> <a class="link_gnb link_gnb12" href="https://focus.daum.net/ch/news/factcheck"><span class="ir_wa">팩트체크</span><span class="bar_gnb"><span class="inner_bar"></span></span></a> </li>
# </ul>
# <div class="gnb_etc">
# <div class="gnb_weather"> <strong class="screen_out">날씨 정보</strong>
# <div id="gnb_weather">
# <ul class="list_weather" data-nightyn="N"></ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="bar_progress" data-cloud="pc_header_gnb" id="barProgress"></div>
# </div>
# <div id="dummyKakaoGnb" style="height:137px; display:none;"></div>
# <hr class="hide"/>
# <div class="cont_view" id="kakaoContent" role="main">
# <h2 class="screen_out" id="kakaoBody">정치</h2>
# <div data-cloud-area="title" id="cSub">
# <div class="head_view" data-cloud="pc_article_title_and_util"> <em class="info_cp"> <a class="link_cp" href="http://news.kbs.co.kr/" target="_blank"> <img alt="KBS" class="thumb_g" src="https://t1.daumcdn.net/media/news/news2016/cp/cp_kbs.gif"/> </a> </em>
# <h3 class="tit_view" data-translation="true">[무등의 아침] 이동학 "이재명 당 대표 되면 적대적 공생..망가진 정치 바꿀 것"</h3> <span class="info_view"> <span class="txt_info">정길훈</span> <span class="txt_info">입력 <span class="num_date">2022. 07. 26. 11:14</span></span> <button class="emph_g2 link_cmt" id="alexCounter">댓글 <span class="alex-count-area">0</span>개</button> </span>
# <div class="util_view">
# <h4 class="screen_out">기사 도구 모음</h4>
# <div class="btn_util tts_btn"> <button aria-expanded="false" class="btn_set btn_tts" type="button"> <span class="ico_newsview ico_speak">음성 기사 듣기</span> </button>
# <div class="wrap_setlayer">
# <div class="layer_util layer_set layer_tts"> <strong class="screen_out">음성 기사 옵션 조절 레이어</strong>
# <ul class="list_set list_tts">
# <li> <input class="screen_out" id="ttsGenderMale" name="ttsGender" type="radio" value="Male"/> <label class="lab_set" for="ttsGenderMale"><span class="ico_newsview"></span>남성</label> </li>
# <li> <input class="screen_out" id="ttsGenderFemale" name="ttsGender" type="radio" value="Female"/> <label class="lab_set" for="ttsGenderFemale"><span class="ico_newsview"></span>여성</label> </li>
# </ul>
# <ul class="list_set list_tts list_ttsspeed">
# <li> <input class="screen_out" id="ttsSpeedSlow" name="ttsSpeed" type="radio" value="slow"/> <label class="lab_set" for="ttsSpeedSlow"><span class="ico_newsview"></span>느림</label> </li>
# <li> <input class="screen_out" id="ttsSpeedNormal" name="ttsSpeed" type="radio" value="normal"/> <label class="lab_set" for="ttsSpeedNormal"><span class="ico_newsview"></span>보통</label> </li>
# <li> <input class="screen_out" id="ttsSpeedFast" name="ttsSpeed" type="radio" value="fast"/> <label class="lab_set" for="ttsSpeedFast"><span class="ico_newsview"></span>빠름</label> </li>
# </ul>
# </div>
# </div>
# <audio id="ttsPlayer" preload="none" style="display:none"></audio>
# </div>
# <div class="btn_util translate_btn"> <button aria-expanded="false" class="btn_set btn_translate #util #translate #set" type="button"><span class="ico_newsview">번역 설정</span></button>
# <div class="wrap_translatelayer">
# <div class="layer_util layer_translate"> <strong class="tit_translate">번역<span class="ico_newsview">beta</span> </strong>
# <p class="desc_translate txt_newsview">Translated by <a class="link_kakaoi #util #translate #kakaoi_link" href="https://kakao.ai/" target="_blank">kakao i</a></p> <strong class="screen_out">번역할 언어 선택</strong>
# <ul class="list_lang">
# <li> <button class="btn_lang btn_en #util #translate #lang_en" name="en"> <span class="ico_newsview ico_flag"></span> <strong class="ico_newsview tit_lang">English</strong> </button> </li>
# <li> <button class="btn_lang btn_ch #util #translate #lang_cn" name="cn" type="button"> <span class="ico_newsview ico_flag"></span> <strong class="ico_newsview tit_lang">简体中文</strong> </button> </li>
# <li> <button class="btn_lang btn_jp #util #translate #lang_jp" name="jp" type="button"> <span class="ico_newsview ico_flag"></span> <strong class="ico_newsview tit_lang">日本語</strong> </button> </li>
# <li> <button class="btn_lang btn_ind #util #translate #lang_id" name="id" type="button"> <span class="ico_newsview ico_flag"></span> <strong class="ico_newsview tit_lang">Bahasa Indonesia</strong> </button> </li>
# <li> <button class="btn_lang btn_viet #util #translate #lang_vi" name="vi" type="button"> <span class="ico_newsview ico_flag"></span> <strong class="ico_newsview tit_lang">tiếng Việt</strong> </button> </li>
# <li> <button class="btn_lang btn_ko #util #translate #lang_kr" name="kr" type="button"> <span class="ico_newsview ico_flag"></span> <strong class="ico_newsview tit_lang">한국어</strong> </button> </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="btn_util share_btn"> <button aria-expanded="false" class="btn_set btn_share" id="rSocialShareButton"> <span class="ico_newsview">공유</span> </button>
# <div id="rSocialShareLayerContainer"></div>
# </div>
# <div class="btn_util font_btn"> <button aria-expanded="false" class="btn_set btn_font" type="button"> <span class="ico_newsview ico_font">글씨크기 조절하기</span> </button>
# <div class="wrap_setlayer">
# <div class="layer_util layer_set layer_font"> <strong class="screen_out">글자 크기 조절 레이어</strong>
# <ul class="list_set list_font">
# <li> <input class="screen_out" id="inpFont17" name="inpFont" type="radio" value="17"/> <label class="lab_set lab_size0" for="inpFont17"> <span class="ico_newsview"></span> <span aria-hidden="true">가나다라마바사</span> <span class="screen_out">매우 작은 폰트</span> </label> </li>
# <li> <input class="screen_out" id="inpFont18" name="inpFont" type="radio" value="18"/> <label class="lab_set lab_size1" for="inpFont18"> <span class="ico_newsview"></span> <span aria-hidden="true">가나다라마바사</span> <span class="screen_out">작은 폰트</span> </label> </li>
# <li> <input class="screen_out" id="inpFont19" name="inpFont" type="radio" value="19"/> <label class="lab_set lab_size2" for="inpFont19"> <span class="ico_newsview"></span> <span aria-hidden="true">가나다라마바사</span> <span class="screen_out">보통 폰트</span> </label> </li>
# <li> <input class="screen_out" id="inpFont20" name="inpFont" type="radio" value="20"/> <label class="lab_set lab_size3" for="inpFont20"> <span class="ico_newsview"></span> <span aria-hidden="true">가나다라마바사</span> <span class="screen_out">큰 폰트</span> </label> </li>
# <li> <input class="screen_out" id="inpFont21" name="inpFont" type="radio" value="21"/> <label class="lab_set lab_size4" for="inpFont21"> <span class="ico_newsview"></span> <span aria-hidden="true">가나다라마바사</span> <span class="screen_out">매우 큰 폰트</span> </label> </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="btn_util"> <button class="btn_print" type="button"><span class="ico_newsview">인쇄하기 새창열림</span></button>
# </div>
# </div>
# </div>
# </div>
# <div id="cMain">
# <div id="mArticle">
# <div data-cloud-area="article">
# <div class="status_view" data-cloud="pc_article_body" id="translateNotice" style="display:none;"> <span class="inner_status"> <p class="txt_status notice_lang notice_lang_en" style="display:none;">The copyright belongs to the original writer of the content, and there may be errors in machine translation results.</p> <p class="txt_status notice_lang notice_lang_cn" style="display:none;">版权归内容原作者所有。机器翻译结果可能存在错误。</p> <p class="txt_status notice_lang notice_lang_jp" style="display:none;">原文の著作権は原著著作者にあり、機械翻訳の結果にエラーが含まれることがあります。</p> <p class="txt_status notice_lang notice_lang_id" style="display:none;">Hak cipta milik penulis asli dari konten, dan mungkin ditemukan kesalahan dalam hasil terjemahan mesin.</p> <p class="txt_status notice_lang notice_lang_vi" style="display:none;">Bản quyền thuộc về tác giả gốc của nội dung và có thể có lỗi trong kết quả dịch bằng máy.</p> </span>
# </div>
# <div class="news_view" data-cloud="pc_article_body" style="font-size:17px"> <strong class="summary_view" data-translation="true"> - "어제 광주 방문..민주당에 대한 실망 여론 들어"<br/>- "양당제 폐해 심각..정치 교체 위해 당대표 경선 출마"<br/>- "이재명 당 대표 되면 적대적 공생관계 강화..정치 교체 청사진 밝혀야"<br/>- "반명 단일화 거부..친명, 반명 아닌 다양한 의제로 경선 치러야"<br/>- "이준석·박지현 소신 높게 평가..청년정치, 기득권에 맞서야"<br/>- "민주당, 양당제 기득권 누려..호남서 낮은 투표율로 심판 받아" </strong>
# <div class="article_view" data-translation-body="true" id="harmonyContainer">
# <section dmcf-sid="UMrHpuLZAi">
# <div dmcf-pid="uAYz46mBjJ" dmcf-ptype="general">
#            [KBS 광주]
#           </div>
# <figure class="figure_frm origin_fig" dmcf-pid="7Wbdjc1iod" dmcf-ptype="figure">
# <p class="link_figure"><img class="thumb_g_article" data-org-src="https://t1.daumcdn.net/news/202207/26/kbs/20220726111418759vxaw.jpg" data-org-width="1920" dmcf-mid="5jZ3b9cpcj" dmcf-mtype="image" height="auto" src="https://img2.daumcdn.net/thumb/R658x0.q70/?fname=https://t1.daumcdn.net/news/202207/26/kbs/20220726111418759vxaw.jpg" width="658"/></p>
# </figure>
# <div dmcf-pid="zSqRajZdae" dmcf-ptype="general">
# <br/>
# </div>
# <blockquote class="pretip_frm" dmcf-pid="qvBeNA5JAR" dmcf-ptype="pre">
#             ■ 인터뷰 자료의 저작권은 KBS에 있습니다. 인용보도 시 출처를 밝혀주시기 바랍니다.
#            <br/> ■ 프로그램명 : [출발! 무등의 아침]
#            <br/> ■ 방송시간 : 08:30∼09:00 KBS광주 1R FM 90.5 MHz
#            <br/> ■ 진행 : 정길훈 앵커(전 보도국장)
#            <br/> ■ 출연 : 이동학 민주당 당 대표 후보
#            <br/> ■ 구성 : 정유라 작가
#            <br/> ■ 기술 : 임재길 감독
#            <br/>
# </blockquote>
# <div dmcf-pid="Bh7xoaHRoM" dmcf-ptype="general">
# <br/>
# </div>
# <div class="video_frm" dmcf-pid="b3MkClbDax" dmcf-ptype="embed">
# <div class="layer_vod">
# <div class="vod_player">
# <iframe allowfullscreen="" class="player_iframe" dmcf-mid="0Bbdjc1ijL" dmcf-mtype="video/youtube" frameborder="0" height="370" id="video@0Bbdjc1ijL" scrolling="no" src="https://www.youtube.com/embed/urNWncrapxY?origin=https://news.v.daum.net&amp;enablejsapi=1&amp;playsinline=1" width="100%"></iframe>
# </div>
# </div>
# </div>
# <div dmcf-pid="KyKJAktnoQ" dmcf-ptype="general">
# <br/>▶유튜브 영상 바로가기 주소 https://youtu.be/urNWncrapxY
#           </div>
# <p dmcf-pid="97imTWfOaP" dmcf-ptype="general">◇ 정길훈 앵커 (이하 정길훈): 민주당 당권 주자 가운데 유일한 청년 후보인 이동학 전 최고위원이 어제 광주를 찾았습니다. 이 후보는 낡은 기득권 정치를 끝내고 정치 교체를 이루자, 이렇게 주장하고 있는데요. 이동학 후보 연결합니다. 안녕하십니까?</p>
# <p dmcf-pid="2vBeNA5Jj6" dmcf-ptype="general">◆ 더불어민주당 이동학 전 최고위원 (이하 이동학): 안녕하십니까?</p>
# <figure class="figure_frm origin_fig" dmcf-pid="VbgCGXPlN8" dmcf-ptype="figure">
# <p class="link_figure"><img class="thumb_g_article" data-org-src="https://t1.daumcdn.net/news/202207/26/kbs/20220726111420337yrnq.jpg" data-org-width="1920" dmcf-mid="18SY3piHjN" dmcf-mtype="image" height="auto" src="https://img3.daumcdn.net/thumb/R658x0.q70/?fname=https://t1.daumcdn.net/news/202207/26/kbs/20220726111420337yrnq.jpg" width="658"/></p>
# </figure>
# <p dmcf-pid="ftQAOCqkN4" dmcf-ptype="general"><br/>◇ 정길훈: 어제 광주를 방문해서 당원들도 만나고 시민도 만나셨을 텐데요. 민심이 어땠습니까?</p>
# <p dmcf-pid="4KahHZQSNf" dmcf-ptype="general">◆ 이동학: 우선 최선을 다해서 밀어줬는데 대선에서 패배한 데 대해서 실망을 표하시는 분들도 계셨고요. 민주당이 개선의 노력은 안 하는데 선거 때만 읍소를 한다, 이런 실망감을 표시하시는 분도 계셨습니다.</p>
# <p dmcf-pid="8znsyY4IcV" dmcf-ptype="general">◇ 정길훈: 현재 당권에 여덟 분이 도전하고 있는데요. 이 후보가 당 대표에 도전해야 되겠다고 결심한 이유 어떤 것입니까?</p>
# <figure class="figure_frm origin_fig" dmcf-pid="6gyuV4wzA2" dmcf-ptype="figure">
# <p class="link_figure"><img alt="사진 출처 : 연합뉴스" class="thumb_g_article" data-org-src="https://t1.daumcdn.net/news/202207/26/kbs/20220726111421878esza.jpg" data-org-width="640" dmcf-mid="tDz9xRhVoa" dmcf-mtype="image" height="auto" src="https://img4.daumcdn.net/thumb/R658x0.q70/?fname=https://t1.daumcdn.net/news/202207/26/kbs/20220726111421878esza.jpg" width="658"/></p>
# <figcaption class="txt_caption default_figure">
#             사진 출처 : 연합뉴스
#            </figcaption>
# </figure>
# <p dmcf-pid="P7imTWfOg9" dmcf-ptype="general"><br/>◆ 이동학: 우선 저는 정치가 좀 망가져 있는 것 아닌가라고 판단을 하고 있는데요. 이것은 왜 그러냐 하면 우리가 상대방의 발목을 잡고 못하게 막으면 저들이 넘어지게 되어 있잖아요.</p>
# <p dmcf-pid="QznsyY4IcK" dmcf-ptype="general">◇ 정길훈: 양당 정치에서 말씀하시는 것이지요.</p>
# <p dmcf-pid="xIUPnoYxkb" dmcf-ptype="general">◆ 이동학: 네. 그러면 선택지가 우리밖에 없으니 우리를 뽑게 되는 것이에요. 국민들 입장에서는요. 그리고 상대방이 또 우리의 발목을 잡고 우리가 넘어지면 또 상대방을 찍는 것이에요. 그러니까 아무런 개선이 없어도 상대방 발목만 잡으면 집권을 하거나 당선이 되는 정치를 하다 보니 국민 입장에서는 삶이 제대로 지켜지기가 어렵다. 이 문제를 지적하면서 지금 게임의 룰을 바꿔야, 정치인에게 이익이 되는 룰이 아니라 국민에게 이익이 되는 룰로 바꿔야 된다. 몇십 년 동안 이렇게 한국 정치가 오면서 점점 양극단의 분노가 계속 쌓이고 있는 것 같아서 이런 상태로는 아무런 위기를 해결할 수 없겠다 이런 절박감에 나오게 됐습니다.</p>
# <p dmcf-pid="yznsyY4IjB" dmcf-ptype="general">◇ 정길훈: 정치가 망가져 있다고 하셨는데요. 이 후보가 당 대표가 되면 민주당의 모습 어떻게 달라지겠습니까?</p>
# <p dmcf-pid="WznsyY4Icq" dmcf-ptype="general">◆ 이동학: 지금 제가 말씀드린 양당제의 폐해, 이것으로 인해서 많은 국민이 피해를 입고 계시는데 이것부터 연내에 처리를 하도록 노력할 생각입니다. 엊그저께 국회에 정치개혁특위가 만들어지게 됐고요. 거기에서 근본적으로 양당제를 만들게 되는 선거법 같은 것들을 개정하려고 합니다. 특히 비례대표를 훨씬 더 확대해서 지금은 사실 양당제가 주요한 이슈들, 민생 이슈를 다루지 않으면서 실제로 그들의 이익관계에 놓여 있는 문제만을 다루게 돼 있습니다. 그래서 지금 우리가 생각하고 있는 기후위기라든가 아니면 초고령화 문제로 인해서 상당히 지역의 젊은이들은 떠나가게 되고 지역은 초고령화 되고 산업은 또 사라지고 이러한 문제가 사실상 양당제에 막혀서 후순위로 다 밀려 있는 것입니다. 이런 민생 문제를 정치가 제대로 다룰 수 있도록 정치 체계를 정비하는 역할을 할 생각입니다. 그래서 그것을 연내에 처리하게 되고요. 이렇게 되면 실제 우리 정치에 굉장히 큰 변화가 있을 것입니다.</p>
# <p dmcf-pid="YaW7f8rqNz" dmcf-ptype="general">◇ 정길훈: 그런데 양당 정치의 폐해를 극복하기 위해서 비례대표 확대하려면 선거법을 바꿔야 되지 않습니까? 선거 제도를 개혁해야 하는데 거대 양당은 별로 관심이 없어 보이고요. 당 내부에서 의원들을 어떻게 설득하시겠습니까?</p>
# <p dmcf-pid="5lzMgNXec0" dmcf-ptype="general">◇ 정길훈: 이 후보는 현재 1위를 달리고 있는 이재명 후보에 맞서서 단일화하자, 이런 반명 후보들의 제안을 거부한 것으로 아는데요. 어떠한 이유에서입니까?</p>
# <p dmcf-pid="1SqRajZda3" dmcf-ptype="general">◆ 이동학: 일단 제가 뛰어들게 된 이유는 친명도 반명도 아닙니다. 누군가를 당선시키기 위해 나온 것도 아니고 누군가를 반대하기 위해서 나온 것도 아니고요. 저는 소명을 가지고 나왔습니다. 그런데 친명, 반명 구도에서 반대 이재명이 아닌 모든 사람들을 다 모아서 단일화를 하자는 것 자체는 그 친명, 반명 구도에 저를 집어넣는 것과 다름없습니다. 그래서 저는 저의 목소리를 계속해서 다양하게 낼 필요가 있다고 생각했고요. 특히나 이번 전당대회에서 본선에 이동학이라고 하는 사람이 올라가게 된다면 지금 '어대명', 혹은 친명, 반명 이 구조로 논의가 이루어지고 있는 것에서 초고령화 문제라든지 지역 소멸이라든지 기후 변화라든지 더 다양한 어젠다들을 민주당 전당대회에서 보여줄 수 있다고 생각합니다. 그러면 국민께서도 민주당 전당대회가 누군가를 찬성하냐, 반대하냐 이런 단순한 논리가 아니라 다양한 논의가 이루어지고 있구나라는 점에서 많이 주목하게 될 점이라고 생각합니다.</p>
# <p dmcf-pid="t7imTWfOgF" dmcf-ptype="general">◇ 정길훈: 28일 이틀 뒤에 예비 경선에서 3명으로 추려지는데요. 이 후보는 그 3명 안에 들 자신이 있으십니까?</p>
# <p dmcf-pid="FFxcIhBEot" dmcf-ptype="general">◆ 이동학: 지난주에 나온 여론조사에서도 적지 않게 나오고 있는 상황이고요. 그리고 지금 어쨌든 다른 목소리를 내고 있기 때문에요. 이동학을 선택하게 되면 실제로 민주당이 변화의 몸부림을 치고 있구나라고 국민이 인식하게 될 것입니다. 그리고 특히 제가 그렇게 3위 안에 들어가게 된다면 민주당이 바른 선택을 실제로도 할 수 있구나라고 하는 신호를 국민께 줄 수 있고요. 변화는 사실 그때부터 시작이라고 생각합니다.</p>
# <p dmcf-pid="39NlX5xvN1" dmcf-ptype="general">◇ 정길훈: 이 후보가 유일한 40대 청년 후보인데요. 그와 관련된 질문도 드리겠습니다. 현재 국민의힘 이준석 대표나 박지현 전 비대위원장이나 정치 중심에서 밀려나 있는데요. 청년 정치가 선거에 이용되고 팽 당한 것 아니냐 이런 시각도 있습니다. 그 부분에 대해서 어떻게 보십니까?</p>
# <figure class="figure_frm origin_fig" dmcf-pid="0eI1zBNFg5" dmcf-ptype="figure">
# <p class="link_figure"><img alt="사진 출처 : 연합뉴스" class="thumb_g_article" data-org-src="https://t1.daumcdn.net/news/202207/26/kbs/20220726111424814hiky.jpg" data-org-width="640" dmcf-mid="3sGuV4wzko" dmcf-mtype="image" height="auto" src="https://img3.daumcdn.net/thumb/R658x0.q70/?fname=https://t1.daumcdn.net/news/202207/26
면 아마 또 변화된 것은 없을 겁니다. 그래서 실제 제가 어제 만났던 당원 분들도 그런 것에 대해서 정확하게 민주당이 인식을 해야 된다고 지적해주셨고요. 그 변화를 만들기 위해서 제가 선거법 개정이라든지 이런 것들에 대한 노력을 지금부터 강력하게 해나가야겠다고 또다시 결심한 계기가 됐는데요. 젊은이들이 지방을 계속해서 떠나가고 산업이 당연히 죽고 있는 상황이고요. 그러다 보니까 지역 소멸은 가속화되고 있고 대학은 쓰러지고 있고 이런 상황이기 때문에 지금의 양당제 정치는 주로 서울에서 이루어지고 있는 정치거든요. 서울에서 멀수록 이 도시의 기반을 만들기가 굉장히 어려워지고 있는 상황이고 이것은 계속 악화일로를 걸을 수밖에 없다고 생각해요. 그래서 서울 중심의 양당제 정치 이런 부분을 지금 당장 저희가 깨나가야 된다고 생각하고요. 그런 측면에서 제가 세대교체라는 말보다는 세력 교체다, 실제 그러한 국가의 미래, 지역의 미래 준비할 수 있는 정치 체계를 만드는 세력 구축이 이번에 돼야만 우리가 그 일을 연말까지 혹은 내년까지 해낼 수 있다 이렇게 생각합니다.</p>
# <p dmcf-pid="qyKJAktnAW" dmcf-ptype="general">◇ 정길훈: 오늘 이야기는 여기까지 듣겠습니다.</p>
# <p dmcf-pid="B3MkClbDay" dmcf-ptype="general">◆ 이동학: 고맙습니다.</p>
# <p dmcf-pid="b0REhSKwAT" dmcf-ptype="general">◇ 정길훈: 지금까지 민주당 당 대표 선거에 출마한 이동학 후보였습니다.</p>
# <p dmcf-pid="Km34diT6ov" dmcf-ptype="general">정길훈 기자 (skynsky@kbs.co.kr)</p>
# </section>
# <p data-translation="true">저작권자ⓒ KBS(news.kbs.co.kr) 무단복제-재배포 금지</p>
# </div>
# </div>
# </div>
# <div class="foot_view" data-cloud-area="addition">
# <div class="emotion_wrap" data-cloud="alex_action_emotion">
# <div class="emotion_tit"> <strong class="tit_emotion">이 기사에 대해 어떻게 생각하시나요?</strong>
# </div>
# <div class="emotion_list">
# <div class="alex-actions" data-action-mode="REACTION" data-client-id="26BXAvKny5WF5Z09lr5k77Y8" data-item-key="20220726111417964" data-message-channel="alex-action-reactions" id="alex_action_emotion">
# </div>
# </div>
# </div>
# <div class="relate_series hide" data-cloud="pc_news_cluster"> <strong class="tit_series"> <em class="tag_series">연재</em> <span class="title_series"></span> </strong>
# <ul class="list_series"></ul> <a class="link_more" href="#none">더보기</a>
# </div>
# <div class="cp_view" data-cloud="pc_related_news">
# <div class="cp_tit">
# <h3 class="tit_cp">KBS 주요 뉴스</h3>
# <p class="info_cp">해당 언론사로 연결됩니다.</p>
# </div>
# <ul class="list_relate">
# <li><a class="link_txt" data-type="related" href="https://news.kbs.co.kr/news/view.do?ncd=5517902&amp;ref=D" target="_blank" title="[영상] 윤 대통령, 경찰 집단반발에 “중대한 기강문란”">[영상] 윤 대통령, 경찰 집단반발에 “중대한 기강문란”</a></li>
# <li><a class="link_txt" data-type="related" href="https://news.kbs.co.kr/news/view.do?ncd=5517706&amp;ref=D" target="_blank" title="레고랜드, 개장 두 달여 만에 5번째 멈춰…왜?">레고랜드, 개장 두 달여 만에 5번째 멈춰…왜?</a></li>
# <li><a class="link_txt" data-type="related" href="https://news.kbs.co.kr/news/view.do?ncd=5517747&amp;ref=D" target="_blank" title="“강제배차·탄력요금제 검토”…심야 택시난 해소될까">“강제배차·탄력요금제 검토”…심야 택시난 해소될까</a></li>
# <li><a class="link_txt" data-type="related" href="https://news.kbs.co.kr/news/view.do?ncd=5517713&amp;ref=D" target="_blank" title="박범계 “법치 농단” vs 한동훈 “文 때 총장 패싱”…오늘 경제분야 쟁점">박범계 “법치 농단” vs 한동훈 “文 때 총장 패싱”…오늘 경제분야 쟁점</a></li>
# <li><a class="link_txt" data-type="related" href="https://news.kbs.co.kr/news/view.do?ncd=5517845&amp;ref=D" target="_blank" title="난수표 같은 우윳값 계산식, 바꿔야 할까요?">난수표 같은 우윳값 계산식, 바꿔야 할까요?</a></li>
# <li><a class="link_txt" data-type="related" href="https://news.kbs.co.kr/news/view.do?ncd=5517844&amp;ref=D" target="_blank" title="[폭염격차]④ ‘가까이하기엔 너무 먼’ 배달 라이더 쉼터">[폭염격차]④ ‘가까이하기엔 너무 먼’ 배달 라이더 쉼터</a></li>
# <li><a class="link_txt" data-type="related" href="https://news.kbs.co.kr/news/view.do?ncd=5517748&amp;ref=D" target="_blank" title="[팩트체크K] 정부의 ‘탈(脫) 탈원전’ 정책…에너지법 개정 없인 불가능?">[팩트체크K] 정부의 ‘탈(脫) 탈원전’ 정책…에너지법 개정 없인 불가능?</a></li>
# <li><a class="link_txt" data-type="related" href="https://news.kbs.co.kr/news/view.do?ncd=5517493&amp;ref=D" target="_blank" title="대형마트 새벽 배송·의무 휴업 규제 완화 검토…소상공인 반발">대형마트 새벽 배송·의무 휴업 규제 완화 검토…소상공인 반발</a></li>
# <li><a class="link_txt" data-type="related" href="https://news.kbs.co.kr/news/view.do?ncd=5517739&amp;ref=D" target="_blank" title="[톡톡 지구촌] 입에 깡통 낀 야생 북극곰, 민가 찾아와 “도와 주세요”">[톡톡 지구촌] 입에 깡통 낀 야생 북극곰, 민가 찾아와 “도와 주세요”</a></li>
# <li><a class="link_txt" data-type="related" href="https://news.kbs.co.kr/news/view.do?ncd=5517254&amp;ref=D" target="_blank" title="세탁기 유리문 또 ‘와장창’…삼성 “드물게 그럴 수도”">세탁기 유리문 또 ‘와장창’…삼성 “드물게 그럴 수도”</a></li>
# </ul>
# </div>
# <div data-cloud="pc_article_bottom_ad" id="alex-scroll-area"></div>
# <ins class="kakao_ad_area recomm_ad" data-ad-height="120" data-ad-onfail="daRenderFailCallBack" data-ad-unit="DAN-28ewRUAQYNwThl1H" data-ad-width="655" data-cloud="pc_article_bottom_ad" style="display: block; text-decoration: none; height: 120px; max-height: inherit; min-height: 120px; min-width: 655px; width: 655px;"> </ins>
# <div class="cmt_news cmt_view" data-cloud="pc_comment">
# <div class="news_notice" id="newsviewNotice"></div>
# <div class="alex-area" data-base-url="//comment.daum.net" data-client-id="26BXAvKny5WF5Z09lr5k77Y8" data-initial-limit="3" data-is-mobile="false" data-kakao-appkey="9076ba452fea1a434141d6b6a2c11a3c" data-max-length="300" data-page-limit="10" data-post-id="@20220726111417964" data-show-mask-alert="true" data-sort="P" data-use-attachment="false" data-use-emoticon="true" data-use-fold="true" data-use-force-fold="true" data-use-live-comment-mode="notify" data-use-my="true" data-use-official="true" data-use-reply="true" data-use-safebot="true" data-use-skin="newsView" data-use-social-share="true" id="alex-area">
# </div>
# </div>
# </div>
# </div>
# <div data-cloud-area="aside" id="mAside">
# <ins class="kakao_ad_area aside_g aside_ad" data-ad-height="250" data-ad-type="D" data-ad-unit="05d24" data-ad-width="250" data-cloud="pc_aside_top_ad" style="display:block;width:250px;height:250px;"> </ins>
# <div class="aside_g aside_phototv hide" data-cloud="pc_news_photo_tv">
# <h3 class="txt_newsview">포토&amp;TV</h3>
# <div class="cont_aside">
# <ul class="list_phototv"></ul>
# </div>
# </div>
# <ins class="kakao_ad_area aside_g aside_ad" data-ad-height="250" data-ad-type="D" data-ad-unit="0QH44" data-ad-width="250" data-cloud="pc_aside_bottom_ad" style="display:block;width:250px;height:250px;"> </ins>
# </div>
# </div>
# <div id="cEtc">
# <div class="realtime_view">
# <div class="inner_realtime">
# <div data-cloud-area="etc">
# <div class="realtime_news" data-cloud="pc_realtime_news">
# <h3 class="txt_newsview">이 시각 추천뉴스</h3>
# <ul class="list_realtime">
# <li class="item_main item_realtime_news"></li>
# <li class="item_main item_realtime_news"></li>
# <li class="item_realtime_news"></li>
# <li class="item_realtime_news"></li>
# <li class="item_realtime_news"></li>
# <li class="item_realtime_news"></li>
# <li class="item_realtime_news"></li>
# <li class="item_realtime_news"></li>
# <li class="item_realtime_news"></li>
# <li class="item_realtime_news"></li>
# <li class="item_realtime_news"></li>
# <li class="item_realtime_news"></li>
# </ul>
# </div>
# </div>
# <div class="realtime_aside" data-cloud-area="etc-aside" id="realtime_aside">
# <ins class="kakao_ad_area etc_bottom_ad" data-ad-height="250" data-ad-onfail="onFailEtcBottomAd" data-ad-unit="DAN-kQxraZPBvpl52CWq" data-ad-width="250" data-cloud="pc_etc_bottom_ad" style="display: block; width: 100%;"> </ins>
# </div>
# </div>
# </div>
# <div data-cloud-area="etc-addition">
# </div>
# </div>
# </div>
# <hr class="hide"/>
# <div class="footer_comm" data-cloud-area="footer" id="kakaoFoot" role="contentinfo">
# <div class="inner_foot" data-cloud="pc_footer">
# <div class="direct_link">
# <h2 class="tit_direct">바로가기</h2>
# <div class="item_bundle"> <a class="link_txt" href="https://news.daum.net/">뉴스홈</a> <a class="link_txt" href="https://news.daum.net/society/">사회</a> <a class="link_txt" href="https://news.daum.net/politics/">정치</a> <a class="link_txt" href="https://news.daum.net/economic/">경제</a> <a class="link_txt" href="https://news.daum.net/foreign/">국제</a> <a class="link_txt" href="https://news.daum.net/culture/">문화</a> <a class="link_txt" href="https://news.daum.net/digital/">IT</a> <a class="link_txt" href="https://news.daum.net/photo/">포토</a> <a class="link_txt" href="https://news.daum.net/tv/">TV</a>
# </div>
# <div class="item_bundle"> <a class="link_txt" href="https://news.daum.net/cp">언론사별 뉴스</a>
# </div>
# <div class="item_bundle"> <a class="link_txt" href="https://news.daum.net/newsbox">배열이력</a>
# </div>
# <div class="item_bundle"> <a class="link_txt" href="https://news.daum.net/breakingnews">전체뉴스</a> <a class="link_txt" href="https://news.daum.net/ranking/popular">랭킹</a> <a class="link_txt" href="https://news.daum.net/series">연재</a> <a class="link_txt" href="https://focus.daum.net/ch/news/factcheck">팩트체크</a>
# </div> <button class="btn_fold" type="button"><span class="ico_news">바로가기 링크 더보기/접기</span></button>
# </div>
# <h2 class="screen_out">서비스 이용정보</h2>
# <div class="footer_link"> <a class="link_info" href="https://news.daum.net/info/intro">다음뉴스 소개</a> <span class="txt_dot"> ・ </span> <a class="link_info" href="https://news.daum.net/notice">공지사항</a> <span class="txt_dot"> ・ </span> <a class="link_info" href="https://news.daum.net/info/bbsrule">게시물 운영원칙</a> <span class="txt_dot"> ・ </span> <a class="link_info" href="https://policy.daum.net/info/info">서비스 약관/정책</a> <span class="txt_dot"> ・ </span> <a class="link_info" href="https://with.kakao.com/media">뉴스제휴</a> <span class="txt_dot"> ・ </span> <a class="link_info" href="https://business.kakao.com/">비즈니스</a> <span class="txt_dot"> ・ </span> <a class="link_info" href="https://cs.daum.net/redbell/top.html">권리침해신고</a> <span class="txt_dot"> ・ </span> <a class="link_info" href="https://cs.daum.net/faq/63.html">다음뉴스 고객센터</a>
# </div>
# <div class="footer_link"> <a class="link_info" href="https://news.daum.net/info/newscenter24">24시간 뉴스센터</a> <span class="txt_dot"> ・ </span> <a class="link_info" href="https://news.daum.net/info/edit">서비스원칙</a> <span class="txt_dot"> ・ </span> <a class="link_info" href="https://news.daum.net/info/correct">고침기사, 정정・반론・추후보도 모음</a> <span class="txt_dot"> ・ </span> <span class="link_info">기사배열책임자 : 황유지</span> <span class="txt_dot"> ・ </span> <span class="link_info">청소년보호책임자 : 정현주</span>
# </div>
# <div class="info_copyright"> <strong class="info_warn">위 내용에 대한 저작권 및 법적 책임은 자료제공사 또는 <br/>글쓴이에 있으며, Kakao의 입장과 다를 수 있습니다.</strong> <small class="txt_copyright">Copyright © <strong class="txt_kakao"><a class="link_kakao" href="https://www.kakaocorp.com">Kakao Corp.</a></strong> All rights reserved.</small>
# </div>
# </div>
# </div> <samp data-cloud-area="util"> </samp>
# </div>
# <script src="//t1.daumcdn.net/harmony_static/cloud/2022/06/29/vendor.1687580f7a28c20f6195.js"></script>
# <script src="//t1.daumcdn.net/harmony_static/cloud/2022/06/29/common.98cb4e1c81a314168abb.js"></script>
# <script src="//t1.daumcdn.net/kas/static/ba.min.js"></script>
# <script src="//t1.daumcdn.net/kas/static/na.min.js"></script>
# <script src="//m1.daumcdn.net/svc/original/U03/cssjs/userAgent/userAgent-1.0.12.min.js"></script>
# <script>"use strict";function _classCallCheck(e,t){if(!(e instanceof t))throw new TypeError("Cannot call a class as a function")}function _defineProperties(e,t){for(var a=0;a<t.length;a++){var n=t[a];n.enumerable=n.enumerable||!1,n.configurable=!0,"value"in n&&(n.writable=!0),Object.defineProperty(e,n.key,n)}}function _createClass(e,t,a){return t&&_defineProperties(e.prototype,t),a&&_defineProperties(e,a),e}!(function(){var a="<li>\n                          <a href=\"https://search.daum.net/search?nil_suggest=btn&w=tot&DA=SBC&q=<%= specialRegionName %>%20날씨\" class=\"link_cont\">\n                          <span class=\"ico_weather ico_weather<%= weatherIconCode %>\"><%= specialRegionName %></span> \n                          <span class=\"txt_weather\"><%= specialRegionName %>\n                              <span class=\"num_heat\"><%= temperature %></span> \n                              <span class=\"txt_heat\">℃</span>\n                          </span>\n                          </a>\n                        </li>",t=document.querySelector('.gnb_weather'),n=t.querySelector('ul'),e="".concat(Conf.api.hadesRest,"/pc_weather");axios.get(e).then(function(e){var t=e.data.body.data,e=t.isNightIconYn,t=t.weatherData;n.dataset.nightyn=e,n.innerHTML=t.map(function(e){return _.template(a)(e)}).join('');new s(n)}).catch(function(e){t.parentNode.removeChild(t)});var s=(function(){function t(e){_classCallCheck(this,t),this.PAUSE_TIME=4e3,this.TRANSITION_TIME=500,this.list=e,this.frameId=null,this.pause=this.pause.bind(this),this.start=this.start.bind(this),this.moveUp=this.moveUp.bind(this),this.init(),this.start(),this.list.style.marginTop='0px'}return _createClass(t,[{key:"start",value:function(){this.frameId=setInterval(this.moveUp,this.PAUSE_TIME)}},{key:"pause",value:function(){clearInterval(this.frameId)}},{key:"moveUp",value:function(){var e=this.list,t=e.firstElementChild.cloneNode(!0);e.classList.add('slidein'),e.style.marginTop='-30px',setTimeout(function(){e.classList.remove('slidein'),e.style.marginTop='0px',e.removeChild(e.firstElementChild),e.appendChild(t)},this.TRANSITION_TIME)}},{key:"init",value:function(){var t=this,e=this.list;e.addEventListener('mouseenter',this.pause),e.addEventListener('mouseleave',this.start),e.querySelectorAll('a').forEach(function(e){e.addEventListener('focus',t.pause),e.addEventListener('blur',t.start)})}}]),t})()})();</script>
# <script>"use strict";!(function(){var e=-1<''.indexOf('tv_news')?'tv':'politics',t=document.querySelector('.gnb_comm');(t=e&&t.querySelector(".".concat(e)))&&t.setAttribute('class',"".concat(e," on"))})();</script>
# <script src="https://t1.daumcdn.net/cssjs/jquery/jquery-1.9.0.min.js"></script>
# <script src="https://search1.daumcdn.net/search/suggest_pc/suggest-1.2.16.min.js"></script>
# <script>"use strict";!(function(){document.getElementById('search_news'),new suggest.Suggest(document.getElementById("search_news"),{inputEl:'qVal',suggestBoxEl:'suggestBox',autoFocus:'NORMAL',suggestLimit:10,isReverse:!1,searchURL:'https://search.daum.net/search',APIServer:{host:'//dapi.kakao.com/suggest/v2/pc.json',apiType:suggest.Suggest.APITYPE.DAPISUGGEST,appkey:'d7022f6ca2a04430ce1b97b922da58e8',queries:{mod:'json',code:'utf_in_out'}}}).on('click-item',function(){var e=document.getElementById('kakaoSearch');e.querySelector("input[name='DA']").value='23B',e.submit()});var t=document.getElementById('qVal');t.addEventListener?(t.addEventListener('focus',function(e){e&&e.preventDefault(),0<=t.value.length&&t.parentNode.classList.add('search_on')}),t.addEventListener('blur',function(e){e&&e.preventDefault(),0===t.value.length&&t.parentNode.classList.remove('search_on')})):(t.attachEvent('onfocus',function(e){e&&(e.preventDefault?e.preventDefault():e.returnValue=!1),0<=t.value.length&&t.parentNode.setAttribute('class','box_searchbar search_on')}),t.attachEvent('onblur',function(e){e&&(e.preventDefault?e.preventDefault():e.returnValue=!1),0===t.value.length&&t.parentNode.setAttribute('class','box_searchbar')}))})(jQuery);</script>
# <script src="//t1.daumcdn.net/daumtop_deco/socialshare/socialshare_nocss_pc-2.4.2.js"></script>
# <script>"use strict";function _slicedToArray(e,t){return _arrayWithHoles(e)||_iterableToArrayLimit(e,t)||_unsupportedIterableToArray(e,t)||_nonIterableRest()}function _nonIterableRest(){throw new TypeError("Invalid attempt to destructure non-iterable instance.\nIn order to be iterable, non-array objects must have a [Symbol.iterator]() method.")}function _unsupportedIterableToArray(e,t){if(e){if("string"==typeof e)return _arrayLikeToArray(e,t);var n=Object.prototype.toString.call(e).slice(8,-1);return"Object"===n&&e.constructor&&(n=e.constructor.name),"Map"===n||"Set"===n?Array.from(e):"Arguments"===n||/^(?:Ui|I)nt(?:8|16|32)(?:Clamped)?Array$/.test(n)?_arrayLikeToArray(e,t):void 0}}function _arrayLikeToArray(e,t){(null==t||t>e.length)&&(t=e.length);for(var n=0,r=new Array(t);n<t;n++)r[n]=e[n];return r}function _iterableToArrayLimit(e,t){if("undefined"!=typeof Symbol&&Symbol.iterator in Object(e)){var n=[],r=!0,o=!1,a=void 0;try{for(var i,s=e[Symbol.iterator]();!(r=(i=s.next()).done)&&(n.push(i.value),!t||n.length!==t);r=!0);}catch(e){o=!0,a=e}finally{try{r||null==s["return"]||s["return"]()}finally{if(o)throw a}}return n}}function _arrayWithHoles(e){if(Array.isArray(e))return e}!(function(){var t,e,n,r,o,a='VIEW_TTS',i='v.daum.net',s={slow_Male:'http://k-v1.kakaocdn.net/dn/bi3rtm/btrIhjI6i5i/vs46YtSuCaRNqTOXnRcKJK/original.m4a',normal_Male:'http://k-v1.kakaocdn.net/dn/bOH9qM/btrIcGZ5vH6/soKM6JpapIFODFllrvPXj1/original.m4a',fast_Male:'http://k-v1.kakaocdn.net/dn/mYCar/btrIcHEKDsZ/z0i0gXxhg1GBQStXTXeOU0/original.m4a',slow_Female:'http://k-v1.kakaocdn.net/dn/gXar7/btrIbL1CYCD/cg2h9ceZl13zKKqW8KOkGK/original.m4a',normal_Female:'http://k-v1.kakaocdn.net/dn/bwjBXy/btrIfSLKwCX/yTG1iYkbbW4Ul2TiXjwke0/original.m4a',fast_Female:'http://k-v1.kakaocdn.net/dn/bzjCU3/btrIfSLKtbB/gVZzGR4tZaElirGToHckeK/original.m4a'},l=document.querySelector('.util_view .tts_btn'),c=l.querySelectorAll('.list_tts input'),u=l.querySelector('.btn_tts'),d=l.querySelector('.ico_speak'),y=l.querySelector('.wrap_setlayer').querySelectorAll('.ico_newsview'),f=l.querySelector('#ttsPlayer');function m(){var e,t,n,r,o=(e=l.querySelector('input[name=ttsSpeed]:checked').value,t=l.querySelector('input[name=ttsGender]:checked').value,"".concat(e,"_").concat(t));f.setAttribute('src',s[o]),n=o,Cookies.set(a,'',{expires:-1}),Cookies.set(a,n,{domain:i,expires:new Date(1*new Date+365*864e5)}),r=o,u.className='btn_set btn_tts #util #tts #p_'+r}function p(e){'playOptions'==e?(m(),f.load(),f.play(),d.textContent='음성 기사 정지'):'play'==e?(f.load(),f.play(),d.textContent='음성 기사 정지'):(f[e](),d.textContent='음성 기사 듣기')}function v(){clearTimeout(n),t.classList.add('layer_open'),e.setAttribute('aria-expanded',!0)}function _(){r||(n=setTimeout(b,100))}function b(){t.classList.remove('layer_open'),e.setAttribute('aria-expanded',!1)}function L(e){e?t.classList.add('on'):t.classList.remove('on')}function h(e,t){document.getElementById("ttsSpeed".concat(e)).checked=!0,document.getElementById("ttsGender".concat(t)).checked=!0}t=(o={layer:l,btn:u,radios:c}).layer,e=o.btn,o=o.radios,r=!(n=0),t.addEventListener('mouseover',function(e){r=!0,v()}),t.addEventListener('mouseleave',function(e){r=!1,_()}),e.addEventListener('keydown',function(e){13===e.keyCode&&((r=!r)?v:b)()}),t.addEventListener('blur',function(e){r=!1,_()}),e.addEventListener('click',function(e){f.paused?(L(!0),p('play')):(L(!1),p('pause'))}),o.forEach(function(e){e.addEventListener('change',function(e){t.classList.add('on'),p('playOptions')}),e.addEventListener('blur',function(e){r=!1,_()}),e.addEventListener('focus',function(e){r=!0,v()})}),y=(o={icons:y,radios:c}).icons,c=o.radios,y.forEach(function(e){e.addEventListener('mouseover',function(e){this.classList.add('ico_focused')}),e.addEventListener('mouseleave',function(e){this.classList.remove('ico_focused')})}),c.forEach(function(e){e.addEventListener('focus',function(e){this.nextElementSibling.querySelector('span').classList.add('ico_focused')}),e.addEventListener('blur',function(e ...
# <script>"use strict";!(function(){var n=document.createElement('DIV');n.innerHTML="\n <div id=\"translatingLayer\" class=\"translate_layer\">\n <div class=\"inner_translate_layer\">\n <div class=\"layer_body\">\n <strong class=\"tit_translate\">\n 번역중 <span class=\"eng_tit\">Now in translation</span>\n </strong>\n </div>\n </div>\n </div>\n\n <div id=\"translateErrorLayer\" class=\"translate_layer\">\n <div class=\"inner_translate_layer inner_error_layer\">\n <div class=\"layer_body\">\n <span class=\"ico_newsview ico_error\"></span>\n <strong class=\"tit_translate\">\n 잠시 후 다시 시도해 주세요 <span class=\"eng_tit\">Please try again in a moment</span>\n </strong>\n </div>\n </div>\n </div>\n ",document.body.querySelector("#kakaoWrap").appendChild(n)})();</script>
# <script>"use strict";function _toConsumableArray(e){return _arrayWithoutHoles(e)||_iterableToArray(e)||_unsupportedIterableToArray(e)||_nonIterableSpread()}function _nonIterableSpread(){throw new TypeError("Invalid attempt to spread non-iterable instance.\nIn order to be iterable, non-array objects must have a [Symbol.iterator]() method.")}function _unsupportedIterableToArray(e,t){if(e){if("string"==typeof e)return _arrayLikeToArray(e,t);var n=Object.prototype.toString.call(e).slice(8,-1);return"Object"===n&&e.constructor&&(n=e.constructor.name),"Map"===n||"Set"===n?Array.from(e):"Arguments"===n||/^(?:Ui|I)nt(?:8|16|32)(?:Clamped)?Array$/.test(n)?_arrayLikeToArray(e,t):void 0}}function _iterableToArray(e){if("undefined"!=typeof Symbol&&Symbol.iterator in Object(e))return Array.from(e)}function _arrayWithoutHoles(e){if(Array.isArray(e))return _arrayLikeToArray(e)}function _arrayLikeToArray(e,t){(null==t||t>e.length)&&(t=e.length);for(var n=0,r=new Array(t);n<t;n++)r[n]=e[n];return r}!(function(){var e,t,n,r,a=document.querySelector('.translate_btn'),o=a.querySelector('.btn_translate'),l=a.querySelector('.link_kakaoi'),s=a.querySelectorAll('.btn_lang'),i=document.getElementById('translatingLayer'),c=document.getElementById('translateErrorLayer'),y=document.getElementById('kakaoWrap');function u(){i.style.display='none',c.style.display='none',document.body.style.overflow=''}function d(){clearTimeout(e),t.classList.add('layer_open'),n.setAttribute('aria-expanded',!0)}function f(){t.classList.remove('layer_open'),n.setAttribute('aria-expanded',!1)}function p(){r||(e=setTimeout(f,1))}function m(e){var t=e.currentTarget.name;u(),i.style.display='block',document.body.style.overflow='hidden';try{HarmonyTranslator.translate('kr',t,_,b)}catch(e){console.error('번역 에러:',e)}}function _(e){var t=document.querySelector('#translateNotice'),e=e.targetLang;switch(e){case'en':case'id':y.classList.add('lang_type1'),y.classList.remove('lang_type2'),y.classList.remove('lang_type3');break;case'cn':case'jp':y.classList.remove('lang_type1'),y.classList.add('lang_type2'),y.classList.remove('lang_type3');break;case'vi':y.classList.remove('lang_type1'),y.classList.remove('lang_type2'),y.classList.add('lang_type3');break;default:y.classList.remove('lang_type1'),y.classList.remove('lang_type2'),y.classList.remove('lang_type3')}'kr'==e?(t.querySelectorAll('.notice_lang').forEach(function(e){e.style.display='none'}),t.style.display='none'):(t.querySelectorAll(".notice_lang:not(.notice_lang_".concat(e,")")).forEach(function(e){e.style.display='none'}),t.querySelector(".notice_lang.notice_lang_".concat(e)).style.display='block',t.style.display='block'),setTimeout(function(){u()},500)}function b(e,t){u(),c.style.display='block',document.body.style.overflow='hidden',setTimeout(function(){u()},2e3)}l={layer:a,btn:o,inputs:[l].concat(_toConsumableArray(s))},t=l.layer,n=l.btn,l=l.inputs,r=!1,n.addEventListener('click',function(){((r=!r)?d:p)()}),t.addEventListener('mouseover',function(){r=!0,d()}),t.addEventListener('mouseleave',function(){r=!1,f()}),l.forEach(function(e){e.addEventListener('focus',function(e){r=!0,d()}),e.addEventListener('blur',function(e){r=!1,p()})}),s.forEach(function(e){e.addEventListener('click',m)})})();</script>
# <script>"use strict";!(function(){var e,t=(o='[무등의 아침] 이동학 &quot;이재명 당 대표 되면 적대적 공생..망가진 정치 바꿀 것&quot;',(c=document.createElement('div')).innerHTML=o,c.textContent),a='20220726111417964'||'Z5yfeJv8jA',n="".concat(location.protocol,"//").concat(location.host,"/v/").concat(a),o="http://scrap.cafe.daum.net/_dss_/scrap?folder_id=100000&source_location_code=10&target_location_code=1&data_id=".concat(a),c={shareType:'sendScrap',shareData:{requestUrl:n,templateId:7952,installTalk:!0,templateArgs:{'${EncodingUrl}':encodeURIComponent(n),'${webUrl}':n+'?f=p','${mobileWebUrl}':n+'?f=m'}}},r=document.querySelector('.share_btn'),i=document.getElementById('rSocialShareButton'),a=document.getElementById('rSocialShareLayerContainer'),d=new socialshareRenewal.Main(i,{moreViewContainer:a,action:'hover',link:n,prefix:t,service_name:'다음뉴스',cafe:o,kakaoAPI:{appkey:'53e566aa17534bc816eb1b5d8f7415ee',kakaoLinkData:c}}),s=!1;function l(){e=setTimeout(function(){s=!1,r.classList.remove('layer_open'),i.setAttribute('aria-expanded',!1),d.close()},100)}function u(){s=!0,m(),r.classList.add('layer_open'),i.setAttribute('aria-expanded',!0),d.open()}function m(){clearTimeout(e)}i.addEventListener('mouseenter',u),i.addEventListener('mouseleave',l),i.addEventListener('click',function(e){(s?l:u)()}),a.addEventListener('mouseenter',m),a.addEventListener('mouseleave',l),a.querySelectorAll('a').forEach(function(e){e.addEventListener('focus',m),e.addEventListener('blur',l)})})();</script>
# <script>"use strict";!(function(){var e,t,n,o,i=document.querySelector('.news_view'),s=document.querySelector('.font_btn'),c=s.querySelector('.btn_font'),r=s.querySelector('.list_font'),u=r.querySelectorAll('input'),a='GS_font_size',l='v.daum.net';function d(e){i.style.fontSize="".concat(e,"px"),document.querySelector("#inpFont".concat(e)).checked=!0,r.querySelectorAll('label').forEach(function(e){return e.classList.remove('on')}),r.querySelector("label[for=inpFont".concat(e,"]")).classList.add('on'),e=e,Cookies.set(a,'',{expires:-1}),Cookies.set(a,e,{domain:l,expires:new Date(1*new Date+365*864e5)})}function f(){clearTimeout(e),t.classList.add('layer_open'),n.setAttribute('aria-expanded',!0)}function v(){t.classList.remove('layer_open'),n.setAttribute('aria-expanded',!1)}function p(){o&&(e=setTimeout(v,1))}d(Cookies.get(a)||17),u.forEach(function(e){e.addEventListener('change',function(e){d(e.target.value)})}),t=(c={layer:s,btn:c,inputs:u}).layer,n=c.btn,c=c.inputs,o=!1,t.addEventListener('mouseover',function(){o=!0,f()}),t.addEventListener('mouseleave',function(){o=!1,v()}),c.forEach(function(e){e.addEventListener('focus',f),e.addEventListener('blur',p)}),n.addEventListener('click',function(e){((o=!o)?f:v)()}),s={options:s.querySelectorAll('.ico_newsview'),inputs:u},u=s.options,s=s.inputs,u.forEach(function(e){e.addEventListener('mouseover',function(){this.classList.add('ico_focused')}),e.addEventListener('mouseleave',function(){this.classList.remove('ico_focused')})}),s.forEach(function(e){e.addEventListener('focus',function(){this.nextElementSibling.querySelector('span').classList.add('ico_focused')}),e.addEventListener('blur',function(){this.nextElementSibling.querySelector('span').classList.remove('ico_focused')})})})();</script>
# <script>"use strict";document.body.querySelector(".btn_print").parentNode.addEventListener("click",function(t){t.preventDefault(),window.open('https://news.v.daum.net/v/20220726111417964?s=print_news','newsPrint','width=750,height=550,scrollbars=yes')});</script>
# <script type="text/javascript">
#
#     var alex = document.querySelector('#alex_action_emotion');
#     alex.setAttribute('data-selections','[{"type":"RECOMMEND","animation":"SLIDE","image":"https://t1.daumcdn.net/harmony_static/alex_emotion/SLIDE_RECOMMEND_1x.png","highResImage":"https://t1.daumcdn.net/harmony_static/alex_emotion/SLIDE_RECOMMEND_2x.png"},{"type":"LIKE","animation":"SLIDE","image":"https://t1.daumcdn.net/harmony_static/alex_emotion/SLIDE_LIKE_1x.png","highResImage":"https://t1.daumcdn.net/harmony_static/alex_emotion/SLIDE_LIKE_2x.png"},{"type":"IMPRESS","animation":"SLIDE","image":"https://t1.daumcdn.net/harmony_static/alex_emotion/SLIDE_IMPRESS_1x.png","highResImage":"https://t1.daumcdn.net/harmony_static/alex_emotion/SLIDE_IMPRESS_2x.png"},{"type":"ANGRY","animation":"SLIDE","image":"https://t1.daumcdn.net/harmony_static/alex_emotion/SLIDE_ANGRY_1x.png","highResImage":"https://t1.daumcdn.net/harmony_static/alex_emotion/SLIDE_ANGRY_2x.png"},{"type":"SAD","animation":"SLIDE","image":"https://t1.daumcdn.net/harmony_static/alex_emotion/SLIDE_SAD_1x.png","highResImage":"https://t1.daumcdn.net/harmony_static/alex_emotion/SLIDE_SAD_2x.png"}]');
#
#     var itemKey = alex.getAttribute('data-item-key');
#     if (isNumber(itemKey))
#         alex.setAttribute('data-item-key', '@' + itemKey);
#
#     function isNumber(x) {
#         return !isNaN(Number(x));
#     }
# </script>
# <script src="//action.kakao.com/latest/alex.actions.js" type="text/javascript"></script>
# <script>"use strict";!(function(){var s="20220726111417964",e="".concat(Conf.api.hadesRest,"/pc_mc2_news?cate=").concat("news","&id=").concat(s),a='<li class="on"> <div class="inner_box"><span class="link_txt"><%= title %></span></div> </li>',i='<li> <div class="inner_box"><a href="https://news.v.daum.net/v/<%= contentId %>" class="link_txt"><%= title %></a></div> </li>',c='//news.daum.net/series',r=document.querySelector('.relate_series'),o=r.querySelector('.title_series'),d=r.querySelector('.link_more'),l=r.querySelector('.list_series');function m(e){e&&e.parentNode.removeChild(e)}axios.get(e).then(function(e){var t,n=e.data.body.data.data;_.isEmpty(n)||'series'!==n[0].factor.type?m(r):(t=n[0],e=t.contents,n=t._id,t=t.title,e.length<3&&l.classList.add('relate_series2'),o.textContent=t,d.setAttribute('href',c+'/'+n),l.innerHTML=e.map(function(e){var t=e.contentId,e=e.title;return t==s?_.template(a)({title:e}):_.template(i)({contentId:t,title:e})}).join(''),(e=r)&&e.classList.remove('hide'))}).catch(function(e){console.error("[클러스터]: 데이터를 가져오는데 실패했습니다. 에러: ",e,"에러 데이터: ",e.response.data),m(r)})})();</script>
# <script>"use strict";function daRenderFailCallBack(e){e.parentElement.removeChild(e)}</script>
# <script>"use strict";document.addEventListener('DOMContentLoaded',function(){var t="".concat(Conf.api.hadesRest)+"/service_notice?id="+"3393",n=document.querySelector("#newsviewNotice");axios.get(t).then(function(t){var e=t.data.body.data,t=e.noticeTitle,e=e.noticeUrl;null!==t?n.innerHTML="<strong class=\"tit_notice\">공지</strong><span class=\"txt_notice\"><a href=\"".concat(e,"\" class=\"link_txt\">").concat(t,"</a></span>"):n.parentNode.removeChild(n)}).catch(function(t){console.log("댓글 공지 오류: "+t),n.parentNode.removeChild(n)})});</script>
# <script src="//comment.daum.net/js/latest/alex.single.min.js"></script>
# <script>"use strict";window.excludeCorejs=!1,window.alexConfig={label:{emptyImage:'//i1.daumcdn.net/img-section/enter2013/liveviewer/pc_emot_co.gif'},onLoad:function(){window.isLoadComment=!0}};</script>
# <script>"use strict";!(function(){var t="<li>\n <a class=\"link_cont\" href=\"<%= url %>\">\n <span class=\"wrap_thumb\">\n <img class=\"thumb_g\" src=\"<%= thumbnail %>\" alt=\"\"/>\n <span class=\"ico_phototv\">\n <% if (type == 'photo') { %>\n <span class=\"ico_newsview ico_photo\">포토</span>\n <% } else { %>\n <span class=\"ico_newsview ico_vod\">영상</span>\n <% } %>\n </span>\n </span>\n <strong class=\"tit_thumb\"><%= title %></strong>\n </a>\n </li>",o=document.querySelector('.aside_phototv'),s=o.querySelector('.list_phototv'),n="".concat(Conf.api.hadesRest,"/pc_photo_tv");function a(n){n&&n.parentNode.removeChild(n)}axios.get(n).then(function(n){n=n.data.body.data;_.isEmpty(n)?a(o):(s.innerHTML=n.map(function(n){return _.template(t)(n)}).join(''),(n=o)&&n.classList.remove('hide'))}).catch(function(n){console.error('[PC 뉴스 포토&TV]:',n),a(o)})})();</script>
# <script>"use strict";!(function(){var n='S570x320',e="20220726111417964",t=encodeURIComponent(JSON.stringify({itemid:e,category:"news".replace('tain','')})),e={source:e},r="<a href=\"<%=obj.url%>\" class=\"link_cont\" data-itemid=\"<%=obj._id%>\"\" data-pos=\"<%=obj.pos%>\">\n <span class=\"wrap_thumb\"><img src=\"<%=obj.thumbnail%>\" class=\"thumb_g\" alt=\"\"></span>\n <strong class=\"tit_thumb\"><%=obj.title%></strong>\n </a>",o="<strong class=\"tit_g\">\n <span class=\"info_news\"><%=obj.cp_name%></span>\n <a href=\"<%=obj.url%>\" data-itemid=\"<%=obj._id%>\" data-pos=\"<%=obj.pos%>\" class=\"link_txt\"><%=obj.title%></a>\n </strong>",m=[];new Toros.Connector({url:'mediadaum/most_similar',queryParams:t,map:function(e){var t=e._id,a=e.title,i=e.image,e=e.cp_name,e={_id:t,url:"https://v.daum.net/v/".concat(t),title:a,thumbnail:StringUtil.makeThumbnail(i,n),cp_name:e};if(!(m.length<2&&i))return e;m.push(e)},svc:'mediadaum_sim',impLabel:'toros_mediadaum_sim_imp',impProps:e,viewLabel:'toros_mediadaum_sim_vimp',viewProps:e,clickLabel:'toros_mediadaum_sim_click',clickProps:e,customRender:function(e,i,n){var s=e.filter(function(e){return!!e._id});m.length<2||s.length<10?document.querySelector('.realtime_news').remove():document.querySelectorAll('.item_realtime_news').forEach(function(e,t){var a=t<2?{article:m.shift(),template:r}:{article:s.shift(),template:o},t=a.article,a=a.template;t?(e.insertAdjacentHTML('beforeend',_.template(a)(t)),e.classList.remove('item_realtime_news'),e.classList.length||e.removeAttribute('class'),t=e.querySelector('a'),i.observe(t),t.addEventListener('click',n)):e.remove()})}}).render()})();</script>
# <script>"use strict";function onFailEtcBottomAd(){var t;null!==(t=document.querySelector('.etc_bottom_ad'))&&void 0!==t&&t.remove()}</script>
# <script>"use strict";!(function(){var e=document.querySelector(".direct_link");e.querySelector(".btn_fold").addEventListener('click',function(){e.classList.toggle("direct_open")})})();</script>
# <script>
#     window.minidaum_options = JSON.parse('{"bgType":"white","enableLogoutRetun":true,"returnUrl":"","disableHotissue":false,"disableLogo":false,"disableTracker":true,"enableTopLink":false}');
# </script>
# <script src="https://go.daum.net/minidaum_pc.daum"></script>
# <script>"use strict";document.querySelectorAll('.kakao_ad_area').forEach(function(a){a.setAttribute('data-ad-param-channel','harmony'),a.setAttribute('data-ad-param-cp','327_pc_media_news')});</script>
# <script>"use strict";!(function(){var e,t,i,c='<div class="direct_view" style="top:<%= top %>px; width:<%= width %>px; margin-left:<%= left %>px"> <a href="<%= url %>" class="link_view"> <span class="txt_g"><%= title %></span> <span class="ico_view"> <span class="ico_newsview ico_gallery">갤러리 이동</span> </span> </a> </div>';e='Z5yfeJv8jA',!(t='')||(i=document.querySelector('img[dmcf-mtype="image"]'))&&!i.querySelector('.direct_vod')&&axios.get("".concat(Conf.api.hadesRest,"/photo_gallery_link_info?docId=").concat(e,"&galleryId=").concat(parseInt(t,10))).then(function(e){var t,a=e.data.body.data;t=i,a=(e=a).title,e=e.pcLink,a&&e&&(e={title:a,url:e,top:t.clientHeight-62,width:a=t.clientWidth,left:a/2*-1},a=document.createElement('div'),t.parentNode.appendChild(a),a.outerHTML=_.template(c)(e))})})();</script>
# <script src="//search1.daumcdn.net/search/statics/common/js/g/search_dragselection.min.js"></script>
# <script>"use strict";!(function(){var e=document.querySelector(".head_media"),n=document.getElementById("wrapMinidaum").offsetHeight+e.offsetHeight,o=document.getElementById("barProgress"),d=document.getElementById("mAside"),s=document.getElementById("kakaoWrap"),l=document.getElementById("kakaoGnb"),r=document.getElementById("mArticle"),a=document.querySelector(".cmt_news"),c=document.querySelector(".aside_ad:first-child"),f=document.querySelector(".aside_ad:last-child"),g=document.getElementById('realtime_aside');function t(){var e=window.scrollY||window.pageYOffset,t=document.body.offsetHeight,i=window.innerHeight;n<e?(i=100*e/(t-i),s.classList.add("header_fixed"),o.style.width=parseInt(i,10)+"%"):s.classList.remove("header_fixed")}function i(){var e=window.scrollX||window.pageXOffset,t=cMain.clientWidth,i=r.clientWidth,n=t-i-d.clientWidth,o=getComputedStyle(cMain),s=null;s=g?(t=g.getBoundingClientRect().left)<880?t+e:t:i+n+parseInt(o['marginLeft'],10)-e,r.offsetHeight<d.offsetHeight||(a.style.minHeight='250px',0<(n=(window.scrollY||window.pageYOffset)-cMain.offsetTop-8-c.clientHeight)?(o=r.offsetHeight-a.offsetHeight,(e=d.offsetHeight-f.offsetHeight)+n+8<o?(d.style.position='fixed',d.style.top=l.clientHeight-c.offsetHeight-74+'px',d.style.left=s+'px'):(d.style.position='relative',d.style.top=o-e+'px',d.style.left='inherit')):(d.style.position='static',d.style.top='inherit',d.style.left='inherit'))}'false'!='true'&&'news'=='news'?(window.addEventListener("resize",_.throttle(i,100)),window.addEventListener("scroll",_.throttle(function(){t(),i()},100)),t(),i()):(window.addEventListener("scroll",_.throttle(function(){t()},100)),t())})();</script>
# <script src="//t1.daumcdn.net/tiara/js/v1/tiara.min.js" type="text/javascript"></script>
# <script>"use strict";!(function(){if(window.TiaraTracker){var c=!1,s=new Date,l="pc_news",m=null;try{m=Cookies.get('DAUMTOP')||Cookies.get('HARMONY_TOROS_IMP')&&window.atob(Cookies.get('HARMONY_TOROS_IMP'))}catch(e){m=Cookies.get('DAUMTOP')}var u='',g='',y=TiaraTracker.getInstance().setSvcDomain("media.daum.net").setPage("newsview").trackPage("newsview").setSection("politics").setEnableAlwaysImage(!0),p={id:"20220726111417964",type:"article",name:"[\uBB34\uB4F1\uC758 \uC544\uCE68] \uC774\uB3D9\uD559 \"\uC774\uC7AC\uBA85 \uB2F9 \uB300\uD45C \uB418\uBA74 \uC801\uB300\uC801 \uACF5\uC0DD..\uB9DD\uAC00\uC9C4 \uC815\uCE58 \uBC14\uAFC0 \uAC83\"",category_id:"1020",category:"politics",author:"\uC815\uAE38\uD6C8",author_id:"",provider:"KBS",provider_id:"327",regdate:"2022-07-26 11:14:16",plink:"https://media.daum.net/v/20220726111417964",image:"https://t1.daumcdn.net/news/202207/26/kbs/20220726111418759vxaw.jpg",harmony_consumer_id:"media",media:"pcweb"},f={contentUniqueKey:"hamny-".concat(p.id),docId:"Z5yfeJv8jA",harmony_consumer_id:"media",media:"pcweb",reg_dt:"2022-07-26 11:14:16",reg_timestamp:"1658801656994"},e=function(){c||y.actionKind("ViewContent").pageMeta(p).customProps(f).track()},t=function(){if(!c){c=!0;var e=document.body.scrollHeight,t=window.scrollY,a=e-t,o=window.innerHeight,n=Math.round(t/(e-o)*100),i={},o={duration:(new Date).getTime()-s.getTime(),scroll_percent:n,scroll_height:e,scroll_top:t,scroll_bottom:a,scroll_inner_height:o};try{var d,r=!1;!m||(d=JSON.parse(m)).contents_unique_key===f.contentUniqueKey&&(i={toros_imp_id:d.impression_id,toros_file_hash_key:d.toros_file_hash_key,toros_user_id_type:"uuid",toros_page_meta_id:f.contentUniqueKey,toros_event_meta_id:f.contentUniqueKey,toros_action_type:"dwelltime"},Cookies.remove('HARMONY_TOROS_IMP',{path:'/',domain:location.hostname.substring(location.hostname.indexOf('.'))}),Cookies.remove('DAUMTOP',{path:'/',domain:'.daum.net'}),r=!0),!r&&0<u.length&&(i={toros_imp_id:window.atob(u),toros_file_hash_key:window.atob(g),toros_user_id_type:"uuid",toros_page_meta_id:f.contentUniqueKey,toros_event_meta_id:f.contentUniqueKey,toros_action_type:"dwelltime"})}catch(e){}y.trackUsage().actionKind("UsagePage").pageMeta(p).usage(o).customProps(_.assignIn(f,i)).track()}};"onpagehide"in window?(window.addEventListener("pageshow",e,!1),window.addEventListener("pagehide",t,!1)):(window.addEventListener("load",e,!1),window.addEventListener("unload",t,!1)),document.addEventListener("visibilitychange",function(){(document["hidden"]?t:e)()},!1),document.addEventListener("mousedown",function(e){var t,a,o,n,i,d,r,c=e.target,s=c.closest("[data-cloud]"),m=c.closest("a")||c.closest("button");m&&null!=s&&s.contains(m)&&((i=TiaraTracker.getClickInfo(e))&&(a=(null==(t=i.action)?void 0:t.name)||"",o=(null==t?void 0:t.kind)||"",n=_.assignIn(f,i.customProps),i=c.closest("[data-tiara]"),c=m.querySelector("img"),d=0,Array.from((s||i).querySelectorAll("a, button")).map(function(e,t){e==m&&(d=t)}),e={layer1:l,layer2:s.dataset.cloud,layer3:(null==i?void 0:i.dataset.tiara)||"",click_url:m.href||"",ordnum:d,copy:(r=m.getAttribute('data-action-type'),['RECOMMEND','LIKE','IMPRESS','ANGRY','SAD'].includes(r)?null==t?void 0:t.name:m.innerText),image:(null==c?void 0:c.src)||"",posX:e.clientX,posY:e.clientY},y.trackEvent(a).pageMeta(p).actionKind(o).customProps(n).click(e).track()))})}})();</script>
# </body>
# </html>

# %%
title = bs2.find('h3',class_='tit_view').text
body = '\n'.join([line.text for line in bs2.find('section').find_all('p')[1:]])
print(title + '\n' + body)
# Out:
# [무등의 아침] 이동학 "이재명 당 대표 되면 적대적 공생..망가진 정치 바꿀 것"
# ◇ 정길훈 앵커 (이하 정길훈): 민주당 당권 주자 가운데 유일한 청년 후보인 이동학 전 최고위원이 어제 광주를 찾았습니다. 이 후보는 낡은 기득권 정치를 끝내고 정치 교체를 이루자, 이렇게 주장하고 있는데요. 이동학 후보 연결합니다. 안녕하십니까?
# ◆ 더불어민주당 이동학 전 최고위원 (이하 이동학): 안녕하십니까?
#
# ◇ 정길훈: 어제 광주를 방문해서 당원들도 만나고 시민도 만나셨을 텐데요. 민심이 어땠습니까?
# ◆ 이동학: 우선 최선을 다해서 밀어줬는데 대선에서 패배한 데 대해서 실망을 표하시는 분들도 계셨고요. 민주당이 개선의 노력은 안 하는데 선거 때만 읍소를 한다, 이런 실망감을 표시하시는 분도 계셨습니다.
# ◇ 정길훈: 현재 당권에 여덟 분이 도전하고 있는데요. 이 후보가 당 대표에 도전해야 되겠다고 결심한 이유 어떤 것입니까?
#
# ◆ 이동학: 우선 저는 정치가 좀 망가져 있는 것 아닌가라고 판단을 하고 있는데요. 이것은 왜 그러냐 하면 우리가 상대방의 발목을 잡고 못하게 막으면 저들이 넘어지게 되어 있잖아요.
# ◇ 정길훈: 양당 정치에서 말씀하시는 것이지요.
# ◆ 이동학: 네. 그러면 선택지가 우리밖에 없으니 우리를 뽑게 되는 것이에요. 국민들 입장에서는요. 그리고 상대방이 또 우리의 발목을 잡고 우리가 넘어지면 또 상대방을 찍는 것이에요. 그러니까 아무런 개선이 없어도 상대방 발목만 잡으면 집권을 하거나 당선이 되는 정치를 하다 보니 국민 입장에서는 삶이 제대로 지켜지기가 어렵다. 이 문제를 지적하면서 지금 게임의 룰을 바꿔야, 정치인에게 이익이 되는 룰이 아니라 국민에게 이익이 되는 룰로 바꿔야 된다. 몇십 년 동안 이렇게 한국 정치가 오면서 점점 양극단의 분노가 계속 쌓이고 있는 것 같아서 이런 상태로는 아무런 위기를 해결할 수 없겠다 이런 절박감에 나오게 됐습니다.
# ◇ 정길훈: 정치가 망가져 있다고 하셨는데요. 이 후보가 당 대표가 되면 민주당의 모습 어떻게 달라지겠습니까?
# ◆ 이동학: 지금 제가 말씀드린 양당제의 폐해, 이것으로 인해서 많은 국민이 피해를 입고 계시는데 이것부터 연내에 처리를 하도록 노력할 생각입니다. 엊그저께 국회에 정치개혁특위가 만들어지게 됐고요. 거기에서 근본적으로 양당제를 만들게 되는 선거법 같은 것들을 개정하려고 합니다. 특히 비례대표를 훨씬 더 확대해서 지금은 사실 양당제가 주요한 이슈들, 민생 이슈를 다루지 않으면서 실제로 그들의 이익관계에 놓여 있는 문제만을 다루게 돼 있습니다. 그래서 지금 우리가 생각하고 있는 기후위기라든가 아니면 초고령화 문제로 인해서 상당히 지역의 젊은이들은 떠나가게 되고 지역은 초고령화 되고 산업은 또 사라지고 이러한 문제가 사실상 양당제에 막혀서 후순위로 다 밀려 있는 것입니다. 이런 민생 문제를 정치가 제대로 다룰 수 있도록 정치 체계를 정비하는 역할을 할 생각입니다. 그래서 그것을 연내에 처리하게 되고요. 이렇게 되면 실제 우리 정치에 굉장히 큰 변화가 있을 것입니다.
# ◇ 정길훈: 그런데 양당 정치의 폐해를 극복하기 위해서 비례대표 확대하려면 선거법을 바꿔야 되지 않습니까? 선거 제도를 개혁해야 하는데 거대 양당은 별로 관심이 없어 보이고요. 당 내부에서 의원들을 어떻게 설득하시겠습니까?
# ◆ 이동학: 작년 대선 경쟁에 들어가면서 제가 최고위원이 되었기 때문에 이런 대선 국면에서 목소리를 낸다는 것이 쉬운 국면은 아니었습니다. 그런데 많은 분께서 그래도 기억을 해주시는 것은 제가 2015년도에 당에서 혁신위원을 할 때 당시 분란이 엄청 심했는데 당시에 선배 세대들을 향해서 조금 더 새로운 깃발을 들어달라, 그리고 당이 어려우니 지역구를 고수할 것이 아니라 험지로 가서 출마해서 당의 외연을 확장해달라, 이런 요구를 당차게 하기도 했었던 모습을 많이 기억해주시더라고요. 저는 지금도 그렇게 생각합니다. 아마도 스피커의 크기가 그렇게 크지 않은 상태이기 때문에 더 청년들의 목소리 혹은 미래 어젠다 이런 것이 민주당에서 더 나올 수 있도록 앞으로 계속 노력해나가도록 하겠습니다.
# ◇ 정길훈: 호남 이야기도 해보겠습니다. 호남에서 민주당에 대한 실망감이 큰데요. 지난 6.1 지방선거에서 광주 지역 투표율 37%로 역대 최저치 기록했고요. 이런 상황이 민주당에 시사하는 점 어떤 점이라고 보십니까?
# ◆ 이동학: 우선 지금 민주당은 양당제의 기득권을 누리고 있는 정당입니다. 그러다 보니까 사실은 잘못해도 호남 같은 지역에서는 심판받지 않는 것이에요. 그런데 이렇게 투표율이 낮았다고 하는 것은 사실상 심판받았다고 봐야 되거든요. 그런데 아마도 우리가 또 개선 같은 것을 하지 않아도 다음번에 또 당선될 수도 있다는 확신이 들면 아마 또 변화된 것은 없을 겁니다. 그래서 실제 제가 어제 만났던 당원 분들도 그런 것에 대해서 정확하게 민주당이 인식을 해야 된다고 지적해주셨고요. 그 변화를 만들기 위해서 제가 선거법 개정이라든지 이런 것들에 대한 노력을 지금부터 강력하게 해나가야겠다고 또다시 결심한 계기가 됐는데요. 젊은이들이 지방을 계속해서 떠나가고 산업이 당연히 죽고 있는 상황이고요. 그러다 보니까 지역 소멸은 가속화되고 있고 대학은 쓰러지고 있고 이런 상황이기 때문에 지금의 양당제 정치는 주로 서울에서 이루어지고 있는 정치거든요. 서울에서 멀수록 이 도시의 기반을 만들기가 굉장히 어려워지고 있는 상황이고 이것은 계속 악화일로를 걸을 수밖에 없다고 생각해요. 그래서 서울 중심의 양당제 정치 이런 부분을 지금 당장 저희가 깨나가야 된다고 생각하고요. 그런 측면에서 제가 세대교체라는 말보다는 세력 교체다, 실제 그러한 국가의 미래, 지역의 미래 준비할 수 있는 정치 체계를 만드는 세력 구축이 이번에 돼야만 우리가 그 일을 연말까지 혹은 내년까지 해낼 수 있다 이렇게 생각합니다.
# ◇ 정길훈: 오늘 이야기는 여기까지 듣겠습니다.
# ◆ 이동학: 고맙습니다.
# ◇ 정길훈: 지금까지 민주당 당 대표 선거에 출마한 이동학 후보였습니다.
# 정길훈 기자 (skynsky@kbs.co.kr)

# %% [markdown]
# ##### 추가연습) 김건희 여사 기사 내용 뽑기

# %%
url = 'https://news.v.daum.net/v/20220726105712920'

# %%
print(url)

html = rq.get(url)
bs2 = BeautifulSoup(html.text, 'html.parser')
bs2
# Out:
# https://news.v.daum.net/v/20220726105712920
# <!DOCTYPE html>
#
# <html lang="ko">
# <head data-cloud-area="head">
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <style>
#             @import url('//t1.daumcdn.net/harmony_static/cloud/page/07dbf94b96594fe2ea9953108239daca8e501bfc1653982322266.css');
#             @import url('//t1.daumcdn.net/harmony_static/cloud/2022/06/29/common.98cb4e1c81a314168abb.css')
#         </style>
# <style>
#             /* 다음 카페 소셜 쉐어 임시 비활성화 */
#             .list_sns li:nth-child(6) {
#                 display: none;
#             }
#         </style>
# <meta content="UOf9JnyP9M" property="mccp:docId"/>
# <meta content="다음뉴스" property="og:site_name"/>
# <meta content="2주 넘게 '두문불출' 김 여사..목요일 등장할까?" property="og:title"/>
# <meta content="20220726105712" property="og:regDate"/>
# <meta content="article" property="og:type"/>
# <meta content="MBC" property="og:article:author"/>
# <meta content="https://news.v.daum.net/v/UOf9JnyP9M" property="og:url"/>
# <meta content="https://img1.daumcdn.net/thumb/S1200x630/?fname=https://t1.daumcdn.net/news/202207/26/imbc/20220726111013886nswx.jpg" property="og:image"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="630" property="og:image:height"/>
# <meta content='■ "마드리드 이후 김건희 여사가 안 보인다" 윤석열 대통령의 지지율 추이와 더불어 최근 언론이 자주 언급하는 기사는 "김건희 여사가 공개 행보를 중단했다"는 내용입니다. 북대서양조약기구, NATO 순방 동행을 마치고 난 뒤 두문불출하고 있다는 겁니다. 정치평론가들은 김 여사가 공개 행보에 나설 때마다 관심을 끌기는 했지만 팬클럽, 수행원, 제2부속실' property="og:description"/>
# <meta content="daumapps://web?url=https%3A%2F%2Fnews.v.daum.net/v/UOf9JnyP9M" property="al:android:url"/>
# <meta content="net.daum.android.daum" property="al:android:package"/>
# <meta content="다음앱" property="al:android:app_name"/>
# <meta content="daumapps://web?url=https%3A%2F%2Fnews.v.daum.net/v/UOf9JnyP9M" property="al:ios:url"/>
# <meta content="365494029" property="al:ios:app_store_id"/>
# <meta content="다음앱" property="al:ios:app_name"/>
# <meta content="summary_large_image" property="twitter:card"/>
# <meta content="daumapps://web?url=https%3A%2F%2Fnews.v.daum.net/v/UOf9JnyP9M" property="twitter:app:url:googleplay"/>
# <meta content="net.daum.android.daum" property="twitter:app:id:googleplay"/>
# <meta content="다음앱" property="twitter:app:name:googleplay"/>
# <meta content="KR" property="twitter:app:country"/>
# <meta content="daumapps://web?url=https%3A%2F%2Fnews.v.daum.net/v/UOf9JnyP9M" property="twitter:app:url:iphone"/>
# <meta content="365494029" property="twitter:app:id:iphone"/>
# <meta content="다음앱" property="twitter:app:name:iphone"/>
# <meta content="daumapps://web?url=https%3A%2F%2Fnews.v.daum.net/v/UOf9JnyP9M" property="twitter:app:url:ipad"/>
# <meta content="365494029" property="twitter:app:id:ipad"/>
# <meta content="다음앱" property="twitter:app:name:ipad"/>
# <meta content="unsafe-url" name="referrer"/>
# <title>2주 넘게 '두문불출' 김 여사..목요일 등장할까?</title>
# <link href="//t1.daumcdn.net/top/favicon.ico" rel="shortcut icon"/>
# </head>
# <body class="">
# <div id="kakaoIndex"> <a href="#kakaoBody">본문 바로가기</a> <a href="#kakaoGnb">메뉴 바로가기</a>
# </div>
# <div class="newsview_media" id="kakaoWrap">
# <div id="wrapMinidaum"></div>
# <div data-cloud-area="header" id="kakaoHead" role="banner">
# <div class="head_media" data-cloud="pc_header_gnb">
# <h1> <a class="link_daum" href="https://www.daum.net"> <img alt="Daum" class="thumb_g" height="19" src="//t1.daumcdn.net/media/news/news2016/retina/logo_daum.jpg" width="45"/> </a> <a href="//news.daum.net" id="kakaoServiceLogo"><span class="ir_wa">뉴스</span></a> </h1> <strong class="screen_out">관련서비스</strong>
# <ul id="kakaoRelServicesNew">
# <li><a class="link_services" href="https://entertain.daum.net/"><span class="ir_wa">연예</span></a></li>
# <li><a class="link_services" href="https://sports.daum.net/"><span class="ir_wa">스포츠</span></a></li>
# </ul>
# <h2 class="screen_out">검색</h2>
# <div class="search_news" id="search_news">
# <form action="https://search.daum.net/search" id="kakaoSearch" method="get" name="kakaoSearch">
# <fieldset class="fld_inside"> <legend class="screen_out">검색어 입력폼</legend>
# <div class="box_searchbar"> <label class="lab_search" for="qVal">통합검색</label>
# <input name="nil_profile" type="hidden" value="search"/>
# <input name="nil_src" type="hidden" value="media"/>
# <input name="DA" type="hidden" value="23A"/>
# <input name="rtmaxcoll" type="hidden" value="NNS"/>
# <input autocomplete="off" class="tf_keyword" id="qVal" name="q" spellcheck="false" title="검색어 입력" type="text" value=""/> <button class="btn_search" id="kakaoBtnSearch" type="submit"><span class="ir_wa">검색</span></button>
# </div>
# </fieldset>
# <div class="wrap_suggestBox" id="wrap_suggestBox">
# <div class="suggestBox box_sub" id="suggestBox">
# <div class="baseBox bg" style="display: none"></div>
# </div>
# </div>
# </form>
# </div>
# </div>
# <div data-cloud="pc_header_gnb" id="kakaoGnb" role="navigation">
# <div class="inner_gnb">
# <h2 class="screen_out">뉴스 메인메뉴</h2>
# <ul class="gnb_comm" data-category="politics">
# <li class="home"><a class="link_gnb link_gnb1" href="//news.daum.net/"><span class="ir_wa">홈</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li class="society"><a class="link_gnb link_gnb2" href="//news.daum.net/society/"><span class="ir_wa">사회</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li class="politics"><a class="link_gnb link_gnb3" href="//news.daum.net/politics/"><span class="ir_wa">정치</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li class="economic"><a class="link_gnb link_gnb4" href="//news.daum.net/economic/"><span class="ir_wa">경제</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li class="foreign"><a class="link_gnb link_gnb5" href="//news.daum.net/foreign/"><span class="ir_wa">국제</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li class="culture"><a class="link_gnb link_gnb6" href="//news.daum.net/culture/"><span class="ir_wa">문화</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li class="digital"><a class="link_gnb link_gnb7" href="//news.daum.net/digital/"><span class="ir_wa">IT</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li class="series editorial"><a class="link_gnb link_gnb9" href="//news.daum.net/series"><span class="ir_wa">연재</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li class="photo"><a class="link_gnb link_gnb10" href="//news.daum.net/photo"><span class="ir_wa">포토</span><span class="bar_gnb"><span class="inner_bar"></span></span></a></li>
# <li class="factcheck"> <a class="link_gnb link_gnb12" href="https://focus.daum.net/ch/news/factcheck"><span class="ir_wa">팩트체크</span><span class="bar_gnb"><span class="inner_bar"></span></span></a> </li>
# </ul>
# <div class="gnb_etc">
# <div class="gnb_weather"> <strong class="screen_out">날씨 정보</strong>
# <div id="gnb_weather">
# <ul class="list_weather" data-nightyn="N"></ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="bar_progress" data-cloud="pc_header_gnb" id="barProgress"></div>
# </div>
# <div id="dummyKakaoGnb" style="height:137px; display:none;"></div>
# <hr class="hide"/>
# <div class="cont_view" id="kakaoContent" role="main">
# <h2 class="screen_out" id="kakaoBody">정치</h2>
# <div data-cloud-area="title" id="cSub">
# <div class="head_view" data-cloud="pc_article_title_and_util"> <em class="info_cp"> <a class="link_cp" href="http://imnews.imbc.com/" target="_blank"> <img alt="MBC" class="thumb_g" src="https://t1.daumcdn.net/media/news/news2016/cp/cp_imbc.gif"/> </a> </em>
# <h3 class="tit_view" data-translation="true">2주 넘게 '두문불출' 김 여사..목요일 등장할까?</h3> <span class="info_view"> <span class="txt_info">정승혜 luxmundi@mbc.co.kr</span> <span class="txt_info">입력 <span class="num_date">2022. 07. 26. 10:57</span></span> <span class="txt_info">수정 <span class="num_date">2022. 07. 26. 11:10</span></span> <button class="emph_g2 link_cmt" id="alexCounter">댓글 <span class="alex-count-area">0</span>개</button> </span>
# <div class="util_view">
# <h4 class="screen_out">기사 도구 모음</h4>
# <div class="btn_util util_summary"> <button aria-expanded="false" class="btn_summary" type="button"><span class="ico_newsview">자동요약</span></button>
# <div class="wrap_setlayer">
# <div class="layer_util layer_summary">
# <p>윤석열 대통령의 지지율 추이와 더불어 최근 언론이 자주 언급하는 기사는 "김건희 여사가 공개 행보를 중단했다"는 내용입니다.</p>
# <p>장성철 공론센터 소장은 "김건희 여사가 최근 2주간 사라졌다"면서 "김 여사가 지지율에 중대한 영향을 끼친다는 정무적인 판단이 있었을 것"이라고 말했습니다.</p>
# <p>배종찬 인사이트케이 소장 역시 윤 대통령의 지지율 하락 원인 중 하나로 김건희 여사를 꼽았습니다.</p> <span class="info_summary"><span class="ico_newsview"></span>기사 제목과 주요 문장을 기반으로 자동요약한 결과입니다. 전체 맥락을 이해하기 위해서는 본문 보기를 권장합니다.</span>
# </div>
# </div>
# </div>
# <div class="btn_util tts_btn"> <button aria-expanded="false" class="btn_set btn_tts" type="button"> <span class="ico_newsview ico_speak">음성 기사 듣기</span> </button>
# <div class="wrap_setlayer">
# <div class="layer_util layer_set layer_tts"> <strong class="screen_out">음성 기사 옵션 조절 레이어</strong>
# <ul class="list_set list_tts">
# <li> <input class="screen_out" id="ttsGenderMale" name="ttsGender" type="radio" value="Male"/> <label class="lab_set" for="ttsGenderMale"><span class="ico_newsview"></span>남성</label> </li>
# <li> <input class="screen_out" id="ttsGenderFemale" name="ttsGender" type="radio" value="Female"/> <label class="lab_set" for="ttsGenderFemale"><span class="ico_newsview"></span>여성</label> </li>
# </ul>
# <ul class="list_set list_tts list_ttsspeed">
# <li> <input class="screen_out" id="ttsSpeedSlow" name="ttsSpeed" type="radio" value="slow"/> <label class="lab_set" for="ttsSpeedSlow"><span class="ico_newsview"></span>느림</label> </li>
# <li> <input class="screen_out" id="ttsSpeedNormal" name="ttsSpeed" type="radio" value="normal"/> <label class="lab_set" for="ttsSpeedNormal"><span class="ico_newsview"></span>보통</label> </li>
# <li> <input class="screen_out" id="ttsSpeedFast" name="ttsSpeed" type="radio" value="fast"/> <label class="lab_set" for="ttsSpeedFast"><span class="ico_newsview"></span>빠름</label> </li>
# </ul>
# </div>
# </div>
# <audio id="ttsPlayer" preload="none" style="display:none"></audio>
# </div>
# <div class="btn_util translate_btn"> <button aria-expanded="false" class="btn_set btn_translate #util #translate #set" type="button"><span class="ico_newsview">번역 설정</span></button>
# <div class="wrap_translatelayer">
# <div class="layer_util layer_translate"> <strong class="tit_translate">번역<span class="ico_newsview">beta</span> </strong>
# <p class="desc_translate txt_newsview">Translated by <a class="link_kakaoi #util #translate #kakaoi_link" href="https://kakao.ai/" target="_blank">kakao i</a></p> <strong class="screen_out">번역할 언어 선택</strong>
# <ul class="list_lang">
# <li> <button class="btn_lang btn_en #util #translate #lang_en" name="en"> <span class="ico_newsview ico_flag"></span> <strong class="ico_newsview tit_lang">English</strong> </button> </li>
# <li> <button class="btn_lang btn_ch #util #translate #lang_cn" name="cn" type="button"> <span class="ico_newsview ico_flag"></span> <strong class="ico_newsview tit_lang">简体中文</strong> </button> </li>
# <li> <button class="btn_lang btn_jp #util #translate #lang_jp" name="jp" type="button"> <span class="ico_newsview ico_flag"></span> <strong class="ico_newsview tit_lang">日本語</strong> </button> </li>
# <li> <button class="btn_lang btn_ind #util #translate #lang_id" name="id" type="button"> <span class="ico_newsview ico_flag"></span> <strong class="ico_newsview tit_lang">Bahasa Indonesia</strong> </button> </li>
# <li> <button class="btn_lang btn_viet #util #translate #lang_vi" name="vi" type="button"> <span class="ico_newsview ico_flag"></span> <strong class="ico_newsview tit_lang">tiếng Việt</strong> </button> </li>
# <li> <button class="btn_lang btn_ko #util #translate #lang_kr" name="kr" type="button"> <span class="ico_newsview ico_flag"></span> <strong class="ico_newsview tit_lang">한국어</strong> </button> </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="btn_util share_btn"> <button aria-expanded="false" class="btn_set btn_share" id="rSocialShareButton"> <span class="ico_newsview">공유</span> </button>
# <div id="rSocialShareLayerContainer"></div>
# </div>
# <div class="btn_util font_btn"> <button aria-expanded="false" class="btn_set btn_font" type="button"> <span class="ico_newsview ico_font">글씨크기 조절하기</span> </button>
# <div class="wrap_setlayer">
# <div class="layer_util layer_set layer_font"> <strong class="screen_out">글자 크기 조절 레이어</strong>
# <ul class="list_set list_font">
# <li> <input class="screen_out" id="inpFont17" name="inpFont" type="radio" value="17"/> <label class="lab_set lab_size0" for="inpFont17"> <span class="ico_newsview"></span> <span aria-hidden="true">가나다라마바사</span> <span class="screen_out">매우 작은 폰트</span> </label> </li>
# <li> <input class="screen_out" id="inpFont18" name="inpFont" type="radio" value="18"/> <label class="lab_set lab_size1" for="inpFont18"> <span class="ico_newsview"></span> <span aria-hidden="true">가나다라마바사</span> <span class="screen_out">작은 폰트</span> </label> </li>
# <li> <input class="screen_out" id="inpFont19" name="inpFont" type="radio" value="19"/> <label class="lab_set lab_size2" for="inpFont19"> <span class="ico_newsview"></span> <span aria-hidden="true">가나다라마바사</span> <span class="screen_out">보통 폰트</span> </label> </li>
# <li> <input class="screen_out" id="inpFont20" name="inpFont" type="radio" value="20"/> <label class="lab_set lab_size3" for="inpFont20"> <span class="ico_newsview"></span> <span aria-hidden="true">가나다라마바사</span> <span class="screen_out">큰 폰트</span> </label> </li>
# <li> <input class="screen_out" id="inpFont21" name="inpFont" type="radio" value="21"/> <label class="lab_set lab_size4" for="inpFont21"> <span class="ico_newsview"></span> <span aria-hidden="true">가나다라마바사</span> <span class="screen_out">매우 큰 폰트</span> </label> </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="btn_util"> <button class="btn_print" type="button"><span class="ico_newsview">인쇄하기 새창열림</span></button>
# </div>
# </div>
# </div>
# </div>
# <div id="cMain">
# <div id="mArticle">
# <div data-cloud-area="article">
# <div class="status_view" data-cloud="pc_article_body" id="translateNotice" style="display:none;"> <span class="inner_status"> <p class="txt_status notice_lang notice_lang_en" style="display:none;">The copyright belongs to the original writer of the content, and there may be errors in machine translation results.</p> <p class="txt_status notice_lang notice_lang_cn" style="display:none;">版权归内容原作者所有。机器翻译结果可能存在错误。</p> <p class="txt_status notice_lang notice_lang_jp" style="display:none;">原文の著作権は原著著作者にあり、機械翻訳の結果にエラーが含まれることがあります。</p> <p class="txt_status notice_lang notice_lang_id" style="display:none;">Hak cipta milik penulis asli dari konten, dan mungkin ditemukan kesalahan dalam hasil terjemahan mesin.</p> <p class="txt_status notice_lang notice_lang_vi" style="display:none;">Bản quyền thuộc về tác giả gốc của nội dung và có thể có lỗi trong kết quả dịch bằng máy.</p> </span>
# </div>
# <div class="news_view" data-cloud="pc_article_body" style="font-size:17px">
# <div class="article_view" data-translation-body="true" id="harmonyContainer">
# <section dmcf-sid="uk1XBKA0bx">
# <figure class="figure_frm origin_fig" dmcf-pid="uyxoRdS42t" dmcf-ptype="figure">
# <p class="link_figure"><img class="thumb_g_article" data-org-src="https://t1.daumcdn.net/news/202207/26/imbc/20220726111013886nswx.jpg" data-org-width="600" dmcf-mid="pvT1WG8Cb3" dmcf-mtype="image" height="auto" src="https://img4.daumcdn.net/thumb/R658x0.q70/?fname=https://t1.daumcdn.net/news/202207/26/imbc/20220726111013886nswx.jpg" width="658"/></p>
# </figure>
# <p dmcf-pid="7lxoRdS4b1" dmcf-ptype="general"><strong>■ "마드리드 이후 김건희 여사가 안 보인다"</strong></p>
# <p dmcf-pid="zI6iQMC2q5" dmcf-ptype="general">윤석열 대통령의 지지율 추이와 더불어 최근 언론이 자주 언급하는 기사는 "김건희 여사가 공개 행보를 중단했다"는 내용입니다. </p>
# <p dmcf-pid="qSMgeJv8KZ" dmcf-ptype="general">북대서양조약기구, NATO 순방 동행을 마치고 난 뒤 두문불출하고 있다는 겁니다.</p>
# <figure class="figure_frm origin_fig" dmcf-pid="BpEhwmUNbX" dmcf-ptype="figure">
# <p class="link_figure"><img class="thumb_g_article" data-org-src="https://t1.daumcdn.net/news/202207/26/imbc/20220726111014063gogb.jpg" data-org-width="600" dmcf-mid="U7v5yY4I2F" dmcf-mtype="image" height="auto" src="https://img2.daumcdn.net/thumb/R658x0.q70/?fname=https://t1.daumcdn.net/news/202207/26/imbc/20220726111014063gogb.jpg" width="658"/></p>
# </figure>
# <p dmcf-pid="bhQLMelfqH" dmcf-ptype="general"> 정치평론가들은 김 여사가 공개 행보에 나설 때마다 관심을 끌기는 했지만 팬클럽, 수행원, 제2부속실 설치, 명품 목걸이 논란 등으로 부정적인 여론이 대두되자 ‘리스크 관리’에 들어간 것으로 보고 있습니다. </p>
# <p dmcf-pid="KzmTOCqkbG" dmcf-ptype="general">장성철 공론센터 소장은 “김건희 여사가 최근 2주간 사라졌다”면서 “김 여사가 지지율에 중대한 영향을 끼친다는 정무적인 판단이 있었을 것”이라고 말했습니다. 배종찬 인사이트케이 소장 역시 윤 대통령의 지지율 하락 원인 중 하나로 김건희 여사를 꼽았습니다. 배 소장은 경제, 인사, 양극화, 김 여사, 도어스테핑의 앞글자를 딴 ‘경인양김도’가 지지율이 떨어진 이유라고 분석했습니다. 유튜브 채널 ‘시사저널 TV’에 출연한 진중권 전 교수는 “지금 김건희 여사는 잘하고 있는 것 아니냐?”는 사회자의 질문에 “그렇다. 조금 더 기다려야 될 것 같다”고 조언하기도 했습니다.</p>
# <p dmcf-pid="9ZgwNA5JfY" dmcf-ptype="general"><strong>■ 공개행보 재개는? 목요일 진수식이 유력</strong></p>
# <p dmcf-pid="2qsyIhBEbW" dmcf-ptype="general">그렇다면 김건희 여사는 언제쯤 다시 언론에 모습을 드러낼까요? 목요일인 28일이 될 가능성이 높습니다. 차세대 이지스함인 정조대왕 진수식이 열리는데, 여기에 참석하지 않을까 예상됩니다.</p>
# <p dmcf-pid="VUDlrsuj2y" dmcf-ptype="general">배에 이름을 붙이고 처음 물에 띄워 바다로 내보내는 의식인 진수식(進水式)에서는 진수도끼(보통 금토끼)로 밧줄을 끊거나 샴페인을 깨는 행사가 있습니다. 진수식의 하이라이트인데요, 관례적으로 여성이 해왔다고 합니다. 왜 여성이 하게 됐는지를 놓고 영국 빅토리아 여왕이 세레모니를 한 이후 관례로 굳어졌다는 설도 있고, 배(ship)를 여성 대명사인 she로 받는데서 유래했다 혹은 탯줄을 자르는 상징적인 의미가 있기 때문에 여성이 하게 됐다는 여러 가지 설들이 있습니다. </p>
# <p dmcf-pid="fn3bpuLZ2T" dmcf-ptype="general">김건희 여사가 진수식에 등장할지는 목요일 확인할 수 있을 것 같습니다.</p>
# <p dmcf-pid="4pEhwmUNBv" dmcf-ptype="general">정승혜 기자 (luxmundi@mbc.co.kr)</p>
# <p dmcf-pid="8rVR46mBqS" dmcf-ptype="general">기사 원문 - https://imnews.imbc.com/news/2022/politics/article/6392168_35666.html</p>
# </section>
# <p data-translation="true">저작권자(c) MBC (www.imnews.com) 무단복제-재배포 금지 </p>
# </div>
# </div>
# </div>
# <div class="foot_view" data-cloud-area="addition">
# <div class="emotion_wrap" data-cloud="alex_action_emotion">
# <div class="emotion_tit"> <strong class="tit_emotion">이 기사에 대해 어떻게 생각하시나요?</strong>
# </div>
# <div class="emotion_list">
# <div class="alex-actions" data-action-mode="REACTION" data-client-id="26BXAvKny5WF5Z09lr5k77Y8" data-item-key="20220726105712920" data-message-channel="alex-action-reactions" id="alex_action_emotion">
# </div>
# </div>
# </div>
# <div class="relate_series hide" data-cloud="pc_news_cluster"> <strong class="tit_series"> <em class="tag_series">연재</em> <span class="title_series"></span> </strong>
# <ul class="list_series"></ul> <a class="link_more" href="#none">더보기</a>
# </div>
# <div class="cp_view" data-cloud="pc_related_news">
# <div class="cp_tit">
# <h3 class="tit_cp">MBC 주요 뉴스</h3>
# <p class="info_cp">해당 언론사로 연결됩니다.</p>
# </div>
# <ul class="list_relate">
# <li><a class="link_txt" data-type="related" href="https://imnews.imbc.com
data-ad-height="250" data-ad-type="D" data-ad-unit="05d24" data-ad-width="250" data-cloud="pc_aside_top_ad" style="display:block;width:250px;height:250px;"> </ins>
# <div class="aside_g aside_phototv hide" data-cloud="pc_news_photo_tv">
# <h3 class="txt_newsview">포토&amp;TV</h3>
# <div class="cont_aside">
# <ul class="list_phototv"></ul>
# </div>
# </div>
# <ins class="kakao_ad_area aside_g aside_ad" data-ad-height="250" data-ad-type="D" data-ad-unit="0QH44" data-ad-width="250" data-cloud="pc_aside_bottom_ad" style="display:block;width:250px;height:250px;"> </ins>
# </div>
# </div>
# <div id="cEtc">
# <div class="realtime_view">
# <div class="inner_realtime">
# <div data-cloud-area="etc">
# <div class="realtime_news" data-cloud="pc_realtime_news">
# <h3 class="txt_newsview">이 시각 추천뉴스</h3>
# <ul class="list_realtime">
# <li class="item_main item_realtime_news"></li>
# <li class="item_main item_realtime_news"></li>
# <li class="item_realtime_news"></li>
# <li class="item_realtime_news"></li>
# <li class="item_realtime_news"></li>
# <li class="item_realtime_news"></li>
# <li class="item_realtime_news"></li>
# <li class="item_realtime_news"></li>
# <li class="item_realtime_news"></li>
# <li class="item_realtime_news"></li>
# <li class="item_realtime_news"></li>
# <li class="item_realtime_news"></li>
# </ul>
# </div>
# </div>
# <div class="realtime_aside" data-cloud-area="etc-aside" id="realtime_aside">
# <ins class="kakao_ad_area etc_bottom_ad" data-ad-height="250" data-ad-onfail="onFailEtcBottomAd" data-ad-unit="DAN-kQxraZPBvpl52CWq" data-ad-width="250" data-cloud="pc_etc_bottom_ad" style="display: block; width: 100%;"> </ins>
# </div>
# </div>
# </div>
# <div data-cloud-area="etc-addition">
# </div>
# </div>
# </div>
# <hr class="hide"/>
# <div class="footer_comm" data-cloud-area="footer" id="kakaoFoot" role="contentinfo">
# <div class="inner_foot" data-cloud="pc_footer">
# <div class="direct_link">
# <h2 class="tit_direct">바로가기</h2>
# <div class="item_bundle"> <a class="link_txt" href="https://news.daum.net/">뉴스홈</a> <a class="link_txt" href="https://news.daum.net/society/">사회</a> <a class="link_txt" href="https://news.daum.net/politics/">정치</a> <a class="link_txt" href="https://news.daum.net/economic/">경제</a> <a class="link_txt" href="https://news.daum.net/foreign/">국제</a> <a class="link_txt" href="https://news.daum.net/culture/">문화</a> <a class="link_txt" href="https://news.daum.net/digital/">IT</a> <a class="link_txt" href="https://news.daum.net/photo/">포토</a> <a class="link_txt" href="https://news.daum.net/tv/">TV</a>
# </div>
# <div class="item_bundle"> <a class="link_txt" href="https://news.daum.net/cp">언론사별 뉴스</a>
# </div>
# <div class="item_bundle"> <a class="link_txt" href="https://news.daum.net/newsbox">배열이력</a>
# </div>
# <div class="item_bundle"> <a class="link_txt" href="https://news.daum.net/breakingnews">전체뉴스</a> <a class="link_txt" href="https://news.daum.net/ranking/popular">랭킹</a> <a class="link_txt" href="https://news.daum.net/series">연재</a> <a class="link_txt" href="https://focus.daum.net/ch/news/factcheck">팩트체크</a>
# </div> <button class="btn_fold" type="button"><span class="ico_news">바로가기 링크 더보기/접기</span></button>
# </div>
# <h2 class="screen_out">서비스 이용정보</h2>
# <div class="footer_link"> <a class="link_info" href="https://news.daum.net/info/intro">다음뉴스 소개</a> <span class="txt_dot"> ・ </span> <a class="link_info" href="https://news.daum.net/notice">공지사항</a> <span class="txt_dot"> ・ </span> <a class="link_info" href="https://news.daum.net/info/bbsrule">게시물 운영원칙</a> <span class="txt_dot"> ・ </span> <a class="link_info" href="https://policy.daum.net/info/info">서비스 약관/정책</a> <span class="txt_dot"> ・ </span> <a class="link_info" href="https://with.kakao.com/media">뉴스제휴</a> <span class="txt_dot"> ・ </span> <a class="link_info" href="https://business.kakao.com/">비즈니스</a> <span class="txt_dot"> ・ </span> <a class="link_info" href="https://cs.daum.net/redbell/top.html">권리침해신고</a> <span class="txt_dot"> ・ </span> <a class="link_info" href="https://cs.daum.net/faq/63.html">다음뉴스 고객센터</a>
# </div>
# <div class="footer_link"> <a class="link_info" href="https://news.daum.net/info/newscenter24">24시간 뉴스센터</a> <span class="txt_dot"> ・ </span> <a class="link_info" href="https://news.daum.net/info/edit">서비스원칙</a> <span class="txt_dot"> ・ </span> <a class="link_info" href="https://news.daum.net/info/correct">고침기사, 정정・반론・추후보도 모음</a> <span class="txt_dot"> ・ </span> <span class="link_info">기사배열책임자 : 황유지</span> <span class="txt_dot"> ・ </span> <span class="link_info">청소년보호책임자 : 정현주</span>
# </div>
# <div class="info_copyright"> <strong class="info_warn">위 내용에 대한 저작권 및 법적 책임은 자료제공사 또는 <br/>글쓴이에 있으며, Kakao의 입장과 다를 수 있습니다.</strong> <small class="txt_copyright">Copyright © <strong class="txt_kakao"><a class="link_kakao" href="https://www.kakaocorp.com">Kakao Corp.</a></strong> All rights reserved.</small>
# </div>
# </div>
# </div> <samp data-cloud-area="util"> </samp>
# </div>
# <script src="//t1.daumcdn.net/harmony_static/cloud/2022/06/29/vendor.1687580f7a28c20f6195.js"></script>
# <script src="//t1.daumcdn.net/harmony_static/cloud/2022/06/29/common.98cb4e1c81a314168abb.js"></script>
# <script src="//t1.daumcdn.net/kas/static/ba.min.js"></script>
# <script src="//t1.daumcdn.net/kas/static/na.min.js"></script>
# <script src="//m1.daumcdn.net/svc/original/U03/cssjs/userAgent/userAgent-1.0.12.min.js"></script>
# <script>"use strict";function _classCallCheck(e,t){if(!(e instanceof t))throw new TypeError("Cannot call a class as a function")}function _defineProperties(e,t){for(var a=0;a<t.length;a++){var n=t[a];n.enumerable=n.enumerable||!1,n.configurable=!0,"value"in n&&(n.writable=!0),Object.defineProperty(e,n.key,n)}}function _createClass(e,t,a){return t&&_defineProperties(e.prototype,t),a&&_defineProperties(e,a),e}!(function(){var a="<li>\n                          <a href=\"https://search.daum.net/search?nil_suggest=btn&w=tot&DA=SBC&q=<%= specialRegionName %>%20날씨\" class=\"link_cont\">\n                          <span class=\"ico_weather ico_weather<%= weatherIconCode %>\"><%= specialRegionName %></span> \n                          <span class=\"txt_weather\"><%= specialRegionName %>\n                              <span class=\"num_heat\"><%= temperature %></span> \n                              <span class=\"txt_heat\">℃</span>\n                          </span>\n                          </a>\n                        </li>",t=document.querySelector('.gnb_weather'),n=t.querySelector('ul'),e="".concat(Conf.api.hadesRest,"/pc_weather");axios.get(e).then(function(e){var t=e.data.body.data,e=t.isNightIconYn,t=t.weatherData;n.dataset.nightyn=e,n.innerHTML=t.map(function(e){return _.template(a)(e)}).join('');new s(n)}).catch(function(e){t.parentNode.removeChild(t)});var s=(function(){function t(e){_classCallCheck(this,t),this.PAUSE_TIME=4e3,this.TRANSITION_TIME=500,this.list=e,this.frameId=null,this.pause=this.pause.bind(this),this.start=this.start.bind(this),this.moveUp=this.moveUp.bind(this),this.init(),this.start(),this.list.style.marginTop='0px'}return _createClass(t,[{key:"start",value:function(){this.frameId=setInterval(this.moveUp,this.PAUSE_TIME)}},{key:"pause",value:function(){clearInterval(this.frameId)}},{key:"moveUp",value:function(){var e=this.list,t=e.firstElementChild.cloneNode(!0);e.classList.add('slidein'),e.style.marginTop='-30px',setTimeout(function(){e.classList.remove('slidein'),e.style.marginTop='0px',e.removeChild(e.firstElementChild),e.appendChild(t)},this.TRANSITION_TIME)}},{key:"init",value:function(){var t=this,e=this.list;e.addEventListener('mouseenter',this.pause),e.addEventListener('mouseleave',this.start),e.querySelectorAll('a').forEach(function(e){e.addEventListener('focus',t.pause),e.addEventListener('blur',t.start)})}}]),t})()})();</script>
# <script>"use strict";!(function(){var e=-1<''.indexOf('tv_news')?'tv':'politics',t=document.querySelector('.gnb_comm');(t=e&&t.querySelector(".".concat(e)))&&t.setAttribute('class',"".concat(e," on"))})();</script>
# <script src="https://t1.daumcdn.net/cssjs/jquery/jquery-1.9.0.min.js"></script>
# <script src="https://search1.daumcdn.net/search/suggest_pc/suggest-1.2.16.min.js"></script>
# <script>"use strict";!(function(){document.getElementById('search_news'),new suggest.Suggest(document.getElementById("search_news"),{inputEl:'qVal',suggestBoxEl:'suggestBox',autoFocus:'NORMAL',suggestLimit:10,isReverse:!1,searchURL:'https://search.daum.net/search',APIServer:{host:'//dapi.kakao.com/suggest/v2/pc.json',apiType:suggest.Suggest.APITYPE.DAPISUGGEST,appkey:'d7022f6ca2a04430ce1b97b922da58e8',queries:{mod:'json',code:'utf_in_out'}}}).on('click-item',function(){var e=document.getElementById('kakaoSearch');e.querySelector("input[name='DA']").value='23B',e.submit()});var t=document.getElementById('qVal');t.addEventListener?(t.addEventListener('focus',function(e){e&&e.preventDefault(),0<=t.value.length&&t.parentNode.classList.add('search_on')}),t.addEventListener('blur',function(e){e&&e.preventDefault(),0===t.value.length&&t.parentNode.classList.remove('search_on')})):(t.attachEvent('onfocus',function(e){e&&(e.preventDefault?e.preventDefault():e.returnValue=!1),0<=t.value.length&&t.parentNode.setAttribute('class','box_searchbar search_on')}),t.attachEvent('onblur',function(e){e&&(e.preventDefault?e.preventDefault():e.returnValue=!1),0===t.value.length&&t.parentNode.setAttribute('class','box_searchbar')}))})(jQuery);</script>
# <script src="//t1.daumcdn.net/daumtop_deco/socialshare/socialshare_nocss_pc-2.4.2.js"></script>
# <script>"use strict";!(function(){var t=document.querySelector('.util_summary'),r=t.querySelector('.btn_summary'),e=t.querySelectorAll(".layer_summary p"),n=!1;function i(){t.classList.remove('layer_open'),r.setAttribute('aria-expanded',!1)}function a(e){if(e.target===r||e.target===r.children[0])return!1;i(),window.removeEventListener('click',a)}e.forEach(function(e){return e.classList.add("desc_news")}),r.addEventListener('click',function(e){(n=!n)?(t.classList.add('layer_open'),r.setAttribute('aria-expanded',!0),window.addEventListener('click',a)):i()}),r.addEventListener('blur',function(e){n=!1,i()})})();</script>
# <script>"use strict";function _slicedToArray(e,t){return _arrayWithHoles(e)||_iterableToArrayLimit(e,t)||_unsupportedIterableToArray(e,t)||_nonIterableRest()}function _nonIterableRest(){throw new TypeError("Invalid attempt to destructure non-iterable instance.\nIn order to be iterable, non-array objects must have a [Symbol.iterator]() method.")}function _unsupportedIterableToArray(e,t){if(e){if("string"==typeof e)return _arrayLikeToArray(e,t);var n=Object.prototype.toString.call(e).slice(8,-1);return"Object"===n&&e.constructor&&(n=e.constructor.name),"Map"===n||"Set"===n?Array.from(e):"Arguments"===n||/^(?:Ui|I)nt(?:8|16|32)(?:Clamped)?Array$/.test(n)?_arrayLikeToArray(e,t):void 0}}function _arrayLikeToArray(e,t){(null==t||t>e.length)&&(t=e.length);for(var n=0,r=new Array(t);n<t;n++)r[n]=e[n];return r}function _iterableToArrayLimit(e,t){if("undefined"!=typeof Symbol&&Symbol.iterator in Object(e)){var n=[],r=!0,o=!1,a=void 0;try{for(var i,s=e[Symbol.iterator]();!(r=(i=s.next()).done)&&(n.push(i.value),!t||n.length!==t);r=!0);}catch(e){o=!0,a=e}finally{try{r||null==s["return"]||s["return"]()}finally{if(o)throw a}}return n}}function _arrayWithHoles(e){if(Array.isArray(e))return e}!(function(){var t,e,n,r,o,a='VIEW_TTS',i='v.daum.net',s={slow_Male:'http://k-v1.kakaocdn.net/dn/cQkp7v/btrIfRMQEp9/pgVKvM7CIosoYEbpx3ru00/original.m4a',normal_Male:'http://k-v1.kakaocdn.net/dn/pqQnI/btrIhjbgqBG/pA96lp8fy1K1J3W90wVHwK/original.m4a',fast_Male:'http://k-v1.kakaocdn.net/dn/bTEF4s/btrH9HyGxP2/KB6qgNs3yyjagXfClbDh3K/original.m4a',slow_Female:'http://k-v1.kakaocdn.net/dn/np1R0/btrIhiwFumO/qrxT1rcU7Xt0YCFrEFEfJ0/original.m4a',normal_Female:'http://k-v1.kakaocdn.net/dn/qOmZv/btrIdyAxnB7/eo6ZM0IA0s3qVMZjQVPZnK/original.m4a',fast_Female:'http://k-v1.kakaocdn.net/dn/cDzFfs/btrH9H6umAe/73GrNm6TiqU0GwK1cPLyek/original.m4a'},l=document.querySelector('.util_view .tts_btn'),c=l.querySelectorAll('.list_tts input'),u=l.querySelector('.btn_tts'),d=l.querySelector('.ico_speak'),y=l.querySelector('.wrap_setlayer').querySelectorAll('.ico_newsview'),f=l.querySelector('#ttsPlayer');function m(){var e,t,n,r,o=(e=l.querySelector('input[name=ttsSpeed]:checked').value,t=l.querySelector('input[name=ttsGender]:checked').value,"".concat(e,"_").concat(t));f.setAttribute('src',s[o]),n=o,Cookies.set(a,'',{expires:-1}),Cookies.set(a,n,{domain:i,expires:new Date(1*new Date+365*864e5)}),r=o,u.className='btn_set btn_tts #util #tts #p_'+r}function p(e){'playOptions'==e?(m(),f.load(),f.play(),d.textContent='음성 기사 정지'):'play'==e?(f.load(),f.play(),d.textContent='음성 기사 정지'):(f[e](),d.textContent='음성 기사 듣기')}function v(){clearTimeout(n),t.classList.add('layer_open'),e.setAttribute('aria-expanded',!0)}function _(){r||(n=setTimeout(b,100))}function b(){t.classList.remove('layer_open'),e.setAttribute('aria-expanded',!1)}function L(e){e?t.classList.add('on'):t.classList.remove('on')}function h(e,t){document.getElementById("ttsSpeed".concat(e)).checked=!0,document.getElementById("ttsGender".concat(t)).checked=!0}t=(o={layer:l,btn:u,radios:c}).layer,e=o.btn,o=o.radios,r=!(n=0),t.addEventListener('mouseover',function(e){r=!0,v()}),t.addEventListener('mouseleave',function(e){r=!1,_()}),e.addEventListener('keydown',function(e){13===e.keyCode&&((r=!r)?v:b)()}),t.addEventListener('blur',function(e){r=!1,_()}),e.addEventListener('click',function(e){f.paused?(L(!0),p('play')):(L(!1),p('pause'))}),o.forEach(function(e){e.addEventListener('change',function(e){t.classList.add('on'),p('playOptions')}),e.addEventListener('blur',function(e){r=!1,_()}),e.addEventListener('focus',function(e){r=!0,v()})}),y=(o={icons:y,radios:c}).icons,c=o.radios,y.forEach(function(e){e.addEventListener('mouseover',function(e){this.classList.add('ico_focused')}),e.addEventListener('mouseleave',function(e){this.classList.remove('ico_focused')})}),c.forEach(function(e){e.addEventListener('focus',function(e){this.nextElementSibling.querySelector('span').classList.add('ico_focused')}),e.addEventListener('blur',function(e) ...
# <script>"use strict";!(function(){var n=document.createElement('DIV');n.innerHTML="\n <div id=\"translatingLayer\" class=\"translate_layer\">\n <div class=\"inner_translate_layer\">\n <div class=\"layer_body\">\n <strong class=\"tit_translate\">\n 번역중 <span class=\"eng_tit\">Now in translation</span>\n </strong>\n </div>\n </div>\n </div>\n\n <div id=\"translateErrorLayer\" class=\"translate_layer\">\n <div class=\"inner_translate_layer inner_error_layer\">\n <div class=\"layer_body\">\n <span class=\"ico_newsview ico_error\"></span>\n <strong class=\"tit_translate\">\n 잠시 후 다시 시도해 주세요 <span class=\"eng_tit\">Please try again in a moment</span>\n </strong>\n </div>\n </div>\n </div>\n ",document.body.querySelector("#kakaoWrap").appendChild(n)})();</script>
# <script>"use strict";function _toConsumableArray(e){return _arrayWithoutHoles(e)||_iterableToArray(e)||_unsupportedIterableToArray(e)||_nonIterableSpread()}function _nonIterableSpread(){throw new TypeError("Invalid attempt to spread non-iterable instance.\nIn order to be iterable, non-array objects must have a [Symbol.iterator]() method.")}function _unsupportedIterableToArray(e,t){if(e){if("string"==typeof e)return _arrayLikeToArray(e,t);var n=Object.prototype.toString.call(e).slice(8,-1);return"Object"===n&&e.constructor&&(n=e.constructor.name),"Map"===n||"Set"===n?Array.from(e):"Arguments"===n||/^(?:Ui|I)nt(?:8|16|32)(?:Clamped)?Array$/.test(n)?_arrayLikeToArray(e,t):void 0}}function _iterableToArray(e){if("undefined"!=typeof Symbol&&Symbol.iterator in Object(e))return Array.from(e)}function _arrayWithoutHoles(e){if(Array.isArray(e))return _arrayLikeToArray(e)}function _arrayLikeToArray(e,t){(null==t||t>e.length)&&(t=e.length);for(var n=0,r=new Array(t);n<t;n++)r[n]=e[n];return r}!(function(){var e,t,n,r,a=document.querySelector('.translate_btn'),o=a.querySelector('.btn_translate'),l=a.querySelector('.link_kakaoi'),s=a.querySelectorAll('.btn_lang'),i=document.getElementById('translatingLayer'),c=document.getElementById('translateErrorLayer'),y=document.getElementById('kakaoWrap');function u(){i.style.display='none',c.style.display='none',document.body.style.overflow=''}function d(){clearTimeout(e),t.classList.add('layer_open'),n.setAttribute('aria-expanded',!0)}function f(){t.classList.remove('layer_open'),n.setAttribute('aria-expanded',!1)}function p(){r||(e=setTimeout(f,1))}function m(e){var t=e.currentTarget.name;u(),i.style.display='block',document.body.style.overflow='hidden';try{HarmonyTranslator.translate('kr',t,_,b)}catch(e){console.error('번역 에러:',e)}}function _(e){var t=document.querySelector('#translateNotice'),e=e.targetLang;switch(e){case'en':case'id':y.classList.add('lang_type1'),y.classList.remove('lang_type2'),y.classList.remove('lang_type3');break;case'cn':case'jp':y.classList.remove('lang_type1'),y.classList.add('lang_type2'),y.classList.remove('lang_type3');break;case'vi':y.classList.remove('lang_type1'),y.classList.remove('lang_type2'),y.classList.add('lang_type3');break;default:y.classList.remove('lang_type1'),y.classList.remove('lang_type2'),y.classList.remove('lang_type3')}'kr'==e?(t.querySelectorAll('.notice_lang').forEach(function(e){e.style.display='none'}),t.style.display='none'):(t.querySelectorAll(".notice_lang:not(.notice_lang_".concat(e,")")).forEach(function(e){e.style.display='none'}),t.querySelector(".notice_lang.notice_lang_".concat(e)).style.display='block',t.style.display='block'),setTimeout(function(){u()},500)}function b(e,t){u(),c.style.display='block',document.body.style.overflow='hidden',setTimeout(function(){u()},2e3)}l={layer:a,btn:o,inputs:[l].concat(_toConsumableArray(s))},t=l.layer,n=l.btn,l=l.inputs,r=!1,n.addEventListener('click',function(){((r=!r)?d:p)()}),t.addEventListener('mouseover',function(){r=!0,d()}),t.addEventListener('mouseleave',function(){r=!1,f()}),l.forEach(function(e){e.addEventListener('focus',function(e){r=!0,d()}),e.addEventListener('blur',function(e){r=!1,p()})}),s.forEach(function(e){e.addEventListener('click',m)})})();</script>
# <script>"use strict";!(function(){var e,t=(o='2주 넘게 &#x27;두문불출&#x27; 김 여사..목요일 등장할까?',(c=document.createElement('div')).innerHTML=o,c.textContent),a='20220726105712920'||'UOf9JnyP9M',n="".concat(location.protocol,"//").concat(location.host,"/v/").concat(a),o="http://scrap.cafe.daum.net/_dss_/scrap?folder_id=100000&source_location_code=10&target_location_code=1&data_id=".concat(a),c={shareType:'sendScrap',shareData:{requestUrl:n,templateId:7952,installTalk:!0,templateArgs:{'${EncodingUrl}':encodeURIComponent(n),'${webUrl}':n+'?f=p','${mobileWebUrl}':n+'?f=m'}}},r=document.querySelector('.share_btn'),i=document.getElementById('rSocialShareButton'),a=document.getElementById('rSocialShareLayerContainer'),d=new socialshareRenewal.Main(i,{moreViewContainer:a,action:'hover',link:n,prefix:t,service_name:'다음뉴스',cafe:o,kakaoAPI:{appkey:'53e566aa17534bc816eb1b5d8f7415ee',kakaoLinkData:c}}),s=!1;function l(){e=setTimeout(function(){s=!1,r.classList.remove('layer_open'),i.setAttribute('aria-expanded',!1),d.close()},100)}function u(){s=!0,m(),r.classList.add('layer_open'),i.setAttribute('aria-expanded',!0),d.open()}function m(){clearTimeout(e)}i.addEventListener('mouseenter',u),i.addEventListener('mouseleave',l),i.addEventListener('click',function(e){(s?l:u)()}),a.addEventListener('mouseenter',m),a.addEventListener('mouseleave',l),a.querySelectorAll('a').forEach(function(e){e.addEventListener('focus',m),e.addEventListener('blur',l)})})();</script>
# <script>"use strict";!(function(){var e,t,n,o,i=document.querySelector('.news_view'),s=document.querySelector('.font_btn'),c=s.querySelector('.btn_font'),r=s.querySelector('.list_font'),u=r.querySelectorAll('input'),a='GS_font_size',l='v.daum.net';function d(e){i.style.fontSize="".concat(e,"px"),document.querySelector("#inpFont".concat(e)).checked=!0,r.querySelectorAll('label').forEach(function(e){return e.classList.remove('on')}),r.querySelector("label[for=inpFont".concat(e,"]")).classList.add('on'),e=e,Cookies.set(a,'',{expires:-1}),Cookies.set(a,e,{domain:l,expires:new Date(1*new Date+365*864e5)})}function f(){clearTimeout(e),t.classList.add('layer_open'),n.setAttribute('aria-expanded',!0)}function v(){t.classList.remove('layer_open'),n.setAttribute('aria-expanded',!1)}function p(){o&&(e=setTimeout(v,1))}d(Cookies.get(a)||17),u.forEach(function(e){e.addEventListener('change',function(e){d(e.target.value)})}),t=(c={layer:s,btn:c,inputs:u}).layer,n=c.btn,c=c.inputs,o=!1,t.addEventListener('mouseover',function(){o=!0,f()}),t.addEventListener('mouseleave',function(){o=!1,v()}),c.forEach(function(e){e.addEventListener('focus',f),e.addEventListener('blur',p)}),n.addEventListener('click',function(e){((o=!o)?f:v)()}),s={options:s.querySelectorAll('.ico_newsview'),inputs:u},u=s.options,s=s.inputs,u.forEach(function(e){e.addEventListener('mouseover',function(){this.classList.add('ico_focused')}),e.addEventListener('mouseleave',function(){this.classList.remove('ico_focused')})}),s.forEach(function(e){e.addEventListener('focus',function(){this.nextElementSibling.querySelector('span').classList.add('ico_focused')}),e.addEventListener('blur',function(){this.nextElementSibling.querySelector('span').classList.remove('ico_focused')})})})();</script>
# <script>"use strict";document.body.querySelector(".btn_print").parentNode.addEventListener("click",function(t){t.preventDefault(),window.open('https://news.v.daum.net/v/20220726105712920?s=print_news','newsPrint','width=750,height=550,scrollbars=yes')});</script>
# <script type="text/javascript">
#
#     var alex = document.querySelector('#alex_action_emotion');
#     alex.setAttribute('data-selections','[{"type":"RECOMMEND","animation":"SLIDE","image":"https://t1.daumcdn.net/harmony_static/alex_emotion/SLIDE_RECOMMEND_1x.png","highResImage":"https://t1.daumcdn.net/harmony_static/alex_emotion/SLIDE_RECOMMEND_2x.png"},{"type":"LIKE","animation":"SLIDE","image":"https://t1.daumcdn.net/harmony_static/alex_emotion/SLIDE_LIKE_1x.png","highResImage":"https://t1.daumcdn.net/harmony_static/alex_emotion/SLIDE_LIKE_2x.png"},{"type":"IMPRESS","animation":"SLIDE","image":"https://t1.daumcdn.net/harmony_static/alex_emotion/SLIDE_IMPRESS_1x.png","highResImage":"https://t1.daumcdn.net/harmony_static/alex_emotion/SLIDE_IMPRESS_2x.png"},{"type":"ANGRY","animation":"SLIDE","image":"https://t1.daumcdn.net/harmony_static/alex_emotion/SLIDE_ANGRY_1x.png","highResImage":"https://t1.daumcdn.net/harmony_static/alex_emotion/SLIDE_ANGRY_2x.png"},{"type":"SAD","animation":"SLIDE","image":"https://t1.daumcdn.net/harmony_static/alex_emotion/SLIDE_SAD_1x.png","highResImage":"https://t1.daumcdn.net/harmony_static/alex_emotion/SLIDE_SAD_2x.png"}]');
#
#     var itemKey = alex.getAttribute('data-item-key');
#     if (isNumber(itemKey))
#         alex.setAttribute('data-item-key', '@' + itemKey);
#
#     function isNumber(x) {
#         return !isNaN(Number(x));
#     }
# </script>
# <script src="//action.kakao.com/latest/alex.actions.js" type="text/javascript"></script>
# <script>"use strict";!(function(){var s="20220726105712920",e="".concat(Conf.api.hadesRest,"/pc_mc2_news?cate=").concat("news","&id=").concat(s),a='<li class="on"> <div class="inner_box"><span class="link_txt"><%= title %></span></div> </li>',i='<li> <div class="inner_box"><a href="https://news.v.daum.net/v/<%= contentId %>" class="link_txt"><%= title %></a></div> </li>',c='//news.daum.net/series',r=document.querySelector('.relate_series'),o=r.querySelector('.title_series'),d=r.querySelector('.link_more'),l=r.querySelector('.list_series');function m(e){e&&e.parentNode.removeChild(e)}axios.get(e).then(function(e){var t,n=e.data.body.data.data;_.isEmpty(n)||'series'!==n[0].factor.type?m(r):(t=n[0],e=t.contents,n=t._id,t=t.title,e.length<3&&l.classList.add('relate_series2'),o.textContent=t,d.setAttribute('href',c+'/'+n),l.innerHTML=e.map(function(e){var t=e.contentId,e=e.title;return t==s?_.template(a)({title:e}):_.template(i)({contentId:t,title:e})}).join(''),(e=r)&&e.classList.remove('hide'))}).catch(function(e){console.error("[클러스터]: 데이터를 가져오는데 실패했습니다. 에러: ",e,"에러 데이터: ",e.response.data),m(r)})})();</script>
# <script>"use strict";function daRenderFailCallBack(e){e.parentElement.removeChild(e)}</script>
# <script>"use strict";document.addEventListener('DOMContentLoaded',function(){var t="".concat(Conf.api.hadesRest)+"/service_notice?id="+"3393",n=document.querySelector("#newsviewNotice");axios.get(t).then(function(t){var e=t.data.body.data,t=e.noticeTitle,e=e.noticeUrl;null!==t?n.innerHTML="<strong class=\"tit_notice\">공지</strong><span class=\"txt_notice\"><a href=\"".concat(e,"\" class=\"link_txt\">").concat(t,"</a></span>"):n.parentNode.removeChild(n)}).catch(function(t){console.log("댓글 공지 오류: "+t),n.parentNode.removeChild(n)})});</script>
# <script src="//comment.daum.net/js/latest/alex.single.min.js"></script>
# <script>"use strict";window.excludeCorejs=!1,window.alexConfig={label:{emptyImage:'//i1.daumcdn.net/img-section/enter2013/liveviewer/pc_emot_co.gif'},onLoad:function(){window.isLoadComment=!0}};</script>
# <script>"use strict";!(function(){var t="<li>\n <a class=\"link_cont\" href=\"<%= url %>\">\n <span class=\"wrap_thumb\">\n <img class=\"thumb_g\" src=\"<%= thumbnail %>\" alt=\"\"/>\n <span class=\"ico_phototv\">\n <% if (type == 'photo') { %>\n <span class=\"ico_newsview ico_photo\">포토</span>\n <% } else { %>\n <span class=\"ico_newsview ico_vod\">영상</span>\n <% } %>\n </span>\n </span>\n <strong class=\"tit_thumb\"><%= title %></strong>\n </a>\n </li>",o=document.querySelector('.aside_phototv'),s=o.querySelector('.list_phototv'),n="".concat(Conf.api.hadesRest,"/pc_photo_tv");function a(n){n&&n.parentNode.removeChild(n)}axios.get(n).then(function(n){n=n.data.body.data;_.isEmpty(n)?a(o):(s.innerHTML=n.map(function(n){return _.template(t)(n)}).join(''),(n=o)&&n.classList.remove('hide'))}).catch(function(n){console.error('[PC 뉴스 포토&TV]:',n),a(o)})})();</script>
# <script>"use strict";!(function(){var n='S570x320',e="20220726105712920",t=encodeURIComponent(JSON.stringify({itemid:e,category:"news".replace('tain','')})),e={source:e},r="<a href=\"<%=obj.url%>\" class=\"link_cont\" data-itemid=\"<%=obj._id%>\"\" data-pos=\"<%=obj.pos%>\">\n <span class=\"wrap_thumb\"><img src=\"<%=obj.thumbnail%>\" class=\"thumb_g\" alt=\"\"></span>\n <strong class=\"tit_thumb\"><%=obj.title%></strong>\n </a>",o="<strong class=\"tit_g\">\n <span class=\"info_news\"><%=obj.cp_name%></span>\n <a href=\"<%=obj.url%>\" data-itemid=\"<%=obj._id%>\" data-pos=\"<%=obj.pos%>\" class=\"link_txt\"><%=obj.title%></a>\n </strong>",m=[];new Toros.Connector({url:'mediadaum/most_similar',queryParams:t,map:function(e){var t=e._id,a=e.title,i=e.image,e=e.cp_name,e={_id:t,url:"https://v.daum.net/v/".concat(t),title:a,thumbnail:StringUtil.makeThumbnail(i,n),cp_name:e};if(!(m.length<2&&i))return e;m.push(e)},svc:'mediadaum_sim',impLabel:'toros_mediadaum_sim_imp',impProps:e,viewLabel:'toros_mediadaum_sim_vimp',viewProps:e,clickLabel:'toros_mediadaum_sim_click',clickProps:e,customRender:function(e,i,n){var s=e.filter(function(e){return!!e._id});m.length<2||s.length<10?document.querySelector('.realtime_news').remove():document.querySelectorAll('.item_realtime_news').forEach(function(e,t){var a=t<2?{article:m.shift(),template:r}:{article:s.shift(),template:o},t=a.article,a=a.template;t?(e.insertAdjacentHTML('beforeend',_.template(a)(t)),e.classList.remove('item_realtime_news'),e.classList.length||e.removeAttribute('class'),t=e.querySelector('a'),i.observe(t),t.addEventListener('click',n)):e.remove()})}}).render()})();</script>
# <script>"use strict";function onFailEtcBottomAd(){var t;null!==(t=document.querySelector('.etc_bottom_ad'))&&void 0!==t&&t.remove()}</script>
# <script>"use strict";!(function(){var e=document.querySelector(".direct_link");e.querySelector(".btn_fold").addEventListener('click',function(){e.classList.toggle("direct_open")})})();</script>
# <script>
#     window.minidaum_options = JSON.parse('{"bgType":"white","enableLogoutRetun":true,"returnUrl":"","disableHotissue":false,"disableLogo":false,"disableTracker":true,"enableTopLink":false}');
# </script>
# <script src="https://go.daum.net/minidaum_pc.daum"></script>
# <script>"use strict";document.querySelectorAll('.kakao_ad_area').forEach(function(a){a.setAttribute('data-ad-param-channel','harmony'),a.setAttribute('data-ad-param-cp','98_pc_media_news')});</script>
# <script>"use strict";!(function(){var e,t,i,c='<div class="direct_view" style="top:<%= top %>px; width:<%= width %>px; margin-left:<%= left %>px"> <a href="<%= url %>" class="link_view"> <span class="txt_g"><%= title %></span> <span class="ico_view"> <span class="ico_newsview ico_gallery">갤러리 이동</span> </span> </a> </div>';e='UOf9JnyP9M',!(t='')||(i=document.querySelector('img[dmcf-mtype="image"]'))&&!i.querySelector('.direct_vod')&&axios.get("".concat(Conf.api.hadesRest,"/photo_gallery_link_info?docId=").concat(e,"&galleryId=").concat(parseInt(t,10))).then(function(e){var t,a=e.data.body.data;t=i,a=(e=a).title,e=e.pcLink,a&&e&&(e={title:a,url:e,top:t.clientHeight-62,width:a=t.clientWidth,left:a/2*-1},a=document.createElement('div'),t.parentNode.appendChild(a),a.outerHTML=_.template(c)(e))})})();</script>
# <script src="//search1.daumcdn.net/search/statics/common/js/g/search_dragselection.min.js"></script>
# <script>"use strict";!(function(){var e=document.querySelector(".head_media"),n=document.getElementById("wrapMinidaum").offsetHeight+e.offsetHeight,o=document.getElementById("barProgress"),d=document.getElementById("mAside"),s=document.getElementById("kakaoWrap"),l=document.getElementById("kakaoGnb"),r=document.getElementById("mArticle"),a=document.querySelector(".cmt_news"),c=document.querySelector(".aside_ad:first-child"),f=document.querySelector(".aside_ad:last-child"),g=document.getElementById('realtime_aside');function t(){var e=window.scrollY||window.pageYOffset,t=document.body.offsetHeight,i=window.innerHeight;n<e?(i=100*e/(t-i),s.classList.add("header_fixed"),o.style.width=parseInt(i,10)+"%"):s.classList.remove("header_fixed")}function i(){var e=window.scrollX||window.pageXOffset,t=cMain.clientWidth,i=r.clientWidth,n=t-i-d.clientWidth,o=getComputedStyle(cMain),s=null;s=g?(t=g.getBoundingClientRect().left)<880?t+e:t:i+n+parseInt(o['marginLeft'],10)-e,r.offsetHeight<d.offsetHeight||(a.style.minHeight='250px',0<(n=(window.scrollY||window.pageYOffset)-cMain.offsetTop-8-c.clientHeight)?(o=r.offsetHeight-a.offsetHeight,(e=d.offsetHeight-f.offsetHeight)+n+8<o?(d.style.position='fixed',d.style.top=l.clientHeight-c.offsetHeight-74+'px',d.style.left=s+'px'):(d.style.position='relative',d.style.top=o-e+'px',d.style.left='inherit')):(d.style.position='static',d.style.top='inherit',d.style.left='inherit'))}'false'!='true'&&'news'=='news'?(window.addEventListener("resize",_.throttle(i,100)),window.addEventListener("scroll",_.throttle(function(){t(),i()},100)),t(),i()):(window.addEventListener("scroll",_.throttle(function(){t()},100)),t())})();</script>
# <script src="//t1.daumcdn.net/tiara/js/v1/tiara.min.js" type="text/javascript"></script>
# <script>"use strict";!(function(){if(window.TiaraTracker){var c=!1,s=new Date,l="pc_news",m=null;try{m=Cookies.get('DAUMTOP')||Cookies.get('HARMONY_TOROS_IMP')&&window.atob(Cookies.get('HARMONY_TOROS_IMP'))}catch(e){m=Cookies.get('DAUMTOP')}var u='',g='',y=TiaraTracker.getInstance().setSvcDomain("media.daum.net").setPage("newsview").trackPage("newsview").setSection("politics").setEnableAlwaysImage(!0),p={id:"20220726105712920",type:"article",name:"2\uC8FC \uB118\uAC8C \'\uB450\uBB38\uBD88\uCD9C\' \uAE40 \uC5EC\uC0AC..\uBAA9\uC694\uC77C \uB4F1\uC7A5\uD560\uAE4C?",category_id:"1020",category:"politics",author:"\uC815\uC2B9\uD61C luxmundi@mbc.co.kr",author_id:"",provider:"MBC",provider_id:"98",regdate:"2022-07-26 10:57:12",plink:"https://media.daum.net/v/20220726105712920",image:"https://t1.daumcdn.net/news/202207/26/imbc/20220726111013886nswx.jpg",harmony_consumer_id:"media",media:"pcweb"},f={contentUniqueKey:"hamny-".concat(p.id),docId:"UOf9JnyP9M",harmony_consumer_id:"media",media:"pcweb",reg_dt:"2022-07-26 10:57:12",reg_timestamp:"1658800632928"},e=function(){c||y.actionKind("ViewContent").pageMeta(p).customProps(f).track()},t=function(){if(!c){c=!0;var e=document.body.scrollHeight,t=window.scrollY,a=e-t,o=window.innerHeight,n=Math.round(t/(e-o)*100),i={},o={duration:(new Date).getTime()-s.getTime(),scroll_percent:n,scroll_height:e,scroll_top:t,scroll_bottom:a,scroll_inner_height:o};try{var d,r=!1;!m||(d=JSON.parse(m)).contents_unique_key===f.contentUniqueKey&&(i={toros_imp_id:d.impression_id,toros_file_hash_key:d.toros_file_hash_key,toros_user_id_type:"uuid",toros_page_meta_id:f.contentUniqueKey,toros_event_meta_id:f.contentUniqueKey,toros_action_type:"dwelltime"},Cookies.remove('HARMONY_TOROS_IMP',{path:'/',domain:location.hostname.substring(location.hostname.indexOf('.'))}),Cookies.remove('DAUMTOP',{path:'/',domain:'.daum.net'}),r=!0),!r&&0<u.length&&(i={toros_imp_id:window.atob(u),toros_file_hash_key:window.atob(g),toros_user_id_type:"uuid",toros_page_meta_id:f.contentUniqueKey,toros_event_meta_id:f.contentUniqueKey,toros_action_type:"dwelltime"})}catch(e){}y.trackUsage().actionKind("UsagePage").pageMeta(p).usage(o).customProps(_.assignIn(f,i)).track()}};"onpagehide"in window?(window.addEventListener("pageshow",e,!1),window.addEventListener("pagehide",t,!1)):(window.addEventListener("load",e,!1),window.addEventListener("unload",t,!1)),document.addEventListener("visibilitychange",function(){(document["hidden"]?t:e)()},!1),document.addEventListener("mousedown",function(e){var t,a,o,n,i,d,r,c=e.target,s=c.closest("[data-cloud]"),m=c.closest("a")||c.closest("button");m&&null!=s&&s.contains(m)&&((i=TiaraTracker.getClickInfo(e))&&(a=(null==(t=i.action)?void 0:t.name)||"",o=(null==t?void 0:t.kind)||"",n=_.assignIn(f,i.customProps),i=c.closest("[data-tiara]"),c=m.querySelector("img"),d=0,Array.from((s||i).querySelectorAll("a, button")).map(function(e,t){e==m&&(d=t)}),e={layer1:l,layer2:s.dataset.cloud,layer3:(null==i?void 0:i.dataset.tiara)||"",click_url:m.href||"",ordnum:d,copy:(r=m.getAttribute('data-action-type'),['RECOMMEND','LIKE','IMPRESS','ANGRY','SAD'].includes(r)?null==t?void 0:t.name:m.innerText),image:(null==c?void 0:c.src)||"",posX:e.clientX,posY:e.clientY},y.trackEvent(a).pageMeta(p).actionKind(o).customProps(n).click(e).track()))})}})();</script>
# </body>
# </html>

# %%
title = bs2.find('h3',class_='tit_view').text
body = '\n'.join([line.text for line in bs2.find('section').find_all('p')[1:]])
print(title + '\n' + body)
# Out:
# 2주 넘게 '두문불출' 김 여사..목요일 등장할까?
# ■ "마드리드 이후 김건희 여사가 안 보인다"
# 윤석열 대통령의 지지율 추이와 더불어 최근 언론이 자주 언급하는 기사는 "김건희 여사가 공개 행보를 중단했다"는 내용입니다.
# 북대서양조약기구, NATO 순방 동행을 마치고 난 뒤 두문불출하고 있다는 겁니다.
#
#  정치평론가들은 김 여사가 공개 행보에 나설 때마다 관심을 끌기는 했지만 팬클럽, 수행원, 제2부속실 설치, 명품 목걸이 논란 등으로 부정적인 여론이 대두되자 ‘리스크 관리’에 들어간 것으로 보고 있습니다.
# 장성철 공론센터 소장은 “김건희 여사가 최근 2주간 사라졌다”면서 “김 여사가 지지율에 중대한 영향을 끼친다는 정무적인 판단이 있었을 것”이라고 말했습니다. 배종찬 인사이트케이 소장 역시 윤 대통령의 지지율 하락 원인 중 하나로 김건희 여사를 꼽았습니다. 배 소장은 경제, 인사, 양극화, 김 여사, 도어스테핑의 앞글자를 딴 ‘경인양김도’가 지지율이 떨어진 이유라고 분석했습니다. 유튜브 채널 ‘시사저널 TV’에 출연한 진중권 전 교수는 “지금 김건희 여사는 잘하고 있는 것 아니냐?”는 사회자의 질문에 “그렇다. 조금 더 기다려야 될 것 같다”고 조언하기도 했습니다.
# ■ 공개행보 재개는? 목요일 진수식이 유력
# 그렇다면 김건희 여사는 언제쯤 다시 언론에 모습을 드러낼까요? 목요일인 28일이 될 가능성이 높습니다. 차세대 이지스함인 정조대왕 진수식이 열리는데, 여기에 참석하지 않을까 예상됩니다.
# 배에 이름을 붙이고 처음 물에 띄워 바다로 내보내는 의식인 진수식(進水式)에서는 진수도끼(보통 금토끼)로 밧줄을 끊거나 샴페인을 깨는 행사가 있습니다. 진수식의 하이라이트인데요, 관례적으로 여성이 해왔다고 합니다. 왜 여성이 하게 됐는지를 놓고 영국 빅토리아 여왕이 세레모니를 한 이후 관례로 굳어졌다는 설도 있고, 배(ship)를 여성 대명사인 she로 받는데서 유래했다 혹은 탯줄을 자르는 상징적인 의미가 있기 때문에 여성이 하게 됐다는 여러 가지 설들이 있습니다.
# 김건희 여사가 진수식에 등장할지는 목요일 확인할 수 있을 것 같습니다.
# 정승혜 기자 (luxmundi@mbc.co.kr)
# 기사 원문 - https://imnews.imbc.com/news/2022/politics/article/6392168_35666.html

# %% [markdown]
# ## headers
# ##### (크롤링 시) 접속 차단되었을 때, header의 User-Agent  지정
#
# https://m.blog.naver.com/PostView.naver?isHttpsRedirect=true&blogId=kiddwannabe&logNo=221185808375

# %%
#접속이 안되는 경우 예시

url = 'https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=102'

req = requests.get(url)
bs = BeautifulSoup(req.content, 'html.parser')
print(bs)
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File ~\anaconda3\envs\cakd7\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443 try:
# --> 444     httplib_response = conn.getresponse()
#     445 except BaseException as e:
#     446     # Remove the TypeError from the exception chain in
#     447     # Python 3 (including for exceptions like SystemExit).
#     448     # Otherwise it looks like a bug in the code.
#
# File ~\anaconda3\envs\cakd7\lib\http\client.py:1348, in HTTPConnection.getresponse(self)
#    1347 try:
# -> 1348     response.begin()
#    1349 except ConnectionError:
#
# File ~\anaconda3\envs\cakd7\lib\http\client.py:316, in HTTPResponse.begin(self)
#     315 while True:
# --> 316     version, status, reason = self._read_status()
#     317     if status != CONTINUE:
#
# File ~\anaconda3\envs\cakd7\lib\http\client.py:277, in HTTPResponse._read_status(self)
#     276 def _read_status(self):
# --> 277     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278     if len(line) > _MAXLINE:
#
# File ~\anaconda3\envs\cakd7\lib\socket.py:669, in SocketIO.readinto(self, b)
#     668 try:
# --> 669     return self._sock.recv_into(b)
#     670 except timeout:
#
# File ~\anaconda3\envs\cakd7\lib\ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#
# File ~\anaconda3\envs\cakd7\lib\ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1098 if buffer is not None:
# -> 1099     return self._sslobj.read(len, buffer)
#    1100 else:
#
# ConnectionResetError: [WinError 10054] 현재 연결은 원격 호스트에 의해 강제로 끊겼습니다
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File ~\anaconda3\envs\cakd7\lib\site-packages\requests\adapters.py:440, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     439 if not chunked:
# --> 440     resp = conn.urlopen(
#     441         method=request.method,
#     442         url=url,
#     443         body=request.body,
#     444         headers=request.headers,
#     445         redirect=False,
#     446         assert_same_host=False,
#     447         preload_content=False,
#     448         decode_content=False,
#     449         retries=self.max_retries,
#     450         timeout=timeout
#     451     )
#     453 # Send the request.
#     454 else:
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\urllib3\connectionpool.py:785, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     783     e = ProtocolError("Connection aborted.", e)
# --> 785 retries = retries.increment(
#     786     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     787 )
#     788 retries.sleep()
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\urllib3\util\retry.py:550, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     549 if read is False or not self._is_method_retryable(method):
# --> 550     raise six.reraise(type(error), error, _stacktrace)
#     551 elif read is not None:
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\urllib3\packages\six.py:769, in reraise(tp, value, tb)
#     768 if value.__traceback__ is not tb:
# --> 769     raise value.with_traceback(tb)
#     770 raise value
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443 try:
# --> 444     httplib_response = conn.getresponse()
#     445 except BaseException as e:
#     446     # Remove the TypeError from the exception chain in
#     447     # Python 3 (including for exceptions like SystemExit).
#     448     # Otherwise it looks like a bug in the code.
#
# File ~\anaconda3\envs\cakd7\lib\http\client.py:1348, in HTTPConnection.getresponse(self)
#    1347 try:
# -> 1348     response.begin()
#    1349 except ConnectionError:
#
# File ~\anaconda3\envs\cakd7\lib\http\client.py:316, in HTTPResponse.begin(self)
#     315 while True:
# --> 316     version, status, reason = self._read_status()
#     317     if status != CONTINUE:
#
# File ~\anaconda3\envs\cakd7\lib\http\client.py:277, in HTTPResponse._read_status(self)
#     276 def _read_status(self):
# --> 277     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278     if len(line) > _MAXLINE:
#
# File ~\anaconda3\envs\cakd7\lib\socket.py:669, in SocketIO.readinto(self, b)
#     668 try:
# --> 669     return self._sock.recv_into(b)
#     670 except timeout:
#
# File ~\anaconda3\envs\cakd7\lib\ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#
# File ~\anaconda3\envs\cakd7\lib\ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1098 if buffer is not None:
# -> 1099     return self._sslobj.read(len, buffer)
#    1100 else:
#
# ProtocolError: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Input In [285], in <cell line: 3>()
#       1 url = 'https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=102'
# ----> 3 req = requests.get(url)
#       4 bs = BeautifulSoup(req.content, 'html.parser')
#       5 print(bs)
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\requests\api.py:75, in get(url, params, **kwargs)
#      64 def get(url, params=None, **kwargs):
#      65     r"""Sends a GET request.
#      66
#      67     :param url: URL for the new :class:`Request` object.
#    (...)
#      72     :rtype: requests.Response
#      73     """
# ---> 75     return request('get', url, params=params, **kwargs)
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\requests\api.py:61, in request(method, url, **kwargs)
#      57 # By using the 'with' statement we are sure the session is closed, thus we
#      58 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      59 # cases, and look like a memory leak in others.
#      60 with sessions.Session() as session:
# ---> 61     return session.request(method=method, url=url, **kwargs)
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\requests\sessions.py:529, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     524 send_kwargs = {
#     525     'timeout': timeout,
#     526     'allow_redirects': allow_redirects,
#     527 }
#     528 send_kwargs.update(settings)
# --> 529 resp = self.send(prep, **send_kwargs)
#     531 return resp
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\requests\sessions.py:645, in Session.send(self, request, **kwargs)
#     642 start = preferred_clock()
#     644 # Send the request
# --> 645 r = adapter.send(request, **kwargs)
#     647 # Total elapsed time of the request (approximately)
#     648 elapsed = preferred_clock() - start
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\requests\adapters.py:501, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     498             raise
#     500 except (ProtocolError, socket.error) as err:
# --> 501     raise ConnectionError(err, request=request)
#     503 except MaxRetryError as e:
#     504     if isinstance(e.reason, ConnectTimeoutError):
#     505         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))

# %%
#유저 정보 추가

url = 'https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=102'
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}


req = requests.get(url, headers=headers)   #봇이 아님을 인증하는 헤더 정보 추가
bs = BeautifulSoup(req.content, 'html.parser')
print(bs)
# Out:
# <!DOCTYPE HTML>
#
# <html lang="ko">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta contents="always" name="referrer"/>
# <meta content="600" http-equiv="refresh">
# <meta content="width=1106" name="viewport">
# <meta content="사회 : 네이버 뉴스" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102" property="og:url"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_200x200_20160804.png" property="og:image">
# <meta content="교육, 언론, 의료, 인물, 사건사고 등 사회 분야 뉴스 제공" property="og:description"/>
# <meta content="네이버" property="og:article:author">
# <meta content="summary" name="twitter:card"/>
# <meta content="사회 : 네이버 뉴스" name="twitter:title"/>
# <meta content="네이버 뉴스" name="twitter:site"/>
# <meta content="네이버 뉴스" name="twitter:creator"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_200x200_20160804.png" name="twitter:image"/>
# <meta content="교육, 언론, 의료, 인물, 사건사고 등 사회 분야 뉴스 제공" name="twitter:description"/>
# <title>사회 홈 : 네이버 뉴스	</title>
# <link href="https://ssl.pstatic.net/static.news/image/news/2014/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="https://ssl.pstatic.net/static.news/pnews/resources/20220616_145844/css/common.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.news/pnews/resources/20220616_145844/css/news.css" rel="stylesheet" type="text/css"/>
# <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20220616_145844/js/news.jindo.js" type="text/javascript"></script>
# <script charset="utf-8" src="https://ssl.pstatic.net/static.news/pnews/resources/20220616_145844/js/news.jquery.js" type="text/javascript"></script>
# <script type="text/javascript">
# var _MAIN_NEWS_MENU_ID='shm';
# var _MAIN_NEWS_SECTION_ID='103';
# var ccsrv='cc.naver.com';
# var g_ssc='news.sec';
# window.nsc = g_ssc;
# var gnb_service='news';
# var gnb_logout=encodeURIComponent(location.href);
# var gnb_template='gnb_utf8';
# var gnb_brightness = 3;
# var gnb_searchbox='on';
# var gnb_shortnick='on';
#
# var gnb_timestamp = "Tue Jul 26 11:34:13 KST 2022";
# </script>
# <script charset="euc-kr" src="https://ssl.pstatic.net/static.news/pnews/resources/20220616_145844/js/news.service.js" type="text/javascript"></script>
# <script>
#
#     var isUnderIE10 = navigator.appName === "Microsoft Internet Explorer";
#     if (!isUnderIE10) {
#         var gladSDK = document.createElement("script");
#         gladSDK.async = true;
#         gladSDK.src = "https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js";
#         document.head.appendChild(gladSDK);
#     }
#
#
#     window.gladsdk = window.gladsdk || { cmd: [] };
#
#     window.gladsdk.cmd.push(function () {
#         window.gladsdk.setGlobalConfig({enablePersistAd: true});
#         window.gladsdk.setHostMeta('theme', 'system');
#
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newsend',
#             adSlotElementId: 'glad_ad_newsend'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_newslist',
#             adSlotElementId: 'glad_ad_newslist'
#         });
#         window.gladsdk.defineAdSlot({
#             adUnitId: 'p_news_sidebox',
#             adSlotElementId: 'glad_ad_sidebox'
#         });
#     })
# </script>
# </meta></meta></meta></meta></head>
# <body>
# <div id="wrap">
# <!-- 광고적용 태그 추가 -->
# <div id="da_base"></div>
# <div id="da_stake"></div>
# <div class="header" id="header">
# <div id="u_skip">
# <a href="#lnb" tabindex="1"><span>메인 메뉴로 바로가기</span></a>
# <a href="#main_content" tabindex="2"><span>본문으로 바로가기</span></a>
# </div>
# <div class="snb_area">
# <div class="snb_inner">
# <div class="gnb_area">
# <div class="gnb_wrap">
# <div class="gnb_dark_type2" id="gnb"></div>
# </div>
# <div class="gnb_search is_hidden _search_content">
# </div>
# <div class="gnb_tool" id="gnb_search_tool">
# <a class="tool_button _search_content_toggle_btn nclicks(gnb.sch)" href="javascript:;"><span class="icon_search">검색</span></a>
# </div>
# </div>
# <div id="snb_wrap">
# <h1>
# <a class="h_logo nclicks(gnb.naver)" href="https://www.naver.com/"><span class="blind">NAVER</span></a>
# <a class="h_news nclicks(gnb.news)" href="/"><span class="blind">뉴스</span></a>
# </h1>
# <ul class="snb_related_service">
# <li><span class="snb_bdr"></span><a class="entertain nclicks(gnb.enter)" href="https://entertain.naver.com/home">TV연예</a></li>
# <li><span class="snb_bdr"></span><a class="sports nclicks(gnb.sports)" href="https://sports.news.naver.com">스포츠</a></li>
# <li><span class="snb_bdr"></span><a class="weather nclicks(gnb.weather)" href="https://weather.naver.com">날씨</a></li>
# <li><span class="snb_bdr"></span><a class="premium nclicks(gnb.premium)" href="https://contents.premium.naver.com">프리미엄</a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="lnb_area">
# <div class="lnb_inner">
# <div class="lnb_both">
# <div class="lnb_left">
# <div class="lnb_menu" id="lnb">
# <ul>
# <li><a class="nclicks(lnb.pcmedia)" href="/"><span class="tx">언론사별</span> </a></li>
# <li><a class="nclicks(lnb.pol)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100"><span class="tx">정치</span> </a></li>
# <li><a class="nclicks(lnb.eco)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101"><span class="tx">경제</span> </a></li>
# <li class="on"><a class="nclicks(lnb.soc)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102"><span class="tx">사회</span> <span class="blind">선택됨</span></a></li>
# <li><a class="nclicks(lnb.lif)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=103"><span class="tx">생활/문화</span> </a></li>
# <li><a class="nclicks(lnb.sci)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=105"><span class="tx">IT/과학</span> </a></li>
# <li><a class="nclicks(lnb.wor)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=104"><span class="tx">세계</span> </a></li>
# <li><a class="nclicks(lnb.rankin)" href="/main/ranking/popularDay.naver?mid=etc&amp;sid1=111"><span class="tx">랭킹</span> </a></li>
# <li><a class="nclicks(lnb.paper)" href="/newspaper/home"><span class="tx">신문보기</span> </a></li>
# <li><a class="nclicks(lnb.opi)" href="/main/opinion/home.naver"><span class="tx">오피니언</span> </a></li>
# <li><a class="nclicks(lnb.tv)" href="/main/tv/index.naver?mid=tvh"><span class="tx">TV</span> </a></li>
# <li><a class="nclicks(lnb.fact)" href="/main/factcheck/main.naver"><span class="tx">팩트체크</span> </a></li>
# </ul>
# </div>
# </div>
# <div class="lnb_right">
# <div class="lnb_extra">
# <div class="lnb_extra_menu">
# <ul class="lnb_extra_menu_list">
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right3)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(STA.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link nclicks(nct.right4)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="lnb">
# <span class="lnb_date"><strong>07</strong>.<strong>26</strong><span class="day">(화)</span></span>
# <ul class="lnb_side" tabindex="0">
# <li><a class="nclicks(slb.allmedia)" href="https://news.naver.com/main/officeList.naver" title="전체 언론사">전체 언론사</a></li>
# <li><a class="nclicks(slb.newsstand)" href="https://newsstand.naver.com/" target="_blank" title="뉴스스탠드">뉴스스탠드</a></li>
# <li><a class="nclicks(slb.library)" href="https://newslibrary.naver.com/search/searchByDate.nhn" target="_blank" title="라이브러리">라이브러리</a></li>
# </ul>
# </div>
# </div>
# <hr/>
# <table cellpadding="0" cellspacing="0" class="container">
# <caption class="blind">기사목록</caption>
# <colgroup>
# <col class="col_snb"/>
# <col class="col_content"/>
# <col class="col_aside"/>
# </colgroup>
# <tr>
# <td class="snb">
# <div class="snb" id="snb">
# <h2 class="h4"><a class="nclicks(lmn_soc.home)" href="/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102">사회</a></h2>
# <ul class="nav">
# <li><a class="snb_s26 nclicks(lmn_soc.mnl,,1)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=102&amp;sid2=249">사건사고 </a></li>
# <li><a class="snb_s27 nclicks(lmn_soc.mnl,,2)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=102&amp;sid2=250">교육 </a></li>
# <li><a class="snb_s28 nclicks(lmn_soc.mnl,,3)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=102&amp;sid2=251">노동 </a></li>
# <li><a class="snb_s29 nclicks(lmn_soc.mnl,,4)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=102&amp;sid2=254">언론 </a></li>
# <li><a class="snb_s30 nclicks(lmn_soc.mnl,,5)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=102&amp;sid2=252">환경 </a></li>
# <li><a class="snb_s31 nclicks(lmn_soc.mnl,,6)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=102&amp;sid2=59b">인권/복지 </a></li>
# <li><a class="snb_s32 nclicks(lmn_soc.mnl,,7)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=102&amp;sid2=255">식품/의료 </a></li>
# <li><a class="snb_s90 nclicks(lmn_soc.mnl,,8)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=102&amp;sid2=256">지역 </a></li>
# <li><a class="snb_s104 nclicks(lmn_soc.mnl,,9)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=102&amp;sid2=276">인물 </a></li>
# <li><a class="snb_s33 nclicks(lmn_soc.mnl,,10)" href="/main/list.naver?mode=LS2D&amp;mid=shm&amp;sid1=102&amp;sid2=257">사회 일반 </a></li>
# </ul>
# <div class="snb_banner">
# <a class="nclicks(lmn_soc.pmb,,1)" href="https://contents.premium.naver.com/"><img alt="네이버 프리미엄콘텐츠" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/05/28/233112515_DA%2540PC%25B4%25BA%25BD%25BA%25C1%25C2%25C3%25F8.png" width="71"/></a>
# </div>
# <div class="snb_banner">
# <a class="nclicks(lmn_soc.pmb,,1)" href="https://media.naver.com/channel/setting?back=main"><img alt="언론사 구독하기" height="74" src="https://imgnews.pstatic.net/image/upload/item/2021/01/14/142956425_144518244_%2525B8%2525F0%2525B9%2525D9%2525C0%2525CF%2525B8%2525DE%2525C0%2525CE.png" width="71"/></a>
# </div>
# </div>
# </td>
# <td class="content">
# <div class="content" id="main_content">
# <div class="list_body section_index">
# <div class="cluster">
# <div class="cluster_title">
# <span class="cluster_title_inner"><a class="cluster_title_icon_link _news_cluster_layer_btn" href="#biF7L"><i class="cluster_title_icon">안내</i>헤드라인 뉴스</a></span>
# <div class="cluster_title_layer _news_cluster_layer is_hidden">
# <div class="cluster_title_layer_text">
#                             헤드라인 뉴스와 각 기사묶음 타이틀은 <br/> 기사 내용을 기반으로 <strong>자동 추출</strong>됩니다.
#                         </div>
# <div class="cluster_title_layer_image"></div>
# <button class="cluster_title_layer_close _news_cluster_layer_close_btn" type="button">닫기</button>
# </div>
# </div>
# </div>
# <div class="_persist">
# <div class="cluster">
# <div class="cluster_group _cluster_content">
# <div class="cluster_head">
# <div class="cluster_head_inner">
# <a class="cluster_head_more nclicks(cls_nav.clstitle)" href="/main/clusterArticles.naver?id=c_202207260650_00000033&amp;mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=020&amp;aid=0003442168"><span class="cluster_head_more_icon_num">19</span><span class="blind">개의 관련뉴스 더보기</span></a>
# <div class="cluster_head_topic_wrap">
# <h2 class="cluster_head_topic">
# <a class="nclicks(cls_nav.clstitle)" href="/main/clusterArticles.naver?id=c_202207260650_00000033&amp;mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=020&amp;aid=0003442168">
# <span class="cluster_head_sub_topic">만평 올린 전장연 </span><span class="cluster_head_sub_topic">우영우엔 공감 우리에겐 욕설 </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/020/0003442168?sid=102">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/020/2022/07/26/3442168.jpg?type=nf132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/020/0003442168?sid=102">“우영우엔 공감, 우리에겐 욕설” 2컷 만평 띄운 전장연</a>
# <div class="cluster_text_lede">장애인 권리예산 확보를 요구하며 ‘출근길 지하철 시위’를 벌이고 있는 전국장애인차별철폐연대(전장연)가 최근 인기리에 방영 중인 ENA 드라마 ‘이상한 변 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news020,0003442168',params:{sid1:'102'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">동아일보</div>
# </div>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news022,0003718891',params:{sid1:'102'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">세계일보</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/022/0003718891?sid=102">전장연 “‘우영우’엔 공감, 우리에겐 비난·조롱·욕설… 왜 이렇게 다른 반응?”</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news008,0004775154',params:{sid1:'102'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">머니투데이</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/008/0004775154?sid=102">"우영우엔 공감하면서 지하철 장애인은 조롱" 만평 올린 전장연</a>
# </div>
# </li>
# <li class="cluster_item as_line">
# <div class="cluster_text">
# <div class="cluster_text_info _rcount" data-comment="{gno:'news057,0001679289',params:{sid1:'102'},nclicks:'cmt.count','type':'sectionHomeCluster'}">
# <div class="cluster_text_press">MBN</div>
# </div>
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/057/0001679289?sid=102">전장연 "우영우는 공감하면서, 우리에겐 왜 비난·조롱"</a>
# </div>
# </li>
# </ul>
# </div>
# </div>
# <div class="cluster_group _cluster_content">
# <div class="cluster_head">
# <div class="cluster_head_inner">
# <a class="cluster_head_more nclicks(cls_nav.clstitle)" href="/main/clusterArticles.naver?id=c_202207261010_00000021&amp;mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=421&amp;aid=0006240084"><span class="cluster_head_more_icon_num">7</span><span class="blind">개의 관련뉴스 더보기</span></a>
# <div class="cluster_head_topic_wrap">
# <h2 class="cluster_head_topic">
# <a class="nclicks(cls_nav.clstitle)" href="/main/clusterArticles.naver?id=c_202207261010_00000021&amp;mode=LSD&amp;mid=shm&amp;sid1=102&amp;oid=421&amp;aid=0006240084">
# <span class="cluster_head_sub_topic">대기발령 후 첫 출근 </span><span class="cluster_head_sub_topic">류삼영 총경의 외로운 싸움 </span>
# </a>
# </h2>
# </div>
# </div>
# </div>
# <div class="cluster_body">
# <ul class="cluster_list">
# <li class="cluster_item">
# <div class="cluster_thumb">
# <div class="cluster_thumb_inner">
# <a class="cluster_thumb_link nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/421/0006240084?sid=102">
# <img alt="" height="90" onerror="javascript:this.src='https://ssl.pstatic.net/static.news/image/news/2009/noimage_132x90.png';this.style.width=132;this.style.height=90;" src="https://imgnews.pstatic.net/image/origin/421/2022/07/26/6240084.jpg?type=nf132_90" width="132"/>
# </a>
# </div>
# </div>
# <div class="cluster_text">
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/421/0006240084?sid=102">류삼영 총경의 외로운 싸움…오는 30일 14만 경찰 전체회의[뉴스1 PICK]</a>
# <div class="cluster_text_lede">경찰국 신설에 반발해 '전국경찰서장(총경) 회의'를 주도한 류삼영 총경이 대기발령 조치 이후 울산경찰청으로 첫 출근을 했다. 류 총장은 지난 25일 '대 …</div>
# <div class="cluster_text_info _rcount" data-comment="{gno:'news421,0
</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/003/0011325928?sid=105" title="올 상반기 5G 통신분쟁 신청 급증…전년 대비 3배 수준">올 상반기 5G 통신분쟁 신청 급증…전년 대비 3배 수준</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/092/0002263516?sid=105" title='네이버 노조 "5개 계열사 쟁의행위 본격화"'>네이버 노조 "5개 계열사 쟁의행위 본격화"</a> </li>
# </ul>
# <ul class="list_txt">
# <ul class="list_txt">
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/421/0006240039?sid=102" title="석달만에 10만명 '코앞'…신규 확진 9만9327명(종합)">석달만에 10만명 '코앞'…신규 확진 9만9327명(종합)</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/014/0004873062?sid=102" title="이상민 &quot;무기, 쿠데타&quot;에 &quot;총, 무기 1도 관계 없어&quot;, 경감이 불붙인 '전체 경찰회의'">이상민 "무기, 쿠데타"에 "총, 무기 1도 관계 없어", 경감이 불붙인 '전체 경찰회의'</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/009/0004996333?sid=102" title="광주 고교 '답안지 유출' 사실이었다…학생 2명 교사 컴퓨터에 악성코드 심어">광주 고교 '답안지 유출' 사실이었다…학생 2명 교사 컴퓨터에 악성코드 심어</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/003/0011325443?sid=103" title="'중복'에 폭염 이어져...일부 지역은 열대야도">'중복'에 폭염 이어져...일부 지역은 열대야도</a> </li>
# <li> <a class="nclicks(rig.secteco)" href="https://n.news.naver.com/mnews/article/052/0001768676?sid=103" title="[날씨] '중복' 전국 폭염특보, 서울 33℃...오후 소나기">[날씨] '중복' 전국 폭염특보, 서울 33℃...오후 소나기</a> </li>
# </ul>
# </ul>
# </ul>
# </div>
# </div>
# <div class="section">
# <div class="banner">
# <a class="nclicks(rig.banner)" href="https://media.naver.com/channel/settings"> <img alt="네이버 메인에서 바로 보는 언론사 편집뉴스 지금 바로 구독해보세요!" src="https://imgnews.pstatic.net/image/upload/item/2018/11/27/175025584_PC_%25BF%25EC%25C3%25F8%25B9%25E8%25B3%25CA_%25B1%25B8%25B5%25B6%25C8%25B0%25BC%25BA%25C8%25AD.png" width="300"> </img></a>
# </div>
# </div>
# <div class="section">
# <div class="banner">
# <a class="nclicks(rig.banner)" href="https://news.naver.com/main/ombudsman/guidecenter.naver?mid=omb" target="_blank"> <img alt="뉴스 기사와 댓글로 인한 문제 발생 시 24시간 센터로 접수해주세요" src="https://imgnews.pstatic.net/image/upload/item/2018/08/29/183254054_%25BD%25C5%25B0%25ED%25B9%25E8%25B3%25CA.png" width="300"> </img></a>
# </div>
# </div>
# <div class="section">
# <h4> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver"> 서비스 안내 </a> </h4>
# <ul class="list_txt">
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/errorArticleList.naver?mid=omb"> 고침 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/revisionArticleList.naver?mid=omb"> 정정·반론·추후 보도 기사 모음 </a> </li>
# <li> <a class="nclicks(rig.text)" href="https://news.naver.com/main/hotissue/sectionList.naver?mid=hot&amp;sid1=100&amp;cid=909906&amp;decorator=ombudsman&amp;confirm=true"> 불공정 선거 보도 기사 모음 </a> </li>
# </ul>
# <a class="more_link nclicks(rig.text)" href="https://news.naver.com/main/ombudsman/index.naver"><span class="blind">서비스 안내</span>더보기</a>
# </div>
# <script>
#     window.gladsdk.cmd.push(function () {
#         var adSlot = window.gladsdk.findAdSlot("glad_ad_sidebox");
#
#         adSlot.setCustomParam("calp", 'shome');
#         window.gladsdk.displayAd(adSlot);
#     });
# </script>
# </div>
# </td>
# </tr>
# </table>
# </div>
# <hr/>
# <div class="index">
# <div class="index_inner">
# <div class="floating_btn">
# <div class="floating_inner">
# <a class="floating_btn_back" href="javascript:history.back();"><span class="blind">이젠 페이지</span></a>
# <a class="floating_btn_top" href="#" onclick="window.scrollTo(0,0);oWebAccessibilityUtil.moveFocus(document.getElementById('da_base'));return false;"><span class="blind">맨위로</span></a>
# </div>
# </div>
# <div class="index_tab" id="index.press_category">
# <a class="spr stit nclicks(fot.press)" href="#" id="index.press.btn">언론사 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content is_hidden" id="index.press.area"></div>
# <a class="spr stit2 nclicks(fot.section)" href="#" id="index.category.btn">분야별 목록<span class="_stit_tab_arrow stit_arrow"><span class="blind">열기</span></span><span class="loading" style="display:none;">로딩 중</span></a>
# <div class="index_content02 is_hidden" id="index.category.area"></div>
# </div>
# </div>
# </div>
# <hr/>
# <div id="footer">
# <ul>
# <li class="first"><a class="nclicks(fot.agreement)" href="http://www.naver.com/rules/service.html">이용약관</a></li>
# <li><a class="nclicks(fot.guide)" href="/main/ombudsman/index.naver">서비스 안내</a></li>
# <li><a class="nclicks(fot.editor)" href="/main/ombudsman/edit.naver?mid=omb">기사배열 원칙 책임자 : 유봉석</a></li>
# <li>청소년 보호 책임자 : 이희만</li>
# <li><strong><a class="nclicks(fot.privacy)" href="http://www.naver.com/rules/privacy.html">개인정보처리방침</a></strong></li>
# <li><a class="nclicks(fot.disclaimer)" href="http://www.naver.com/rules/disclaimer.html">책임의 한계와 법적고지</a></li>
# <li><a class="nclicks(fot.help)" href="#" onclick="news.external.OPS.helpNews(); return false;" title="새창">뉴스 고객센터</a></li>
# </ul>
# <p class="copyright">본 콘텐츠의 저작권은 제공처 또는 네이버에 있으며 이를 무단 이용하는 경우 저작권법 등에 따라 법적책임을 질 수 있습니다.</p>
# <address class="address_nhn">
# <a class="logo nclicks(fot.naver)" href="https://www.navercorp.com/" target="_blank"><span class="blind">NAVER</span></a>
# <em>Copyright ©</em>
# <a class="nclicks(fot.navercorp)" href="https://www.navercorp.com/" target="_blank">NAVER Corp.</a>
# <span>All Rights Reserved.</span>
# </address>
# <!-- -->
# </div>
# <script type="text/javascript">
#
#
#
#
#
#
#
# var index_tab = new news.index.TabController('index.press_category');
# index_tab.add(new news.index.Tab('index.press.btn','stit','index.press.area','/main/ajax/bottomIndex/press.naver'));
# index_tab.add(new news.index.Tab('index.category.btn','stit2','index.category.area','/main/ajax/bottomIndex/category.naver'));
# jindo.$Fn(index_tab.toggle, index_tab).attach(index_tab.tabs.keys(), 'click');
#
#
# (function() {
# 	news.right.RightSideFloatingManager.init();
# })();
#
#
#
#     (function() {
#         news.right.TopDownFloatingManager.init();
#     })();
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ;(function(){
#     var eventType = "onpageshow" in window ? "pageshow" : "load";
#     jindo.$Fn(function(){
#
#
# 	lcs_do();
#
#     }).attach(window, eventType);
# })();
#
#
#
#
#
#
#
#
# news.startup();
#
#
# jindo.$Fn(function(){
#     var welSkip = jindo.$Element("u_skip");
#     if (welSkip === null) {
#         return;
#     }
#     welSkip.delegate("click", "a", function(weEvent){
#         weEvent.stopDefault();
#         var elTarget = jindo.$(weEvent.element.href.split("#")[1]);
#         oWebAccessibilityUtil.moveFocus(elTarget);
#     });
# }).attach(window, "load");
#
#
# document.documentElement.setAttribute('data-useragent',navigator.userAgent);
# </script>
# </body>
# </html>

# %%
#기사 대표 head 한 개뽑기

target = bs.select_one('#main_content > div > div._persist > div:nth-child(1) > div:nth-child(1) > div.cluster_body > ul > li:nth-child(1) > div.cluster_text > a')
print(target.text, '\n')
print(target, '\n')
print(target['class'], '\n')
print(target['href'])
# Out:
# “우영우엔 공감, 우리에겐 욕설” 2컷 만평 띄운 전장연
#
# <a class="cluster_text_headline nclicks(cls_nav.clsart)" href="https://n.news.naver.com/mnews/article/020/0003442168?sid=102">“우영우엔 공감, 우리에겐 욕설” 2컷 만평 띄운 전장연</a>
#
# ['cluster_text_headline', 'nclicks(cls_nav.clsart)']
#
# https://n.news.naver.com/mnews/article/020/0003442168?sid=102

# %%
#기사 대표 head 전체 뽑기

targets = bs.select('#main_content > div > div > div > div > div > ul > li > div > a')
head_all='\n'.join([t.text for t in targets])
print(head_all)
# Out:
# “우영우엔 공감, 우리에겐 욕설” 2컷 만평 띄운 전장연
# 전장연 “‘우영우’엔 공감, 우리에겐 비난·조롱·욕설… 왜 이렇게 다른 반응?”
# "우영우엔 공감하면서 지하철 장애인은 조롱" 만평 올린 전장연
# 전장연 "우영우는 공감하면서, 우리에겐 왜 비난·조롱"
# 류삼영 총경의 외로운 싸움…오는 30일 14만 경찰 전체회의[뉴스1 PICK]
# 류삼영, 대기발령 후 첫 출근 "닭의 목 비틀어도 새벽은 온다"
# 류삼영 총경 "행안부 경찰국은 경찰의 정치적 중립 훼손"
# "경찰의 정당한 목소리, 감찰과 위협 맞지 않아"
# 광주 사립고 시험지 유출 의혹…경찰 수사
# 광주 모 고교 시험문제 유출…경찰 수사 중
# 광주 사립고교서 답안지 유출 의혹…고교생 주거지 압수수색
# '답안지 유출' 광주 사립고 학생 경찰 조사
# ‘복마전’ 농협 비상임이사 돈선거…출마자·대의원 무더기 적발
# 아직도 이런일이...돈으로 표 사려한 농협 비상임이사 후보들
# 농협 이사 선거 앞두고 금품 거래…경찰, 68명 적발
# 농협 선거 때 돈 봉투 건넨 이사 ‘집행유예 2년’
# https://n.news.naver.com/mnews/article/008/0004775150?sid=102
# ‘부적절 관계, 성적 조작 의혹’ 교사 수사
# https://n.news.naver.com/mnews/article/056/0011308628?sid=102
# 택시비 1만5000원 안주려다 67배 물어낸 50대, 무슨일이
# https://n.news.naver.com/mnews/article/009/0004996250?sid=102
# 택시비 1만5000원 아끼려다…벌금으로 67배 물게 된 50대男
# https://n.news.naver.com/mnews/article/022/0003718919?sid=102
# “또 확산?” 서울역 광장에 코로나19 선별검사소 재개
# https://n.news.naver.com/mnews/article/243/0000029140?sid=102
# 입국 당일 PCR 검사 받아야… 붐비는 인천공항 검사소 [현장르포]
# https://n.news.naver.com/mnews/article/014/0004872668?sid=102
# 바다를 걸으며 달라진 어촌을 느껴보세요
# https://n.news.naver.com/mnews/article/003/0011326203?sid=102
# 태안군, 어촌 개발 정부 공모 5년간 1312억원 확보
# https://n.news.naver.com/mnews/article/421/0006240316?sid=102

# %%
#이미지 추출하기

url = 'https://n.news.naver.com/mnews/article/014/0004872935?sid=102'
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}

res = rq.get(url, headers=headers)
html = res.content
bs = BeautifulSoup(html,'lxml')

target = bs.select_one('#img1')
print(target)
print('\n')
print(target['data-src'])
# Out:
# <img class="_LAZY_LOADING" data-src="https://imgnews.pstatic.net/image/014/2022/07/26/0004872935_001_20220726083904125.jpg?type=w647" id="img1"/>
#
#
# https://imgnews.pstatic.net/image/014/2022/07/26/0004872935_001_20220726083904125.jpg?type=w647

# %% [markdown]
# #### 연습문제
# Q. url = 'https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=100' 사이트에서 뉴스기사를 출력하세요.
#
# - 용도는 주요 키워드 분석을 위한 데이터셋 만들기

# %%
import requests as rq
from bs4 import BeautifulSoup

url = 'https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=100'
headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}

res = rq.get(url, headers = headers)
html = res.content
bs = BeautifulSoup(html)

# %%
#분석을 위한 데이터셋 만들기

body = bs.select('#main_content > div > div > div > div > div > ul > li > div > a')  #기사 헤드라인 태그 뽑기

all_header=[b.text for b in body]   #기사 헤드라인의 텍스트만 뽑기

all_str_headers='\n'.join(all_header)   #기사 헤드라인 텍스트 타입을 string으로 바꾸기

print(all_str_headers)
# Out:
# 박지원, 한동훈·이상민 직격 “과연 스타장관은 특별한 재능 가졌구나”
# 박지원 "왜 쿠데타냐‥경찰들이 총 한 방 쐈나"
# 박지원 "경찰 징계…尹, 대통령직을 검찰총장직으로 생각하는 듯"
# 박지원, 이상민 직격 "경찰이 총 쏘고 한강 넘었냐…한심한 작태"
# 행안부 內 경찰국 신설안 국무회의 의결…내달 2일 공포
# '행안부 경찰국 신설안' 국무회의 통과…내달 2일 공포(종합)
# 경찰 반발에도 '8월 2일 경찰국 신설' 시행령안 국무회의 통과
# [2보] '행안부 경찰국 신설안' 국무회의 의결…내달 2일 공포
# “법정주의 용어 아냐” “말씀해주시면 듣겠다”… 전·현직 법무장관 설전
# '실세장관' 2인 집중 타깃한 민주…韓·李, '엄호' 대치전선(종합2보)
#  한동훈 vs 박범계, 전현직 법무장관의 격돌[속보영상]
# 대정부질문 데뷔전…한덕수 '노련' 한동훈 '무난' 이상민 '미흡'
# 이준석 "5명의 당원이 만나고자 해도 다 찾아가겠다"(종합)
# "지금 팔도 유람할 때냐" 당내 비판에 이준석 "닭먹고 힘내자" 화답
# 이준석, 이번엔 울릉도행…보수 텃밭 TK 돌며 '장외정치'
# 울릉도 간 이준석 "5명이 만나자 해도 갈 것"...장외 정치 계속
# 한동훈, 내일 첫 ‘尹 독대 보고’…어떤 사안 언급될까
# 윤 대통령, 오늘 법무부 · 행안부 업무보고
# '경찰국 신설 시행령' 국무회의行 vs. 野, 용산行 "경찰장악 규탄"
# 野 “두달만에 민주주의 통째로 부정”…‘尹정부 경찰장악 규탄’ 총공세
# 박지원 “검로경불…이상민 ‘스타 장관’이 尹대통령 망친다”
# 박지원 "'검로경불' 이상민 장관, 아카데미·대종상 감"
# [속보]尹대통령 "여가부 폐지 로드맵 조속히 마련하라" 지시
# 여성가족부, 추진과제 보고했더니‥윤 대통령 "폐지 로드맵 조속히"
# 尹 “경찰 집단행동에 깊은 우려…국가기강 문란될 수 있어”
# 尹대통령 "중대한 국가 기강 문란"…경찰에 한달새 2번 강력 경고
# 박홍근 "이상민, '행정쿠데타' 발상…국기문란? 누가 일으키나"
# 용산으로 몰려간 野…박홍근 "진정 국기문란은 윤석열 정부가"
# 野 컷오프 이틀 앞인데…비명계 '조기 단일화' 속내는?
# 박용진 "尹, 왼손에는 한동훈, 오른손엔 이상민"
# 국민의힘 수신료 폐지주장에 "비전문가적 주장" 비판한 KBS노조
# 與 "KBS 수신료 분리징수안 강력 추진…전기요금에서 분리"
# 권영세 “유엔사, 강제북송 알고 승인한 것 아냐”
# 탈북어민 북송 때 유엔사, 정부에 항의…권영세 “강제북송인 건 몰랐다”
# "박범계, 한동훈에 참패했다"…진중권 평가한 두 가지 이유
# 진중권 "박범계 한동훈에 참패..논리도 밀리고 너무 흥분했다"
# 안철수, ‘김경수 사면’공개 반대
# 안철수, 김경수 사면설에 "국정농단 주범‥면죄부 줘선 안 돼"
# 與 "경찰국은 민주적 견제"…경찰·민주 쌍끌이 비판
# 권성동 “軍 항명과 경찰 항명은 같다, 같은 무게로 책임 물어야”

# %%
# 정규표현식으로 '...','\n' 삭제

import re

all_str_headers = re.sub('…',' ',all_str_headers)
print(all_str_headers)
# Out:
# 박지원 한동훈·이상민 직격 “과연 스타장관은 특별한 재능 가졌구나” 박지원  왜 쿠데타냐‥경찰들이 총 한 방 쐈나  박지원  경찰 징계 尹 대통령직을 검찰총장직으로 생각하는 듯  박지원 이상민 직격  경찰이 총 쏘고 한강 넘었냐 한심한 작태  행안부 內 경찰국 신설안 국무회의 의결 내달 2일 공포  행안부 경찰국 신설안  국무회의 통과 내달 2일 공포(종합) 경찰 반발에도  8월 2일 경찰국 신설  시행령안 국무회의 통과 [2보]  행안부 경찰국 신설안  국무회의 의결 내달 2일 공포 “법정주의 용어 아냐” “말씀해주시면 듣겠다”  전·현직 법무장관 설전  실세장관  2인 집중 타깃한 민주 韓·李  엄호  대치전선(종합2보)  한동훈 vs 박범계 전현직 법무장관의 격돌[속보영상] 대정부질문 데뷔전 한덕수  노련  한동훈  무난  이상민  미흡  이준석  5명의 당원이 만나고자 해도 다 찾아가겠다 (종합)  지금 팔도 유람할 때냐  당내 비판에 이준석  닭먹고 힘내자  화답 이준석 이번엔 울릉도행 보수 텃밭 TK 돌며  장외정치  울릉도 간 이준석  5명이 만나자 해도 갈 것 ...장외 정치 계속 한동훈 내일 첫 ‘尹 독대 보고’ 어떤 사안 언급될까 윤 대통령 오늘 법무부 · 행안부 업무보고  경찰국 신설 시행령  국무회의行 vs. 野 용산行  경찰장악 규탄  野 “두달만에 민주주의 통째로 부정” ‘尹정부 경찰장악 규탄’ 총공세 박지원 “검로경불 이상민 ‘스타 장관’이 尹대통령 망친다” 박지원   검로경불  이상민 장관 아카데미·대종상 감  [속보]尹대통령  여가부 폐지 로드맵 조속히 마련하라  지시 여성가족부 추진과제 보고했더니‥윤 대통령  폐지 로드맵 조속히  尹 “경찰 집단행동에 깊은 우려 국가기강 문란될 수 있어” 尹대통령  중대한 국가 기강 문란  경찰에 한달새 2번 강력 경고 박홍근  이상민  행정쿠데타  발상 국기문란? 누가 일으키나  용산으로 몰려간 野 박홍근  진정 국기문란은 윤석열 정부가  野 컷오프 이틀 앞인데 비명계  조기 단일화  속내는? 박용진  尹 왼손에는 한동훈 오른손엔 이상민  국민의힘 수신료 폐지주장에  비전문가적 주장  비판한 KBS노조 與  KBS 수신료 분리징수안 강력 추진 전기요금에서 분리  권영세 “유엔사 강제북송 알고 승인한 것 아냐” 탈북어민 북송 때 유엔사 정부에 항의 권영세 “강제북송인 건 몰랐다”  박범계 한동훈에 참패했다  진중권 평가한 두 가지 이유 진중권  박범계 한동훈에 참패..논리도 밀리고 너무 흥분했다  안철수 ‘김경수 사면’공개 반대 안철수 김경수 사면설에  국정농단 주범‥면죄부 줘선 안 돼  與  경찰국은 민주적 견제  경찰·민주 쌍끌이 비판 권성동 “軍 항명과 경찰 항명은 같다 같은 무게로 책임 물어야”

# %%
#윤정준님

from konlpy.tag import Okt
from collections import Counter
from bs4 import BeautifulSoup
import requests

url = 'https://news.naver.com/main/main.nhn?mode=LSD&mid=shm&sid1=100'
rqs = requests.get(url,headers=headers).text
bs = BeautifulSoup(rqs,'lxml')
bs = bs.find_all('div',class_='cluster')
result = []
for i in bs:
    result.append(i.get_text())
bs = re.sub('[^가-힣]+',' ',str(result))

okok = Okt()
okok2 = okok.pos(bs)
okre = []
for i, j in okok2:
    if (j =='Noun')& (len(i)> 1 ):
        okre.append(i)

okreid = dict(Counter(okre).most_common())
okreid = sorted(okreid.items(), key=lambda x:x[1], reverse=True)
okreid

# %% [markdown]
# #### 과제07/26_2
# ##### 제품 테이블에서 첫번째 타이틀 행을 제외한 모든 제품 행을 출력하세요
# - html = urlopen('http://www.pythonscraping.com/pages/page3.html',context=context)

# %% [markdown]
# #### 과제07/26_3
# ##### 네이버 카테고리별 기사를 아래 카테고리 정의를 기준으로 크롤링한 후 불필요한 공백을 제거하고 한글만으로 된 데이터 프레임을 출력하세요.
# - 카테고리 정의
#     - 100 정치
#         - (청와대[264] + 국회/정당[265] + 북한[268] + 국방/외교[267])
#
#     - 101 경제
#         - (금융[259] + 증권[258] + 산업/재계[261] + 글로벌 경제[262] + 부동산[260])
#
#     - 103 생활/문화
#         - (건강정보[241] + 여행/레저[237] + 공연/전시[242] + 날씨[248] + 생활문화 일반[245])
#
#     - 105 IT/과학
#         - (통신/뉴미디어[227] + IT 일반[230] + 컴퓨터[283] + 과학 일반[228])
#
# - 카테고리별 1000개, 총 4천개로 구성된 데이터프레임 생성

# %%
#참고
#sid1= 정치/경제/생활문화/IT과학
https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=100
#sid2= 각각의 sub 탭
https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid1=100&sid2=264
#page
https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid2=264&sid1=100&date=20220726&page=2

# %%
'''
url = 'https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid2='+str(cat2)+'&sid1=100&date=20220726&page='+str(i+1)
'''
# Out:
# "\nurl = 'https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid2='+str(cat2)+'&sid1=100&date=20220726&page='+str(i+1)\n"

# %%
import pandas as pd

news_df = pd.DataFrame(columns=['news','category'])
news_df
# Out:
# Empty DataFrame
# Columns: [news, category]
# Index: []

# %%
#정치

cats = [264,265,268,267]
ind = 0
for cat in cats:
    if 
    for i in range(15):
        url = 'https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid2='+str(cat)+'&sid1=100&date=20220726&page='+str(i+1)
        headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}
        
        news = requests.get(url, headers = headers)
        bs = BeautifulSoup(news.content, 'lxml')
        links = bs.select('#main_content > div > ul > li > dl > dt > a')
        
        #기사 헤드를 긁어서 뉴스링크들 모으기
        newslinks=[]
        for j, link in enumerate(links):            
            newslink = link.get('href')
            newslinks.append(newslink)
            newslinks = list(set(newslinks))    #중복 기사 제거
        
        #뉴스링크들 가지고 기사 본문 크롤링
        for link in newslinks:
            res2 = requests.get(link, headers = headers).text
            bs2 = BeautifulSoup(res2, 'html.parser')
            news = bs2.find('div', id='dic_area').text
            news = re.sub('\n', '', news)  #개행을 공백으로
            news = re.sub('\t', '', news)  #탭을 공백으로
            news_df.loc[ind] = [news, cat]
            ind += 1

news_df
# Out:
#                                                    news  category
# 0     "업무보고서 사면 얘기 안 나와…검찰총장, 상식·정의 따라 검찰 이끄는 분 될 것"...       264
# 1     [서울=뉴시스] 윤석열 대통령이 26일 서울 용산 대통령실 청사에서 한동훈 법무부 ...       264
# 2     [[the300](상보)]윤석열 대통령이 26일 용산 대통령실 집무실에서 한동훈 법...       264
# 3     기사내용 요약전담수사부서 살리고 형사부 수사권 부여검경 협의회 통해 '검수완박' 시...       264
# 4     기사내용 요약티타임 '검언유착' 비판에 "그렇게 보이지 않는다""공직자, 언론으로부...       264
# ...                                                 ...       ...
# 1159      (울산=연합뉴스) 김근주 기자 = 행정안전부 경찰국 신설 반대 경찰서장 회의...       267
# 1160  총리 주재 국무회의서 시행령 의결“행안장관, 잘 설득해 달라” 주문다음 달 2일 공...       267
# 1161  (인천공항=뉴스1) 조태형 기자 = 이종섭 국방부 장관이 한미 국방장관회담과 한국전...       267
# 1162  (서울=연합뉴스) 김영은 기자 = 국가보훈처에 따르면 미국 워싱턴D.C에 있는 한국...       267
# 1163  미얀마의 민주화 투쟁 (광주=연합뉴스) 5·18 기념재단은 오는 17일부터 미얀마 ...       267
#
# [1164 rows x 2 columns]

# %%
news_df2=pd.DataFrame(columns=['news','category'])
news_df2
# Out:
# Empty DataFrame
# Columns: [news, category]
# Index: []

# %%
#경제
#(금융[259] + 증권[258] + 산업/재계[261] + 글로벌 경제[262] + 부동산[260])

import requests as rq
from bs4 import BeautifulSoup

category = [259,258,261,262,260]
ind = 0

for cat in category:
    if cat==262:
        for i in range(6):
            url = 'https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid2='+str(cat)+'&sid1=101&date=20220726&page='+str(i+1)
            headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}
            html = rq.get(url, headers = headers).content
            bs = BeautifulSoup(html, 'html.parser')
            a = bs.select('#main_content > div > ul > li > dl > dt> a')
    else:
        for i in range(15):
            url = 'https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid2='+str(cat)+'&sid1=101&date=20220726&page='+str(i+1)
            headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}
            html = rq.get(url, headers = headers).content
            bs = BeautifulSoup(html, 'html.parser')
            a = bs.select('#main_content > div > ul > li > dl > dt> a')
        
            #a태그 내 뉴스링크 모으기
            news_links = []
            for i in a:
                news_link = i.get('href')
                news_links.append(news_link)
                news_links = list(set(news_links))

            #뉴스링크로 뉴스 본문 크롤링
            for link in news_links:
                html2 = rq.get(link, headers = headers).content
                bs2 = BeautifulSoup(html2, 'html.parser')
                bs2.find('div', id='dic_area').text
                news = bs2.find('div', id='dic_area').text
                news = re.sub('\n','',news)
                news = re.sub('\t','',news)
                news_df2.loc[ind] = [news, cat]
                ind += 1
news_df2
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File ~\anaconda3\envs\cakd7\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443 try:
# --> 444     httplib_response = conn.getresponse()
#     445 except BaseException as e:
#     446     # Remove the TypeError from the exception chain in
#     447     # Python 3 (including for exceptions like SystemExit).
#     448     # Otherwise it looks like a bug in the code.
#
# File ~\anaconda3\envs\cakd7\lib\http\client.py:1348, in HTTPConnection.getresponse(self)
#    1347 try:
# -> 1348     response.begin()
#    1349 except ConnectionError:
#
# File ~\anaconda3\envs\cakd7\lib\http\client.py:316, in HTTPResponse.begin(self)
#     315 while True:
# --> 316     version, status, reason = self._read_status()
#     317     if status != CONTINUE:
#
# File ~\anaconda3\envs\cakd7\lib\http\client.py:277, in HTTPResponse._read_status(self)
#     276 def _read_status(self):
# --> 277     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278     if len(line) > _MAXLINE:
#
# File ~\anaconda3\envs\cakd7\lib\socket.py:669, in SocketIO.readinto(self, b)
#     668 try:
# --> 669     return self._sock.recv_into(b)
#     670 except timeout:
#
# File ~\anaconda3\envs\cakd7\lib\ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#
# File ~\anaconda3\envs\cakd7\lib\ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1098 if buffer is not None:
# -> 1099     return self._sslobj.read(len, buffer)
#    1100 else:
#
# ConnectionResetError: [WinError 10054] 현재 연결은 원격 호스트에 의해 강제로 끊겼습니다
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File ~\anaconda3\envs\cakd7\lib\site-packages\requests\adapters.py:440, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     439 if not chunked:
# --> 440     resp = conn.urlopen(
#     441         method=request.method,
#     442         url=url,
#     443         body=request.body,
#     444         headers=request.headers,
#     445         redirect=False,
#     446         assert_same_host=False,
#     447         preload_content=False,
#     448         decode_content=False,
#     449         retries=self.max_retries,
#     450         timeout=timeout
#     451     )
#     453 # Send the request.
#     454 else:
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\urllib3\connectionpool.py:785, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     783     e = ProtocolError("Connection aborted.", e)
# --> 785 retries = retries.increment(
#     786     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     787 )
#     788 retries.sleep()
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\urllib3\util\retry.py:550, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     549 if read is False or not self._is_method_retryable(method):
# --> 550     raise six.reraise(type(error), error, _stacktrace)
#     551 elif read is not None:
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\urllib3\packages\six.py:769, in reraise(tp, value, tb)
#     768 if value.__traceback__ is not tb:
# --> 769     raise value.with_traceback(tb)
#     770 raise value
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443 try:
# --> 444     httplib_response = conn.getresponse()
#     445 except BaseException as e:
#     446     # Remove the TypeError from the exception chain in
#     447     # Python 3 (including for exceptions like SystemExit).
#     448     # Otherwise it looks like a bug in the code.
#
# File ~\anaconda3\envs\cakd7\lib\http\client.py:1348, in HTTPConnection.getresponse(self)
#    1347 try:
# -> 1348     response.begin()
#    1349 except ConnectionError:
#
# File ~\anaconda3\envs\cakd7\lib\http\client.py:316, in HTTPResponse.begin(self)
#     315 while True:
# --> 316     version, status, reason = self._read_status()
#     317     if status != CONTINUE:
#
# File ~\anaconda3\envs\cakd7\lib\http\client.py:277, in HTTPResponse._read_status(self)
#     276 def _read_status(self):
# --> 277     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278     if len(line) > _MAXLINE:
#
# File ~\anaconda3\envs\cakd7\lib\socket.py:669, in SocketIO.readinto(self, b)
#     668 try:
# --> 669     return self._sock.recv_into(b)
#     670 except timeout:
#
# File ~\anaconda3\envs\cakd7\lib\ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#
# File ~\anaconda3\envs\cakd7\lib\ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1098 if buffer is not None:
# -> 1099     return self._sslobj.read(len, buffer)
#    1100 else:
#
# ProtocolError: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Input In [437], in <cell line: 10>()
#      20 url = 'https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid2='+str(cat)+'&sid1=101&date=20220726&page='+str(i+1)
#      21 headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}
# ---> 22 html = rq.get(url, headers = headers).content
#      23 bs = BeautifulSoup(html, 'html.parser')
#      24 a = bs.select('#main_content > div > ul > li > dl > dt> a')
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\requests\api.py:75, in get(url, params, **kwargs)
#      64 def get(url, params=None, **kwargs):
#      65     r"""Sends a GET request.
#      66
#      67     :param url: URL for the new :class:`Request` object.
#    (...)
#      72     :rtype: requests.Response
#      73     """
# ---> 75     return request('get', url, params=params, **kwargs)
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\requests\api.py:61, in request(method, url, **kwargs)
#      57 # By using the 'with' statement we are sure the session is closed, thus we
#      58 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      59 # cases, and look like a memory leak in others.
#      60 with sessions.Session() as session:
# ---> 61     return session.request(method=method, url=url, **kwargs)
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\requests\sessions.py:529, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     524 send_kwargs = {
#     525     'timeout': timeout,
#     526     'allow_redirects': allow_redirects,
#     527 }
#     528 send_kwargs.update(settings)
# --> 529 resp = self.send(prep, **send_kwargs)
#     531 return resp
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\requests\sessions.py:645, in Session.send(self, request, **kwargs)
#     642 start = preferred_clock()
#     644 # Send the request
# --> 645 r = adapter.send(request, **kwargs)
#     647 # Total elapsed time of the request (approximately)
#     648 elapsed = preferred_clock() - start
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\requests\adapters.py:501, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     498             raise
#     500 except (ProtocolError, socket.error) as err:
# --> 501     raise ConnectionError(err, request=request)
#     503 except MaxRetryError as e:
#     504     if isinstance(e.reason, ConnectTimeoutError):
#     505         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))

# %%
news_df3=pd.DataFrame(columns=['news','category'])
news_df3
# Out:
# Empty DataFrame
# Columns: [news, category]
# Index: []

# %%
#생활/문화: 103

category = [241,237,242,248,245]
ind = 0

for cat in category:
    for i in range(15):
        url = 'https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid2='+str(cat)+'&sid1=103&date=20220726&page='+str(i+1)
        html = rq.get(url, headers = headers).content
        bs = BeautifulSoup(html,'html.parser')
        a = bs.select('#main_content > div > ul > li > dl > dt> a')
        
        news_links=[]
        for i in a:
            link = i['href']
            news_links.append(link)
            news_links = list(set(news_links))
            
        for news_link in news_links:
            html2 = rq.get(news_link, headers = headers).content
            bs2 = BeautifulSoup(html2, 'html.parser')
            if bs2.find('div', id='dic_area').text==None:
                pass
            else:
                news = bs2.find('div', id='dic_area').text
            news = re.sub('\n\t','',news)
            news_df3.loc[ind]=[news, cat]
            ind += 1
news_df3
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [430], in <cell line: 6>()
#      20 html2 = rq.get(news_link, headers = headers).content
#      21 bs2 = BeautifulSoup(html2, 'html.parser')
# ---> 22 news = bs2.find('div', id='dic_area').text
#      23 news = re.sub('\n\t','',news)
#      24 news_df3.loc[ind]=[news, cat]
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
#IT/과학: 105

category = [227,230,283,228]
ind = 0

for cat in category:
    url = 'https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid2='+str(cat)+'&sid1=105&date=20220726&page='+str(i+1)
    html = rq.get(url, headers = headers)
    bs = BeautifulSoup(html,'lxml')
    a = bs.select('#main_content > div > ul > li > dl > dt> a')
    
    for i in a:
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File ~\anaconda3\envs\cakd7\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443 try:
# --> 444     httplib_response = conn.getresponse()
#     445 except BaseException as e:
#     446     # Remove the TypeError from the exception chain in
#     447     # Python 3 (including for exceptions like SystemExit).
#     448     # Otherwise it looks like a bug in the code.
#
# File ~\anaconda3\envs\cakd7\lib\http\client.py:1348, in HTTPConnection.getresponse(self)
#    1347 try:
# -> 1348     response.begin()
#    1349 except ConnectionError:
#
# File ~\anaconda3\envs\cakd7\lib\http\client.py:316, in HTTPResponse.begin(self)
#     315 while True:
# --> 316     version, status, reason = self._read_status()
#     317     if status != CONTINUE:
#
# File ~\anaconda3\envs\cakd7\lib\http\client.py:277, in HTTPResponse._read_status(self)
#     276 def _read_status(self):
# --> 277     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278     if len(line) > _MAXLINE:
#
# File ~\anaconda3\envs\cakd7\lib\socket.py:669, in SocketIO.readinto(self, b)
#     668 try:
# --> 669     return self._sock.recv_into(b)
#     670 except timeout:
#
# File ~\anaconda3\envs\cakd7\lib\ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#
# File ~\anaconda3\envs\cakd7\lib\ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1098 if buffer is not None:
# -> 1099     return self._sslobj.read(len, buffer)
#    1100 else:
#
# ConnectionResetError: [WinError 10054] 현재 연결은 원격 호스트에 의해 강제로 끊겼습니다
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File ~\anaconda3\envs\cakd7\lib\site-packages\requests\adapters.py:440, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     439 if not chunked:
# --> 440     resp = conn.urlopen(
#     441         method=request.method,
#     442         url=url,
#     443         body=request.body,
#     444         headers=request.headers,
#     445         redirect=False,
#     446         assert_same_host=False,
#     447         preload_content=False,
#     448         decode_content=False,
#     449         retries=self.max_retries,
#     450         timeout=timeout
#     451     )
#     453 # Send the request.
#     454 else:
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\urllib3\connectionpool.py:785, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     783     e = ProtocolError("Connection aborted.", e)
# --> 785 retries = retries.increment(
#     786     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     787 )
#     788 retries.sleep()
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\urllib3\util\retry.py:550, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     549 if read is False or not self._is_method_retryable(method):
# --> 550     raise six.reraise(type(error), error, _stacktrace)
#     551 elif read is not None:
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\urllib3\packages\six.py:769, in reraise(tp, value, tb)
#     768 if value.__traceback__ is not tb:
# --> 769     raise value.with_traceback(tb)
#     770 raise value
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443 try:
# --> 444     httplib_response = conn.getresponse()
#     445 except BaseException as e:
#     446     # Remove the TypeError from the exception chain in
#     447     # Python 3 (including for exceptions like SystemExit).
#     448     # Otherwise it looks like a bug in the code.
#
# File ~\anaconda3\envs\cakd7\lib\http\client.py:1348, in HTTPConnection.getresponse(self)
#    1347 try:
# -> 1348     response.begin()
#    1349 except ConnectionError:
#
# File ~\anaconda3\envs\cakd7\lib\http\client.py:316, in HTTPResponse.begin(self)
#     315 while True:
# --> 316     version, status, reason = self._read_status()
#     317     if status != CONTINUE:
#
# File ~\anaconda3\envs\cakd7\lib\http\client.py:277, in HTTPResponse._read_status(self)
#     276 def _read_status(self):
# --> 277     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     278     if len(line) > _MAXLINE:
#
# File ~\anaconda3\envs\cakd7\lib\socket.py:669, in SocketIO.readinto(self, b)
#     668 try:
# --> 669     return self._sock.recv_into(b)
#     670 except timeout:
#
# File ~\anaconda3\envs\cakd7\lib\ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#
# File ~\anaconda3\envs\cakd7\lib\ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1098 if buffer is not None:
# -> 1099     return self._sslobj.read(len, buffer)
#    1100 else:
#
# ProtocolError: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Input In [439], in <cell line: 6>()
#       6 for cat in category:
#       7     url = 'https://news.naver.com/main/list.naver?mode=LS2D&mid=shm&sid2='+str(cat)+'&sid1=105&date=20220726&page='+str(i+1)
# ----> 8     html = rq.get(url, headers = headers)
#       9     bs = BeautifulSoup(html,'lxml')
#      10     a = bs.select('#main_content > div > ul > li > dl > dt> a')
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\requests\api.py:75, in get(url, params, **kwargs)
#      64 def get(url, params=None, **kwargs):
#      65     r"""Sends a GET request.
#      66
#      67     :param url: URL for the new :class:`Request` object.
#    (...)
#      72     :rtype: requests.Response
#      73     """
# ---> 75     return request('get', url, params=params, **kwargs)
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\requests\api.py:61, in request(method, url, **kwargs)
#      57 # By using the 'with' statement we are sure the session is closed, thus we
#      58 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      59 # cases, and look like a memory leak in others.
#      60 with sessions.Session() as session:
# ---> 61     return session.request(method=method, url=url, **kwargs)
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\requests\sessions.py:529, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     524 send_kwargs = {
#     525     'timeout': timeout,
#     526     'allow_redirects': allow_redirects,
#     527 }
#     528 send_kwargs.update(settings)
# --> 529 resp = self.send(prep, **send_kwargs)
#     531 return resp
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\requests\sessions.py:645, in Session.send(self, request, **kwargs)
#     642 start = preferred_clock()
#     644 # Send the request
# --> 645 r = adapter.send(request, **kwargs)
#     647 # Total elapsed time of the request (approximately)
#     648 elapsed = preferred_clock() - start
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\requests\adapters.py:501, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     498             raise
#     500 except (ProtocolError, socket.error) as err:
# --> 501     raise ConnectionError(err, request=request)
#     503 except MaxRetryError as e:
#     504     if isinstance(e.reason, ConnectTimeoutError):
#     505         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, '현재 연결은 원격 호스트에 의해 강제로 끊겼습니다', None, 10054, None))
