# %% [markdown]
# ## 와인 라벨 이미지 내 텍스트 추출

# %% [markdown]
# ### 해당 라이브러리 설치
# - tesseract.exe도 따로 설치 후, 환경변수에서 Path에 'C:\Program Files\Tesseract-OCR' 추가해줘야 함
# - 참고: https://devsmile.tistory.com/entry/%ED%8C%8C%EC%9D%B4%EC%8D%AC-%EC%9D%B4%EB%AF%B8%EC%A7%80%EC%97%90%EC%84%9C-%ED%85%8D%EC%8A%A4%ED%8A%B8-%EC%B6%94%EC%B6%9C%ED%95%98%EA%B8%B0-1-tesseract

# %%
# ! pip install pytesseract
# ! pip install Pillow
# ! pip install opencv-python
# Out:
# Collecting pytesseract
#   Downloading pytesseract-0.3.10-py3-none-any.whl (14 kB)
# Requirement already satisfied: packaging>=21.3 in c:\users\new\anaconda3\envs\cakd7\lib\site-packages (from pytesseract) (21.3)
# Requirement already satisfied: Pillow>=8.0.0 in c:\users\new\anaconda3\envs\cakd7\lib\site-packages (from pytesseract) (9.0.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\new\anaconda3\envs\cakd7\lib\site-packages (from packaging>=21.3->pytesseract) (3.0.4)
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.3.10
# Requirement already satisfied: Pillow in c:\users\new\anaconda3\envs\cakd7\lib\site-packages (9.0.1)

# %% [markdown]
# ### 와인 이미지 내 텍스트 추출

# %%
import numpy as np
from pytesseract import Output
import pytesseract
import cv2
from PIL import Image

# %%
img1 = np.array(Image.open('C:/cakd7/cakd7_class/와인추천솔루션/이미지인식_test.jpg'))
text = pytesseract.image_to_string(img1)
print(text)

# %%
import pytesseract

pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract'

text = pytesseract.image_to_string('wine_이미지인식_오레무스드라이만돌라스.jpg',
                                    lang = 'kor+eng', 
                                    config = '-c preserve_interword_space=1 --psm 4')
text
# Out:
# ' \n\n세품명 | 오레무스 드라이 만돌라스 |제조번호|현품별도표기 |내용량 및 알코올 |/500Ｌ, 현품별도표기\n(주) 신세계엘앤비 [6102-727-1685             :\nNESS)) B27 Obstsle 563, HSINAINS 78[4BCs| Ta DEES\n 수입업소 또는 구입처\n\n보관방법|취급은 신중히 서늘한 응달에 보관| 부정 불량 식품 신고는 국번없이 1399 해\\0[41\n\n손상이나 지매들 유발합니다.\n\n임신 중 음주는 기형마 출생 위험을 높입니다.\n\n \n\x0c'

# %%
import pytesseract

pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract'

text2 = pytesseract.image_to_string('wine_인식_투바인샤도네이.jpg',
                                    lang = 'kor+eng', 
                                    config = '-c preserve_interword_space=1 --psm 4')
text2
# Out:
# '  \n    \n \n\nTWO VINES\n\n2018\nCHARDONNAY\nWASHINGTON STATE\n\n^\n\x0c'

# %% [markdown]
# ### 와인이름에 해당하는 단어만 추출

# %% [markdown]
# #### trial

# %%
# 라벨 내 글씨 전처리
import re
text_in_label = re.sub('\s+','',text)


# 크롤링 데이터프레임 내 와인이름 리스트 만들기
import pandas as pd

wine_df = pd.read_csv('wine_final_real.csv')



# 와인이름 내 텍스트 종류 분석
wine_li = wine_df['와인이름'].tolist()

all_str = []
for name in wine_li:
    for n in name:
        all_str.append(n)
print(set(all_str))


# 삭제해야하는 단어 지정
stopword = [' ', '&',',','‘','’','“','”']


# 정규표현식으로 제거
wine_li_str = []
for name in wine_li:
    for s in stopword:
        name = re.sub(s, '', name)
    wine_li_str.append(name)
wine_li_str
# Out:
# {'럼', '두', '섹', '솔', '베', '페', '만', '냐', '로', '오', '르', '패', '폰', '겔', '위', '뀌', 'D', '산', '뒤', '몽', '터', '무', '래', '웬', '앵', '펄', '쉔', '자', '허', '톨', '루', '저', '년', '폴', '칸', '월', '당', '렉', '워', '판', '펠', '벡', '‘', '뮈', '쉬', '세', '제', '올', '0', '샬', '린', '츠', '달', '&', '댕', '히', '셉', '뇨', '타', '노', '에', '칼', '익', '랭', '나', '떼', '푀', '탄', '든', '푸', '리', '슈', '사', '시', '차', 'S', '아', '플', '벙', 'V', '롱', '튀', '뒥', '1', '캐', '벨', '골', '깐', '뚜', '치', '댄', '뤼', '지', '커', '람', '띠', '밀', '부', '슬', '넬', '진', '토', '델', '쉴', '따', '장', '포', '고', '용', '운', 'C', '슐', '우', '딘', '씨', '젤', '를', '수', 'G', '케', '투', 'T', '쉐', '몬', '후', '말', '뱅', '스', '쥐', '가', '버', '렌', '쁘', '”', ',', '랑', '인', '룸', '실', '또', '블', '즐', '뫼', '셰', '릴', '’', '엑', '랄', '릭', '윌', '티', '까', '미', '게', '바', '꿀', '크', '꼬', '꼴', '쟈', '갈', '유', 'I', '보', '디', '라', '데', '5', '물', '러', '조', '돈', '어', '넷', '닉', '쓰', '트', '드', '파', '뿌', '멜', '듀', '톤', '핸', '프', '방', '생', '그', '름', '기', '일', '션', '퓌', '륀', '뜨', '안', '반', '코', '켈', '거', 'O', '비', '옹', '꽁', '죠', '3', '쿨', '소', '엘', '엠', '쥬', '므', '클', '셀', '구', '뇽', '멘', '힐', '온', '헤', '펜', '론', '뿔', '꾸', '와', '존', '헨', '빈', '밸', '샤', '숌', '본', '삐', '똥', '셸', '더', '살', '막', '엔', '링', '갸', '쏘', '모', '레', '다', '체', '릿', '뉘', '알', '화', '틴', '퀸', '뽀', '질', '“', '넨', '흐', ' ', '야', '락', '멧', '니', '하', '팔', '테', '마', '도', '누', '느', '롤', '땡', '카', '랜', '메', '핀', '샴', '탈', '즈', '던', '볼', '끌', '럴', '돔', '키', '날', '배', '2', '젠', '슨', '4', '콜', '발', '쑤', '렐', '즌', '샹', '퇴', '성', '상', '7', '네', '맹', 'H', '켄', '앙', '싱', '이', '초', '악', '륏', '너', '돌', '콘', '푼', '센', '신', 'R', '피', '륄', '뉴', '글', '빌', '브', '첼', '서', '란', '롬'}
# ['이기갈꼬뜨뒤론레드',
#  '이기갈꼬뜨뒤론화이트',
#  '이기갈꼬뜨로띠브륀블롱드',
#  '이기갈꼬뜨로띠샤또당퓌',
#  '이기갈꽁드리유',
#  '이기갈생조셉레드',
#  '이기갈에르미따쥐레드',
#  '이기갈에르미따쥐화이트',
#  '이기갈에르미따쥐엑스보또화이트',
#  '이기갈크로즈에르미따쥐레드',
#  '아차발페레멘도사말벡',
#  '아차발페레핀까벨라비스타',
#  '아차발페레키메라',
#  '아차발페레핀까미라도',
#  '솔라시오로쏘',
#  '스칼리올라돌체스바고',
#  '지오코피오레',
#  '파르팔레모스카토다스티',
#  '아조르드몬페라토로쏘',
#  '스칼리올라피에몬테샤르도네',
#  '지디바이라바롤로브리코델레비올레',
#  '지디바이라랑게프레이사키에',
#  '에고메이',
#  '플로라',
#  '프리츠그뤼너벨트리너바그람',
#  '피치니키안티',
#  '메모로화이트',
#  '피치니키안티클라시코',
#  '피치니키안티리제르바꼴레지오네오로',
#  '피치니브루넬로디몬탈치노',
#  '피치니브루넬로디몬탈치노리제르바',
#  '사쏘알포지오',
#  '도멘베르따냐부죠블랑프르미에크뤼레크라',
#  '생클레어파이오니어블락14피노누아',
#  '생클레어파이오니어블락소비뇽블랑',
#  '엘푼티도',
#  '시에라깐따브리아크리안자',
#  '시에라깐따브리아그란레세르바',
#  '시에라깐따브리아꼴레시온프리바다',
#  '랭윌라멧밸리피노누아',
#  '랭윌라멧밸리리저브피노누아',
#  '랭쓰리힐뀌베피노누아',
#  '랭에스테이트빈야드피노누아',
#  '샤또몽페라화이트',
#  '지롤라트',
#  '토후말보로피노누아',
#  '토후말보로로어리저브피노누아',
#  '토후말보로샤르도네',
#  '토후말보로무그위리저브소비뇽블랑',
#  '알파로린제이페이지샤르도네',
#  '샤또뚜르데장드르콘티네페리구르딘',
#  '샤또뚜르데장드르안솔로지아',
#  '바로크버블리화이트',
#  '바로크화이트빈241',
#  '도멘드루앵던디힐샤르도네아서',
#  '도멘드루앵던디힐피노누아',
#  '빌까르살몽끌로생힐레르',
#  '뀌베엘리자베스살몽로제',
#  '까르따비에하까베르네소비뇽',
#  '까르따비에하까르메네르',
#  '까르따비에하메를로',
#  '까르따비에하샤르도네',
#  '워터스톤까베르네소비뇽',
#  '워터스톤메를로',
#  '캐년로드까베르네소비뇽',
#  '캐년로드메를로',
#  '캐년로드화이트진판델',
#  '캐년로드샤르도네',
#  '캐년로드모스카토',
#  '막소렐에르미타쥐루즈',
#  '르리쉬까베르네소비뇽리저브',
#  '르리쉬까베르네소비뇽',
#  '르리쉬까베르네메를로',
#  '르리쉬샤르도네',
#  '라인가우리슬링키드리히그래펜베르그스패트레제',
#  '라인가우리슬링키드리히그래펜베르그아우스레제',
#  '벨레너존넨누어리슬링카비넷파인헤르브',
#  '벨트악스아이스바인',
#  '벨트악스아우스레제',
#  '벨트악스베어렌아우스레제',
#  '벨트악스트로켄베어렌아우스레제',
#  '벨트악스돈펠더',
#  '핀까엘오리엔그란레세르바말벡',
#  '핀까엘오리엔레세르바말벡',
#  '핀까엘오리엔레세르바까베르네소비뇽',
#  '핀까엘오리엔말벡',
#  'G7레세르바까베르네소비뇽',
#  'G7레세르바까르메네르',
#  'G7레세르바샤르도네',
#  'G7까베르네소비뇽',
#  'G7메를로',
#  'G7샤르도네',
#  '운두라가스파클링드미섹',
#  'TH까베르네소비뇽',
#  'TH시라',
#  '뿌삐유',
#  '메오까뮈제본느로마네프르미에크뤼레숌므',
#  '메오까뮈제뉘생조르쥬프르미에크뤼부도',
#  '메오까뮈제뉘생조르쥬프르미에크뤼페리에르',
#  '메오까뮈제샹볼뮈지니프르미에크뤼레푀슬로트',
#  '메오까뮈제본느로마네프리미에크뤼오브륄레',
#  '미셀마니앙마르사네블랑',
#  '미셀마니앙쥐브리샹베르땡레소브레비에유비뉴',
#  '미셀마니앙본느로마네비에유비뉴',
#  '미셀마니앙쥐브리샹베르땡프르메에크뤼레카즈띠에',
#  '미셀마니앙샹볼뮈지니프르미에크뤼레성티에',
#  '미셀마니앙샤름샹베르땡',
#  '에고메이알마',
#  '로스바스코스그랑리저브까베르네소비뇽',
#  '부켈라까베르네소비뇽',
#  '부켈라미카',
#  '러버스와인버블리로제',
#  '러버스와인버블리화이트',
#  '프랑수아미쿨스키뫼르소',
#  '프랑수아미쿨스키뫼르소프르미에크뤼레샤르므',
#  '프랑수아미쿨스키뫼르소프르미에크뤼레뽀르조',
#  '피치니파트리알레',
#  '돔리슬링트로켄',
#  '스칼리올라프리모바치오모스카토다스티',
#  '돔리슬링프루티',
#  '생클레어오마카리저브샤르도네',
#  '생클레어비카스초이스소비뇽블랑스파클링',
#  '토카이아쑤에센시아',
#  '오레무스토카이드라이만돌라스',
#  '토카이아쑤5푸토뇨스',
#  '이기갈꼬뜨로띠라랑돈',
#  '이기갈꼬뜨로띠라튀르크',
#  '이기갈꼬뜨로띠라물린',
#  '미안더화이트모스카토',
#  '핀까엘오리엔파이',
#  '이기갈에르미따쥐엑스보또루즈',
#  '르리쉬리쉐스',
#  '케익브레드나파밸리소비뇽블랑',
#  '케익브레드투크릭빈야드피노누아',
#  '케익브레드나파밸리메를로',
#  '베떼디산레오나르도',
#  '떼레디산레오나르도',
#  '로버트바일키드리히그래펜베르그아이스바인',
#  '루이자도꼬르똥샤를마뉴그랑크뤼',
#  '루이자도끌로드라로쉬그랑크뤼',
#  '루이자도마꽁빌라쥐',
#  '루이자도바따르몽라셰그랑크뤼',
#  '루이자도본프르미에크뤼끌로데우르쉴모노폴',
#  '루이자도본그레브프르미에크뤼르끌로블랑',
#  '루이자도볼네프르미에크뤼끌로드라바르모노폴',
#  '루이자도부르고뉴루즈꾸벙데쟈꼬뱅',
#  '루이자도부르고뉴블랑꾸벙데쟈꼬뱅',
#  '루이자도상뜨네레드끌로드말트',
#  '루이자도샤블리프르미에크뤼푸르숌므',
#  '루이자도샤블리',
#  '루이자도샤사뉴몽라셰',
#  '루이자도샤펠샹베르땡그랑크뤼',
#  '루이자도도멘뒥드마젠타뿔리니몽라셰프르미에크뤼끌로드라갸렌느',
#  '루이자도도멘뒥드마젠타샤사뉴몽라셰프르미에크뤼모르조끌로드라샤펠모노폴',
#  '칸티모스카토다스티',
#  '칸티모스카토콜레지오네디파밀리아',
#  '샹파뉴살롱S',
#  '루이자도꼬뜨드본빌라쥐레드',
#  '루이자도모레생드니프르미에크뤼끌로데조름',
#  '루이자도본프르미에크뤼퇴롱',
#  '루이자도뽀마르',
#  '루이자도뿌이퓌세',
#  '루이자도쥐브리샹베르땡',
#  '도멘페레뿌이퓌세르끌로',
#  '칸티프로세코',
#  '칸티피에몬테브라케토',
#  '케익브레드댄싱베어랜치',
#  '아차발페레핀까알타미라',
#  '이기갈생조셉비뉴드로스피스',
#  '쁘띠폴리',
#  '로치올리에스테이트피노누아',
#  '로치올리에스테이트샤르도네',
#  '트웬티비스비달아이스와인',
#  '시즌스비달아이스와인',
#  '샤또오카디날생떼밀리옹그랑크뤼',
#  '폰토디비냐데소르보키안티클라시코그란셀레지오네',
#  '폰토디키안티클라시코',
#  '코노수르싱글빈야드까베르네소비뇽',
#  '코노수르싱글빈야드까르메네르',
#  '코노수르싱글빈야드메를로',
#  '코노수르싱글빈야드시라',
#  '코노수르싱글빈야드샤르도네',
#  '코노수르레세르바에스페샬까베르네소비뇽',
#  '코노수르레세르바에스페샬까르메네르',
#  '코노수르레세르바에스페샬메를로',
#  '코노수르레세르바에스페샬샤르도네',
#  '코노수르비씨클레타까베르네소비뇽',
#  '코노수르비씨클레타까르메네르',
#  '코노수르비씨클레타피노누아',
#  '코노수르1551까베르네소비뇽',
#  '코노수르1551샤르도네',
#  '코노수르실렌시오',
#  '코노수르오씨오',
#  '코노수르20배럴피노누아',
#  '코노수르20배럴메를로',
#  '코노수르20배럴샤르도네',
#  '코노수르20배럴까베르네소비뇽',
#  '지디바이라모스카토다스티',
#  '코노수르스파클링브륏로제',
#  '토후말보로소비뇽블랑',
#  '퀸오브몽페라레드',
#  '퀸오브몽페라화이트',
#  '오레무스토카이아쑤3푸토뇨스',
#  '피치니그란프루넬로',
#  '루이자도꼬뜨드뉘빌라쥐르보크랭',
#  '루스토VORS페드로히메네즈',
#  '루이자도부르고뉴알리고떼',
#  '칸티모스카토다스티DOCG골드에디션',
#  '코노수르비씨클레타메를로',
#  '레드다이아몬드샤르도네',
#  '레드다이아몬드메를로',
#  '레드다이아몬드쉬라즈',
#  '레드다이아몬드피노누아',
#  '레드다이아몬드까베르네소비뇽',
#  '콜롬비아크레스트그랜드에스테이트샤르도네',
#  '콜롬비아크레스트그랜드에스테이트까베르네소비뇽',
#  '콜롬비아크레스트그랜드에스테이트메를로',
#  '콜롬비아크레스트그랜드에스테이트시라',
#  '콜롬비아크레스트리저브까베르네소비뇽',
#  '콜롬비아크레스트리저브레드월터클로어',
#  '투바인까베르네소비뇽',
#  '투바인메를로',
#  '투바인쉬라즈',
#  '투바인샤르도네',
#  '콜롬비아크레스트H3샤르도네',
#  '콜롬비아크레스트H3까베르네소비뇽',
#  '콜롬비아크레스트H3메를로',
#  '루이자도샹볼뮈지니',
#  '자이에질부르고뉴오뜨꼬뜨드본블랑',
#  '자이에질부르고뉴오뜨꼬뜨드뉘루즈',
#  '투핸즈아레스쉬라즈',
#  '투핸즈아프로디테까베르네소비뇽',
#  '투핸즈싱글빈야드시크릿블락쉬라즈',
#  '투핸즈싱글빈야드야카블락쉬라즈',
#  '투핸즈싱글빈야드와차블락쉬라즈',
#  '투핸즈싱글빈야드코치하우스블락쉬라즈',
#  '투핸즈릴리스가든쉬라즈',
#  '투핸즈벨라스가든쉬라즈',
#  '투핸즈더보이리슬링',
#  '투핸즈날리듀즈',
#  '투핸즈브레이브페이스',
#  '투핸즈섹시비스트까베르네소비뇽',
#  '투핸즈엔젤스쉐어쉬라즈',
#  '그롱네까르페디엠엑스트라브륏',
#  '빌라그레스티디산레오나르도',
#  '브루노미셸라드미륀브륏',
#  '브루노미셸레브루스프르미에크뤼브륏',
#  '샤또뒤세드르',
#  '엑스트라리브르',
#  '엑스트라리브르르세드르',
#  '브루노지아코사팔레토돌체토달바',
#  '펄루나파밸리까베르네소비뇽',
#  '르피치나파밸리까베르네소비뇽',
#  '존스시스터까베르네소비뇽',
#  '마카신피노누아',
#  '마카신샤르도네',
#  '니콜슨존스셀러샤르도네',
#  '부커마이페이버릿네이버',
#  '키드리히그래펜베르그리슬링트로켄GG',
#  '투핸즈아에로페그르나쉬',
#  '샤또레스트릴까마르땡레드',
#  '코노수르비씨클레타게부르츠트라미너',
#  '코노수르싱글빈야드리슬링',
#  '라세그레타로쏘',
#  '라세그레타비앙코',
#  '플라네타부르데제',
#  '플라네타샤르도네',
#  '플라네타알라스트로',
#  '플라네타플럼바고',
#  '플라네타코메타',
#  '플라네타에트나로쏘',
#  '플라네타에트나비앙코',
#  '로저뿌이용레블랑쉬엔',
#  '로저뿌이용슈맹뒤부아',
#  '에이슬빈야드소비뇽블랑',
#  '이기갈에르미타쥐루즈아트레이블',
#  '토코르날샤르도네',
#  '그라허히멜라히리슬링카비넷트로켄',
#  '브라우네베르거쥬페리슬링카비넷',
#  '에르데너트레쉔리슬링슈페트레제',
#  '에스테이트리슬링',
#  '도멘슐룸베르거게부르츠트라미너',
#  '도멘슐룸베르거리슬링',
#  '도멘슐룸베르거피노그리',
#  '도멘슐룸베르거게부르츠트라미너케슬러그랑크뤼',
#  '도멘슐룸베르거리슬링사에링그랑크뤼',
#  '도멘슐룸베르거피노그리슈피겔그랑크뤼',
#  '도멘슐룸베르거게부르츠트라미너뀌베안느셀렉시옹그랑노블',
#  '도멘슐룸베르거게부르츠트라미너뀌베크리스틴방당쥬따르디브',
#  '즐라탄오토크플라바치그랑크뤼',
#  '즐라탄오토크뀌베레드',
#  '즐라탄오토크흐바르화이트',
#  '즐라탄오토크플라바치',
#  '즐라탄오토크플라바치오가닉',
#  '콜로살레세르바화이트',
#  '콜로살레세르바레드',
#  '퀸타두에스페리토산토레드',
#  '퀸타두에스페리토산토레세르바',
#  '팔하카나스화이트',
#  '팔하카나스레드',
#  '팔하카나스레세르바',
#  '브리갈다라발폴리첼라',
#  '브리갈다라발폴리첼라수페리오레까세베체',
#  '브리갈다라리파소수페리오레',
#  '브리갈다라아마로네클라시코',
#  '브리갈다라아마로네까세베체',
#  '브리갈다라레치오토',
#  '브리갈다라소아베',
#  '톨라이니발디산티토스카나IGT',
#  '톨라이니피코네로토스카나IGT',
#  '카바이라반',
#  '플라네타로제',
#  '코노수르비씨클레타피노누아리미티드에디션',
#  '샴페인르그레미네랄',
#  '엘빈꿀로파라헤라골로사그란레세르바',
#  '샴페인코피네자댕소바쥬',
#  '부켈라까베르네소비뇽아트레이블',
#  '까테나자파타알라모스토론테스',
#  '까테나자파타알라모스말벡',
#  '까테나자파타까테나샤르도네',
#  '까테나자파타까테나말벡',
#  '까테나자파타까테나알타샤르도네',
#  '까테나자파타까테나알타말벡',
#  '까테나자파타니카시아말벡',
#  '까테나자파타아르헨티노말벡']

# %% [markdown]
# #### 라벨 및 데이터프레임 내 텍스트 전처리

# %% [markdown]
# ##### 한국어 버전

# %%
# 라벨 이미지 내 텍스트 추출
import pytesseract

pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract'

text = pytesseract.image_to_string('wine_인식_투바인샤도네이.jpg',
                                    lang = 'kor+eng', 
                                    config = '-c preserve_interword_space=1 --psm 4')

import pandas as pd
wine_df = pd.read_csv('wine_final_real.csv')

# 라벨 텍스트에서 텍스트, 숫자로만 이루어진 단어 추출
word_li = re.findall('\w+',text)



# 데이터프레임 내 와인 이름 단어 추출
wine_li = wine_df['와인이름'].tolist()

# 삭제해야하는 단어 지정
stopword = ['&',',','‘','’','“','”']


# 정규표현식으로 삭제해야하는 단어 제거
# 띄어쓰기제거 한 와인이름 리스트도 생성
wine_li_delete_stopword = []
wine_li_delete_blank = []
for name in wine_li:
    for s in stopword:
        name = re.sub(s, '', name)
        name2 = re.sub('\s','', name)
    wine_li_delete_stopword.append(name)
    wine_li_delete_blank.append(name2)
    
# 데이터프레임 내 와인이름 단어 리스트 중복 제거
wine_str_set = list(set(' '.join(wine_li_delete_stopword).split()))


# 중복제거된 와인이름 단어 리스트 내 존재하면 찾아야할 와인이름 완성하기
wine_name = ''
for w in word_li:
    if w in wine_str_set:
        wine_name += w
print(wine_name)



# 해당 와인 이름과 85% 이상 일치하는 와인 인덱스 불러오기
from difflib import SequenceMatcher

for idx, df_wine_name in enumerate(wine_li_delete_blank):
    if SequenceMatcher(None, df_wine_name, wine_name).ratio() > 0.8:
        display(wine_df.loc[idx])

# %% [markdown]
# ##### 영어버전

# %%
# 라벨 이미지 내 텍스트 추출
import pytesseract

pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract'

text = pytesseract.image_to_string('wine_인식_투바인샤도네이.jpg',
                                    lang = 'kor+eng', 
                                    config = '-c preserve_interword_space=1 --psm 4')

import pandas as pd
wine_df = pd.read_csv('wine_final_real.csv')

# 라벨 텍스트에서 텍스트, 숫자로만 이루어진 단어 추출
word_li = [word.lower() for word in re.findall('\w+',text)]
print(word_li)
# Out:
# ['two', 'vines', '2018', 'chardonnay', 'washington', 'state']

# %%
# 데이터프레임 내 와인 이름 단어 추출
wine_li = wine_df['영어이름'].tolist()


# 삭제해야하는 단어 지정하기 위해 모든 글자 추출 
all_str = []
for name in wine_li:
    for n in name:
        all_str.append(n)
# print(set(all_str))

# 삭제해야하는 단어 지정
stopword = ['\"','&', "\'", '\(', '\)', ',', '-', '[.]', '/','‘','’','“','”']



# 정규표현식으로 삭제해야하는 단어 제거
# 띄어쓰기제거 한 와인이름 리스트도 생성
wine_li_delete_stopword = []
wine_li_delete_blank = []
for name in wine_li:
    name = name.lower()
    for s in stopword:
        name = re.sub(s, '', name)
        name2 = re.sub('\s','', name)
    wine_li_delete_stopword.append(name)
    wine_li_delete_blank.append(name2)

    
# 데이터프레임  와인이름 단어 리스트 중복 제거
wine_str_set = list(set(' '.join(wine_li_delete_stopword).split()))


# 중복제거된 와인이름 단어 리스트 내 존재하면 찾아야할 와인이름 완성하기
wine_name = ''
for w in word_li:
    if w in wine_str_set:
        wine_name += w
print(wine_name)



# 해당 와인 이름과 85% 이상 일치하는 와인 인덱스 불러오기
from difflib import SequenceMatcher

for idx, df_wine_name in enumerate(wine_li_delete_blank):
    if SequenceMatcher(None, df_wine_name, wine_name).ratio() > 0.8:
        display(wine_df.loc[idx])
# Out:
# twovineschardonnay
# Unnamed: 0                                                   223
# 와인이름                                                   투바인 샤르도네
# 영어이름                                        Two Vines Chardonnay
# 와인타입                                                      화이트 와인
# 나라, 와이너리                                    미국 > 워싱턴 / 콜럼비아 크레스트
# 한줄소개           세계적인 와인전문지에서 Best Value, Best Buy 와인으로 추천받은 투바...
# 포도종                                            샤르도네 89%, 블렌딩 11%
# 도수                                                          13.0
# 당도                                                             1
# 산도                                                             3
# 바디                                                             3
# 와이너리이름                                 콜럼비아 크레스트  Columbia Crest
# 와이너리설명         콜롬비아 크레스트는 워싱턴 주 전체 수출량의 85%, 전체 생산량의 75%를 점유하...
# 와이너리특징         미국의 떠오르는 와인산지 워싱턴 주의 대표 와이너리\r포도재배에 최적화된 자연환경을...
# 아로마 딕셔너리       {'자연(Earthy)': ['토양'], '오크(Oak)': ['코코넛'], '유산...
# 곁들일 음식            크림소스 파스타, 랍스터 등 각종 해산물 요리, 치킨, 담백하게 구운 돼지고기 요리
# 음식                                                     육류 해산물 양식
# 상황별추천 군집화                                                 가족과 함께
# 상황별추천 군집화_n                                                    0
# 추천솔루션 군집화                                         어른입맛 WHITE 술청년
# 추천솔루션 군집화_n                                                    1
# Name: 223, dtype: object

# %% [markdown]
# #### 국/영문 합친 버전

# %% [markdown]
# ##### 데이터프레임 내 와인이름(국문/영문) 전처리

# %%
import pandas as pd
wine_df = pd.read_csv('wine_final_real.csv')

# 데이터프레임 내 와인 이름 단어 추출
wine_li_ko = wine_df['와인이름'].tolist()
wine_li_en = wine_df['영어이름'].tolist()



# 삭제해야하는 단어 지정하기 위해 모든 글자 추출 
all_str_ko = []
for name in wine_li_ko:
    for n in name:
        all_str_ko.append(n)

all_str_en = []
for name in wine_li_en:
    for n in name:
        all_str_en.append(n)


# 삭제해야하는 단어 지정
stopword_ko = ['&',',','‘','’','“','”']
stopword_en = ['\"','&', "\'", '\(', '\)', ',', '-', '[.]', '/','‘','’','“','”']



# 정규표현식으로 삭제해야하는 단어 제거
# 띄어쓰기제거 한 와인이름 리스트도 생성

wine_li_delete_stopword_ko = []
wine_li_delete_blank_ko = []
for name in wine_li_ko:
    for s in stopword_ko:
        name = re.sub(s, '', name)
        name2 = re.sub('\s','', name)
    wine_li_delete_stopword_ko.append(name)
    wine_li_delete_blank_ko.append(name2)
    



wine_li_delete_stopword_en = []
wine_li_delete_blank_en = []
for name in wine_li_en:
    name = name.lower()
    for s in stopword_en:
        name = re.sub(s, '', name)
        name2 = re.sub('\s','', name)
    wine_li_delete_stopword_en.append(name)
    wine_li_delete_blank_en.append(name2)

    
# 데이터프레임 내 와인이름 단어 리스트 중복 제거
wine_str_set_ko = list(set(' '.join(wine_li_delete_stopword_ko).split()))
wine_str_set_en = list(set(' '.join(wine_li_delete_stopword_en).split()))

# %% [markdown]
# ##### 이미지 내 텍스트

# %%
# 라벨 이미지 내 텍스트 추출
import pytesseract

pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract'

# text = pytesseract.image_to_string('wine_인식_투바인샤도네이.jpg',
#                                     lang = 'kor+eng', 
#                                     config = '-c preserve_interword_space=1 --psm 4')

text = pytesseract.image_to_string('wine_이미지인식_오레무스드라이만돌라스.jpg',
                                    lang = 'kor+eng', 
                                    config = '-c preserve_interword_space=1 --psm 4')

# 라벨 텍스트에서 텍스트, 숫자로만 이루어진 단어 추출
word_li = [word.lower() for word in re.findall('\w+',text)]


# 한국어인지 영어인지 확인하는 사용자함수
def is_English_Korean(str):
    k_cnt, e_cnt = 0, 0
     
    for s in str:
        # ord: 문자의 유니코드 값을 돌려주는 함수
        if ord('가') <= ord(s) <= ord('힣'):
            k_cnt += 1
        elif ord('a') <= ord(s.lower()) <= ord('z'):
            e_cnt += 1
            
    return "한국어" if k_cnt > e_cnt else "영어"



lang_wine = is_English_Korean(''.join(text))
# print(text, is_English_Korean(''.join(text)))





# 중복제거된 와인이름 단어 리스트 내 존재하면 찾아야할 와인이름 완성하기
# 해당 와인 이름과 85% 이상 일치하는 와인 인덱스 불러오기
from difflib import SequenceMatcher

if lang_wine == '한국어':
    wine_name = ''
    for w in word_li:
        if w in wine_str_set_ko:
            wine_name += w
            
    for idx, df_wine_name in enumerate(wine_li_delete_blank_ko):
        if SequenceMatcher(None, df_wine_name, wine_name).ratio() > 0.8:
            display(wine_df.loc[idx])
else:
    wine_name = ''
    for w in word_li:
        if w in wine_str_set_en:
            wine_name += w
    for idx, df_wine_name in enumerate(wine_li_delete_blank_en):
        if SequenceMatcher(None, df_wine_name, wine_name).ratio() > 0.8:
            display(wine_df.loc[idx])
# Out:
# Unnamed: 0                                                   123
# 와인이름                                           오레무스 토카이 드라이 만돌라스
# 영어이름                                  Oremus Tokaji Dry Mandolas
# 와인타입                                                      화이트 와인
# 나라, 와이너리                                    헝가리 > 더 노스이스트 / 오레무스
# 한줄소개                                     헝가리 토카이 지방의 드라이 화이트 와인
# 포도종                                                     푸르민트100%
# 도수                                                          13.0
# 당도                                                             1
# 산도                                                             3
# 바디                                                             3
# 와이너리이름                                              오레무스  Oremus
# 와이너리설명         헝가리가 공산주의 사회였던 시절의 국영 와인 회사 코르콤비나트가 1993년 해체되면...
# 와이너리특징         세계정상급 디저트 와인 토카이의 명가\r스페인의 전설적인 와인생산자 베가 시실리아 ...
# 아로마 딕셔너리       {'녹색 과일': ['배'], '시트러스': ['라임'], '핵과': ['복숭아',...
# 곁들일 음식                                     신선한샐러드,담백한닭고기요리,흰살생선류
# 음식                                                  육류 해산물 에피타이저
# 상황별추천 군집화                                                 가족과 함께
# 상황별추천 군집화_n                                                    0
# 추천솔루션 군집화                                         어른입맛 WHITE 술청년
# 추천솔루션 군집화_n                                                    1
# Name: 123, dtype: object

# %% [markdown]
# #### 국/영문 합친 버전(전체)

# %%
import numpy as np
from pytesseract import Output
import pytesseract
import cv2
from PIL import Image
import re
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [2], in <cell line: 2>()
#       1 import numpy as np
# ----> 2 from pytesseract import Output
#       3 import pytesseract
#       4 import cv2
#
# ModuleNotFoundError: No module named 'pytesseract'

# %% [markdown]
# ##### 데이터프레임 내 와인이름(국문/영문) 전처리

# %%
wine_df
# Out:
#                      와인이름                                           영어이름  \
# 0           이기갈 꼬뜨 뒤 론 레드                  E.Guigal Cotes du Rhone Rouge
# 1          이기갈 꼬뜨 뒤 론 화이트                  E.Guigal Cotes du Rhone Blanc
# 2    이기갈 꼬뜨 로띠 ‘브륀 & 블롱드’  E.Guigal Cot-Rotie ‘Brune & Blonde de Guigal’
# 3       이기갈 꼬뜨 로띠 ‘샤또 당퓌’         E.Guigal Cote-Rotie ‘Chateau d’Ampuis’
# 4                이기갈 꽁드리유                              E.Guigal Condrieu
# ..                    ...                                            ...
# 320        까테나 자파타 까테나 말벡                    Catena Zapata Catena Malbec
# 321   까테나 자파타 까테나 알타 샤르도네          Catena Zapata Catena Alta Chardonnay
# 322     까테나 자파타 까테나 알타 말벡               Catena Zapata Catena Alta Malbec
# 323       까테나 자파타 니카시아 말벡                   Catena Zapata Nicasia Malbec
# 324      까테나 자파타 아르헨티노 말벡                 Catena Zapata Argentino Malbec
#
#        와인타입               나라, 와이너리  \
# 0     레드 와인         프랑스 > 론 / 이 기갈
# 1    화이트 와인         프랑스 > 론 / 이 기갈
# 2     레드 와인         프랑스 > 론 / 이 기갈
# 3     레드 와인         프랑스 > 론 / 이 기갈
# 4    화이트 와인         프랑스 > 론 / 이 기갈
# ..      ...                    ...
# 320   레드 와인  아르헨티나 > 멘도자 / 까테나 자파타
# 321  화이트 와인  아르헨티나 > 멘도자 / 까테나 자파타
# 322   레드 와인  아르헨티나 > 멘도자 / 까테나 자파타
# 323   레드 와인  아르헨티나 > 멘도자 / 까테나 자파타
# 324   레드 와인  아르헨티나 > 멘도자 / 까테나 자파타
#
#                                            한줄소개  \
# 0    "King of the Rhone"으로 불리는 E.Guigal의 와인입니다.
# 1    "King of the Rhone"으로 불리는 E.Guigal의 와인입니다.
# 2    "King of the Rhone"으로 불리는 E.Guigal의 와인입니다.
# 3    "King of the Rhone"으로 불리는 E.Guigal의 와인입니다.
# 4    "King of the Rhone"으로 불리는 E.Guigal의 와인입니다.
# ..                                          ...
# 320                부드러운 탄닌감과 선명한 산도의 말벡 100% 와인
# 321          최적의 시기에 수확한 포도를 선별해 만든 아르헨티나 화이트와인
# 322           최적의 시기에 수확한 포도를 선별해 만든 아르헨티나 레드와인
# 323           까테나 자파타 최고도 빈야드에서 생산되는 100% 말벡 와인
# 324                      열정의 나라, 아르헨티나의 프리미엄 와인
#
#                                               포도종    도수  당도  산도  바디  \
# 0                      시라 49%, 그르나쉬 48%, 무르베드르 3%  13.0   1   2   4
# 1    비오니에 70%, 루산느 10%, 마르산느 9%, 끌레레뜨 8%, 부르불랑 3%  13.0   1   3   3
# 2                                 시라 96%, 비오니에 4%  13.0   1   3   5
# 3                                 시라 93%, 비오니에 7%  13.0   1   3   5
# 4                                       비오니에 100%  13.0   1   3   4
# ..                                            ...   ...  ..  ..  ..
# 320                                       말백 100%  14.0   1   3   3
# 321                                     샤르도네 100%  13.0   2   3   4
# 322                                       말백 100%  14.0   1   3   4
# 323                                       말벡 100%  14.0   1   3   5
# 324                                       말벡 100%  14.0   1   4   5
#
#                      와이너리이름  \
# 0            이 기갈  E.Guigal
# 1            이 기갈  E.Guigal
# 2            이 기갈  E.Guigal
# 3            이 기갈  E.Guigal
# 4            이 기갈  E.Guigal
# ..                      ...
# 320  까테나 자파타  Catena Zapata
# 321  까테나 자파타  Catena Zapata
# 322  까테나 자파타  Catena Zapata
# 323  까테나 자파타  Catena Zapata
# 324  까테나 자파타  Catena Zapata
#
#                                                 와이너리설명  \
# 0    이기갈(E.Guigal)은 오늘날 프랑스 론 최고의 생산자로 꼽힌다. 1946년 에...
# 1    이기갈(E.Guigal)은 오늘날 프랑스 론 최고의 생산자로 꼽힌다. 1946년 에...
# 2    이기갈(E.Guigal)은 오늘날 프랑스 론 최고의 생산자로 꼽힌다. 1946년 에...
# 3    이기갈(E.Guigal)은 오늘날 프랑스 론 최고의 생산자로 꼽힌다. 1946년 에...
# 4    이기갈(E.Guigal)은 오늘날 프랑스 론 최고의 생산자로 꼽힌다. 1946년 에...
# ..                                                 ...
# 320  까테나 자파타(Catena Zapata)는 아르헨티나 멘도자의 와인을 전 세계에 제...
# 321  까테나 자파타(Catena Zapata)는 아르헨티나 멘도자의 와인을 전 세계에 제...
# 322  까테나 자파타(Catena Zapata)는 아르헨티나 멘도자의 와인을 전 세계에 제...
# 323  까테나 자파타(Catena Zapata)는 아르헨티나 멘도자의 와인을 전 세계에 제...
# 324  까테나 자파타(Catena Zapata)는 아르헨티나 멘도자의 와인을 전 세계에 제...
#
#                                                 와이너리특징  \
# 0    "King of the Rhone" - 영국의 와인전문지 <디캔터(Decanter)...
# 1    "King of the Rhone" - 영국의 와인전문지 <디캔터(Decanter)...
# 2    "King of the Rhone" - 영국의 와인전문지 <디캔터(Decanter)...
# 3    "King of the Rhone" - 영국의 와인전문지 <디캔터(Decanter)...
# 4    "King of the Rhone" - 영국의 와인전문지 <디캔터(Decanter)...
# ..                                                 ...
# 320  아르헨티나 고급 와인의 선구자\r멘도자를 세계적인 와인 산지로 올려 놓은 와이너리\...
# 321  아르헨티나 고급 와인의 선구자\r멘도자를 세계적인 와인 산지로 올려 놓은 와이너리\...
# 322  아르헨티나 고급 와인의 선구자\r멘도자를 세계적인 와인 산지로 올려 놓은 와이너리\...
# 323  아르헨티나 고급 와인의 선구자\r멘도자를 세계적인 와인 산지로 올려 놓은 와이너리\...
# 324  아르헨티나 고급 와인의 선구자\r멘도자를 세계적인 와인 산지로 올려 놓은 와이너리\...
#
#                                               아로마 딕셔너리  \
# 0                    {'빨간 과일': ['딸기'], '허베이셔스': ['풀']}
# 1                 {'꽃': ['아카시아'], '핵과': ['복숭아', '살구']}
# 2    {'자연(Earthy)': ['커피', '토스트'], '오크(Oak)': ['바닐라...
# 3    {'오크(Oak)': ['바닐라'], '녹색 과일': ['배'], '빨간 과일': ...
# 4                                {'핵과': ['복숭아', '살구']}
# ..                                                 ...
# 320  {'자연(Earthy)': ['가죽', '미네랄'], '오크(Oak)': ['바닐라...
# 321  {'자연(Earthy)': ['토스트', '미네랄'], '녹색 과일': ['애플']...
# 322  {'오크(Oak)': ['바닐라'], '빨간 과일': ['베리'], '까만 과일':...
# 323  {'오크(Oak)': ['초콜릿'], '꽃': ['바이올렛'], '빨간 과일': [...
# 324  {'녹색 과일': ['배'], '빨간 과일': ['라즈베리', '베리'], '까만 ...
#
#                                            곁들일 음식                 음식  \
# 0                       차가운 육류요리나 가금류, 붉은육류요리, 치즈           육류 에피타이저
# 1                          해산물이나 매콤한 요리, 간단한 핑거푸드  매운음식 해산물 sweet디저트
# 2                                     붉은 육류요리, 치즈           육류 에피타이저
# 3                                     붉은 육류요리, 치즈           육류 에피타이저
# 4               푸아그라, 송로버섯을 가미한 달걀요리 등 섬세한 풍미의 음식                 육류
# ..                                            ...                ...
# 320                      훈제 오리, 그릴드 치킨,  각종 육류 요리                 육류
# 321  신선한 해산물, 바질 오일파스타, 파마산 치즈를 곁들인 썬 드라이 토마토 샐러드       해산물 양식 에피타이저
# 322                      달콤한 육포, 스테이크, 훈연 소시지, 치즈           육류 에피타이저
# 323               양갈비, 로스트비프, 트러플 치즈 파니니, 머쉬룸 파스타        육류 양식 에피타이저
# 324                  치즈, 육즙이 풍부한 스테이크, 양고기, 블루 치즈           육류 에피타이저
#
#      상황별추천 군집화  상황별추천 군집화_n       추천솔루션 군집화  추천솔루션 군집화_n
# 0       가족과 함께            0   어른입맛 RED 술청년             0
# 1       가족과 함께            0  어른입맛 WHITE 술청년            1
# 2       가족과 함께            0   어른입맛 RED 술청년             0
# 3       가족과 함께            0   어른입맛 RED 술청년             0
# 4       가족과 함께            0  어른입맛 WHITE 술청년            1
# ..         ...          ...             ...          ...
# 320  술른이 연인과함께            3   어른입맛 RED 술청년             0
# 321     가족과 함께            0  어른입맛 WHITE 술청년            1
# 322  술른이 연인과함께            3   어른입맛 RED 술청년             0
# 323  술른이 연인과함께            3   어른입맛 RED 술청년             0
# 324  술른이 연인과함께            3   어른입맛 RED 술청년             0
#
# [325 rows x 20 columns]

# %%
import pytesseract
from PIL import Image
import numpy as np
import pandas as pd
import re

wine_df = pd.read_csv('wine_final_real.csv', index_col = 0)

# 데이터프레임 내 와인 이름 단어 추출
wine_li_all = wine_df['와인이름'].tolist() + wine_df['영어이름'].tolist()
# print(wine_li_all)


# 삭제해야하는 단어 지정하기 위해 모든 글자 추출 
all_str = []
for name in wine_li_all:
    for n in name:
        all_str.append(n)

# 삭제해야하는 단어 지정
stopwords = ['\"','&', "\'", '\(', '\)', ',', '-', '[.]', '/','‘','’','“','”']


# 한국어인지 영어인지 확인하는 사용자함수
def is_English_Korean(str):
    k_cnt, e_cnt = 0, 0
     
    for s in str:
        # ord: 문자의 유니코드 값을 돌려주는 함수
        if ord('가') <= ord(s) <= ord('힣'):
            k_cnt += 1
        elif ord('a') <= ord(s.lower()) <= ord('z'):
            e_cnt += 1
            
    return "한국어" if k_cnt > e_cnt else "영어"





wine_li_delete_stopword = []
wine_li_delete_blank = []

for name in wine_li_all:
    # 영어면 소문자로 변경하기
    if is_English_Korean(name) == '영어':
        name = name.lower()
    
    # 정규표현식으로 삭제해야하는 단어 제거
    # 띄어쓰기제거 한 와인이름 리스트도 생성
    for s in stopwords:
        name = re.sub(s, '', name)
        name2 = re.sub('\s','', name)
    wine_li_delete_stopword.append(name)
    wine_li_delete_blank.append(name2)
    
    
    
# 데이터프레임 내 와인이름 단어 리스트 중복 제거
wine_str_set = list(set(' '.join(wine_li_delete_stopword).split()))

print(wine_li_delete_stopword)
print(wine_li_delete_blank)
print(wine_str_set)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 import pytesseract
#       2 from PIL import Image
#       3 import numpy as np
#
# ModuleNotFoundError: No module named 'pytesseract'

# %% [markdown]
# ##### 이미지 내 텍스트

# %%
# 라벨 이미지 내 텍스트 추출
import pytesseract

pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract'

## (일치율 100%) 
# text = pytesseract.image_to_string('wine_이미지인식_(있음)투바인샤도네이.jpg',
#                                     lang = 'kor+eng', 
#                                     config = '-c preserve_interword_space=1 --psm 4')

# ## 한개 나옴
# text = pytesseract.image_to_string('wine_이미지인식_(있음)오레무스드라이만돌라스.jpg',
#                                     lang = 'kor+eng', 
#                                     config = '-c preserve_interword_space=1 --psm 4')

## 여러개 나옴
text = pytesseract.image_to_string('wine_이미지인식_(있음_여러개)이기갈두론.jpg',
                                    lang = 'kor+eng', 
                                    config = '-c preserve_interword_space=1 --psm 4')

## 없음
# text = pytesseract.image_to_string('wine_이미지인식_(없음)도메인꽁드리유.jpg',
#                                     lang = 'kor+eng', 
#                                     config = '-c preserve_interword_space=1 --psm 4')
print(text)


# 라벨 텍스트에서 텍스트, 숫자로만 이루어진 단어 추출
word_li = [word.lower() for word in re.findall('\w+',text)]


# 중복제거된 와인이름 단어 리스트 내 존재하면 찾아야할 와인이름 완성하기
from difflib import SequenceMatcher
wine_name = ''
for w in word_li:
    if w in wine_str_set:
        wine_name += w
print(wine_name)
        
# 검색해야되는 와인이름 언어가 국문/영문인지 확인
wine_lang = is_English_Korean(wine_name)        
print(wine_lang)


# 데이터프레임 내 국문 와인이름 리스트, 영문 와인이름 리스트 구분  
wine_ko = wine_li_delete_blank[:325]
wine_en = wine_li_delete_blank[325:]



#해당 와인 이름과 60% 이상 일치하는 와인 인덱스 불러오기
## 와인데이터프레임 복사
wine_df_result = wine_df.copy()
wine_df_result['와인이름 일치율'] = np.nan

## 한국어/영어 구분하고 와인이름 일치율을 내림차순 정렬, 새로운 데이터프레임 생성
if wine_lang == '한국어':
    for idx, df_wine_name in enumerate(wine_ko):
        search_range = SequenceMatcher(None, df_wine_name, wine_name).ratio()
        if search_range > 0.6:
            wine_df_result.loc[idx,'와인이름 일치율'] = search_range
            
        
else:
    for idx, df_wine_name in enumerate(wine_en):
        search_range = SequenceMatcher(None, df_wine_name, wine_name).ratio()
        if search_range > 0.6:
            wine_df_result.loc[idx,'와인이름 일치율'] = search_range
        
wine_df_result = wine_df_result.sort_values(by = '와인이름 일치율', ascending = False).dropna(subset = '와인이름 일치율')


# 일치율에 따라 데이터 불러오기
# 일치율이 1이면 바로 출력
if len(wine_df_result[wine_df_result['와인이름 일치율'] == 1]):
    output = wine_df_result[wine_df_result['와인이름 일치율'] == 1]

# 일치하는게 하나도 없으면 해당와인없음 반환
elif len(wine_df_result) == 0:
    output = '해당와인은 존재하지 않습니다.'

else:
    output = wine_df_result

    
output
# Out:
#
#
#
# 00601
#
# = COTES DU RHONE
#
# cotesdurhone
# 영어
#              와인이름                           영어이름    와인타입        나라, 와이너리  \
# 0   이기갈 꼬뜨 뒤 론 레드  E.Guigal Cotes du Rhone Rouge   레드 와인  프랑스 > 론 / 이 기갈
# 1  이기갈 꼬뜨 뒤 론 화이트  E.Guigal Cotes du Rhone Blanc  화이트 와인  프랑스 > 론 / 이 기갈
#
#                                          한줄소개  \
# 0  "King of the Rhone"으로 불리는 E.Guigal의 와인입니다.
# 1  "King of the Rhone"으로 불리는 E.Guigal의 와인입니다.
#
#                                             포도종    도수  당도  산도  바디  ...  \
# 0                    시라 49%, 그르나쉬 48%, 무르베드르 3%  13.0   1   2   4  ...
# 1  비오니에 70%, 루산느 10%, 마르산느 9%, 끌레레뜨 8%, 부르불랑 3%  13.0   1   3   3  ...
#
#                                               와이너리설명  \
# 0  이기갈(E.Guigal)은 오늘날 프랑스 론 최고의 생산자로 꼽힌다. 1946년 에...
# 1  이기갈(E.Guigal)은 오늘날 프랑스 론 최고의 생산자로 꼽힌다. 1946년 에...
#
#                                               와이너리특징  \
# 0  "King of the Rhone" - 영국의 와인전문지 <디캔터(Decanter)...
# 1  "King of the Rhone" - 영국의 와인전문지 <디캔터(Decanter)...
#
#                                아로마 딕셔너리                     곁들일 음식  \
# 0     {'빨간 과일': ['딸기'], '허베이셔스': ['풀']}  차가운 육류요리나 가금류, 붉은육류요리, 치즈
# 1  {'꽃': ['아카시아'], '핵과': ['복숭아', '살구']}     해산물이나 매콤한 요리, 간단한 핑거푸드
#
#                   음식 상황별추천 군집화 상황별추천 군집화_n       추천솔루션 군집화 추천솔루션 군집화_n  \
# 0           육류 에피타이저    가족과 함께           0   어른입맛 RED 술청년            0
# 1  매운음식 해산물 sweet디저트    가족과 함께           0  어른입맛 WHITE 술청년           1
#
#    와인이름 일치율
# 0  0.666667
# 1  0.666667
#
# [2 rows x 21 columns]

# %% [markdown]
# ### 검색기능

# %%
# 검색기능

from difflib import SequenceMatcher

for name in wine_li_str:
    if SequenceMatcher(None, name, '오레무스 드라이 만돌라스').ratio() > 0.8:
        print(name)
