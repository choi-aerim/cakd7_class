# %% [markdown]
# # SURPRISE API

# %%
import surprise

print(surprise.__version__)
# Out:
# 1.1.3

# %%
from surprise import SVD
from surprise import Dataset
from surprise import accuracy
from surprise.model_selection import train_test_split

# %% [markdown]
# ### movie, ratings 데이터 불러오기
# - 직접 사이트에서 내려받은 데이터와 다름 주의

# %%
data  = Dataset.load_builtin('ml-100k')
# Out:
# Dataset ml-100k could not be found. Do you want to download it? [Y/n] Y
# Trying to download dataset from https://files.grouplens.org/datasets/movielens/ml-100k.zip...
# Done! Dataset ml-100k has been saved to C:\Users\admin/.surprise_data/ml-100k

# %%
# 영화 평점 데이터 불러오기
data  = Dataset.load_builtin('ml-100k')

# %%
# 추천시스템을 학습하기 위한 데이터/ 테스트 데이터 나누기

trainset, testset = train_test_split(data, test_size = 0.25, random_state = 0)

# %% [markdown]
# ## SVD 잠재요인 협업 필터링

# %% [markdown]
# ### 학습

# %%
# svd알고리즘 객체 생성
algo = SVD(random_state = 0)

# 학습하기
algo.fit(trainset)

# %% [markdown]
# ### 예측
# - test(): 사용자-아이템 평점 데이터 센트 전체에 대해 추천을 예측하여 반환하는 메서드
# - predict(): 개별 사용자의 평점에 대해 추천 평점 예측해서 반환하는 메서드

# %% [markdown]
# #### test()

# %%
predictions = algo.test(testset)

print('predictions type: ', type(predictions))
print('precictions size: ', len(predictions))
print('predictions 결과물: \n', predictions[:5])
# Out:
# predictions type:  <class 'list'>
# precictions size:  25000
# predictions 결과물:
#  [Prediction(uid='120', iid='282', r_ui=4.0, est=3.5114147666251547, details={'was_impossible': False}), Prediction(uid='882', iid='291', r_ui=4.0, est=3.573872419581491, details={'was_impossible': False}), Prediction(uid='535', iid='507', r_ui=5.0, est=4.033583485472447, details={'was_impossible': False}), Prediction(uid='697', iid='244', r_ui=5.0, est=3.8463639495936905, details={'was_impossible': False}), Prediction(uid='751', iid='385', r_ui=4.0, est=3.1807542478219157, details={'was_impossible': False})]

# %% [markdown]
# - test 메서드의 호출 결과는 파이썬 리스트임
# - 리스트 안에 prediction 객체는 surprise 패키지에서 제공하는 데이터 타입이며, 다음을 나타냄
# ```
#   uid: 개별 사용자 아이디
#   iid:아이템(영화) 아이디
#   r_ui: 실제 평점 정보
#   est: 추천 예측 평점
#   details: 내부 처리 시 추천 예측을 할 수 없는 경우에 로그용으로 데이터를 남기는 데 사용됨
#            'was_impossible' : True 인 경우, 예측값을 생성할 수 없는 데이터라는 의미
# ```

# %%
[ (pred.iid, pred.uid, pred.r_ui, 3, pred.details) for pred in predictions]
# Out:
# [('282', '120', 4.0, 3, {'was_impossible': False}),
#  ('291', '882', 4.0, 3, {'was_impossible': False}),
#  ('507', '535', 5.0, 3, {'was_impossible': False}),
#  ('244', '697', 5.0, 3, {'was_impossible': False}),
#  ('385', '751', 4.0, 3, {'was_impossible': False}),
#  ('82', '219', 1.0, 3, {'was_impossible': False}),
#  ('571', '279', 4.0, 3, {'was_impossible': False}),
#  ('568', '429', 3.0, 3, {'was_impossible': False}),
#  ('100', '456', 3.0, 3, {'was_impossible': False}),
#  ('23', '249', 4.0, 3, {'was_impossible': False}),
#  ('183', '493', 5.0, 3, {'was_impossible': False}),
#  ('469', '325', 4.0, 3, {'was_impossible': False}),
#  ('682', '631', 2.0, 3, {'was_impossible': False}),
#  ('121', '276', 4.0, 3, {'was_impossible': False}),
#  ('405', '269', 1.0, 3, {'was_impossible': False}),
#  ('1095', '159', 5.0, 3, {'was_impossible': False}),
#  ('965', '385', 4.0, 3, {'was_impossible': False}),
#  ('358', '21', 3.0, 3, {'was_impossible': False}),
#  ('1359', '181', 1.0, 3, {'was_impossible': False}),
#  ('124', '561', 3.0, 3, {'was_impossible': False}),
#  ('1079', '658', 2.0, 3, {'was_impossible': False}),
#  ('269', '354', 4.0, 3, {'was_impossible': False}),
#  ('483', '325', 5.0, 3, {'was_impossible': False}),
#  ('241', '601', 4.0, 3, {'was_impossible': False}),
#  ('1020', '409', 5.0, 3, {'was_impossible': False}),
#  ('300', '801', 5.0, 3, {'was_impossible': False}),
#  ('21', '289', 1.0, 3, {'was_impossible': False}),
#  ('896', '378', 4.0, 3, {'was_impossible': False}),
#  ('294', '609', 2.0, 3, {'was_impossible': False}),
#  ('452', '442', 3.0, 3, {'was_impossible': False}),
#  ('264', '459', 4.0, 3, {'was_impossible': False}),
#  ('333', '739', 4.0, 3, {'was_impossible': False}),
#  ('98', '297', 5.0, 3, {'was_impossible': False}),
#  ('286', '592', 5.0, 3, {'was_impossible': False}),
#  ('820', '313', 2.0, 3, {'was_impossible': False}),
#  ('802', '393', 3.0, 3, {'was_impossible': False}),
#  ('763', '168', 2.0, 3, {'was_impossible': False}),
#  ('17', '293', 2.0, 3, {'was_impossible': False}),
#  ('1063', '280', 3.0, 3, {'was_impossible': False}),
#  ('461', '379', 4.0, 3, {'was_impossible': False}),
#  ('638', '911', 4.0, 3, {'was_impossible': False}),
#  ('368', '216', 2.0, 3, {'was_impossible': False}),
#  ('195', '10', 4.0, 3, {'was_impossible': False}),
#  ('46', '645', 5.0, 3, {'was_impossible': False}),
#  ('412', '83', 1.0, 3, {'was_impossible': False}),
#  ('521', '321', 2.0, 3, {'was_impossible': False}),
#  ('968', '650', 4.0, 3, {'was_impossible': False}),
#  ('216', '58', 3.0, 3, {'was_impossible': False}),
#  ('211', '897', 5.0, 3, {'was_impossible': False}),
#  ('90', '44', 2.0, 3, {'was_impossible': False}),
#  ('652', '487', 5.0, 3, {'was_impossible': False}),
#  ('313', '104', 4.0, 3, {'was_impossible': False}),
#  ('381', '751', 1.0, 3, {'was_impossible': False}),
#  ('252', '20', 4.0, 3, {'was_impossible': False}),
#  ('588', '528', 2.0, 3, {'was_impossible': False}),
#  ('180', '10', 5.0, 3, {'was_impossible': False}),
#  ('923', '492', 5.0, 3, {'was_impossible': False}),
#  ('591', '16', 4.0, 3, {'was_impossible': False}),
#  ('272', '286', 5.0, 3, {'was_impossible': False}),
#  ('98', '496', 4.0, 3, {'was_impossible': False}),
#  ('678', '724', 2.0, 3, {'was_impossible': False}),
#  ('1560', '655', 2.0, 3, {'was_impossible': False}),
#  ('431', '373', 5.0, 3, {'was_impossible': False}),
#  ('514', '326', 3.0, 3, {'was_impossible': False}),
#  ('14', '184', 4.0, 3, {'was_impossible': False}),
#  ('475', '534', 4.0, 3, {'was_impossible': False}),
#  ('499', '753', 3.0, 3, {'was_impossible': False}),
#  ('248', '58', 4.0, 3, {'was_impossible': False}),
#  ('684', '757', 4.0, 3, {'was_impossible': False}),
#  ('732', '405', 5.0, 3, {'was_impossible': False}),
#  ('229', '660', 2.0, 3, {'was_impossible': False}),
#  ('110', '22', 1.0, 3, {'was_impossible': False}),
#  ('274', '42', 5.0, 3, {'was_impossible': False}),
#  ('1404', '189', 5.0, 3, {'was_impossible': False}),
#  ('96', '13', 4.0, 3, {'was_impossible': False}),
#  ('755', '848', 5.0, 3, {'was_impossible': False}),
#  ('258', '832', 3.0, 3, {'was_impossible': False}),
#  ('201', '658', 3.0, 3, {'was_impossible': False}),
#  ('568', '654', 4.0, 3, {'was_impossible': False}),
#  ('48', '556', 5.0, 3, {'was_impossible': False}),
#  ('515', '294', 5.0, 3, {'was_impossible': False}),
#  ('56', '144', 4.0, 3, {'was_impossible': False}),
#  ('98', '350', 4.0, 3, {'was_impossible': False}),
#  ('49', '860', 2.0, 3, {'was_impossible': False}),
#  ('281', '406', 3.0, 3, {'was_impossible': False}),
#  ('22', '608', 4.0, 3, {'was_impossible': False}),
#  ('729', '180', 5.0, 3, {'was_impossible': False}),
#  ('155', '756', 4.0, 3, {'was_impossible': False}),
#  ('918', '532', 4.0, 3, {'was_impossible': False}),
#  ('527', '758', 5.0, 3, {'was_impossible': False}),
#  ('343', '40', 1.0, 3, {'was_impossible': False}),
#  ('43', '290', 3.0, 3, {'was_impossible': False}),
#  ('11', '392', 4.0, 3, {'was_impossible': False}),
#  ('285', '199', 4.0, 3, {'was_impossible': False}),
#  ('496', '452', 5.0, 3, {'was_impossible': False}),
#  ('975', '630', 4.0, 3, {'was_impossible': False}),
#  ('28', '70', 4.0, 3, {'was_impossible': False}),
#  ('833', '67', 4.0, 3, {'was_impossible': False}),
#  ('578', '709', 4.0, 3, {'was_impossible': False}),
#  ('618', '312', 5.0, 3, {'was_impossible': False}),
#  ('173', '700', 5.0, 3, {'was_impossible': False}),
#  ('25', '402', 4.0, 3, {'was_impossible': False}),
#  ('97', '668', 2.0, 3, {'was_impossible': False}),
#  ('887', '557', 3.0, 3, {'was_impossible': False}),
#  ('318', '474', 5.0, 3, {'was_impossible': False}),
#  ('286', '587', 4.0, 3, {'was_impossible': False}),
#  ('344', '327', 4.0, 3, {'was_impossible': False}),
#  ('258', '8', 5.0, 3, {'was_impossible': False}),
#  ('941', '222', 3.0, 3, {'was_impossible': False}),
#  ('304', '273', 3.0, 3, {'was_impossible': False}),
#  ('423', '500', 3.0, 3, {'was_impossible': False}),
#  ('64', '875', 5.0, 3, {'was_impossible': False}),
#  ('831', '486', 3.0, 3, {'was_impossible': False}),
#  ('287', '437', 2.0, 3, {'was_impossible': False}),
#  ('750', '675', 4.0, 3, {'was_impossible': False}),
#  ('763', '449', 2.0, 3, {'was_impossible': False}),
#  ('12', '239', 5.0, 3, {'was_impossible': False}),
#  ('732', '210', 4.0, 3, {'was_impossible': False}),
#  ('14', '62', 4.0, 3, {'was_impossible': False}),
#  ('554', '70', 3.0, 3, {'was_impossible': False}),
#  ('188', '295', 3.0, 3, {'was_impossible': False}),
#  ('64', '899', 4.0, 3, {'was_impossible': False}),
#  ('94', '279', 3.0, 3, {'was_impossible': False}),
#  ('521', '312', 5.0, 3, {'was_impossible': False}),
#  ('241', '268', 3.0, 3, {'was_impossible': False}),
#  ('496', '840', 5.0, 3, {'was_impossible': False}),
#  ('9', '601', 4.0, 3, {'was_impossible': False}),
#  ('750', '544', 3.0, 3, {'was_impossible': False}),
#  ('795', '901', 3.0, 3, {'was_impossible': False}),
#  ('528', '738', 4.0, 3, {'was_impossible': False}),
#  ('930', '15', 2.0, 3, {'was_impossible': False}),
#  ('58', '397', 5.0, 3, {'was_impossible': False}),
#  ('33', '805', 5.0, 3, {'was_impossible': False}),
#  ('1479', '450', 3.0, 3, {'was_impossible': False}),
#  ('896', '334', 5.0, 3, {'was_impossible': False}),
#  ('124', '334', 5.0, 3, {'was_impossible': False}),
#  ('209', '201', 3.0, 3, {'was_impossible': False}),
#  ('689', '362', 5.0, 3, {'was_impossible': False}),
#  ('499', '840', 4.0, 3, {'was_impossible': False}),
#  ('476', '416', 5.0, 3, {'was_impossible': False}),
#  ('186', '512', 5.0, 3, {'was_impossible': False}),
#  ('1267', '201', 3.0, 3, {'was_impossible': False}),
#  ('662', '846', 3.0, 3, {'was_impossible': False}),
#  ('86', '882', 5.0, 3, {'was_impossible': False}),
#  ('1093', '886', 1.0, 3, {'was_impossible': False}),
#  ('258', '166', 4.0, 3, {'was_impossible': False}),
#  ('321', '764', 1.0, 3, {'was_impossible': False}),
#  ('132', '776', 3.0, 3, {'was_impossible': False}),
#  ('127', '8', 5.0, 3, {'was_impossible': False}),
#  ('1113', '916', 4.0, 3, {'was_impossible': False}),
#  ('322', '782', 4.0, 3, {'was_impossible': False}),
#  ('135', '721', 3.0, 3, {'was_impossible': False}),
#  ('22', '13', 4.0, 3, {'was_impossible': False}),
#  ('499', '659', 4.0, 3, {'was_impossible': False}),
#  ('72', '476', 4.0, 3, {'was_impossible': False}),
#  ('936', '558', 5.0, 3, {'was_impossible': False}),
#  ('250', '715', 2.0, 3, {'was_impossible': False}),
#  ('478', '269', 4.0, 3, {'was_impossible': False}),
#  ('503', '389', 3.0, 3, {'was_impossible': False}),
#  ('174', '415', 5.0, 3, {'was_impossible': False}),
#  ('487', '450', 4.0, 3, {'was_impossible': False}),
#  ('47', '567', 4.0, 3, {'was_impossible': False}),
#  ('127', '46', 5.0, 3, {'was_impossible': False}),
#  ('479', '734', 4.0, 3, {'was_impossible': False}),
#  ('117', '251', 4.0, 3, {'was_impossible': False}),
#  ('751', '99', 4.0, 3, {'was_impossible': False}),
#  ('233', '130', 4.0, 3, {'was_impossible': False}),
#  ('91', '194', 3.0, 3, {'was_impossible': False}),
#  ('181', '632', 5.0, 3, {'was_impossible': False}),
#  ('385', '588', 3.0, 3, {'was_impossible': False}),
#  ('1419', '600', 3.0, 3, {'was_impossible': False}),
#  ('1168', '707', 3.0, 3, {'was_impossible': False}),
#  ('143', '194', 3.0, 3, {'was_impossible': False}),
#  ('184', '521', 4.0, 3, {'was_impossible': False}),
#  ('435', '193', 4.0, 3, {'was_impossible': False}),
#  ('269', '105', 4.0, 3, {'was_impossible': False}),
#  ('322', '546', 4.0, 3, {'was_impossible': False}),
#  ('925', '181', 2.0, 3, {'was_impossible': False}),
#  ('985', '634', 4.0, 3, {'was_impossible': False}),
#  ('77', '303', 4.0, 3, {'was_impossible': False}),
#  ('17', '393', 1.0, 3, {'was_impossible': False}),
#  ('819', '653', 3.0, 3, {'was_impossible': False}),
#  ('1089', '624', 2.0, 3, {'was_impossible': False}),
#  ('28', '661', 5.0, 3, {'was_impossible': False}),
#  ('961', '269', 5.0, 3, {'was_impossible': False}),
#  ('332', '431', 3.0, 3, {'was_impossible': False}),
#  ('196', '406', 2.0, 3, {'was_impossible': False}),
#  ('123', '50', 4.0, 3, {'was_impossible': False}),
#  ('554', '405', 1.0, 3, {'was_impossible': False}),
#  ('545', '7', 2.0, 3, {'was_impossible': False}),
#  ('286', '724', 1.0, 3, {'was_impossible': False}),
#  ('797', '217', 4.0, 3, {'was_impossible': False}),
#  ('468', '454', 3.0, 3, {'was_impossible': False}),
#  ('12', '561', 5.0, 3, {'was_impossible': False}),
#  ('285', '116', 4.0, 3, {'was_impossible': False}),
#  ('949', '840', 4.0, 3, {'was_impossible': False}),
#  ('233', '881', 3.0, 3, {'was_impossible': False}),
#  ('629', '815', 4.0, 3, {'was_impossible': False}),
#  ('144', '676', 4.0, 3, {'was_impossible': False}),
#  ('1037', '385', 1.0, 3, {'was_impossible': False}),
#  ('530', '561', 4.0, 3, {'was_impossible': False}),
#  ('32', '297', 4.0, 3, {'was_impossible': False}),
#  ('763', '674', 5.0, 3, {'was_impossible': False}),
#  ('70', '889', 3.0, 3, {'was_impossible': False}),
#  ('258', '170', 3.0, 3, {'was_impossible': False}),
#  ('318', '667', 5.0, 3, {'was_impossible': False}),
#  ('1118', '268', 3.0, 3, {'was_impossible': False}),
#  ('245', '777', 5.0, 3, {'was_impossible': False}),
#  ('28', '716', 5.0, 3, {'was_impossible': False}),
#  ('11', '943', 4.0, 3, {'was_impossible': False}),
#  ('255', '354', 2.0, 3, {'was_impossible': False}),
#  ('597', '793', 3.0, 3, {'was_impossible': False}),
#  ('98', '553', 5.0, 3, {'was_impossible': False}),
#  ('1047', '901', 3.0, 3, {'was_impossible': False}),
#  ('54', '109', 3.0, 3, {'was_impossible': False}),
#  ('750', '448', 5.0, 3, {'was_impossible': False}),
#  ('886', '13', 5.0, 3, {'was_impossible': False}),
#  ('233', '279', 5.0, 3, {'was_impossible': False}),
#  ('230', '127', 5.0, 3, {'was_impossible': False}),
#  ('186', '892', 3.0, 3, {'was_impossible': False}),
#  ('195', '399', 2.0, 3, {'was_impossible': False}),
#  ('185', '454', 2.0, 3, {'was_impossible': False}),
#  ('173', '922', 5.0, 3, {'was_impossible': False}),
#  ('431', '749', 5.0, 3, {'was_impossible': False}),
#  ('318', '44', 5.0, 3, {'was_impossible': False}),
#  ('67', '417', 4.0, 3, {'was_impossible': False}),
#  ('67', '276', 3.0, 3, {'was_impossible': False}),
#  ('479', '796', 4.0, 3, {'was_impossible': False}),
#  ('778', '588', 3.0, 3, {'was_impossible': False}),
#  ('290', '248', 3.0, 3, {'was_impossible': False}),
#  ('331', '752', 4.0, 3, {'was_impossible': False}),
#  ('187', '177', 4.0, 3, {'was_impossible': False}),
#  ('56', '741', 4.0, 3, {'was_impossible': False}),
#  ('772', '259', 4.0, 3, {'was_impossible': False}),
#  ('194', '16', 5.0, 3, {'was_impossible': False}),
#  ('248', '287', 5.0, 3, {'was_impossible': False}),
#  ('328', '485', 2.0, 3, {'was_impossible': False}),
#  ('684', '533', 4.0, 3, {'was_impossible': False}),
#  ('151', '879', 3.0, 3, {'was_impossible': False}),
#  ('1220', '907', 5.0, 3, {'was_impossible': False}),
#  ('33', '218', 4.0, 3, {'was_impossible': False}),
#  ('98', '372', 5.0, 3, {'was_impossible': False}),
#  ('174', '456', 4.0, 3, {'was_impossible': False}),
#  ('399', '70', 4.0, 3, {'was_impossible': False}),
#  ('289', '740', 4.0, 3, {'was_impossible': False}),
#  ('750', '247', 4.0, 3, {'was_impossible': False}),
#  ('558', '449', 4.0, 3, {'was_impossible': False}),
#  ('1117', '184', 2.0, 3, {'was_impossible': False}),
#  ('345', '334', 2.0, 3, {'was_impossible': False}),
#  ('678', '224', 3.0, 3, {'was_impossible': False}),
#  ('128', '621', 4.0, 3, {'was_impossible': False}),
#  ('1490', '655', 2.0, 3, {'was_impossible': False}),
#  ('628', '177', 2.0, 3, {'was_impossible': False}),
#  ('235', '82', 1.0, 3, {'was_impossible': False}),
#  ('735', '561', 3.0, 3, {'was_impossible': False}),
#  ('294', '61', 2.0, 3, {'was_impossible': False}),
#  ('559', '436', 4.0, 3, {'was_impossible': False}),
#  ('14', '463', 1.0, 3, {'was_impossible': False}),
#  ('1005', '449', 5.0, 3, {'was_impossible': False}),
#  ('476', '872', 4.0, 3, {'was_impossible': False}),
#  ('227', '221', 3.0, 3, {'was_impossible': False}),
#  ('97', '286', 4.0, 3, {'was_impossible': False}),
#  ('180', '305', 4.0, 3, {'was_impossible': False}),
#  ('241', '92', 3.0, 3, {'was_impossible': False}),
#  ('748', '159', 3.0, 3, {'was_impossible': False}),
#  ('663', '308', 5.0, 3, {'was_impossible': False}),
#  ('419', '406', 1.0, 3, {'was_impossible': False}),
#  ('2', '301', 2.0, 3, {'was_impossible': False}),
#  ('947', '776', 2.0, 3, {'was_impossible': False}),
#  ('732', '56', 4.0, 3, {'was_impossible': False}),
#  ('174', '774', 3.0, 3, {'was_impossible': False}),
#  ('556', '682', 2.0, 3, {'was_impossible': False}),
#  ('174', '849', 5.0, 3, {'was_impossible': False}),
#  ('272', '221', 5.0, 3, {'was_impossible': False}),
#  ('273', '201', 2.0, 3, {'was_impossible': False}),
#  ('742', '174', 4.0, 3, {'was_impossible': False}),
#  ('221', '90', 4.0, 3, {'was_impossible': False}),
#  ('937', '427', 5.0, 3, {'was_impossible': False}),
#  ('68', '870', 3.0, 3, {'was_impossible': False}),
#  ('848', '537', 3.0, 3, {'was_impossible': False}),
#  ('347', '669', 3.0, 3, {'was_impossible': False}),
#  ('172', '911', 4.0, 3, {'was_impossible': False}),
#  ('709', '591', 4.0, 3, {'was_impossible': False}),
#  ('185', '650', 3.0, 3, {'was_impossible': False}),
#  ('526', '505', 5.0, 3, {'was_impossible': False}),
#  ('38', '709', 3.0, 3, {'was_impossible': False}),
#  ('722', '314', 1.0, 3, {'was_impossible': False}),
#  ('441', '255', 2.0, 3, {'was_impossible': False}),
#  ('200', '378', 3.0, 3, {'was_impossible': False}),
#  ('41', '130', 3.0, 3, {'was_impossible': False}),
#  ('272', '1', 3.0, 3, {'was_impossible': False}),
#  ('108', '268', 3.0, 3, {'was_impossible': False}),
#  ('98', '780', 1.0, 3, {'was_impossible': False}),
#  ('180', '559', 4.0, 3, {'was_impossible': False}),
#  ('403', '276', 4.0, 3, {'was_impossible': False}),
#  ('687', '303', 1.0, 3, {'was_impossible': False}),
#  ('896', '828', 4.0, 3, {'was_impossible': False}),
#  ('269', '634', 4.0, 3, {'was_impossible': False}),
#  ('444', '363', 4.0, 3, {'was_impossible': False}),
#  ('192', '6', 4.0, 3, {'was_impossible': False}),
#  ('724', '734', 3.0, 3, {'was_impossible': False}),
#  ('268', '537', 4.0, 3, {'was_impossible': False}),
#  ('755', '210', 3.0, 3, {'was_impossible': False}),
#  ('655', '577', 4.0, 3, {'was_impossible': False}),
#  ('385', '922', 3.0, 3, {'was_impossible': False}),
#  ('432', '892', 4.0, 3, {'was_impossible': False}),
#  ('205', '200', 4.0, 3, {'was_impossible': False}),
#  ('622', '541', 3.0, 3, {'was_impossible': False}),
#  ('323', '250', 2.0, 3, {'was_impossible': False}),
#  ('710', '23', 4.0, 3, {'was_impossible': False}),
#  ('669', '7', 1.0, 3, {'was_impossible': False}),
#  ('307', '652', 4.0, 3, {'was_impossible': False}),
#  ('101', '622', 5.0, 3, {'was_impossible': False}),
#  ('210', '106', 4.0, 3, {'was_impossible': False}),
#  ('203', '533', 4.0, 3, {'was_impossible': False}),
#  ('739', '709', 3.0, 3, {'was_impossible': False}),
#  ('157', '749', 3.0, 3, {'was_impossible': False}),
#  ('550', '186', 4.0, 3, {'was_impossible': False}),
#  ('223', '417', 5.0, 3, {'was_impossible': False}),
#  ('216', '346', 3.0, 3, {'was_impossible': False}),
#  ('763', '513', 3.0, 3, {'was_impossible': False}),
#  ('121', '37', 2.0, 3, {'was_impossible': False}),
#  ('264', '268', 3.0, 3, {'was_impossible': False}),
#  ('602', '295', 5.0, 3, {'was_impossible': False}),
#  ('298', '592', 5.0, 3, {'was_impossible': False}),
#  ('310', '755', 4.0, 3, {'was_impossible': False}),
#  ('127', '610', 5.0, 3, {'was_impossible': False}),
#  ('385', '758', 4.0, 3, {'was_impossible': False}),
#  ('423', '6', 3.0, 3, {'was_impossible': False}),
#  ('79', '738', 3.0, 3, {'was_impossible': False}),
#  ('413', '294', 3.0, 3, {'was_impossible': False}),
#  ('252', '54', 3.0, 3, {'was_impossible': False}),
#  ('620', '181', 2.0, 3, {'was_impossible': False}),
#  ('230', '487', 5.0, 3, {'was_impossible': False}),
#  ('276', '174', 5.0, 3, {'was_impossible': False}),
#  ('476', '221', 2.0, 3, {'was_impossible': False}),
#  ('756', '194', 1.0, 3, {'was_impossible': False}),
#  ('475', '117', 5.0, 3, {'was_impossible': False}),
#  ('151', '429', 5.0, 3, {'was_impossible': False}),
#  ('607', '535', 5.0, 3, {'was_impossible': False}),
#  ('288', '33', 4.0, 3, {'was_impossible': False}),
#  ('168', '124', 5.0, 3, {'was_impossible': False}),
#  ('8', '591', 3.0, 3, {'was_impossible': False}),
#  ('293', '94', 4.0, 3, {'was_impossible': False}),
#  ('50', '848', 5.0, 3, {'was_impossible': False}),
#  ('692', '188', 5.0, 3, {'was_impossible': False}),
#  ('180', '880', 5.0, 3, {'was_impossible': False}),
#  ('83', '790', 3.0, 3, {'was_impossible': False}),
#  ('514', '95', 2.0, 3, {'was_impossible': False}),
#  ('201', '880', 4.0, 3, {'was_impossible': False}),
#  ('161', '932', 3.0, 3, {'was_impossible': False}),
#  ('520', '758', 5.0, 3, {'was_impossible': False}),
#  ('294', '251', 3.0, 3, {'was_impossible': False}),
#  ('176', '499', 4.0, 3, {'was_impossible': False}),
#  ('124', '1', 5.0, 3, {'was_impossible': False}),
#  ('258', '579', 5.0, 3, {'was_impossible': False}),
#  ('222', '737', 3.0, 3, {'was_impossible': False}),
#  ('508', '527', 3.0, 3, {'was_impossible': False}),
#  ('729', '236', 5.0, 3, {'was_impossible': False}),
#  ('637', '495', 3.0, 3, {'was_impossible': False}),
#  ('732', '653', 2.0, 3, {'was_impossible': False}),
#  ('222', '759', 5.0, 3, {'was_impossible': False}),
#  ('108', '936', 4.0, 3, {'was_impossible': False}),
#  ('264', '1', 2.0, 3, {'was_impossible': False}),
#  ('673', '405', 5.0, 3, {'was_impossible': False}),
#  ('496', '298', 5.0, 3, {'was_impossible': False}),
#  ('191', '342', 5.0, 3, {'was_impossible': False}),
#  ('319', '392', 5.0, 3, {'was_impossible': False}),
#  ('196', '846', 4.0, 3, {'was_impossible': False}),
#  ('98', '690', 5.0, 3, {'was_impossible': False}),
#  ('1028', '684', 4.0, 3, {'was_impossible': False}),
#  ('121', '582', 3.0, 3, {'was_impossible': False}),
#  ('485', '389', 5.0, 3, {'was_impossible': False}),
#  ('184', '388', 4.0, 3, {'was_impossible': False}),
#  ('622', '59', 4.0, 3, {'was_impossible': False}),
#  ('650', '840', 4.0, 3, {'was_impossible': False}),
#  ('292', '171', 4.0, 3, {'was_impossible': False}),
#  ('478', '184', 4.0, 3, {'was_impossible': False}),
#  ('742', '663', 4.0, 3, {'was_impossible': False}),
#  ('131', '450', 4.0, 3, {'was_impossible': False}),
#  ('1230', '95', 1.0, 3, {'was_impossible': False}),
#  ('1064', '48', 4.0, 3, {'was_impossible': False}),
#  ('191', '533', 4.0, 3, {'was_impossible': False}),
#  ('134', '393', 2.0, 3, {'was_impossible': False}),
#  ('98', '655', 4.0, 3, {'was_impossible': False}),
#  ('229', '318', 1.0, 3, {'was_impossible': False}),
#  ('148', '916', 2.0, 3, {'was_impossible': False}),
#  ('720', '788', 3.0, 3, {'was_impossible': False}),
#  ('614', '7', 5.0, 3, {'was_impossible': False}),
#  ('679', '87', 3.0, 3, {'was_impossible': False}),
#  ('62', '127', 5.0, 3, {'was_impossible': False}),
#  ('281', '560', 3.0, 3, {'was_impossible': False}),
#  ('422', '642', 3.0, 3, {'was_impossible': False}),
#  ('64', '870', 5.0, 3, {'was_impossible': False}),
#  ('282', '709', 5.0, 3, {'was_impossible': False}),
#  ('220', '128', 1.0, 3, {'was_impossible': False}),
#  ('95', '363', 3.0, 3, {'was_impossible': False}),
#  ('257', '794', 4.0, 3, {'was_impossible': False}),
#  ('358', '493', 4.0, 3, {'was_impossible': False}),
#  ('122', '504', 1.0, 3, {'was_impossible': False}),
#  ('289', '579', 2.0, 3, {'was_impossible': False}),
#  ('165', '234', 5.0, 3, {'was_impossible': False}),
#  ('168', '239', 4.0, 3, {'was_impossible': False}),
#  ('1206', '291', 3.0, 3, {'was_impossible': False}),
#  ('616', '303', 4.0, 3, {'was_impossible': False}),
#  ('678', '363', 1.0, 3, {'was_impossible': False}),
#  ('609', '401', 3.0, 3, {'was_impossible': False}),
#  ('920', '14', 4.0, 3, {'was_impossible': False}),
#  ('879', '428', 4.0, 3, {'was_impossible': False}),
#  ('277', '119', 4.0, 3, {'was_impossible': False}),
#  ('528', '479', 4.0, 3, {'was_impossible': False}),
#  ('294', '166', 3.0, 3, {'was_impossible': False}),
#  ('284', '347', 3.0, 3, {'was_impossible': False}),
#  ('282', '580', 5.0, 3, {'was_impossible': False}),
#  ('1438', '378', 3.0, 3, {'was_impossible': False}),
#  ('755', '70', 3.0, 3, {'was_impossible': False}),
#  ('1048', '447', 2.0, 3, {'was_impossible': False}),
#  ('780', '405', 3.0, 3, {'was_impossible': False}),
#  ('228', '11', 3.0, 3, {'was_impossible': False}),
#  ('526', '276', 4.0, 3, {'was_impossible': False}),
#  ('513', '361', 5.0, 3, {'was_impossible': False}),
#  ('562', '682', 2.0, 3, {'was_impossible': False}),
#  ('372', '504', 4.0, 3, {'was_impossible': False}),
#  ('517', '207', 3.0, 3, {'was_impossible': False}),
#  ('710', '551', 5.0, 3, {'was_impossible': False}),
#  ('417', '885', 3.0, 3, {'was_impossible': False}),
#  ('572', '693', 2.0, 3, {'was_impossible': False}),
#  ('254', '642', 4.0, 3, {'was_impossible': False}),
#  ('679', '332', 5.0, 3, {'was_impossible': False}),
#  ('137', '506', 2.0, 3, {'was_impossible': False}),
#  ('479', '846', 4.0, 3, {'was_impossible': False}),
#  ('7', '624', 4.0, 3, {'was_impossible': False}),
#  ('42', '327', 3.0, 3, {'was_impossible': False}),
#  ('380', '650', 2.0, 3, {'was_impossible': False}),
#  ('258', '116', 4.0, 3, {'was_impossible': False}),
#  ('8', '200', 4.0, 3, {'was_impossible': False}),
#  ('516', '144', 2.0, 3, {'was_impossible': False}),
#  ('821', '734', 2.0, 3, {'was_impossible': False}),
#  ('527', '535', 3.0, 3, {'was_impossible': False}),
#  ('333', '851', 5.0, 3, {'was_impossible': False}),
#  ('153', '307', 5.0, 3, {'was_impossible': False}),
#  ('124', '942', 4.0, 3, {'was_impossible': False}),
#  ('200', '749', 4.0, 3, {'was_impossible': False}),
#  ('46', '201', 4.0, 3, {'was_impossible': False}),
#  ('488', '854', 4.0, 3, {'was_impossible': False}),
#  ('125', '213', 5.0, 3, {'was_impossible': False}),
#  ('1379', '181', 1.0, 3, {'was_impossible': False}),
#  ('605', '389', 5.0, 3, {'was_impossible': False}),
#  ('1028', '254', 2.0, 3, {'was_impossible': False}),
#  ('835', '389', 5.0, 3, {'was_impossible': False}),
#  ('559', '925', 3.0, 3, {'was_impossible': False}),
#  ('423', '269', 4.0, 3, {'was_impossible': False}),
#  ('484', '447', 5.0, 3, {'was_impossible': False}),
#  ('673', '533', 3.0, 3, {'was_impossible': False}),
#  ('349', '546', 4.0, 3, {'was_impossible': False}),
#  ('1160', '936', 5.0, 3, {'was_impossible': False}),
#  ('307', '36', 4.0, 3, {'was_impossible': False}),
#  ('68', '474', 3.0, 3, {'was_impossible': False}),
#  ('1382', '181', 1.0, 3, {'was_impossible': False}),
#  ('202', '868', 3.0, 3, {'was_impossible': False}),
#  ('597', '261', 4.0, 3, {'was_impossible': False}),
#  ('411', '42', 4.0, 3, {'was_impossible': False}),
#  ('132', '748', 3.0, 3, {'was_impossible': False}),
#  ('692', '530', 4.0, 3, {'was_impossible': False}),
#  ('50', '444', 5.0, 3, {'was_impossible': False}),
#  ('355', '650', 2.0, 3, {'was_impossible': False}),
#  ('347', '393', 4.0, 3, {'was_impossible': False}),
#  ('197', '621', 4.0, 3, {'was_impossible': False}),
#  ('815', '447', 3.0, 3, {'was_impossible': False}),
#  ('481', '326', 1.0, 3, {'was_impossible': False}),
#  ('748', '317', 5.0, 3, {'was_impossible': False}),
#  ('578', '246', 2.0, 3, {'was_impossible': False}),
#  ('317', '659', 4.0, 3, {'was_impossible': False}),
#  ('135', '378', 2.0, 3, {'was_impossible': False}),
#  ('458', '238', 4.0, 3, {'was_impossible': False}),
#  ('228', '276', 4.0, 3, {'was_impossible': False}),
#  ('71', '851', 4.0, 3, {'was_impossible': False}),
#  ('427', '239', 5.0, 3, {'was_impossible': False}),
#  ('158', '13', 1.0, 3, {'was_impossible': False}),
#  ('679', '495', 3.0, 3, {'was_impossible': False}),
#  ('490', '848', 5.0, 3, {'was_impossible': False}),
#  ('11', '640', 4.0, 3, {'was_impossible': False}),
#  ('339', '587', 3.0, 3, {'was_impossible': False}),
#  ('357', '903', 5.0, 3, {'was_impossible': False}),
#  ('505', '383', 4.0, 3, {'was_impossible': False}),
#  ('1151', '435', 1.0, 3, {'was_impossible': False}),
#  ('32', '354', 3.0, 3, {'was_impossible': False}),
#  ('129', '592', 5.0, 3, {'was_impossible': False}),
#  ('651', '846', 3.0, 3, {'was_impossible': False}),
#  ('141', '42', 3.0, 3, {'was_impossible': False}),
#  ('273', '682', 4.0, 3, {'was_impossible': False}),
#  ('1409', '505', 3.0, 3, {'was_impossible': False}),
#  ('8', '280', 5.0, 3, {'was_impossible': False}),
#  ('649', '379', 4.0, 3, {'was_impossible': False}),
#  ('771', '660', 2.0, 3, {'was_impossible': False}),
#  ('210', '313', 4.0, 3, {'was_impossible': False}),
#  ('657', '571', 4.0, 3, {'was_impossible': False}),
#  ('248', '460', 4.0, 3, {'was_impossible': False}),
#  ('831', '457', 2.0, 3, {'was_impossible': False}),
#  ('609', '632', 3.0, 3, {'was_impossible': False}),
#  ('7', '301', 4.0, 3, {'was_impossible': False}),
#  ('540', '796', 2.0, 3, {'was_impossible': False}),
#  ('479', '83', 5.0, 3, {'was_impossible': False}),
#  ('294', '9', 4.0, 3, {'was_impossible': False}),
#  ('70', '311', 4.0, 3, {'was_impossible': False}),
#  ('235', '94', 4.0, 3, {'was_impossible': False}),
#  ('258', '758', 4.0, 3, {'was_impossible': False}),
#  ('271', '740', 2.0, 3, {'was_impossible': False}),
#  ('676', '579', 3.0, 3, {'was_impossible': False}),
#  ('672', '776', 3.0, 3, {'was_impossible': False}),
#  ('993', '116', 2.0, 3, {'was_impossible': False}),
#  ('462', '344', 2.0, 3, {'was_impossible': False}),
#  ('588', '435', 4.0, 3, {'was_impossible': False}),
#  ('430', '325', 5.0, 3, {'was_impossible': False}),
#  ('49', '487', 4.0, 3, {'was_impossible': False}),
#  ('82', '452', 3.0, 3, {'was_impossible': False}),
#  ('216', '639', 3.0, 3, {'was_impossible': False}),
#  ('1231', '130', 4.0, 3, {'was_impossible': False}),
#  ('272', '479', 4.0, 3, {'was_impossible': False}),
#  ('125', '450', 4.0, 3, {'was_impossible': False}),
#  ('93', '889', 3.0, 3, {'was_impossible': False}),
#  ('25', '194', 2.0, 3, {'was_impossible': False}),
#  ('90', '222', 2.0, 3, {'was_impossible': False}),
#  ('433', '379', 4.0, 3, {'was_impossible': False}),
#  ('529', '148', 5.0, 3, {'was_impossible': False}),
#  ('498', '7', 5.0, 3, {'was_impossible': False}),
#  ('214', '766', 2.0, 3, {'was_impossible': False}),
#  ('1070', '264', 4.0, 3, {'was_impossible': False}),
#  ('315', '674', 3.0, 3, {'was_impossible': False}),
#  ('89', '746', 4.0, 3, {'was_impossible': False}),
#  ('529', '269', 5.0, 3, {'was_impossible': False}),
#  ('258', '926', 4.0, 3, {'was_impossible': False}),
#  ('186', '222', 5.0, 3, {'was_impossible': False}),
#  ('612', '846', 5.0, 3, {'was_impossible': False}),
#  ('300', '682', 2.0, 3, {'was_impossible': False}),
#  ('215', '575', 3.0, 3, {'was_impossible': False}),
#  ('98', '270', 5.0, 3, {'was_impossible': False}),
#  ('1116', '426', 4.0, 3, {'was_impossible': False}),
#  ('190', '889', 3.0, 3, {'was_impossible': False}),
#  ('229', '536', 4.0, 3, {'was_impossible': False}),
#  ('531', '606', 5.0, 3, {'was_impossible': False}),
#  ('197', '321', 5.0, 3, {'was_impossible': False}),
#  ('174', '307', 4.0, 3, {'was_impossible': False}),
#  ('615', '932', 5.0, 3, {'was_impossible': False}),
#  ('331', '784', 4.0, 3, {'was_impossible': False}),
#  ('652', '773', 3.0, 3, {'was_impossible': False}),
#  ('478', '450', 5.0, 3, {'was_impossible': False}),
#  ('980', '92', 3.0, 3, {'was_impossible': False}),
#  ('121', '58', 2.0, 3, {'was_impossible': False}),
#  ('1502', '532', 1.0, 3, {'was_impossible': False}),
#  ('178', '82', 4.0, 3, {'was_impossible': False}),
#  ('159', '860', 3.0, 3, {'was_impossible': False}),
#  ('761', '927', 3.0, 3, {'was_impossible': False}),
#  ('268', '171', 4.0, 3, {'was_impossible': False}),
#  ('1192', '655', 4.0, 3, {'was_impossible': False}),
#  ('61', '537', 4.0, 3, {'was_impossible': False}),
#  ('1089', '682', 2.0, 3, {'was_impossible': False}),
#  ('144', '479', 4.0, 3, {'was_impossible': False}),
#  ('435', '87', 5.0, 3, {'was_impossible': False}),
#  ('124', '624', 4.0, 3, {'was_impossible': False}),
#  ('568', '881', 4.0, 3, {'was_impossible': False}),
#  ('819', '798', 3.0, 3, {'was_impossible': False}),
#  ('1299', '704', 3.0, 3, {'was_impossible': False}),
#  ('109', '932', 2.0, 3, {'was_impossible': False}),
#  ('963', '539', 4.0, 3, {'was_impossible': False}),
#  ('176', '165', 4.0, 3, {'was_impossible': False}),
#  ('142', '373', 3.0, 3, {'was_impossible': False}),
#  ('132', '588', 5.0, 3, {'was_impossible': False}),
#  ('151', '403', 4.0, 3, {'was_impossible': False}),
#  ('993', '223', 4.0, 3, {'was_impossible': False}),
#  ('181', '706', 4.0, 3, {'was_impossible': False}),
#  ('300', '578', 4.0, 3, {'was_impossible': False}),
#  ('1117', '345', 4.0, 3, {'was_impossible': False}),
#  ('125', '620', 2.0, 3, {'was_impossible': False}),
#  ('194', '645', 4.0, 3, {'was_impossible': False}),
#  ('636', '890', 3.0, 3, {'was_impossible': False}),
#  ('378', '650', 3.0, 3, {'was_impossible': False}),
#  ('173', '11', 5.0, 3, {'was_impossible': False}),
#  ('117', '222', 5.0, 3, {'was_impossible': False}),
#  ('97', '474', 5.0, 3, {'was_impossible': False}),
#  ('1661', '751', 1.0, 3, {'was_impossible': False}),
#  ('879', '173', 5.0, 3, {'was_impossible': False}),
#  ('1028', '714', 4.0, 3, {'was_impossible': False}),
#  ('430', '840', 5.0, 3, {'was_impossible': False}),
#  ('13', '196', 2.0, 3, {'was_impossible': False}),
#  ('166', '305', 4.0, 3, {'was_impossible': False}),
#  ('1048', '907', 5.0, 3, {'was_impossible': False}),
#  ('292', '811', 3.0, 3, {'was_impossible': False}),
#  ('494', '766', 3.0, 3, {'was_impossible': False}),
#  ('219', '178', 4.0, 3, {'was_impossible': False}),
#  ('256', '49', 4.0, 3, {'was_impossible': False}),
#  ('1167', '312', 4.0, 3, {'was_impossible': False}),
#  ('553', '671', 5.0, 3, {'was_impossible': False}),
#  ('680', '230', 4.0, 3, {'was_impossible': False}),
#  ('220', '253', 4.0, 3, {'was_impossible': False}),
#  ('123', '770', 3.0, 3, {'was_impossible': False}),
#  ('546', '479', 2.0, 3, {'was_impossible': False}),
#  ('339', '3', 3.0, 3, {'was_impossible': False}),
#  ('281', '201', 2.0, 3, {'was_impossible': False}),
#  ('323', '891', 3.0, 3, {'was_impossible': False}),
#  ('993', '92', 4.0, 3, {'was_impossible': False}),
#  ('191', '7', 5.0, 3, {'was_impossible': False}),
#  ('187', '456', 4.0, 3, {'was_impossible': False}),
#  ('179', '627', 5.0, 3, {'was_impossible': False}),
#  ('604', '846', 4.0, 3, {'was_impossible': False}),
#  ('96', '402', 5.0, 3, {'was_impossible': False}),
#  ('45', '339', 5.0, 3, {'was_impossible': False}),
#  ('234', '405', 5.0, 3, {'was_impossible': False}),
#  ('48', '452', 5.0, 3, {'was_impossible': False}),
#  ('162', '280', 3.0, 3, {'was_impossible': False}),
#  ('926', '59', 1.0, 3, {'was_impossible': False}),
#  ('96', '592', 5.0, 3, {'was_impossible': False}),
#  ('307', '112', 4.0, 3, {'was_impossible': False}),
#  ('271', '435', 4.0, 3, {'was_impossible': False}),
#  ('451', '109', 5.0, 3, {'was_impossible': False}),
#  ('153', '305', 3.0, 3, {'was_impossible': False}),
#  ('246', '560', 5.0, 3, {'was_impossible': False}),
#  ('370', '226', 3.0, 3, {'was_impossible': False}),
#  ('331', '129', 2.0, 3, {'was_impossible': False}),
#  ('1126', '696', 3.0, 3, {'was_impossible': False}),
#  ('1013', '141', 1.0, 3, {'was_impossible': False}),
#  ('419', '707', 3.0, 3, {'was_impossible': False}),
#  ('315', '856', 5.0, 3, {'was_impossible': False}),
#  ('172', '468', 4.0, 3, {'was_impossible': False}),
#  ('1018', '95', 3.0, 3, {'was_impossible': False}),
#  ('272', '288', 5.0, 3, {'was_impossible': False}),
#  ('82', '378', 4.0, 3, {'was_impossible': False}),
#  ('169', '373', 5.0, 3, {'was_impossible': False}),
#  ('487', '539', 3.0, 3, {'was_impossible': False}),
#  ('1021', '85', 3.0, 3, {'was_impossible': False}),
#  ('207', '828', 4.0, 3, {'was_impossible': False}),
#  ('174', '151', 5.0, 3, {'was_impossible': False}),
#  ('1312', '279', 3.0, 3, {'was_impossible': False}),
#  ('195', '406', 5.0, 3, {'was_impossible': False}),
#  ('313', '395', 3.0, 3, {'was_impossible': False}),
#  ('51', '682', 5.0, 3, {'was_impossible': False}),
#  ('762', '119', 4.0, 3, {'was_impossible': False}),
#  ('187', '663', 5.0, 3, {'was_impossible': False}),
#  ('1035', '379', 3.0, 3, {'was_impossible': False}),
#  ('194', '562', 5.0, 3, {'was_impossible': False}),
#  ('487', '474', 4.0, 3, {'was_impossible': False}),
#  ('357', '514', 4.0, 3, {'was_impossible': False}),
#  ('515', '343', 4.0, 3, {'was_impossible': False}),
#  ('471', '16', 3.0, 3, {'was_impossible': False}),
#  ('715', '394', 4.0, 3, {'was_impossible': False}),
#  ('87', '721', 3.0, 3, {'was_impossible': False}),
#  ('604', '311', 3.0, 3, {'was_impossible': False}),
#  ('552', '374', 4.0, 3, {'was_impossible': False}),
#  ('191', '398', 4.0, 3, {'was_impossible': False}),
#  ('242', '271', 4.0, 3, {'was_impossible': False}),
#  ('67', '92', 3.0, 3, {'was_impossible': False}),
#  ('559', '343', 3.0, 3, {'was_impossible': False}),
#  ('211', '638', 4.0, 3, {'was_impossible': False}),
#  ('313', '46', 5.0, 3, {'was_impossible': False}),
#  ('151', '279', 4.0, 3, {'was_impossible': False}),
#  ('55', '144', 4.0, 3, {'was_impossible': False}),
#  ('1618', '528', 1.0, 3, {'was_impossible': False}),
#  ('172', '1', 5.0, 3, {'was_impossible': False}),
#  ('260', '7', 1.0, 3, {'was_impossible': False}),
#  ('288', '374', 4.0, 3, {'was_impossible': False}),
#  ('790', '109', 2.0, 3, {'was_impossible': False}),
#  ('161', '37', 5.0, 3, {'was_impossible': False}),
#  ('14', '361', 4.0, 3, {'was_impossible': False}),
#  ('151', '380', 4.0, 3, {'was_impossible': False}),
#  ('802', '405', 1.0, 3, {'was_impossible': False}),
#  ('1278', '736', 1.0, 3, {'was_impossible': False}),
#  ('132', '867', 3.0, 3, {'was_impossible': False}),
#  ('678', '634', 2.0, 3, {'was_impossible': False}),
#  ('292', '437', 5.0, 3, {'was_impossible': False}),
#  ('79', '592', 4.0, 3, {'was_impossible': False}),
#  ('19', '181', 1.0, 3, {'was_impossible': False}),
#  ('663', '58', 2.0, 3, {'was_impossible': False}),
#  ('1038', '459', 4.0, 3, {'was_impossible': False}),
#  ('135', '918', 1.0, 3, {'was_impossible': False}),
#  ('322', '772', 4.0, 3, {'was_impossible': False}),
#  ('693', '201', 4.0, 3, {'was_impossible': False}),
#  ('161', '711', 4.0, 3, {'was_impossible': False}),
#  ('127', '697', 5.0, 3, {'was_impossible': False}),
#  ('10', '662', 4.0, 3, {'was_impossible': False}),
#  ('290', '347', 3.0, 3, {'was_impossible': False}),
#  ('179', '508', 4.0, 3, {'was_impossible': False}),
#  ('815', '93', 4.0, 3, {'was_impossible': False}),
#  ('182', '533', 3.0, 3, {'was_impossible': False}),
#  ('456', '81', 1.0, 3, {'was_impossible': False}),
#  ('300', '66', 5.0, 3, {'was_impossible': False}),
#  ('219', '868', 2.0, 3, {'was_impossible': False}),
#  ('282', '606', 4.0, 3, {'was_impossible': False}),
#  ('1047', '552', 3.0, 3, {'was_impossible': False}),
#  ('584', '244', 5.0, 3, {'was_impossible': False}),
#  ('1180', '279', 2.0, 3, {'was_impossible': False}),
#  ('193', '916', 4.0, 3, {'was_impossible': False}),
#  ('28', '867', 5.0, 3, {'was_impossible': False}),
#  ('509', '271', 4.0, 3, {'was_impossible': False}),
#  ('208', '862', 2.0, 3, {'was_impossible': False}),
#  ('661', '527', 5.0, 3, {'was_impossible': False}),
#  ('429', '648', 4.0, 3, {'was_impossible': False}),
#  ('506', '911', 3.0, 3, {'was_impossible': False}),
#  ('505', '10', 4.0, 3, {'was_impossible': False}),
#  ('172', '704', 2.0, 3, {'was_impossible': False}),
#  ('430', '297', 1.0, 3, {'was_impossible': False}),
#  ('20', '58', 1.0, 3, {'was_impossible': False}),
#  ('1248', '145', 3.0, 3, {'was_impossible': False}),
#  ('1007', '270', 5.0, 3, {'was_impossible': False}),
#  ('69', '151', 4.0, 3, {'was_impossible': False}),
#  ('655', '426', 4.0, 3, {'was_impossible': False}),
#  ('1422', '201', 2.0, 3, {'was_impossible': False}),
#  ('373', '56', 4.0, 3, {'was_impossible': False}),
#  ('242', '617', 3.0, 3, {'was_impossible': False}),
#  ('232', '280', 3.0, 3, {'was_impossible': False}),
#  ('285', '315', 5.0, 3, {'was_impossible': False}),
#  ('286', '828', 4.0, 3, {'was_impossible': False}),
#  ('194', '312', 4.0, 3, {'was_impossible': False}),
#  ('105', '933', 2.0, 3, {'was_impossible': False}),
#  ('63', '541', 3.0, 3, {'was_impossible': False}),
#  ('168', '493', 5.0, 3, {'was_impossible': False}),
#  ('127', '64', 5.0, 3, {'was_impossible': False}),
#  ('129', '892', 3.0, 3, {'was_impossible': False}),
#  ('110', '196', 1.0, 3, {'was_impossible': False}),
#  ('216', '500', 4.0, 3, {'was_impossible': False}),
#  ('293', '665', 4.0, 3, {'was_impossible': False}),
#  ('380', '927', 5.0, 3, {'was_impossible': False}),
#  ('1031', '756', 2.0, 3, {'was_impossible': False}),
#  ('24', '386', 4.0, 3, {'was_impossible': False}),
#  ('546', '634', 4.0, 3, {'was_impossible': False}),
#  ('98', '305', 4.0, 3, {'was_impossible': False}),
#  ('475', '854', 4.0, 3, {'was_impossible': False}),
#  ('56', '889', 5.0, 3, {'was_impossible': False}),
#  ('245', '276', 3.0, 3, {'was_impossible': False}),
#  ('495', '233', 4.0, 3, {'was_impossible': False}),
#  ('231', '545', 4.0, 3, {'was_impossible': False}),
#  ('291', '344', 3.0, 3, {'was_impossible': False}),
#  ('56', '528', 3.0, 3, {'was_impossible': False}),
#  ('496', '605', 5.0, 3, {'was_impossible': False}),
#  ('880', '595', 3.0, 3, {'was_impossible': False}),
#  ('245', '540', 3.0, 3, {'was_impossible': False}),
#  ('1202', '936', 4.0, 3, {'was_impossible': False}),
#  ('472', '344', 3.0, 3, {'was_impossible': False}),
#  ('204', '338', 3.0, 3, {'was_impossible': False}),
#  ('200', '345', 4.0, 3, {'was_impossible': False}),
#  ('21', '160', 1.0, 3, {'was_impossible': False}),
#  ('275', '145', 2.0, 3, {'was_impossible': False}),
#  ('1074', '122', 4.0, 3, {'was_impossible': False}),
#  ('153', '479', 4.0, 3, {'was_impossible': False}),
#  ('161', '472', 5.0, 3, {'was_impossible': False}),
#  ('340', '752', 4.0, 3, {'was_impossible': False}),
#  ('752', '863', 4.0, 3, {'was_impossible': False}),
#  ('300', '504', 4.0, 3, {'was_impossible': False}),
#  ('286', '701', 4.0, 3, {'was_impossible': False}),
#  ('448', '774', 2.0, 3, {'was_impossible': False}),
#  ('419', '381', 5.0, 3, {'was_impossible': False}),
#  ('285', '305', 5.0, 3, {'was_impossible': False}),
#  ('559', '881', 2.0, 3, {'was_impossible': False}),
#  ('732', '437', 4.0, 3, {'was_impossible': False}),
#  ('959', '363', 1.0, 3, {'was_impossible': False}),
#  ('1392', '409', 1.0, 3, {'was_impossible': False}),
#  ('429', '236', 1.0, 3, {'was_impossible': False}),
#  ('448', '367', 4.0, 3, {'was_impossible': False}),
#  ('66', '340', 5.0, 3, {'was_impossible': False}),
#  ('1136', '244', 3.0, 3, {'was_impossible': False}),
#  ('218', '648', 3.0, 3, {'was_impossible': False}),
#  ('654', '840', 4.0, 3, {'was_impossible': False}),
#  ('518', '253', 5.0, 3, {'was_impossible': False}),
#  ('147', '666', 3.0, 3, {'was_impossible': False}),
#  ('558', '293', 3.0, 3, {'was_impossible': False}),
#  ('878', '397', 1.0, 3, {'was_impossible': False}),
#  ('609', '347', 4.0, 3, {'was_impossible': False}),
#  ('553', '145', 3.0, 3, {'was_impossible': False}),
#  ('7', '65', 1.0, 3, {'was_impossible': False}),
#  ('245', '926', 3.0, 3, {'was_impossible': False}),
#  ('523', '781', 5.0, 3, {'was_impossible': False}),
#  ('327', '228', 1.0, 3, {'was_impossible': False}),
#  ('653', '276', 5.0, 3, {'was_impossible': False}),
#  ('285', '696', 4.0, 3, {'was_impossible': False}),
#  ('900', '592', 4.0, 3, {'was_impossible': False}),
#  ('165', '734', 3.0, 3, {'was_impossible': False}),
#  ('200', '102', 3.0, 3, {'was_impossible': False}),
#  ('144', '296', 4.0, 3, {'was_impossible': False}),
#  ('294', '264', 3.0, 3, {'was_impossible': False}),
#  ('301', '425', 4.0, 3, {'was_impossible': False}),
#  ('371', '5', 1.0, 3, {'was_impossible': False}),
#  ('845', '654', 4.0, 3, {'was_impossible': False}),
#  ('50', '832', 3.0, 3, {'was_impossible': False}),
#  ('106', '7', 4.0, 3, {'was_impossible': False}),
#  ('121', '445', 1.0, 3, {'was_impossible': False}),
#  ('1615', '782', 3.0, 3, {'was_impossible': False}),
#  ('480', '804', 5.0, 3, {'was_impossible': False}),
#  ('387', '896', 2.0, 3, {'was_impossible': False}),
#  ('196', '577', 5.0, 3, {'was_impossible': False}),
#  ('408', '344', 5.0, 3, {'was_impossible': False}),
#  ('300', '204', 3.0, 3, {'was_impossible': False}),
#  ('641', '426', 4.0, 3, {'was_impossible': False}),
#  ('735', '42', 4.0, 3, {'was_impossible': False}),
#  ('391', '405', 1.0, 3, {'was_impossible': False}),
#  ('169', '523', 5.0, 3, {'was_impossible': False}),
#  ('291', '851', 4.0, 3, {'was_impossible': False}),
#  ('148', '805', 2.0, 3, {'was_impossible': False}),
#  ('723', '760', 2.0, 3, {'was_impossible': False}),
#  ('241', '244', 4.0, 3, {'was_impossible': False}),
#  ('56', '850', 1.0, 3, {'was_impossible': False}),
#  ('504', '31', 5.0, 3, {'was_impossible': False}),
#  ('655', '911', 5.0, 3, {'was_impossible': False}),
#  ('286', '597', 3.0, 3, {'was_impossible': False}),
#  ('265', '766', 3.0, 3, {'was_impossible': False}),
#  ('1195', '449', 5.0, 3, {'was_impossible': False}),
#  ('427', '669', 4.0, 3, {'was_impossible': False}),
#  ('193', '488', 3.0, 3, {'was_impossible': False}),
#  ('118', '927', 5.0, 3, {'was_impossible': False}),
#  ('642', '308', 5.0, 3, {'was_impossible': False}),
#  ('470', '709', 3.0, 3, {'was_impossible': False}),
#  ('239', '493', 5.0, 3, {'was_impossible': False}),
#  ('1228', '640', 4.0, 3, {'was_impossible': False}),
#  ('252', '659', 4.0, 3, {'was_impossible': False}),
#  ('740', '637', 2.0, 3, {'was_impossible': False}),
#  ('452', '457', 3.0, 3, {'was_impossible': False}),
#  ('1', '250', 4.0, 3, {'was_impossible': False}),
#  ('732', '715', 3.0, 3, {'was_impossible': False}),
#  ('367', '738', 3.0, 3, {'was_impossible': False}),
#  ('90', '450', 4.0, 3, {'was_impossible': False}),
#  ('65', '643', 4.0, 3, {'was_impossible': False}),
#  ('562', '627', 2.0, 3, {'was_impossible': False}),
#  ('734', '416', 3.0, 3, {'was_impossible': False}),
#  ('750', '532', 5.0, 3, {'was_impossible': False}),
#  ('9', '185', 4.0, 3, {'was_impossible': False}),
#  ('43', '659', 4.0, 3, {'was_impossible': False}),
#  ('111', '560', 3.0, 3, {'was_impossible': False}),
#  ('97', '506', 4.0, 3, {'was_impossible': False}),
#  ('195', '458', 4.0, 3, {'was_impossible': False}),
#  ('157', '693', 4.0, 3, {'was_impossible': False}),
#  ('187', '606', 4.0, 3, {'was_impossible': False}),
#  ('69', '658', 4.0, 3, {'was_impossible': False}),
#  ('170', '354', 4.0, 3, {'was_impossible': False}),
#  ('392', '472', 4.0, 3, {'was_impossible': False}),
#  ('66', '291', 4.0, 3, {'was_impossible': False}),
#  ('369', '897', 4.0, 3, {'was_impossible': False}),
#  ('771', '195', 2.0, 3, {'was_impossible': False}),
#  ('270', '130', 5.0, 3, {'was_impossible': False}),
#  ('73', '712', 5.0, 3, {'was_impossible': False}),
#  ('174', '13', 4.0, 3, {'was_impossible': False}),
#  ('255', '108', 2.0, 3, {'was_impossible': False}),
#  ('100', '936', 4.0, 3, {'was_impossible': False}),
#  ('174', '908', 3.0, 3, {'was_impossible': False}),
#  ('545', '774', 1.0, 3, {'was_impossible': False}),
#  ('292', '486', 4.0, 3, {'was_impossible': False}),
#  ('723', '405', 1.0, 3, {'was_impossible': False}),
#  ('132', '298', 5.0, 3, {'was_impossible': False}),
#  ('8', '312', 5.0, 3, {'was_impossible': False}),
#  ('597', '644', 4.0, 3, {'was_impossible': False}),
#  ('121', '717', 2.0, 3, {'was_impossible': False}),
#  ('931', '416', 3.0, 3, {'was_impossible': False}),
#  ('44', '343', 3.0, 3, {'was_impossible': False}),
#  ('230', '763', 3.0, 3, {'was_impossible': False}),
#  ('92', '327', 4.0, 3, {'was_impossible': False}),
#  ('1119', '561', 3.0, 3, {'was_impossible': False}),
#  ('252', '487', 1.0, 3, {'was_impossible': False}),
#  ('489', '426', 5.0, 3, {'was_impossible': False}),
#  ('569', '130', 3.0, 3, {'was_impossible': False}),
#  ('484', '533', 3.0, 3, {'was_impossible': False}),
#  ('231', '757', 2.0, 3, {'was_impossible': False}),
#  ('508', '406', 4.0, 3, {'was_impossible': False}),
#  ('659', '567', 4.0, 3, {'was_impossible': False}),
#  ('147', '894', 3.0, 3, {'was_impossible': False}),
#  ('679', '269', 1.0, 3, {'was_impossible': False}),
#  ('367', '311', 3.0, 3, {'was_impossible': False}),
#  ('989', '747', 3.0, 3, {'was_impossible': False}),
#  ('505', '835', 3.0, 3, {'was_impossible': False}),
#  ('834', '472', 3.0, 3, {'was_impossible': False}),
#  ('470', '880', 4.0, 3, {'was_impossible': False}),
#  ('400', '450', 3.0, 3, {'was_impossible': False}),
#  ('167', '727', 2.0, 3, {'was_impossible': False}),
#  ('942', '805', 3.0, 3, {'was_impossible': False}),
#  ('322', '90', 4.0, 3, {'was_impossible': False}),
#  ('109', '246', 5.0, 3, {'was_impossible': False}),
#  ('96', '387', 4.0, 3, {'was_impossible': False}),
#  ('17', '1', 3.0, 3, {'was_impossible': False}),
#  ('156', '421', 5.0, 3, {'was_impossible': False}),
#  ('1039', '796', 4.0, 3, {'was_impossible': False}),
#  ('286', '257', 5.0, 3, {'was_impossible': False}),
#  ('172', '244', 4.0, 3, {'was_impossible': False}),
#  ('313', '646', 5.0, 3, {'was_impossible': False}),
#  ('298', '577', 4.0, 3, {'was_impossible': False}),
#  ('1204', '942', 4.0, 3, {'was_impossible': False}),
#  ('143', '621', 2.0, 3, {'was_impossible': False}),
#  ('786', '262', 3.0, 3, {'was_impossible': False}),
#  ('815', '365', 3.0, 3, {'was_impossible': False}),
#  ('286', '745', 1.0, 3, {'was_impossible': False}),
#  ('1118', '336', 4.0, 3, {'was_impossible': False}),
#  ('686', '301', 4.0, 3, {'was_impossible': False}),
#  ('183', '600', 5.0, 3, {'was_impossible': False}),
#  ('73', '749', 4.0, 3, {'was_impossible': False}),
#  ('118', '642', 3.0, 3, {'was_impossible': False}),
#  ('176', '916', 4.0, 3, {'was_impossible': False}),
#  ('1010', '537', 2.0, 3, {'was_impossible': False}),
#  ('482', '537', 4.0, 3, {'was_impossible': False}),
#  ('288', '894', 3.0, 3, {'was_impossible': False}),
#  ('567', '504', 2.0, 3, {'was_impossible': False}),
#  ('304', '400', 4.0, 3, {'was_impossible': False}),
#  ('746', '297', 3.0, 3, {'was_impossible': False}),
#  ('96', '850', 4.0, 3, {'was_impossible': False}),
#  ('24', '921', 3.0, 3, {'was_impossible': False}),
#  ('216', '862', 5.0, 3, {'was_impossible': False}),
#  ('210', '848', 5.0, 3, {'was_impossible': False}),
#  ('566', '43', 3.0, 3, {'was_impossible': False}),
#  ('283', '655', 3.0, 3, {'was_impossible': False}),
#  ('576', '346', 3.0, 3, {'was_impossible': False}),
#  ('257', '432', 5.0, 3, {'was_impossible': False}),
#  ('563', '7', 2.0, 3, {'was_impossible': False}),
#  ('357', '788', 4.0, 3, {'was_impossible': False}),
#  ('1473', '280', 3.0, 3, {'was_impossible': False}),
#  ('174', '751', 4.0, 3, {'was_impossible': False}),
#  ('243', '691', 1.0, 3, {'was_impossible': False}),
#  ('11', '610', 4.0, 3, {'was_impossible': False}),
#  ('395', '295', 4.0, 3, {'was_impossible': False}),
#  ('507', '226', 2.0, 3, {'was_impossible': False}),
#  ('948', '880', 4.0, 3, {'was_impossible': False}),
#  ('286', '163', 3.0, 3, {'was_impossible': False}),
#  ('882', '695', 4.0, 3, {'was_impossible': False}),
#  ('328', '832', 3.0, 3, {'was_impossible': False}),
#  ('769', '709', 3.0, 3, {'was_impossible': False}),
#  ('709', '92', 2.0, 3, {'was_impossible': False}),
#  ('3', '654', 3.0, 3, {'was_impossible': False}),
#  ('432', '795', 3.0, 3, {'was_impossible': False}),
#  ('117', '162', 4.0, 3, {'was_impossible': False}),
#  ('465', '399', 3.0, 3, {'was_impossible': False}),
#  ('99', '642', 2.0, 3, {'was_impossible': False}),
#  ('126', '390', 5.0, 3, {'was_impossible': False}),
#  ('479', '308', 5.0, 3, {'was_impossible': False}),
#  ('1074', '87', 3.0, 3, {'was_impossible': False}),
#  ('662', '796', 5.0, 3, {'was_impossible': False}),
#  ('612', '830', 4.0, 3, {'was_impossible': False}),
#  ('680', '782', 1.0, 3, {'was_impossible': False}),
#  ('222', '895', 3.0, 3, {'was_impossible': False}),
#  ('591', '632', 4.0, 3, {'was_impossible': False}),
#  ('597', '26', 2.0, 3, {'was_impossible': False}),
#  ('234', '94', 5.0, 3, {'was_impossible': False}),
#  ('1025', '181', 1.0, 3, {'was_impossible': False}),
#  ('455', '130', 4.0, 3, {'was_impossible': False}),
#  ('1028', '534', 5.0, 3, {'was_impossible': False}),
#  ('221', '445', 1.0, 3, {'was_impossible': False}),
#  ('435', '876', 4.0, 3, {'was_impossible': False}),
#  ('370', '79', 2.0, 3, {'was_impossible': False}),
#  ('137', '490', 3.0, 3, {'was_impossible': False}),
#  ('762', '59', 4.0, 3, {'was_impossible': False}),
#  ('139', '450', 5.0, 3, {'was_impossible': False}),
#  ('321', '574', 1.0, 3, {'was_impossible': False}),
#  ('875', '587', 1.0, 3, {'was_impossible': False}),
#  ('1218', '94', 4.0, 3, {'was_impossible': False}),
#  ('3', '453', 4.0, 3, {'was_impossible': False}),
#  ('185', '686', 5.0, 3, {'was_impossible': False}),
#  ('173', '862', 5.0, 3, {'was_impossible': False}),
#  ('197', '207', 4.0, 3, {'was_impossible': False}),
#  ('278', '760', 4.0, 3, {'was_impossible': False}),
#  ('707', '655', 3.0, 3, {'was_impossible': False}),
#  ('582', '338', 5.0, 3, {'was_impossible': False}),
#  ('193', '290', 4.0, 3, {'was_impossible': False}),
#  ('675', '537', 3.0, 3, {'was_impossible': False}),
#  ('762', '45', 4.0, 3, {'was_impossible': False}),
#  ('401', '314', 3.0, 3, {'was_impossible': False}),
#  ('216', '468', 5.0, 3, {'was_impossible': False}),
#  ('72', '13', 4.0, 3, {'was_impossible': False}),
#  ('730', '316', 4.0, 3, {'was_impossible': False}),
#  ('310', '942', 4.0, 3, {'was_impossible': False}),
#  ('742', '336', 3.0, 3, {'was_impossible': False}),
#  ('291', '2', 3.0, 3, {'was_impossible': False}),
#  ('387', '796', 3.0, 3, {'was_impossible': False}),
#  ('294', '100', 4.0, 3, {'was_impossible': False}),
#  ('268', '139', 4.0, 3, {'was_impossible': False}),
#  ('1076', '642', 2.0, 3, {'was_impossible': False}),
#  ('259', '450', 3.0, 3, {'was_impossible': False}),
#  ('435', '178', 4.0, 3, {'was_impossible': False}),
#  ('597', '455', 3.0, 3, {'was_impossible': False}),
#  ('926', '57', 3.0, 3, {'was_impossible': False}),
#  ('322', '752', 1.0, 3, {'was_impossible': False}),
#  ('305', '428', 3.0, 3, {'was_impossible': False}),
#  ('346', '537', 3.0, 3, {'was_impossible': False}),
#  ('210', '256', 4.0, 3, {'was_impossible': False}),
#  ('89', '297', 4.0, 3, {'was_impossible': False}),
#  ('879', '193', 3.0, 3, {'was_impossible': False}),
#  ('136', '271', 3.0, 3, {'was_impossible': False}),
#  ('38', '532', 3.0, 3, {'was_impossible': False}),
#  ('278', '708', 4.0, 3, {'was_impossible': False}),
#  ('227', '8', 4.0, 3, {'was_impossible': False}),
#  ('274', '447', 1.0, 3, {'was_impossible': False}),
#  ('50', '433', 5.0, 3, {'was_impossible': False}),
#  ('755', '290', 4.0, 3, {'was_impossible': False}),
#  ('357', '42', 5.0, 3, {'was_impossible': False}),
#  ('31', '474', 4.0, 3, {'was_impossible': False}),
#  ('80', '749', 1.0, 3, {'was_impossible': False}),
#  ('307', '444', 3.0, 3, {'was_impossible': False}),
#  ('841', '851', 3.0, 3, {'was_impossible': False}),
#  ('187', '94', 4.0, 3, {'was_impossible': False}),
#  ('111', '588', 1.0, 3, {'was_impossible': False}),
#  ('385', '521', 3.0, 3, {'was_impossible': False}),
#  ('200', '890', 4.0, 3, {'was_impossible': False}),
#  ('346', '752', 4.0, 3, {'was_impossible': False}),
#  ('283', '527', 4.0, 3, {'was_impossible': False}),
#  ('1109', '629', 4.0, 3, {'was_impossible': False}),
#  ('126', '1', 2.0, 3, {'was_impossible': False}),
#  ('866', '416', 4.0, 3, {'was_impossible': False}),
#  ('570', '671', 3.0, 3, {'was_impossible': False}),
#  ('117', '277', 4.0, 3, {'was_impossible': False}),
#  ...]

# %% [markdown]
# - prediction 객체의 uid, iid, details 속성에 접근하려면, 객채명.uid 등의 형식으로 가능함

# %% [markdown]
# #### predict()

# %%
uid = str(120)
iid = str(282)

pred = algo.predict(uid, iid)
pred
# Out:
# Prediction(uid='120', iid='282', r_ui=None, est=3.5114147666251547, details={'was_impossible': False})

# %% [markdown]
# - predict(uid, iid) 인자를 적어주어야하며, str형태여야함!
#
# - prediction 객체 형태로 한개의 값에 대한 실제값 및 예측값 반환
#
#
# - test()메서드는 predict()메서드에 모든 사용자아이디, 아이템아이디를 입력한 결과라고 보면 됨

# %% [markdown]
# ### 평가
# - rmse: 실제값과 예측값 차이 평가

# %%
accuracy.rmse(predictions)
# Out:
# RMSE: 0.9467
# 0.9466860806937948

# %% [markdown]
# ## Surprise 주요 모듈 소개
# - surprise api는 로우 레벨로된 데이터 세트만 적용할 수 있음
#     - row: 사용자, column: 아이템, value: 평점으로 구분된 데이터가 아닌, 컬럼명이 사용자, 아이템, 평점인 데이터프레임으로 로딩해야 함
# - <span style = 'background-color: #ffdce0'>첫번째 컬럼은 사용자, 두번째 컬럼은 아이템, 세번째 컬럼은 평점으로 가정해서 데이터를 로딩하고, 네번째 컬럼부터는 로딩을 수행하지 않음</span>
#     - 따라서, 데이터 세트의 순서를 잘 정리해두어야함

# %% [markdown]
# ```
# 1. Dataset.load_builtin(name = 'ml-100k')
#     - 무비렌즈 아카이브 FTP 서버에서 무비렌즈 데이터를 내려받아서 .surprise_data 디렉토리 밑에 저장함
#     - 해당 디렉토리에 데이터가 있으면 FTP서버에서 다운로드하지 않고 해당 데이터를 이용함
#
# 2. Dataset.load_from_file(file_path, reader)
#     - os 파일에서 데이터를 로딩할 때 사용함
#     - ',', '\t' 등으로 컬럼이 분리된 포맷의 os파일에서 데이터를 로딩함
#
# 3. Dataset.load_from_df(df, reader)
#     - 판다스의 데이터프레임에서 데이터를 로딩함
# ```

# %% [markdown]
# ### Dataset.load_from_file API 이용

# %%
import pandas as pd

# 데이터 불러오기
ratings = pd.read_csv('./dataset_ml_latest_small/ratings.csv')
display(ratings.head())

# Surprise api로 데이터를 불러오기 위해 헤더를 제거 후 ratings_noh로 저장함
ratings.to_csv('./dataset_ml_latest_small/ratings_noh.csv', index = False, header = False)
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %% [markdown]
# #### 데이터 파싱 후 불러오기

# %% [markdown]
# - Reader 클래스 생성자에 각 필드의 컬럼명, 컬럼 분리문자, ratings의 최소/최대 평점을 입력해 객체 생성
# - load_from_file()에 생성된 reader 객체를 참조해서 데이터 파일을 파싱함

# %%
from surprise import Reader

# 데이터 파싱을 위한 Reader 객체 생성
reader = Reader(line_format = 'user item rating timestamp',
                sep = ',',
                rating_scale = (0.5, 5))

# 데이터 불러오기
data = Dataset.load_from_file('./dataset_ml_latest_small/ratings_noh.csv', reader = reader)

# %% [markdown]
# #### 학습

# %%
# 학습용/테스트용 데이터 분리
trainset, testset = train_test_split(data, test_size = 0.25, random_state = 0)

# SVD 알고리즘 객체 생성
algo = SVD(n_factors = 50, random_state = 0)

# 학습
algo.fit(trainset)

# %% [markdown]
# #### 예측

# %%
predictions = algo.test(testset)
predictions[:10]
# Out:
# [Prediction(uid='63', iid='2000', r_ui=3.0, est=3.5016267817280697, details={'was_impossible': False}),
#  Prediction(uid='31', iid='788', r_ui=2.0, est=3.2840758900255937, details={'was_impossible': False}),
#  Prediction(uid='159', iid='6373', r_ui=4.0, est=2.804939396068158, details={'was_impossible': False}),
#  Prediction(uid='105', iid='81564', r_ui=3.0, est=3.9326180027723914, details={'was_impossible': False}),
#  Prediction(uid='394', iid='480', r_ui=3.0, est=3.3135580105479114, details={'was_impossible': False}),
#  Prediction(uid='181', iid='587', r_ui=5.0, est=3.0461782765780097, details={'was_impossible': False}),
#  Prediction(uid='224', iid='3072', r_ui=5.0, est=3.8999397231405495, details={'was_impossible': False}),
#  Prediction(uid='328', iid='1391', r_ui=4.5, est=2.573115352187292, details={'was_impossible': False}),
#  Prediction(uid='50', iid='104283', r_ui=3.5, est=2.6708184859984074, details={'was_impossible': False}),
#  Prediction(uid='125', iid='176371', r_ui=3.5, est=3.8777290199943573, details={'was_impossible': False})]

# %% [markdown]
# #### 평가

# %%
accuracy.rmse(predictions)
# Out:
# RMSE: 0.8682
# 0.8681952927143516

# %% [markdown]
# ### Dataset.load_from_df API 이용

# %%
import pandas as pd
from surprise import Reader, Dataset

# csv파일 불러오기
ratings = pd.read_csv('./dataset_ml_latest_small/ratings.csv')
display(ratings)

# 판다스 데이터프레임을 데이터 파싱 후 불러오기
reader = Reader(rating_scale = (0.5, 5.0))
data = Dataset.load_from_df(ratings[['userId', 'movieId', 'rating']], reader = reader)
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %% [markdown]
# #### 학습

# %%
# 학습/테스트용 데이터 분리
trainset, testset = train_test_split(data)

# 알고리즘 객체화
algo = SVD(n_factors = 50, random_state = 0)

# 학습
algo.fit(trainset)

# %% [markdown]
# #### 예측

# %%
predictions = algo.test(testset)
predictions[:20]
# Out:
# [Prediction(uid=202, iid=2761, r_ui=5.0, est=4.093668844364033, details={'was_impossible': False}),
#  Prediction(uid=47, iid=140247, r_ui=1.0, est=3.0384134077477474, details={'was_impossible': False}),
#  Prediction(uid=113, iid=3044, r_ui=3.0, est=3.5585746579826845, details={'was_impossible': False}),
#  Prediction(uid=607, iid=2422, r_ui=2.0, est=2.9304744384113746, details={'was_impossible': False}),
#  Prediction(uid=153, iid=2174, r_ui=1.0, est=2.225333895190696, details={'was_impossible': False}),
#  Prediction(uid=567, iid=88140, r_ui=1.5, est=2.47197180945177, details={'was_impossible': False}),
#  Prediction(uid=63, iid=108932, r_ui=5.0, est=3.6581398757047254, details={'was_impossible': False}),
#  Prediction(uid=492, iid=810, r_ui=3.0, est=3.3128739559457236, details={'was_impossible': False}),
#  Prediction(uid=226, iid=532, r_ui=3.0, est=3.097956294716411, details={'was_impossible': False}),
#  Prediction(uid=596, iid=1376, r_ui=4.0, est=3.422217396976879, details={'was_impossible': False}),
#  Prediction(uid=572, iid=1220, r_ui=2.0, est=3.983535621251987, details={'was_impossible': False}),
#  Prediction(uid=448, iid=114818, r_ui=2.5, est=2.7203270517254894, details={'was_impossible': False}),
#  Prediction(uid=414, iid=5068, r_ui=4.0, est=3.302289237857713, details={'was_impossible': False}),
#  Prediction(uid=495, iid=7163, r_ui=4.5, est=3.1099778931507673, details={'was_impossible': False}),
#  Prediction(uid=409, iid=910, r_ui=5.0, est=4.17168916301222, details={'was_impossible': False}),
#  Prediction(uid=607, iid=3499, r_ui=5.0, est=4.040972699285888, details={'was_impossible': False}),
#  Prediction(uid=40, iid=588, r_ui=4.0, est=4.362704457075198, details={'was_impossible': False}),
#  Prediction(uid=325, iid=4294, r_ui=3.0, est=3.3151658486869855, details={'was_impossible': False}),
#  Prediction(uid=111, iid=8957, r_ui=0.5, est=3.1157879280702363, details={'was_impossible': False}),
#  Prediction(uid=570, iid=586, r_ui=2.0, est=2.782876645411283, details={'was_impossible': False})]

# %% [markdown]
# #### 평가

# %%
accuracy.rmse( predictions)
# Out:
# RMSE: 0.8717
# 0.8716549066355299

# %% [markdown]
# ## Surprise 추천 알고리즘 클래스

# %% [markdown]
# - <b>SVD</b>: 행렬분해를 통한 잠재요인 협업 필터링을 위한 SVD알고리즘
# - <b>KNNBasic</b>: 최근접 이웃 협업 필터링을 위한 KNN 알고리즘
# - <b>BaselineOnly</b>: 사용자 Bias와 아이템 Bias를 감안한 SGD 베이스라인 알고리즘
# - 이 밖에도 SVD++, NMF등 다양한 유형의 알고리즘 수행할 수 있음
# <br><br>
# - Suprise SVD의 비용함수는 사용자 <span style = 'background-color: #ffdce0'>베이스라인 편향성을 감안한 평점 예측</span>에 Regularization(규제)을 적용한 것
#     - 파라미터:
#         - n_factors: 잠재요인 k의 개수, 디폴트는 100, 커질수록 정확도가 높아질 수 있으나 과적합 문제 발생
#         - n_epochs: SGD 수행 시 반복 횟수, 디폴트는 20
#         - biased(bool): 베이스라인 사용자 편향 적용 여부이며, 디폴트는 True

# %% [markdown]
# - 예측 성능 벤치마크 결과 사이트에서 확인 시,
#    <br>Baseline을 결합한 경우 성능 평가 수치가 대폭 향상함
#    <br><br>
#
# <b>Baseline</b>
# - Baseline이라는 의미는 각 개인이 평점을 부여하는 성향을 반영해 평점을 계산하는 방식임
# - 한 개인의 성향을 반영해 아이템 평가에 편향성 요소를 반영하여 평점을 부과하는 것
#     - ex) 싫은 소리를 벼로 안하는 사람의 경우는 전반적으로 평가에 후한 경향, 냉정한 평가를 해야한다고 생각하는 사람은 짠 평가를 하는 경향
#
# <br>
# <span style = 'background-color: #fff5b1'><b>베이스라인 평점 = 전체 평균 평점 + 사용자 편향 점수 + 아이템 편향 점수</b></span><br>
#     - 전체 평균 평점 =  모든 사용자의 아이템에 대한 평점을 평균한 값<br>
#     - 사용자 편향 점수 = 사용자별 아이템 평점 평균값 - 전체 평균 평점<br>
#     - 아이템 편향 점수 = 아이템별 평점 평균값 -전체 평균 평점<br>

# %% [markdown]
# ## 교차 검증과 하이퍼파라미터 튜닝
# - SURPRISE는 교차검증과 하이퍼파라미터 튜닝을 위해 사이킷런과 유사한 cross_validate(), GridSearchCV 클래스 제공

# %% [markdown]
# ### cross_validate()
# - surprise.model_selection 모듈 내에 존재
# - n개의 학습/검증 폴드 데이터 세트로 분리해 교차 검증을 수행하고 rmse, mae로 성능평가 진행함
# - 출력결과를 폴드별 성능 평가 수치와 전체 폴드의 평균 성능 평가 수치를 함께 보여줌

# %% [markdown]
# #### 데이터 파싱 후 불러오기

# %%
import pandas as pd


# 판다스 dataframe에서 surprise 데이터 세트로 데이터 로딩
ratings = pd.read_csv('./dataset_ml_latest_small/ratings.csv')

reader = Reader(rating_scale = (0.5, 5.0))
data = Dataset.load_from_df(ratings[['userId','movieId', 'rating']], reader = reader)

# %% [markdown]
# #### 교차 검증
# - cross_validate(알고리즘 객체, 데이터프레임, 평가방법(리스트 가능), 폴드개수, 출력 결과 자세히 나타내기 여부)

# %%
from surprise import SVD
from surprise.model_selection import cross_validate


# 알고리즘 객체화
algo = SVD(random_state = 0)


# 교차 검증( 알고리즘, 데이터프레임, 평가방법, 폴드 개수, 폴드별 출력 결과 나타내기 여부)
cross_validate(algo, data, measures = ['RMSE', 'MAE'], cv = 5, verbose = True)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.8709  0.8777  0.8717  0.8729  0.8771  0.8741  0.0028
# MAE (testset)     0.6678  0.6755  0.6701  0.6695  0.6758  0.6718  0.0033
# Fit time          0.77    0.78    0.79    0.77    0.77    0.77    0.01
# Test time         0.11    0.10    0.12    0.11    0.11    0.11    0.00
# {'test_rmse': array([0.87094075, 0.87771248, 0.87174445, 0.8728786 , 0.87705283]),
#  'test_mae': array([0.66781736, 0.67548552, 0.67013041, 0.66952606, 0.6758373 ]),
#  'fit_time': (0.7663037776947021,
#   0.7777009010314941,
#   0.7873952388763428,
#   0.7703745365142822,
#   0.769359827041626),
#  'test_time': (0.10899996757507324,
#   0.10479903221130371,
#   0.1165013313293457,
#   0.10977554321289062,
#   0.109375)}

# %% [markdown]
# #### GridSearchCV
# - 사이킷런의 GridSearchCV와 유사하게 교차 검증을 통한 하이퍼파라미터 최적화 수행
# - SVD의 경우 아래의 파라미터가 존재함
#     - n_epochs: 점진적 하강 방식(SGD) 반복 횟수 step지정
#     - n_factors: 잠재요인 개수 k 지정

# %%
from surprise.model_selection import GridSearchCV

# 최적화 파라미터를 딕셔너리형태로 지정
params = {'n_epochs': [20, 40, 60],
          'n_factors': [50, 100, 200]}


# 학습
# 폴드는 3개로 지정, 성능 평가는 rmse, mse로 수행하도록 gridsearchcv 구성
gs = GridSearchCV(SVD, params, measures = ['rmse', 'mae'], cv = 3 )
gs.fit(data)

# %%
# 최고 RMSE 평가 점수와 하이퍼파라미터 추출

print(np.round(gs.best_score['rmse'],3))
print(gs.best_params['rmse'])
# Out:
# 0.878
# {'n_epochs': 20, 'n_factors': 50}

# %% [markdown]
# ## Suprise를 이용한 개인화 영화 추천 시스템 구축

# %% [markdown]
# - surprise는 전체 데이터세트를 train_test_split()을 이용해 내부에서 사용하는 trainset 클래스 객체로 변환하지 않으면 fit()을 통해 학습할 수가 없음
# - 따라서 전체 데이터 세트를 그대로 fit()에 적용할 수 없는데, 이를 위해 DatasetAutoFolds 클래스를 이용하면 됨

# %% [markdown]
# ### DatasetAutoFolds.build_full_trainset()
# - 전체 데이터세트를 학습 데이터로 사용

# %% [markdown]
# #### 전체 데이터세트를 학습데이터로 지정

# %%
from surprise.dataset import DatasetAutoFolds

# 데이터 파싱
reader = Reader(line_format = 'user item rating timestamp',
                sep = ',',
                rating_scale = (0.5, 5))

# 폴드가 알아서 나눠진 형태로 데이터 불러오기
data_folds = DatasetAutoFolds(ratings_file = './dataset_ml_latest_small/ratings_noh.csv', reader = reader)


# 전체 데이터를 학습데이터로 생성하기
trainset = data_folds.build_full_trainset()

# %% [markdown]
# #### 학습

# %%
# SVD 객체화
algo = SVD(n_epochs = 20, n_factors = 50, random_state = 0)

# 학습
algo.fit(trainset)

# %% [markdown]
# #### 특정 사용자의 평점 예측

# %%
# 데이터 불러오기

ratings = pd.read_csv('./dataset_ml_latest_small/ratings.csv')
movies = pd.read_csv('./dataset_ml_latest_small/movies.csv')

display(ratings.head())
display(movies.head())
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
# userId = 9 인 사용자의 movieId 데이터를 추출
movieIds = ratings.loc[ratings['userId'] == 9, 'movieId']

# movieId가 42인 데이터 있는지 확인
if movieIds[movieIds == 42].count() == 0:
    print('movieId가 42인 평점 정보 없음')
    
    
    
# movieid가 42인 영화 정보 불러오기
print(movies[movies['movieId'] == 42])
# Out:
# movieId가 42인 평점 정보 없음
#     movieId                   title              genres
# 38       42  Dead Presidents (1995)  Action|Crime|Drama

# %%
# 예측 점수 확인

uid = '9'
iid = '42'

pred = algo.predict(uid, iid, verbose = True)
pred.est
# Out:
# user: 9          item: 42         r_ui = None   est = 3.13   {'was_impossible': False}
# 3.130146490888994

# %% [markdown]
# #### 사용자가 평점을 매기지 않은 전체 영화 추출하고 예측 평점 순으로 영화 추천하기

# %%
# 사용자가 평점을 매기지 않은 전체 영화 추출

def get_unseen_surprise(rating_df, movie_df, userid):
    # 해당 사용자가 평점을 남긴 movieid 추출하여 리스트 객체화
    seen_movies = rating_df[rating_df['userId'] == userid]['movieId'].tolist()
    
    # 전체 movieid 추출하여 리스트 객체화
    movies_list = movie_df['movieId'].tolist()
    
    # 해당 사용자가 평점을 남기지 않은 movieid 리스트 생성
    unseen_movies = [movie for movie in movies_list if movie not in seen_movies]
    
    print('평점을 매긴 영화 수: ', len(seen_movies))
    print('추천 대상 영화 수: ', len(unseen_movies))
    print('전체 영화 수: ', len(movies_list))
    
    return unseen_movies

unseen_movies = get_unseen_surprise(ratings, movies, 9)
# Out:
# 평점을 매긴 영화 수:  46
# 추천 대상 영화 수:  9696
# 전체 영화 수:  9742

# %% [markdown]
# - userid가 9인 사용자는 46개의 영화에 대해 평점을 남겼고 9696개의 영화에 대해 추천할 수 있음

# %%
# 예측 평점을 기반으로 top10개에 대해 영화를 추천하는 함수 생성

def recommend_movie_by_surprise(algo, userId, unseen_movies, top_n = 10):
    
    # 알고리즘 객체를 기반으로 평점을 내리지 않은 영화에 대한 예측 평점 리스트 객체화
    predictions = [algo.predict(str(userId), str(movieId)) for movieId in unseen_movies]
    
    # 예측 평점을 기준으로 정렬하기
    ## sortedkey_est 함수는 list 객체의 sort() 함수의 키값으로 사용되어 정렬 수행
    def sortedkey_est(pred):
        return pred.est
    
    ## sortkey() 반환값의 내림차순으로 수행하고 top_n개 최상위 값 추출
    predictions.sort(key = sortedkey_est, reverse = True)
    top_predictions = predictions[:top_n]
    
    # top_n으로 추출된 영화의 정보 추출 -> 영화 아이디, 추천 예상 평점, 제목 추출
    top_movie_ids = [ int(pred.iid) for pred in top_predictions ]
    top_movie_rating = [ int(pred.est) for pred in top_predictions ]
    top_movie_title = movies[ movies['movieId'].isin(top_movie_ids)]['title']
    
    top_movie_preds = [(ids, titles, ratings) for ids, titles, ratings in zip(top_movie_ids, top_movie_title, top_movie_rating)]
    
    return top_movie_preds

unseen_movies = get_unseen_surprise(ratings, movies, 9)
top_movie_preds = recommend_movie_by_surprise(algo, 9, unseen_movies, top_n = 10)

top_movie_preds
# Out:
# 평점을 매긴 영화 수:  46
# 추천 대상 영화 수:  9696
# 전체 영화 수:  9742
# [(858, 'Usual Suspects, The (1995)', 4),
#  (260, 'Star Wars: Episode IV - A New Hope (1977)', 4),
#  (296, 'Pulp Fiction (1994)', 4),
#  (1196, 'Silence of the Lambs, The (1991)', 4),
#  (50, 'Godfather, The (1972)', 4),
#  (1104, 'Streetcar Named Desire, A (1951)', 4),
#  (1210, 'Star Wars: Episode V - The Empire Strikes Back (1980)', 4),
#  (1213, 'Star Wars: Episode VI - Return of the Jedi (1983)', 4),
#  (1242, 'Goodfellas (1990)', 4),
#  (593, 'Glory (1989)', 4)]
