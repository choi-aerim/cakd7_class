# %% [markdown]
# ## 유동인구 데이터불러오기

# %%
import pandas as pd

df = pd.read_csv('cleanmovedf201911.csv', index_col = 0)
df
# Out:
#      시군구명       법정동코드 법정동명  성별     연령대         생활인구수
# 0     강남구  1168010100  역삼동  남성    10대    4650.729117
# 1     강남구  1168010100  역삼동  남성  10대 미만   2415.797217
# 2     강남구  1168010100  역삼동  남성    20대   16127.192763
# 3     강남구  1168010100  역삼동  남성    30대   22808.826961
# 4     강남구  1168010100  역삼동  남성    40대   18946.025865
# ...   ...         ...  ...  ..     ...           ...
# 7451  중랑구  1126010600  신내동  여성    30대    3872.047454
# 7452  중랑구  1126010600  신내동  여성    40대    4077.911732
# 7453  중랑구  1126010600  신내동  여성    50대    4651.755122
# 7454  중랑구  1126010600  신내동  여성    60대    3564.598492
# 7455  중랑구  1126010600  신내동  여성  70대 이상   4291.388937
#
# [7456 rows x 6 columns]

# %% [markdown]
# ## 전체 데이터프레임 merge

# %% [markdown]
# ### merge

# %%
yearmonth = ['201911','202005','202009','202101','202106','202110','202201','202204']

#빈데이터프레임
df_empty = pd.DataFrame(columns = ['시군구명','법정동코드','법정동명','성별','연령대','생활인구수'])

for i in yearmonth:
    df = pd.read_csv(f'cleanmovedf{i}.csv', index_col = 0)
    df['기준년월'] = i
    
    df_empty = pd.concat([df_empty,df])

df_empty
# Out:
#      시군구명       법정동코드 법정동명  성별     연령대         생활인구수    기준년월
# 0     강남구  1168010100  역삼동  남성    10대    4650.729117  201911
# 1     강남구  1168010100  역삼동  남성  10대 미만   2415.797217  201911
# 2     강남구  1168010100  역삼동  남성    20대   16127.192763  201911
# 3     강남구  1168010100  역삼동  남성    30대   22808.826961  201911
# 4     강남구  1168010100  역삼동  남성    40대   18946.025865  201911
# ...   ...         ...  ...  ..     ...           ...     ...
# 7451  중랑구  1126010600  신내동  여성    30대    3864.174639  202204
# 7452  중랑구  1126010600  신내동  여성    40대    4001.136413  202204
# 7453  중랑구  1126010600  신내동  여성    50대    4464.598578  202204
# 7454  중랑구  1126010600  신내동  여성    60대    3594.009983  202204
# 7455  중랑구  1126010600  신내동  여성  70대 이상    4048.79911  202204
#
# [59648 rows x 7 columns]

# %% [markdown]
# ### 분석용으로 전처리

# %% [markdown]
# #### 불필요한 컬럼 삭제
# - groupby 후 연령, 성별 구분 없이 sum
# - 성별, 연령대 컬럼 삭제

# %%
df2 = df_empty.groupby(['기준년월','시군구명','법정동코드','법정동명']).sum().drop(columns = ['성별','연령대'])
df2 = df2.reset_index()
df2
# Out:
#         기준년월 시군구명       법정동코드 법정동명          생활인구수
# 0     201911  강남구  1168010100  역삼동  168983.078177
# 1     201911  강남구  1168010300  개포동   13477.602964
# 2     201911  강남구  1168010400  청담동   45093.138950
# 3     201911  강남구  1168010500  삼성동   90601.448222
# 4     201911  강남구  1168010600  대치동   61287.683811
# ...      ...  ...         ...  ...            ...
# 3723  202204  중랑구  1126010200  상봉동   43662.171909
# 3724  202204  중랑구  1126010300  중화동   41300.558401
# 3725  202204  중랑구  1126010400   묵동   44259.056407
# 3726  202204  중랑구  1126010500  망우동   51494.289108
# 3727  202204  중랑구  1126010600  신내동   51584.415309
#
# [3728 rows x 5 columns]

# %% [markdown]
# #### 기준년월 행열 바꾸기

# %%
df2_pivot = df2.pivot_table(index = ['시군구명','법정동코드','법정동명'], columns = '기준년월', values = '생활인구수')
df2_pivot
# Out:
# 기준년월                         201911         202005         202009  \
# 시군구명 법정동코드      법정동명
# 강남구  1168010100 역삼동   168983.078177  153090.836901  148232.962809
#      1168010300 개포동    13477.602964   13282.464707   13427.803355
#      1168010400 청담동    45093.138950   44666.151048   42767.441839
#      1168010500 삼성동    90601.448222   79464.365715   74321.312638
#      1168010600 대치동    61287.683811   61569.643979   58645.053493
# ...                             ...            ...            ...
# 중랑구  1126010200 상봉동    45204.649189   43914.052619   42087.477192
#      1126010300 중화동    43404.404027   45536.811582   45380.648874
#      1126010400 묵동     46526.519813   45236.413476   45802.374360
#      1126010500 망우동    46348.577272   46131.309424   48900.017561
#      1126010600 신내동    53260.331268   54385.077542   54955.492634
#
# 기준년월                         202101         202106         202110  \
# 시군구명 법정동코드      법정동명
# 강남구  1168010100 역삼동   144812.434567  156177.741820  146784.922032
#      1168010300 개포동    15132.961481   13237.700093   13789.858361
#      1168010400 청담동    41335.111516   45123.991912   43835.352065
#      1168010500 삼성동    73026.306563   79311.038644   72838.762255
#      1168010600 대치동    58583.001345   61254.323063   59427.754050
# ...                             ...            ...            ...
# 중랑구  1126010200 상봉동    43174.407759   42809.233718   44195.273994
#      1126010300 중화동    45293.467661   42778.518840   42466.675440
#      1126010400 묵동     46517.749801   44557.914414   44174.529129
#      1126010500 망우동    50084.358843   48614.054839   48275.386818
#      1126010600 신내동    55087.008675   52015.588189   52821.057097
#
# 기준년월                         202201         202204
# 시군구명 법정동코드      법정동명
# 강남구  1168010100 역삼동   151353.484980  155104.812856
#      1168010300 개포동    14007.923462   14527.942227
#      1168010400 청담동    41982.057747   43190.724611
#      1168010500 삼성동    76292.096498   78672.461573
#      1168010600 대치동    62288.905271   60269.798543
# ...                             ...            ...
# 중랑구  1126010200 상봉동    44434.057699   43662.171909
#      1126010300 중화동    42559.850915   41300.558401
#      1126010400 묵동     44922.267187   44259.056407
#      1126010500 망우동    49277.905425   51494.289108
#      1126010600 신내동    53780.980948   51584.415309
#
# [466 rows x 8 columns]

# %% [markdown]
# #### 증감율 계산

# %%
df2_rate = df2_pivot.pct_change(axis = 'columns')
df2_rate = df2_rate.drop(columns = '201911')
df2_rate
# Out:
# 기준년월                    202005    202009    202101    202106    202110  \
# 시군구명 법정동코드      법정동명
# 강남구  1168010100 역삼동  -0.094046 -0.031732 -0.023075  0.078483 -0.060142
#      1168010300 개포동  -0.014479  0.010942  0.126987 -0.125241  0.041711
#      1168010400 청담동  -0.009469 -0.042509 -0.033491  0.091663 -0.028558
#      1168010500 삼성동  -0.122924 -0.064722 -0.017424  0.086061 -0.081606
#      1168010600 대치동   0.004601 -0.047501 -0.001058  0.045599 -0.029819
# ...                        ...       ...       ...       ...       ...
# 중랑구  1126010200 상봉동  -0.028550 -0.041594  0.025826 -0.008458  0.032377
#      1126010300 중화동   0.049129 -0.003429 -0.001921 -0.055526 -0.007290
#      1126010400 묵동   -0.027728  0.012511  0.015619 -0.042131 -0.008604
#      1126010500 망우동  -0.004688  0.060018  0.024220 -0.029357 -0.006966
#      1126010600 신내동   0.021118  0.010488  0.002393 -0.055756  0.015485
#
# 기준년월                    202201    202204
# 시군구명 법정동코드      법정동명
# 강남구  1168010100 역삼동   0.031124  0.024785
#      1168010300 개포동   0.015813  0.037123
#      1168010400 청담동  -0.042279  0.028790
#      1168010500 삼성동   0.047411  0.031201
#      1168010600 대치동   0.048145 -0.032415
# ...                        ...       ...
# 중랑구  1126010200 상봉동   0.005403 -0.017371
#      1126010300 중화동   0.002194 -0.029589
#      1126010400 묵동    0.016927 -0.014764
#      1126010500 망우동   0.020767  0.044977
#      1126010600 신내동   0.018173 -0.040843
#
# [466 rows x 7 columns]

# %% [markdown]
# #### plot화를 위한 기준년월 행열바꾸기

# %%
df2_rate_melt = pd.melt(df2_rate.reset_index(), id_vars = ['시군구명','법정동코드','법정동명'], value_name = '생활인구 증감율')
df2_rate_melt = df2_rate_melt.groupby(['시군구명','법정동코드','법정동명','기준년월','생활인구 증감율']).sum().reset_index()
df2_rate_melt
# Out:
#      시군구명       법정동코드 법정동명    기준년월  생활인구 증감율
# 0     강남구  1168010100  역삼동  202005 -0.094046
# 1     강남구  1168010100  역삼동  202009 -0.031732
# 2     강남구  1168010100  역삼동  202101 -0.023075
# 3     강남구  1168010100  역삼동  202106  0.078483
# 4     강남구  1168010100  역삼동  202110 -0.060142
# ...   ...         ...  ...     ...       ...
# 3257  중랑구  1126010600  신내동  202101  0.002393
# 3258  중랑구  1126010600  신내동  202106 -0.055756
# 3259  중랑구  1126010600  신내동  202110  0.015485
# 3260  중랑구  1126010600  신내동  202201  0.018173
# 3261  중랑구  1126010600  신내동  202204 -0.040843
#
# [3262 rows x 5 columns]

# %% [markdown]
# #### 구별 디렉토리 생성

# %%
# %pwd
# Out:
# 'C:\\cakd7\\cakd7_class\\데이터 안심구역'

# %%
import os

def createfolder(direc):
    if not os.path.exists(direc):
        os.makedirs(direc)

gu = df2_rate_melt.시군구명.unique()

for i in gu:        
    createfolder(f'유동인구_시각화/{i}')

# %% [markdown]
# #### 시각화-> 저장

# %%
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
import warnings
warnings.filterwarnings('ignore')

# import matplotlib as mpl
# import matplotlib.font_manager as fm
from matplotlib import rc

# mpl.matplotlib_fname()
# font_list = fm.findSystemFonts(fontpaths = None, fontext = 'ttf')
rc('font', family='Malgun Gothic')
plt.rcParams['axes.unicode_minus']=False     # 마이너스 부호 깨짐 방지


for gu in df2_rate_melt.시군구명.unique():
    for dong in df2_rate_melt[df2_rate_melt['시군구명'] == gu].법정동명.unique():
        df3 = df2_rate_melt[(df2_rate_melt['시군구명'] == gu) & (df2_rate_melt['법정동명'] == dong)]       
        df3_plot = df3.drop(columns = ['시군구명','법정동코드','법정동명']).set_index('기준년월')
        
        # 시각화
        fig = plt.figure(figsize = (12,5))
        ax = fig.add_subplot(1,1,1)
        ax.plot(df3_plot, marker = 'o', color = 'purple')
        ax.set_ylim(-0.4,0.8)
        ax.set_title(f'{gu} {dong}')
        
        plt.savefig(f'유동인구_시각화/{gu}/{gu}_{dong}.png')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [9], in <cell line: 16>()
#      16 for gu in df2_rate_melt.시군구명.unique():
#      17     for dong in df2_rate_melt[df2_rate_melt['시군구명'] == gu].법정동명.unique():
# ---> 18         df3 = df2_rate_melt[(df2_rate_melt['시군구명'] == gu) & (df2_rate_melt['법정동명'] == dong)]
#      19         df3_plot = df3.drop(columns = ['시군구명','법정동코드','법정동명']).set_index('기준년월')
#      21         # 시각화
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\pandas\core\frame.py:3496, in DataFrame.__getitem__(self, key)
#    3494 # Do we have a (boolean) 1d indexer?
#    3495 if com.is_bool_indexer(key):
# -> 3496     return self._getitem_bool_array(key)
#    3498 # We are left with two options: a single key, and a collection of keys,
#    3499 # We interpret tuples as collections only for non-MultiIndex
#    3500 is_single_key = isinstance(key, tuple) or not is_list_like(key)
#
# File ~\anaconda3\envs\cakd7\lib\site-packages\pandas\core\frame.py:3550, in DataFrame._getitem_bool_array(self, key)
#    3547 # check_bool_indexer will throw exception if Series key cannot
#    3548 # be reindexed to match DataFrame rows
#    3549 key = check_bool_indexer(self.index, key)
# -> 3550 indexer = key.nonzero()[0]
#    3551 return self._take_with_is_copy(indexer, axis=0)
#
# KeyboardInterrupt:
# Error in callback <function flush_figures at 0x0000026993928040> (for post_execute):
# KeyboardInterrupt

# %%
df3_plot

# %% [markdown]
# ### 주성분 분석

# %% [markdown]
# #### 사용데이터: 증감율

# %%
df2_rate
# Out:
# 기준년월                    202005    202009    202101    202106    202110  \
# 시군구명 법정동코드      법정동명
# 강남구  1168010100 역삼동  -0.094046 -0.031732 -0.023075  0.078483 -0.060142
#      1168010300 개포동  -0.014479  0.010942  0.126987 -0.125241  0.041711
#      1168010400 청담동  -0.009469 -0.042509 -0.033491  0.091663 -0.028558
#      1168010500 삼성동  -0.122924 -0.064722 -0.017424  0.086061 -0.081606
#      1168010600 대치동   0.004601 -0.047501 -0.001058  0.045599 -0.029819
# ...                        ...       ...       ...       ...       ...
# 중랑구  1126010200 상봉동  -0.028550 -0.041594  0.025826 -0.008458  0.032377
#      1126010300 중화동   0.049129 -0.003429 -0.001921 -0.055526 -0.007290
#      1126010400 묵동   -0.027728  0.012511  0.015619 -0.042131 -0.008604
#      1126010500 망우동  -0.004688  0.060018  0.024220 -0.029357 -0.006966
#      1126010600 신내동   0.021118  0.010488  0.002393 -0.055756  0.015485
#
# 기준년월                    202201    202204
# 시군구명 법정동코드      법정동명
# 강남구  1168010100 역삼동   0.031124  0.024785
#      1168010300 개포동   0.015813  0.037123
#      1168010400 청담동  -0.042279  0.028790
#      1168010500 삼성동   0.047411  0.031201
#      1168010600 대치동   0.048145 -0.032415
# ...                        ...       ...
# 중랑구  1126010200 상봉동   0.005403 -0.017371
#      1126010300 중화동   0.002194 -0.029589
#      1126010400 묵동    0.016927 -0.014764
#      1126010500 망우동   0.020767  0.044977
#      1126010600 신내동   0.018173 -0.040843
#
# [466 rows x 7 columns]

# %% [markdown]
# #### 주성분분석: 6차원 -> 2차원 축소

# %%
from sklearn.decomposition import PCA
import seaborn as sns

# 2차원으로 축소
pca = PCA(n_components=2) # n_components = 주성분의 갯수를 결정
pca.fit(df2_rate) # 각도를 찾음

# 축소된 차원으로 데이터를 변환
data2 = pd.DataFrame(data = pca.transform(df2_rate), columns=['pca1', 'pca2'])
data2['법정동명'] = df2_rate.reset_index()['법정동명']
data2 = data2.set_index('법정동명')
display(data2)
pca.explained_variance_ratio_
# Out:
#           pca1      pca2
# 법정동명
# 역삼동  -0.006082 -0.055620
# 개포동   0.208256  0.064654
# 청담동   0.041672 -0.035419
# 삼성동  -0.038519 -0.075394
# 대치동   0.108555 -0.074736
# ...        ...       ...
# 상봉동   0.124213  0.019717
# 중화동   0.202149 -0.014878
# 묵동    0.142154  0.003701
# 망우동   0.138122  0.006353
# 신내동   0.193906  0.005705
#
# [466 rows x 2 columns]
# array([0.69690787, 0.11926931])

# %%
printcipalComponents = pca.fit_transform(df2_rate)

principalDf = pd.DataFrame(data=printcipalComponents, columns = ['principal component1', 'principal component2'])

pca.explained_variance_ratio_

# %% [markdown]
# ### 군집화

# %% [markdown]
# #### 최적의 군집화 개수 찾기

# %%
# 최적의 군집화 갯수 찾기
from sklearn.cluster import KMeans
inertias = []
for k in range(1,10):
    model = KMeans(n_clusters=k) 
    model.fit(data2)
    inertias.append(model.inertia_)
    
# Plot ks vs inertias
plt.figure(figsize = (10,6))
plt.plot(range(1,10), inertias, '-o', color = 'brown')
plt.xlabel('number of clusters, k')
plt.ylabel('inertia')
plt.xticks(range(1,10))
plt.savefig('유동인구_군집화_시각화/최적군집개수.png')
plt.show()

# %% [markdown]
# #### 시각화2: 라벨o

# %%
import numpy as np
import warnings  
from collections import Counter
from matplotlib import rc
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler

rc('font', family='Malgun Gothic')
plt.rcParams['axes.unicode_minus']=False     # 마이너스 부호 깨짐 방지


# 클러스터링 생성
estimator = KMeans(n_clusters = 4)
cluster_ids = estimator.fit_predict(data2)


# 플롯
plt.figure(figsize=(18,18))
plt.scatter(data2['pca1'], data2['pca2'], c=cluster_ids)
plt.xlabel("pca1")
plt.ylabel("pca2")


# 범례 달기
for dong_p, p1, p2 in data2.itertuples():
    plt.annotate(dong_p, (p1, p2))
# plt.savefig('유동인구_군집화.png')    
plt.show()

# %% [markdown]
# #### 시각화2: 라벨x

# %%
import numpy as np
import warnings  
from collections import Counter
from matplotlib import rc
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import MinMaxScaler

rc('font', family='Malgun Gothic')
plt.rcParams['axes.unicode_minus']=False     # 마이너스 부호 깨짐 방지


# 클러스터링 생성
estimator = KMeans(n_clusters = 4)
cluster_ids = estimator.fit_predict(data2)


# 플롯
plt.figure(figsize=(18,18))
plt.scatter(data2['pca1'], data2['pca2'], c=cluster_ids)
plt.xlabel("pca1")
plt.ylabel("pca2")



# 범례 달기
# plt.savefig('유동인구_군집화_글씨없음.png')    
plt.show()

# %%
data2['군집'] = cluster_ids
data2.loc[['남가좌동']]   

# 검정색: 0번
# 파란색: 1번
# 연두색: 2번
# 청록색: 3번
# 노란색: 4번

# %%
data2[data2['군집']==2]

# %%
df2_rate_clu = df2_rate.copy()
df2_rate_clu['군집명'] = cluster_ids
df2_rate_clu
