# %% [markdown]
# ### 판다스 내장 그래프 도구
# - 시각화를 위한 도구라기보다 탐색적 도구
# - 판다스는 Matplotlib 라이브러리의 기능을 일부 내장하고 있어서 별도로  import하지 않고 간단히 그래프 그릴 수 있음.
#
#     - 선그래프 : df.plot()메소드 적용시 다른 옵션을 추가하지 않으면 가장 기본적인 선 그래프를 그림.
# - 변수 1개
#     - 막대 그래프 : df.plot(kind='bar'), df.plot(kind='barh',stacked=True,alpha=0.8)
#     - 히스토그램 : df.plot(kind='hist', bins=n)
#     - 박스 플롯 : df.plot(kind='box'), df.boxplot(column=['feature']) 특정 변수의 데이터 분포와 분산 정도에 대한 정보를 제공
# - 변수 2개
#
#     - 산점도 : df.plot(x=' ', y=' ', kind='scatter'), 상관관계를 볼 수 있음.
#
# ### matplotlib
# - histogram : plt.hist(x, bins= )
# - line plot : plt.plot(x,y)
# - plt.bar(x,y, width= , color='')
# - scatter plot : plt.scatter(x, y):
#
# ### seaborn
# - sns.distplot(data, bins=, color=, kde=), histplot, displot으로 변경
# - sns.boxplot(x, y, data, color)
# - sns.violinplot(x, y, data, color)
# - sns.barplot(x, y, data, color)
# - sns.jointplot(x, y, data, color)
# - sns.pairplot(data, hue, palette)
# - sns.lmplot(x,y,data,color)
# - sns.regplot(x,y,data,fig_reg=False)

# %% [markdown]
# ### 파이썬 내장 그래프 도구

# %%
import pandas as pd
import numpy as np

# %%
import os
os.chdir('C:/cakd7/m2_분석라이브러리활용/visualization')

# %%
# 데이터셋 불러오기
df=pd.read_csv('dataset/주가데이터.csv')
df
# Out:
#           Date  Close  Start   High    Low  Volume
# 0   2018-07-02  10100  10850  10900  10000  137977
# 1   2018-06-29  10700  10550  10900   9990  170253
# 2   2018-06-28  10400  10900  10950  10150  155769
# 3   2018-06-27  10900  10800  11050  10500  133548
# 4   2018-06-26  10800  10900  11000  10700   63039
# 5   2018-06-25  11150  11400  11450  11000   55519
# 6   2018-06-22  11300  11250  11450  10750  134805
# 7   2018-06-21  11200  11350  11750  11200  133002
# 8   2018-06-20  11550  11200  11600  10900  308596
# 9   2018-06-19  11300  11850  11950  11300  180656
# 10  2018-06-18  12000  13400  13400  12000  309787
# 11  2018-06-15  13400  13600  13600  12900  201376
# 12  2018-06-14  13450  13200  13700  13150  347451
# 13  2018-06-12  13200  12200  13300  12050  558148
# 14  2018-06-11  11950  12000  12250  11950   62293
# 15  2018-06-08  11950  11950  12200  11800   59258
# 16  2018-06-07  11950  12200  12300  11900   49088
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    20 non-null     object
#  1   Close   20 non-null     int64
#  2   Start   20 non-null     int64
#  3   High    20 non-null     int64
#  4   Low     20 non-null     int64
#  5   Volume  20 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 1.1+ KB

# %%
#Date변수 datetime으로 변환

df['N_Date']=pd.to_datetime(df['Date'])
df.head()
# Out:
#          Date  Close  Start   High    Low  Volume     N_Date
# 0  2018-07-02  10100  10850  10900  10000  137977 2018-07-02
# 1  2018-06-29  10700  10550  10900   9990  170253 2018-06-29
# 2  2018-06-28  10400  10900  10950  10150  155769 2018-06-28
# 3  2018-06-27  10900  10800  11050  10500  133548 2018-06-27
# 4  2018-06-26  10800  10900  11000  10700   63039 2018-06-26

# %%
#새로운 데이터프레임 생성 후 N_Date변수를 인덱스로 변환

df1=df.copy()

df1.set_index('N_Date',inplace=True)
df1.head()
# Out:
#                   Date  Close  Start   High    Low  Volume
# N_Date
# 2018-07-02  2018-07-02  10100  10850  10900  10000  137977
# 2018-06-29  2018-06-29  10700  10550  10900   9990  170253
# 2018-06-28  2018-06-28  10400  10900  10950  10150  155769
# 2018-06-27  2018-06-27  10900  10800  11050  10500  133548
# 2018-06-26  2018-06-26  10800  10900  11000  10700   63039

# %%
#Date 변수 삭제

df1.drop(['Date','Volume'], axis=1, inplace=True)
df1.head()
# Out:
#             Close  Start   High    Low
# N_Date
# 2018-07-02  10100  10850  10900  10000
# 2018-06-29  10700  10550  10900   9990
# 2018-06-28  10400  10900  10950  10150
# 2018-06-27  10900  10800  11050  10500
# 2018-06-26  10800  10900  11000  10700

# %% [markdown]
# #### 선그래프

# %%
df1.plot()
# Out:
# <AxesSubplot:xlabel='N_Date'>

# %%
#지정 컬럼에 대한 선그래프

#방법1
df1.plot( y='Close')     #인덱스, y에 지정된 선그래프 그려짐
# Out:
# <AxesSubplot:xlabel='N_Date'>

# %%
#방법2
df1.Close.plot()
# Out:
# <AxesSubplot:xlabel='N_Date'>

# %% [markdown]
# #### 막대그래프

# %%
#날짜 오름차순대로 종가 그래프 그리기

#방법1
df1.Close[::-1].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='N_Date'>

# %%
#방법2

df1.sort_index().Close.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='N_Date'>

# %% [markdown]
# #### 실습

# %%
#6월만 추출하여 close 컬럼으로 일별 막대 그래프 그리기

#방법1
df1.loc['2018-06'].Close[::-1].plot(kind='bar')      #loc를 추가하지 않으면 waring 뜸
# Out:
# <AxesSubplot:xlabel='N_Date'>

# %%
#방법2
df1.loc['2018-06','Close'][::-1].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='N_Date'>

# %%
df1.sort_index().Close['2018-06'].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='N_Date'>

# %%
#참고
sns.barplot(x='Close',y=df1.index[::-1],data=df1[::-1],orient='h')
# Out:
# <AxesSubplot:xlabel='Close', ylabel='N_Date'>

# %% [markdown]
# #### 히스토그램

# %%
df1.Close.plot(kind='hist', bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ---

# %% [markdown]
# ### 과제3(7/6)
# - df에서 Volume 컬럼의 분포를 탐색하는 히스토그램을 표현하세요.

# %%
import pandas as pd

df=pd.read_csv('dataset/주가데이터.csv')
df.head()
# Out:
#          Date  Close  Start   High    Low  Volume
# 0  2018-07-02  10100  10850  10900  10000  137977
# 1  2018-06-29  10700  10550  10900   9990  170253
# 2  2018-06-28  10400  10900  10950  10150  155769
# 3  2018-06-27  10900  10800  11050  10500  133548
# 4  2018-06-26  10800  10900  11000  10700   63039

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    20 non-null     object
#  1   Close   20 non-null     int64
#  2   Start   20 non-null     int64
#  3   High    20 non-null     int64
#  4   Low     20 non-null     int64
#  5   Volume  20 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 1.1+ KB

# %%
df['N_Date']=pd.to_datetime(df.Date)
df.head()
# Out:
#          Date  Close  Start   High    Low  Volume     N_Date
# 0  2018-07-02  10100  10850  10900  10000  137977 2018-07-02
# 1  2018-06-29  10700  10550  10900   9990  170253 2018-06-29
# 2  2018-06-28  10400  10900  10950  10150  155769 2018-06-28
# 3  2018-06-27  10900  10800  11050  10500  133548 2018-06-27
# 4  2018-06-26  10800  10900  11000  10700   63039 2018-06-26

# %%
df.set_index('N_Date',inplace=True)
df.head()
# Out:
#                   Date  Close  Start   High    Low  Volume
# N_Date
# 2018-07-02  2018-07-02  10100  10850  10900  10000  137977
# 2018-06-29  2018-06-29  10700  10550  10900   9990  170253
# 2018-06-28  2018-06-28  10400  10900  10950  10150  155769
# 2018-06-27  2018-06-27  10900  10800  11050  10500  133548
# 2018-06-26  2018-06-26  10800  10900  11000  10700   63039

# %%
df.Volume.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ---

# %% [markdown]
# #### 산점도

# %%
df.plot(x='Close', y='Volume', kind='scatter')
# Out:
# <AxesSubplot:xlabel='Close', ylabel='Volume'>

# %% [markdown]
# #### 박스플랏

# %%
df.Close.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df.boxplot('Close')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### 상관관계

# %%
df1.corr()
# Out:
#           Close     Start      High       Low
# Close  1.000000  0.856181  0.941201  0.946297
# Start  0.856181  1.000000  0.961009  0.921467
# High   0.941201  0.961009  1.000000  0.945487
# Low    0.946297  0.921467  0.945487  1.000000

# %%
df1.corr()[['Close']]
# Out:
#           Close
# Close  1.000000
# Start  0.856181
# High   0.941201
# Low    0.946297

# %% [markdown]
# ##### box plot 의미 해석
# - IQR(Inter Quatile Range): 제3분위수-제1분위수
# - lower whisker: Q1-1.5*IQR 이내인 값 중 최솟값
# - upper whisker: Q3+1.5*IQR 이내인 값 중 최댓값
# - 이상치: lower whisker, upper whisker를 벗어나는 값

# %%
df.Close.describe()
# Out:
# count       20.000000
# mean     11662.500000
# std        927.060294
# min      10100.000000
# 25%      11087.500000
# 50%      11725.000000
# 75%      11962.500000
# max      13450.000000
# Name: Close, dtype: float64

# %%
#1,3 분위수 구하기

q1=df.Close.describe()['25%']
q3=df.Close.describe()['75%']

iqr=q3-q1

# %%
#lower,upper whisker 값 구하기

lower_wh=min(df.Close[df['Close']>q1-1.5*iqr])
upper_wh=max(df.Close[df['Close']<q3+1.5*iqr])

lower_wh, upper_wh
# Out:
# (10100, 13200)

# %%
#이상값 구하기

abv=df[(df['Close']<q1-1.5*iqr)|(df['Close']>q3+1.5*iqr)]
abv
# Out:
#           Date  Close  Start   High    Low  Volume     N_Date
# 11  2018-06-15  13400  13600  13600  12900  201376 2018-06-15
# 12  2018-06-14  13450  13200  13700  13150  347451 2018-06-14

# %% [markdown]
# ---

# %% [markdown]
# ### 과제1(7/7)
# Start 컬럼의 분포 및 이상치 여부를 탐색하는 Box Plot 및 이상값 구하기

# %%
df.Start.describe()
# Out:
# count       20.000000
# mean     11755.000000
# std        865.250192
# min      10550.000000
# 25%      11125.000000
# 50%      11800.000000
# 75%      12050.000000
# max      13600.000000
# Name: Start, dtype: float64

# %%
df.Start.plot(kind='box')

#동그라미 하나가 이상값으로 보여짐
# Out:
# <AxesSubplot:>

# %%
#이상값 구하기: q1-1.5*iqr, q3+1.5*iqr

#1,3사분위수 구하기
q1=df.Start.describe()['25%']
q3=df.Start.describe()['75%']

print(q1,q3)
# Out:
# 11125.0 12050.0

# %%
#사분위수 범위 구하기

iqr=q3-q1
print(iqr)
# Out:
# 925.0

# %%
#이상값 기준 구하기

min_iqr=q1-1.5*iqr
max_iqr=q3+1.5*iqr

print(min_iqr,max_iqr)
# Out:
# 9737.5 13437.5

# %%
#이상값 구하기

outlier=df.Start[(df.Start<min_iqr)|(df.Start>max_iqr)]
outlier
# Out:
# 11    13600
# Name: Start, dtype: int64

# %%
#확인하기 

df.Start.describe()
# Out:
# count       20.000000
# mean     11755.000000
# std        865.250192
# min      10550.000000
# 25%      11125.000000
# 50%      11800.000000
# 75%      12050.000000
# max      13600.000000
# Name: Start, dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ### 과제2(7/7)
# mpg 컬럼을 box_plot으로 시각화한 후, 이상치 확인 및 그 값 구하기

# %%
# %pwd
# Out:
# 'C:\\cakd7\\m2_분석라이브러리활용\\visualization'

# %%
import pandas as pd

df_auto=pd.read_csv('../pandas/dataset/auto-mpg.csv')
df_auto.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %% [markdown]
# ### Seaborn 시각화

# %%
#seborn style: darkgrid, whitegrid, white, dark, ticks

# %%
#sns.set_style('darkgrid')
#sns.set_style('whitegrid')

# %%
import seaborn as sns

# %%
# 생선 데이터 불러오기

import pandas as pd

fish_multi=pd.read_csv('dataset/4_fm2.csv')
fish_multi
# Out:
#    species  length
# 0        A       2
# 1        A       3
# 2        A       3
# 3        A       4
# 4        A       4
# 5        A       4
# 6        A       4
# 7        A       5
# 8        A       5
# 9        A       6
# 10       B       5
# 11       B       6
# 12       B       6
# 13       B       7
# 14       B       7
# 15       B       7
# 16       B       7
# 17       B       8
# 18       B       8
# 19       B       9

# %% [markdown]
# ### boxplot

# %%
#생선 종류별 길이 구하기

sns.boxplot(x='species',y='length',data=fish_multi, color='skyblue')
# Out:
# <AxesSubplot:xlabel='species', ylabel='length'>

# %%
fish_multi.groupby('species').describe().T
# Out:
# species               A          B
# length count  10.000000  10.000000
#        mean    4.000000   7.000000
#        std     1.154701   1.154701
#        min     2.000000   5.000000
#        25%     3.250000   6.250000
#        50%     4.000000   7.000000
#        75%     4.750000   7.750000
#        max     6.000000   9.000000

# %%
#데이터에 인위적으로 이상값을 추가하기
import warnings
warnings.filterwarnings('ignore')


fish=fish_multi.copy()
fish.length[5]=10
fish.length[10]=2
fish
# Out:
#    species  length
# 0        A       2
# 1        A       3
# 2        A       3
# 3        A       4
# 4        A       4
# 5        A      10
# 6        A       4
# 7        A       5
# 8        A       5
# 9        A       6
# 10       B       2
# 11       B       6
# 12       B       6
# 13       B       7
# 14       B       7
# 15       B       7
# 16       B       7
# 17       B       8
# 18       B       8
# 19       B       9

# %%
#boxplot 그리기: 이상값 확인하기

sns.boxplot('species','length',data=fish, color='pink')
# Out:
# <AxesSubplot:xlabel='species', ylabel='length'>

# %% [markdown]
# #### 히스토그램

# %%
#평균0, 표준편차1인 표준정규분포 난수 10000개 생성 후 데이터프레임화

from numpy.random import randn

df=pd.DataFrame(randn(10000),columns=['num'])   #컬럼 이름은 무조건 리스트!
df.head()
# Out:
#         num
# 0  0.353318
# 1  0.978603
# 2  0.080203
# 3  1.014487
# 4 -0.148060

# %%
#파이썬 내장 그래프

df.plot(kind='hist', bins=50)    #bins가 커질수록 정규분포에 가까워짐
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#seaborn 그래프

sns.histplot(df, bins=100)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# #### 막대그래프

# %%
import seaborn as sns

tips=pd.read_csv('dataset/tips.csv')
tips.head()
# Out:
#    total_bill   tip smoker  day    time  size
# 0       16.99  1.01     No  Sun  Dinner     2
# 1       10.34  1.66     No  Sun  Dinner     3
# 2       21.01  3.50     No  Sun  Dinner     3
# 3       23.68  3.31     No  Sun  Dinner     2
# 4       24.59  3.61     No  Sun  Dinner     4

# %%
#데이터 전처리

# %% [markdown]
# ##### crosstab, pivot의 차이

# %%
#요일, 테이블 사이즈의 교차테이블 작성
party_counts=pd.crosstab(index=tips['day'],
                         columns=tips['size'],)   
party_counts
                        #특정 value, aggfunc 지정 안해도 count해줌
# Out:
# size  1   2   3   4  5  6
# day
# Fri   1  16   1   1  0  0
# Sat   2  53  18  13  1  0
# Sun   0  39  15  18  3  1
# Thur  1  48   4   5  1  3

# %%
tips.pivot_table(index='day',
                 columns='size',
                 values='smoker',
                 aggfunc='count').round()
                         #특정 value, aggfucn 지정 안하면 전체 변수에 대해 나옴

  #크로스탭과 피벗테이블은 비슷하지만, aggfunc이 count인경우
  #결과적으로 크로스탭이 깔끔한 느낌
# Out:
# size    1     2     3     4    5    6
# day
# Fri   1.0  16.0   1.0   1.0  NaN  NaN
# Sat   2.0  53.0  18.0  13.0  1.0  NaN
# Sun   NaN  39.0  15.0  18.0  3.0  1.0
# Thur  1.0  48.0   4.0   5.0  1.0  3.0

# %%
party_counts=party_counts.loc[:,2:5]
party_counts
# Out:
# size   2   3   4  5
# day
# Fri   16   1   1  0
# Sat   53  18  13  1
# Sun   39  15  18  3
# Thur  48   4   5  1

# %%
#전체 합계가 1이 되도록 표준화 (normalize)

party_counts.sum(1)     #axis=1을 뜻하며, 열끼리 더해서 행의 값으로 출력하란 뜻
# Out:
# day
# Fri     18
# Sat     85
# Sun     75
# Thur    58
# dtype: int64

# %%
party_counts=party_counts.div(party_counts.sum(1),axis=0)
party_counts
# Out:
# size         2         3         4         5
# day
# Fri   0.888889  0.055556  0.055556  0.000000
# Sat   0.623529  0.211765  0.152941  0.011765
# Sun   0.520000  0.200000  0.240000  0.040000
# Thur  0.827586  0.068966  0.086207  0.017241

# %%
#markup개념 기준 팁의 퍼센트 변수 생성

tips['tip_pct']=tips['tip']/(tips['total_bill']-tips['tip'])
tips.head()
     #mark up: x/(y-x)
     #margin: x/y
# Out:
#    total_bill   tip smoker  day    time  size   tip_pct
# 0       16.99  1.01     No  Sun  Dinner     2  0.063204
# 1       10.34  1.66     No  Sun  Dinner     3  0.191244
# 2       21.01  3.50     No  Sun  Dinner     3  0.199886
# 3       23.68  3.31     No  Sun  Dinner     2  0.162494
# 4       24.59  3.61     No  Sun  Dinner     4  0.172069

# %%
#그래프 그리기

sns.barplot(x='day',y='tip_pct',data=tips)

     #검정 선: 데이터의 오차 폭, 신뢰구간임.
     #오차의 폭이 클수록 가변성이 높은 데이터라 볼 수 있음
# Out:
# <AxesSubplot:xlabel='day', ylabel='tip_pct'>

# %%
#barplot으로 수평막대그래프 그리기

sns.barplot(x='tip_pct',y='day',data=tips, orient='h')
           #막대그래프를 수평으로 그리기 위해 x,y를 바꿔 지정하고 
           #orient='h'를 사용하면
           #barhplot을 사용한것 처럼 됨
# Out:
# <AxesSubplot:xlabel='tip_pct', ylabel='day'>

# %% [markdown]
# #### countplot
# - 범주화 변수의 데이터 개수를 나타내는 막대그래프

# %%
sns.countplot(x='size', hue='time', data=tips, palette='bone') 

    #hue: 범례
    #palette: 디자인 틀
    #막대그래프와 다른 점은 x,y축을 같이 지정할 수 없다는 것!
# Out:
# <AxesSubplot:xlabel='size', ylabel='count'>

# %% [markdown]
# #### distplot
# -히스토그램 및 밀도를 나타내는 선그래프(전체 합=1)가 나타남

# %%
#데이터셋 불러오기
fish_multi=pd.read_csv('dataset/4_fm2.csv')
fish_multi.head()
# Out:
#   species  length
# 0       A       2
# 1       A       3
# 2       A       3
# 3       A       4
# 4       A       4

# %%
fish_multi.species.unique()
# Out:
# array(['A', 'B'], dtype=object)

# %%
#쿼리함수로 물고기 종류에 따라 길이변수만 추출

length_a=fish_multi.query('species=="A"')['length']
length_b=fish_multi.query('species=="B"')['length']

# %%
# 그래프 그리기

sns.distplot(x=length_a, bins=6, color='pink',kde=True)
    #kde(kernal density estimation): 밀도함수 여부
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.distplot(length_a, bins=5, color='skyblue')
sns.distplot(length_b, bins=5, color='gray')
# Out:
# <AxesSubplot:xlabel='length', ylabel='Density'>

# %% [markdown]
# #### violinplot
# - 곡선은 상자 대신 히스토그램을 세로로 세워서 배치한 상자그림
# - 곡선에 다라 어느 부분에 데이터가 집중되어 있는지 알 수 있음

# %% [markdown]
# ##### 바이올린플롯과 박스플롯

# %% [markdown]
# ![img.png](attachment:img.png)

# %%
sns.violinplot('species','length',data=fish_multi, color='yellow')
# Out:
# <AxesSubplot:xlabel='species', ylabel='length'>

# %% [markdown]
# #### jointplot
# - 산점도(x,y)와 히스토그램(x),(y)의 분포를 같이 나타냄
# - 밀도함수, 회귀선이 포함된 산점도 등도 그릴 수 있음

# %%
cov_df=pd.read_csv('C:/cakd7/m2_분석라이브러리활용/visualization/dataset/4_cov.csv')
cov_df
# Out:
#       x   y
# 0  18.5  34
# 1  18.7  39
# 2  19.1  41
# 3  19.7  38
# 4  21.5  45
# 5  21.7  41
# 6  21.8  52
# 7  22.0  44
# 8  23.4  44
# 9  23.8  49

# %%
sns.jointplot('x','y',
              data=cov_df,
              joint_kws={'color':'purple'},   #내부
              marginal_kws={'color':'pink'},  #외곽 
              kind='reg'
             )

# %%
sns.jointplot('x','y',
              data=cov_df,
              joint_kws={'color':'purple'},   #내부
              marginal_kws={'color':'pink'},  #외곽 
              kind='scatter'
             )

# %%
sns.jointplot('x','y',
              data=cov_df,
              joint_kws={'color':'purple'},   #내부
              marginal_kws={'color':'pink'},  #외곽 
              kind='kde'
             )

# %% [markdown]
# #### heatmap

# %% [markdown]
# -타이타닉 데이터셋

# %%
tit_df= sns.load_dataset('titanic')
tit_df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
tit_df.replace({'male':0, 'female':1},inplace=True)

sns.heatmap(tit_df[['survived','pclass','sex','age','fare']].corr(),
           annot=True)

#survived와 age가 상관성이 낮게 나타난 이유는 age를 범주화 하지 않았기 때문
# Out:
# <AxesSubplot:>

# %%
#피벗테이블 제작

table=pd.pivot_table(data=tit_df,
                     index='sex',
                     columns='class',
                     values='survived',
                     aggfunc='mean'
)
table
# Out:
# class     First    Second     Third
# sex
# 0      0.368852  0.157407  0.135447
# 1      0.968085  0.921053  0.500000

# %%
sns.heatmap(table, 
            annot=True,    #셀의 데이터 값 나타내기
            fmt='f',       #나타낼 데이터타입 f: float
            cmap='YlGnBu', #색깔
            linewidth=0.75,#셀 사이의 구분 선 두께
            cbar=True)     #컬러바 여부
# Out:
# <AxesSubplot:xlabel='class', ylabel='sex'>

# %% [markdown]
# -autompg데이터셋

# %%
auto_df=pd.read_csv('C:/cakd7/m2_분석라이브러리활용/pandas/dataset/auto-mpg.csv')
auto_df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
sns.heatmap(auto_df.corr(),annot=True)
plt.title('Auto mpg\'s heatmap',size=15)

    #annot: 상관계수 나타내기 여부
# Out:
# Text(0.5, 1.0, "Auto mpg's heatmap")

# %% [markdown]
# #### lmplot
# - 산점도와 회귀선이 같이 그려지는 그래프

# %%
sns.lmplot(x='mpg',y='weight',data=auto_df,
           scatter_kws={'color':'skyblue'},
           line_kws={'color':'blue'}
          )

# %% [markdown]
# #### regplot
# - 산점도와 회귀선이 같이 그려지는 그래프

# %%
sns.regplot(x='weight',y='mpg',data=auto_df,
           scatter_kws={'color':'purple'},
           line_kws={'color':'red'})
# Out:
# <AxesSubplot:xlabel='weight', ylabel='mpg'>

# %% [markdown]
# #### pairplot

# %%
auto_df.corr().round(2)

# 살펴보면, 꽤 많은 변수들이 상관성이 높게 나타남이 보여짐
# mpg-cylinders, mpg-displacement, mpg-weight, cylinders-displacement...
# Out:
#                mpg  cylinders  displacement  weight  acceleration  model year  \
# mpg           1.00      -0.78         -0.80   -0.83          0.42        0.58
# cylinders    -0.78       1.00          0.95    0.90         -0.51       -0.35
# displacement -0.80       0.95          1.00    0.93         -0.54       -0.37
# weight       -0.83       0.90          0.93    1.00         -0.42       -0.31
# acceleration  0.42      -0.51         -0.54   -0.42          1.00        0.29
# model year    0.58      -0.35         -0.37   -0.31          0.29        1.00
# origin        0.56      -0.56         -0.61   -0.58          0.21        0.18
#
#               origin
# mpg             0.56
# cylinders      -0.56
# displacement   -0.61
# weight         -0.58
# acceleration    0.21
# model year      0.18
# origin          1.00

# %%
sns.pairplot(auto_df)

# %%
sns.pairplot(auto_df[['mpg','displacement','weight','cylinders']])

# %% [markdown]
# pairplot으로 확인해 보니, 실린더변수는 범주화 변수로 보이며, 상관성이 높게 나타나긴 했으나 회귀변수로서 가치가 없어보임

# %% [markdown]
# ---

# %% [markdown]
# ### Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
#matplotlib의 활용가능한 스타일

plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
#plt.style.use('ggplot')
#plt.style.use('default')

# %% [markdown]
# ### 선그래프

# %%
import matplotlib.pyplot as plt
from numpy.random import randn

# %%
#표준정규분포의 난수 생성 후 선그래프 그리기

plt.figure(figsize=(8,5))
plt.plot(randn(30),color='y',marker='o')

# %%
#표준정규분포의 난수 생성 후 누적된 값을 그래프로 그리기

plt.plot(randn(30).cumsum(),color='g',marker='^', linestyle='dashed')

# %%
np.random.seed(2)

data=randn(1000).cumsum()
plt.plot(data,linestyle='dotted',color='m')

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#한글 폰트 실행되도록 하기
from matplotlib import font_manager, rc

font_path='C:/cakd7/m2_분석라이브러리활용/visualization/dataset/malgun.ttf'
font_name=font_manager.FontProperties(fname=font_path).get_name()

rc('font',family=font_name)
plt.rcParams['axes.unicode_minus']=False   #마이너스 기호 깨짐 방지

# %%
#여러개 그래프 나타내기

fig=plt.figure(figsize=(10,8))   #그래프 사이즈
ax=fig.add_subplot(1,2,1)        
            #(행, 열, 위치)
            #한개의 행과, 두개의 열이 있는 공간에서 첫번째 자리를 차지함
ax.plot(data,color='m',linestyle='dotted')
ax.set_xticks([0,250,500,750,1000])       #x축 눈금 간격
ax.set_xticklabels(['zero','two','five','seven','ten'],
                  rotation=70,            #x축 눈금 각도
                  fontsize=10)             
ax.set_title('정규분포 난수 분포')         #그래프 제목
ax.set_xlabel('인덱스')                   #x축 이름
ax.set_ylabel('누적 난수')                #y축 이름


ax2=fig.add_subplot(1,2,2)
ax2.plot(data,marker='o',linestyle='dashed',color='y')

# %%
#한 개 그래프에 여러개 그래프 투영하기

fig=plt.figure(figsize=(10,6))
ax=fig.add_subplot(1,1,1)

ax.plot(randn(1000).cumsum(),color='g',linestyle='dashed',label='one')
ax.plot(randn(1000).cumsum(),color='b',linestyle='dotted',label='two')
ax.plot(randn(1000).cumsum(),color='y',label='three')
       #labeling을 하는 이유는 범례에 보여주기 위해서
    
plt.legend(loc='best')     #loc='best' 제일 좋은 위치에 범례나타내기

# %%
# 주석과 글자는 text, arrow, annotate 함수를 이용하여 추가
from datetime import datetime

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

data = pd.read_csv('C:/cakd7/m2_분석라이브러리활용/visualization/dataset/spx.csv',
                   index_col=0, parse_dates=True)
spx = data['SPX']

spx.plot(ax=ax, style='k-')

crisis_data = [
    (datetime(2007, 10, 11), 'Peak of bull market'),
    (datetime(2008, 3, 12), 'Bear Stearns Fails'),
    (datetime(2008, 9, 15), 'Lehman Bankruptcy')
]

for date, label in crisis_data:
    ax.annotate(label, xy=(date, spx.asof(date) + 75),
                xytext=(date, spx.asof(date) + 225),
                arrowprops=dict(facecolor='black', headwidth=4, width=2,
                                headlength=4),
                horizontalalignment='left', verticalalignment='top')

# Zoom in on 2007-2010
ax.set_xlim(['1/1/2007', '1/1/2011'])
ax.set_ylim([600, 1800])

ax.set_title('Important dates in the 2008-2009 financial crisis')
# Out:
# Text(0.5, 1.0, 'Important dates in the 2008-2009 financial crisis')

# %%
#add_subplot없이 plt활용

x=np.arange(1,21,2)
y=np.array([3,5,6,13,30,21,22,29,33,32])

plt.figure(figsize=(8,4))
plt.plot(x,y,color='m',marker='o',markersize=10)
plt.xlabel('인덱스',size=10)
plt.ylabel('컬럼',size=10)
plt.title('난수가지고 놀기',size=20)
plt.legend('lineplot',loc='best')

# %%
#add_subplot 없이 plt활용해서 여러개 그래프 투영하기


x=np.arange(10)
y=np.random.randint(2,10,size=10)
y2=np.random.randint(2,10,size=10)

plt.figure(figsize=(8,4))
plt.plot(x,y)
plt.plot(x,y2, color='y', marker='o', linestyle='dashed', markersize=10)

plt.title('Matplotlib',size=20)
plt.legend(labels=['A','B'],loc='best')

# %% [markdown]
# #### 막대그래프

# %% [markdown]
# - 수직 막대그래프: bar

# %%
x=np.arange(10)
y=np.random.randint(2,10,size=10)

plt.bar(x,y, width=0.7, color='red',bottom=True)   #width: 막대의 너비
                                                   #bottom: 누적막대로 그리기 
plt.title('bar plot',size=20)
# Out:
# Text(0.5, 1.0, 'bar plot')

# %% [markdown]
# - 수평 막대그래프: barh

# %%
plt.barh(x,y,color='pink')
# Out:
# <BarContainer object of 10 artists>

# %%
#두 개의 수평, 수직 막대그래프 그리기

fig, axes=plt.subplots(2,1)
data=pd.Series(np.random.rand(16),index=list('abcdefghijklmnop'))

data.plot.bar(ax=axes[0], color='red',alpha= 0.5)
data.plot.barh(ax=axes[1], color='skyblue', alpha=0.7)
# Out:
# <AxesSubplot:>

# %%
#각 행 값을 묶어서 그룹별 막대그래프로 표현

df=pd.DataFrame(np.random.rand(6,4),
               index=['one','two','three','four','five','six'],
               columns=['A','B','C','D'])


df.plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### 누적막대그래프

# %%
df.plot.barh(stacked=True, alpha=0.7)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### 산점도

# %%
auto_df=pd.read_csv('C:/cakd7/m2_분석라이브러리활용/pandas/dataset/auto-mpg.csv')
auto_df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
auto_df[['mpg','cylinders','weight','displacement']].corr()
# Out:
#                    mpg  cylinders    weight  displacement
# mpg           1.000000  -0.775396 -0.831741     -0.804203
# cylinders    -0.775396   1.000000  0.896017      0.950721
# weight       -0.831741   0.896017  1.000000      0.932824
# displacement -0.804203   0.950721  0.932824      1.000000

# %%
plt.scatter(auto_df.mpg, auto_df.weight, color='skyblue')

# %% [markdown]
# #### 히스토그램

# %%
plt.hist(np.random.randn(50),bins=20, color='purple')
# Out:
# (array([1., 1., 1., 5., 1., 3., 6., 2., 7., 6., 4., 3., 4., 0., 0., 1., 1.,
#         3., 0., 1.]),
#  array([-2.0669019 , -1.82878544, -1.59066897, -1.35255251, -1.11443605,
#         -0.87631958, -0.63820312, -0.40008666, -0.16197019,  0.07614627,
#          0.31426273,  0.5523792 ,  0.79049566,  1.02861212,  1.26672859,
#          1.50484505,  1.74296151,  1.98107797,  2.21919444,  2.4573109 ,
#          2.69542736]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# #### boxplot

# %%
plt.boxplot(auto_df[['mpg','cylinders']])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1b88923ecd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1b88a2245b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1b889248e20>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x1b88a224b50>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x1b88a224e20>,
# ...
#  'means': []}
